# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_and_Spectrogram_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada sadece range-doppler 2D image datası ve spectrogram datası LSTM ile train edildi.
# 2D image'ın column'ları lstm'e sokuldu ve çıktıları dense layer ile classification moduna getirildi.
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.947, mean test f1 score is 0.938, max test accuracy is 0.976, max test f1 score is 0.972, 
# Min test accuracy is 0.924, min test f1 score is 0.910, std of test accuracy is 0.019, std of test f1 score is 0.022
# Time elapsed through all process: 7237.15, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 32
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 16
dense_unit_of_lstm_function = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def lstm_encoder_network_2(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(512)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.5)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_lstm(range_doppler_input)

    input_shape = spectrogram_concat_shuffle_train.shape[1:3]
    base_network_lstm_2 = lstm_encoder_network_2(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_lstm_2(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image, spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler, validation_spectrogram) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5120, 52)]   0           []
#
#  input_4 (InputLayer)           [(None, 423, 52)]    0           []
#
#  model (Functional)             (None, 256)          42608512    ['input_2[0][0]']
#
#  model_1 (Functional)           (None, 256)          3529472     ['input_4[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['model[0][0]',
#                                                                   'model_1[0][0]']
#
#  model_2 (Functional)           (None, 1)            279105      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 46,417,089
# Trainable params: 46,061,313
# Non-trainable params: 355,776
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 19s 383ms/step - loss: 0.5688 - accuracy: 0.5082 - val_loss: 0.5946 - val_accuracy: 0.7037
# Epoch 2/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.4096 - accuracy: 0.5583 - val_loss: 0.5009 - val_accuracy: 0.7407
# Epoch 3/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3980 - accuracy: 0.5536 - val_loss: 0.2446 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3531 - accuracy: 0.5769 - val_loss: 0.2416 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3369 - accuracy: 0.5851 - val_loss: 0.2249 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3207 - accuracy: 0.5793 - val_loss: 0.2343 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3285 - accuracy: 0.5839 - val_loss: 0.1986 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3068 - accuracy: 0.5816 - val_loss: 0.1671 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3001 - accuracy: 0.5897 - val_loss: 0.1615 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3019 - accuracy: 0.5874 - val_loss: 0.1373 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3002 - accuracy: 0.5909 - val_loss: 0.1451 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2885 - accuracy: 0.5909 - val_loss: 0.0984 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2905 - accuracy: 0.5897 - val_loss: 0.1281 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2735 - accuracy: 0.5921 - val_loss: 0.1107 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2845 - accuracy: 0.5909 - val_loss: 0.1311 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2790 - accuracy: 0.5909 - val_loss: 0.1439 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2771 - accuracy: 0.5921 - val_loss: 0.1314 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2741 - accuracy: 0.5909 - val_loss: 0.1511 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2751 - accuracy: 0.5921 - val_loss: 0.1608 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2677 - accuracy: 0.5921 - val_loss: 0.1359 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2697 - accuracy: 0.5909 - val_loss: 0.1264 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2644 - accuracy: 0.5921 - val_loss: 0.1375 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 130ms/step - loss: 0.1915 - accuracy: 0.9118
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5120, 52)]   0           []
#
#  input_4 (InputLayer)           [(None, 423, 52)]    0           []
#
#  model (Functional)             (None, 256)          42608512    ['input_2[0][0]']
#
#  model_1 (Functional)           (None, 256)          3529472     ['input_4[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['model[0][0]',
#                                                                   'model_1[0][0]']
#
#  model_2 (Functional)           (None, 1)            279105      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 46,417,089
# Trainable params: 46,061,313
# Non-trainable params: 355,776
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 16s 371ms/step - loss: 0.5454 - accuracy: 0.4909 - val_loss: 0.4640 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.4306 - accuracy: 0.5274 - val_loss: 0.3442 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3824 - accuracy: 0.5457 - val_loss: 0.3695 - val_accuracy: 0.7778
# Epoch 4/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.3827 - accuracy: 0.5468 - val_loss: 0.2412 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3577 - accuracy: 0.5605 - val_loss: 0.2193 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3269 - accuracy: 0.5651 - val_loss: 0.2100 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3411 - accuracy: 0.5651 - val_loss: 0.2506 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3236 - accuracy: 0.5685 - val_loss: 0.1867 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.3121 - accuracy: 0.5708 - val_loss: 0.1710 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3120 - accuracy: 0.5696 - val_loss: 0.1903 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3155 - accuracy: 0.5685 - val_loss: 0.1598 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3017 - accuracy: 0.5696 - val_loss: 0.1711 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3055 - accuracy: 0.5685 - val_loss: 0.1718 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2978 - accuracy: 0.5696 - val_loss: 0.1951 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2987 - accuracy: 0.5685 - val_loss: 0.1820 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2850 - accuracy: 0.5708 - val_loss: 0.2046 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2977 - accuracy: 0.5708 - val_loss: 0.2198 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2935 - accuracy: 0.5696 - val_loss: 0.2089 - val_accuracy: 0.9259
# Epoch 19/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2848 - accuracy: 0.5708 - val_loss: 0.1780 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2864 - accuracy: 0.5708 - val_loss: 0.1541 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2914 - accuracy: 0.5708 - val_loss: 0.1501 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2851 - accuracy: 0.5708 - val_loss: 0.1776 - val_accuracy: 0.8519
# Epoch 23/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2870 - accuracy: 0.5708 - val_loss: 0.1738 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2806 - accuracy: 0.5708 - val_loss: 0.1915 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2790 - accuracy: 0.5708 - val_loss: 0.1884 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2842 - accuracy: 0.5696 - val_loss: 0.1678 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2768 - accuracy: 0.5708 - val_loss: 0.1900 - val_accuracy: 0.8889
# Epoch 28/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2768 - accuracy: 0.5708 - val_loss: 0.1681 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2728 - accuracy: 0.5708 - val_loss: 0.1630 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2713 - accuracy: 0.5696 - val_loss: 0.1769 - val_accuracy: 0.9259
# Epoch 31/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2660 - accuracy: 0.5708 - val_loss: 0.1749 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 120ms/step - loss: 0.0877 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5120, 52)]   0           []
#
#  input_4 (InputLayer)           [(None, 423, 52)]    0           []
#
#  model (Functional)             (None, 256)          42608512    ['input_2[0][0]']
#
#  model_1 (Functional)           (None, 256)          3529472     ['input_4[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['model[0][0]',
#                                                                   'model_1[0][0]']
#
#  model_2 (Functional)           (None, 1)            279105      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 46,417,089
# Trainable params: 46,061,313
# Non-trainable params: 355,776
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 16s 374ms/step - loss: 0.5169 - accuracy: 0.5240 - val_loss: 0.2011 - val_accuracy: 0.9630
# Epoch 2/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.4658 - accuracy: 0.5320 - val_loss: 0.2705 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.4100 - accuracy: 0.5457 - val_loss: 0.2541 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3511 - accuracy: 0.5582 - val_loss: 0.1456 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3468 - accuracy: 0.5674 - val_loss: 0.1592 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3519 - accuracy: 0.5685 - val_loss: 0.1561 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3398 - accuracy: 0.5651 - val_loss: 0.1469 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.3342 - accuracy: 0.5674 - val_loss: 0.1428 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.3068 - accuracy: 0.5719 - val_loss: 0.1357 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3235 - accuracy: 0.5719 - val_loss: 0.1414 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3043 - accuracy: 0.5742 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2987 - accuracy: 0.5753 - val_loss: 0.1475 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3033 - accuracy: 0.5731 - val_loss: 0.1119 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3001 - accuracy: 0.5708 - val_loss: 0.1211 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2850 - accuracy: 0.5742 - val_loss: 0.1137 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2925 - accuracy: 0.5742 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2864 - accuracy: 0.5731 - val_loss: 0.0651 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2866 - accuracy: 0.5753 - val_loss: 0.0811 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2862 - accuracy: 0.5753 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2867 - accuracy: 0.5753 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2832 - accuracy: 0.5742 - val_loss: 0.0774 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2757 - accuracy: 0.5753 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2766 - accuracy: 0.5753 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2763 - accuracy: 0.5753 - val_loss: 0.0633 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2809 - accuracy: 0.5753 - val_loss: 0.1264 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2790 - accuracy: 0.5742 - val_loss: 0.0791 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2669 - accuracy: 0.5753 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2715 - accuracy: 0.5753 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2752 - accuracy: 0.5753 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2668 - accuracy: 0.5753 - val_loss: 0.0313 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2622 - accuracy: 0.5753 - val_loss: 0.0658 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2645 - accuracy: 0.5753 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2574 - accuracy: 0.5753 - val_loss: 0.1229 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2600 - accuracy: 0.5753 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2661 - accuracy: 0.5753 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2628 - accuracy: 0.5753 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2610 - accuracy: 0.5753 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2671 - accuracy: 0.5742 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2623 - accuracy: 0.5753 - val_loss: 0.0537 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2675 - accuracy: 0.5753 - val_loss: 0.0847 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 126ms/step - loss: 0.1387 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5120, 52)]   0           []
#
#  input_4 (InputLayer)           [(None, 423, 52)]    0           []
#
#  model (Functional)             (None, 256)          42608512    ['input_2[0][0]']
#
#  model_1 (Functional)           (None, 256)          3529472     ['input_4[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['model[0][0]',
#                                                                   'model_1[0][0]']
#
#  model_2 (Functional)           (None, 1)            279105      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 46,417,089
# Trainable params: 46,061,313
# Non-trainable params: 355,776
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 16s 374ms/step - loss: 0.5314 - accuracy: 0.5293 - val_loss: 0.3011 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.4342 - accuracy: 0.5586 - val_loss: 0.2509 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.3892 - accuracy: 0.5743 - val_loss: 0.1934 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3692 - accuracy: 0.5766 - val_loss: 0.2055 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3442 - accuracy: 0.5800 - val_loss: 0.1709 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3409 - accuracy: 0.5878 - val_loss: 0.1383 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3270 - accuracy: 0.5878 - val_loss: 0.1626 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3235 - accuracy: 0.5845 - val_loss: 0.1414 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3095 - accuracy: 0.5901 - val_loss: 0.1746 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3019 - accuracy: 0.5878 - val_loss: 0.1126 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.3000 - accuracy: 0.5878 - val_loss: 0.0927 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3167 - accuracy: 0.5890 - val_loss: 0.1298 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2979 - accuracy: 0.5890 - val_loss: 0.1290 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2902 - accuracy: 0.5923 - val_loss: 0.2107 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2891 - accuracy: 0.5923 - val_loss: 0.0962 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2874 - accuracy: 0.5946 - val_loss: 0.1337 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2797 - accuracy: 0.5946 - val_loss: 0.1765 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2837 - accuracy: 0.5935 - val_loss: 0.1959 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2715 - accuracy: 0.5935 - val_loss: 0.1139 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2611 - accuracy: 0.5946 - val_loss: 0.1141 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2635 - accuracy: 0.5946 - val_loss: 0.1834 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 127ms/step - loss: 0.1692 - accuracy: 0.9118
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5120, 52)]   0           []
#
#  input_4 (InputLayer)           [(None, 423, 52)]    0           []
#
#  model (Functional)             (None, 256)          42608512    ['input_2[0][0]']
#
#  model_1 (Functional)           (None, 256)          3529472     ['input_4[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['model[0][0]',
#                                                                   'model_1[0][0]']
#
#  model_2 (Functional)           (None, 1)            279105      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 46,417,089
# Trainable params: 46,061,313
# Non-trainable params: 355,776
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 15s 392ms/step - loss: 0.5569 - accuracy: 0.5000 - val_loss: 0.2854 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.4335 - accuracy: 0.5312 - val_loss: 0.2560 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3664 - accuracy: 0.5648 - val_loss: 0.2695 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3902 - accuracy: 0.5532 - val_loss: 0.2259 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3414 - accuracy: 0.5706 - val_loss: 0.2290 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3310 - accuracy: 0.5694 - val_loss: 0.2292 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3134 - accuracy: 0.5718 - val_loss: 0.1394 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3290 - accuracy: 0.5683 - val_loss: 0.3437 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3175 - accuracy: 0.5752 - val_loss: 0.1793 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3023 - accuracy: 0.5741 - val_loss: 0.1619 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2974 - accuracy: 0.5741 - val_loss: 0.2130 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3013 - accuracy: 0.5729 - val_loss: 0.3522 - val_accuracy: 0.8519
# Epoch 13/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2944 - accuracy: 0.5741 - val_loss: 0.1025 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3022 - accuracy: 0.5752 - val_loss: 0.2722 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2872 - accuracy: 0.5764 - val_loss: 0.1440 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2897 - accuracy: 0.5752 - val_loss: 0.1280 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3020 - accuracy: 0.5741 - val_loss: 0.1953 - val_accuracy: 0.8889
# Epoch 18/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2863 - accuracy: 0.5764 - val_loss: 0.1386 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2900 - accuracy: 0.5764 - val_loss: 0.1973 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2867 - accuracy: 0.5764 - val_loss: 0.2102 - val_accuracy: 0.8889
# Epoch 21/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2804 - accuracy: 0.5764 - val_loss: 0.1232 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2838 - accuracy: 0.5764 - val_loss: 0.1440 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2850 - accuracy: 0.5764 - val_loss: 0.1327 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 98ms/step - loss: 0.1158 - accuracy: 1.0000
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8fde041d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.9588235139846801]
# [0.9518078840994827]
# Epoch 1/100
# 27/27 [==============================] - 16s 379ms/step - loss: 0.5882 - accuracy: 0.4812 - val_loss: 0.3221 - val_accuracy: 0.7407
# Epoch 2/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.4496 - accuracy: 0.5305 - val_loss: 0.2988 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.4034 - accuracy: 0.5434 - val_loss: 0.2215 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3814 - accuracy: 0.5528 - val_loss: 0.1817 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.3583 - accuracy: 0.5599 - val_loss: 0.2013 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3572 - accuracy: 0.5610 - val_loss: 0.1519 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3344 - accuracy: 0.5646 - val_loss: 0.1391 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.3270 - accuracy: 0.5657 - val_loss: 0.1848 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.3210 - accuracy: 0.5669 - val_loss: 0.2122 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.3240 - accuracy: 0.5646 - val_loss: 0.1885 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.3116 - accuracy: 0.5681 - val_loss: 0.1397 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3135 - accuracy: 0.5669 - val_loss: 0.1281 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.3112 - accuracy: 0.5692 - val_loss: 0.1877 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3089 - accuracy: 0.5681 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3027 - accuracy: 0.5704 - val_loss: 0.1301 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.3047 - accuracy: 0.5681 - val_loss: 0.0951 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2906 - accuracy: 0.5692 - val_loss: 0.1069 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2885 - accuracy: 0.5692 - val_loss: 0.0785 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2956 - accuracy: 0.5692 - val_loss: 0.1095 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2863 - accuracy: 0.5704 - val_loss: 0.1065 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2820 - accuracy: 0.5704 - val_loss: 0.1219 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2841 - accuracy: 0.5692 - val_loss: 0.0856 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2878 - accuracy: 0.5704 - val_loss: 0.1069 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2792 - accuracy: 0.5704 - val_loss: 0.1072 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2744 - accuracy: 0.5704 - val_loss: 0.1027 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2813 - accuracy: 0.5704 - val_loss: 0.1152 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2785 - accuracy: 0.5704 - val_loss: 0.1790 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2703 - accuracy: 0.5704 - val_loss: 0.1065 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 125ms/step - loss: 0.0944 - accuracy: 1.0000
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8fca463d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/100
# 27/27 [==============================] - 16s 380ms/step - loss: 0.5069 - accuracy: 0.5175 - val_loss: 0.7978 - val_accuracy: 0.7037
# Epoch 2/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.4201 - accuracy: 0.5455 - val_loss: 0.3676 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3618 - accuracy: 0.5641 - val_loss: 0.3504 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3538 - accuracy: 0.5723 - val_loss: 0.3410 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3355 - accuracy: 0.5758 - val_loss: 0.3188 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3175 - accuracy: 0.5793 - val_loss: 0.3064 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3369 - accuracy: 0.5746 - val_loss: 0.2647 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.3095 - accuracy: 0.5793 - val_loss: 0.2946 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3065 - accuracy: 0.5804 - val_loss: 0.2375 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.3006 - accuracy: 0.5793 - val_loss: 0.2913 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2910 - accuracy: 0.5769 - val_loss: 0.2583 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2908 - accuracy: 0.5804 - val_loss: 0.2701 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2841 - accuracy: 0.5816 - val_loss: 0.2332 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2821 - accuracy: 0.5816 - val_loss: 0.2846 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2846 - accuracy: 0.5828 - val_loss: 0.2154 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2812 - accuracy: 0.5816 - val_loss: 0.2662 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2765 - accuracy: 0.5816 - val_loss: 0.2912 - val_accuracy: 0.8889
# Epoch 18/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2740 - accuracy: 0.5816 - val_loss: 0.2638 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2760 - accuracy: 0.5828 - val_loss: 0.2468 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2714 - accuracy: 0.5828 - val_loss: 0.3041 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2752 - accuracy: 0.5828 - val_loss: 0.2805 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2669 - accuracy: 0.5828 - val_loss: 0.2269 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2653 - accuracy: 0.5816 - val_loss: 0.2697 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2709 - accuracy: 0.5828 - val_loss: 0.2917 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2710 - accuracy: 0.5828 - val_loss: 0.2705 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 120ms/step - loss: 0.1245 - accuracy: 0.9706
# Epoch 1/100
# ...
# Epoch 18/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2959 - accuracy: 0.5755 - val_loss: 0.3811 - val_accuracy: 0.7778
# Epoch 19/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2930 - accuracy: 0.5743 - val_loss: 0.2238 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2867 - accuracy: 0.5766 - val_loss: 0.2833 - val_accuracy: 0.8889
# Epoch 21/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2724 - accuracy: 0.5766 - val_loss: 0.2948 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2918 - accuracy: 0.5755 - val_loss: 0.2506 - val_accuracy: 0.8519
# Epoch 23/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2882 - accuracy: 0.5755 - val_loss: 0.2976 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2843 - accuracy: 0.5755 - val_loss: 0.3030 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2791 - accuracy: 0.5766 - val_loss: 0.2664 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2867 - accuracy: 0.5755 - val_loss: 0.2838 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2699 - accuracy: 0.5766 - val_loss: 0.2086 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2679 - accuracy: 0.5766 - val_loss: 0.2883 - val_accuracy: 0.8889
# Epoch 29/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2771 - accuracy: 0.5766 - val_loss: 0.2375 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2756 - accuracy: 0.5755 - val_loss: 0.2798 - val_accuracy: 0.9259
# Epoch 31/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2738 - accuracy: 0.5766 - val_loss: 0.2682 - val_accuracy: 0.8889
# Epoch 32/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2681 - accuracy: 0.5755 - val_loss: 0.2272 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2626 - accuracy: 0.5766 - val_loss: 0.2458 - val_accuracy: 0.9259
# Epoch 34/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2674 - accuracy: 0.5766 - val_loss: 0.2142 - val_accuracy: 0.9259
# Epoch 35/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2626 - accuracy: 0.5766 - val_loss: 0.2532 - val_accuracy: 0.9259
# Epoch 36/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2694 - accuracy: 0.5766 - val_loss: 0.2715 - val_accuracy: 0.8889
# Epoch 37/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2752 - accuracy: 0.5766 - val_loss: 0.2999 - val_accuracy: 0.8519
# 2/2 [==============================] - 2s 127ms/step - loss: 0.0660 - accuracy: 1.0000
# Epoch 1/100
# 27/27 [==============================] - 16s 379ms/step - loss: 0.5530 - accuracy: 0.5117 - val_loss: 0.2921 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.4445 - accuracy: 0.5513 - val_loss: 0.1925 - val_accuracy: 0.9630
# Epoch 3/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.3714 - accuracy: 0.5793 - val_loss: 0.2592 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.3545 - accuracy: 0.5734 - val_loss: 0.2062 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3373 - accuracy: 0.5793 - val_loss: 0.2226 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.3359 - accuracy: 0.5781 - val_loss: 0.2133 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3267 - accuracy: 0.5816 - val_loss: 0.1811 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3199 - accuracy: 0.5862 - val_loss: 0.1599 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3083 - accuracy: 0.5828 - val_loss: 0.1447 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3202 - accuracy: 0.5862 - val_loss: 0.1184 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2926 - accuracy: 0.5874 - val_loss: 0.1439 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3093 - accuracy: 0.5851 - val_loss: 0.1502 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2969 - accuracy: 0.5851 - val_loss: 0.1635 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2902 - accuracy: 0.5874 - val_loss: 0.1710 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2937 - accuracy: 0.5886 - val_loss: 0.2246 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2847 - accuracy: 0.5897 - val_loss: 0.1477 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2757 - accuracy: 0.5897 - val_loss: 0.1365 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2923 - accuracy: 0.5862 - val_loss: 0.1265 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2829 - accuracy: 0.5886 - val_loss: 0.1676 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2753 - accuracy: 0.5874 - val_loss: 0.1165 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2794 - accuracy: 0.5897 - val_loss: 0.1884 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2711 - accuracy: 0.5897 - val_loss: 0.2789 - val_accuracy: 0.8519
# Epoch 23/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2819 - accuracy: 0.5886 - val_loss: 0.1658 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2702 - accuracy: 0.5897 - val_loss: 0.1490 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2693 - accuracy: 0.5886 - val_loss: 0.1621 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2651 - accuracy: 0.5897 - val_loss: 0.3169 - val_accuracy: 0.8519
# Epoch 27/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2702 - accuracy: 0.5897 - val_loss: 0.1845 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2654 - accuracy: 0.5886 - val_loss: 0.1322 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2693 - accuracy: 0.5897 - val_loss: 0.1418 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2640 - accuracy: 0.5897 - val_loss: 0.1367 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 126ms/step - loss: 0.1779 - accuracy: 0.9118
# Epoch 1/100
# 27/27 [==============================] - 15s 389ms/step - loss: 0.5783 - accuracy: 0.4896 - val_loss: 1.3227 - val_accuracy: 0.6667
# Epoch 2/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.4409 - accuracy: 0.5197 - val_loss: 0.4565 - val_accuracy: 0.7037
# Epoch 3/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.4001 - accuracy: 0.5336 - val_loss: 0.3665 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3616 - accuracy: 0.5394 - val_loss: 0.3187 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3638 - accuracy: 0.5440 - val_loss: 0.3593 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3652 - accuracy: 0.5405 - val_loss: 0.3080 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3429 - accuracy: 0.5498 - val_loss: 0.2940 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3377 - accuracy: 0.5521 - val_loss: 0.3666 - val_accuracy: 0.8519
# Epoch 9/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3402 - accuracy: 0.5486 - val_loss: 0.2844 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3367 - accuracy: 0.5451 - val_loss: 0.3016 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3206 - accuracy: 0.5486 - val_loss: 0.3244 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3189 - accuracy: 0.5509 - val_loss: 0.2805 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3114 - accuracy: 0.5509 - val_loss: 0.2452 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3151 - accuracy: 0.5521 - val_loss: 0.2899 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2994 - accuracy: 0.5521 - val_loss: 0.2418 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3054 - accuracy: 0.5521 - val_loss: 0.3733 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3077 - accuracy: 0.5532 - val_loss: 0.3887 - val_accuracy: 0.8148
# Epoch 18/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2958 - accuracy: 0.5532 - val_loss: 0.2827 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2929 - accuracy: 0.5521 - val_loss: 0.2792 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2924 - accuracy: 0.5532 - val_loss: 0.3081 - val_accuracy: 0.8889
# Epoch 21/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2928 - accuracy: 0.5521 - val_loss: 0.2916 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2875 - accuracy: 0.5532 - val_loss: 0.3189 - val_accuracy: 0.8889
# Epoch 23/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2798 - accuracy: 0.5532 - val_loss: 0.3007 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2911 - accuracy: 0.5532 - val_loss: 0.2464 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2944 - accuracy: 0.5532 - val_loss: 0.3120 - val_accuracy: 0.8519
# 2/2 [==============================] - 2s 124ms/step - loss: 0.2084 - accuracy: 0.9706
# Epoch 1/100
# 28/28 [==============================] - 16s 376ms/step - loss: 0.4906 - accuracy: 0.5249 - val_loss: 0.3239 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3749 - accuracy: 0.5692 - val_loss: 0.2696 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3297 - accuracy: 0.5896 - val_loss: 0.3294 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3226 - accuracy: 0.5896 - val_loss: 0.2715 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.3223 - accuracy: 0.5862 - val_loss: 0.2515 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.3161 - accuracy: 0.5907 - val_loss: 0.2506 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3226 - accuracy: 0.5952 - val_loss: 0.2768 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2991 - accuracy: 0.5975 - val_loss: 0.2595 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2875 - accuracy: 0.5975 - val_loss: 0.2735 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2858 - accuracy: 0.5986 - val_loss: 0.3067 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2872 - accuracy: 0.5975 - val_loss: 0.2798 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2840 - accuracy: 0.5975 - val_loss: 0.2618 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2836 - accuracy: 0.5941 - val_loss: 0.2780 - val_accuracy: 0.8889
# Epoch 14/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2739 - accuracy: 0.5975 - val_loss: 0.2184 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2748 - accuracy: 0.5975 - val_loss: 0.2307 - val_accuracy: 0.8889
# Epoch 16/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2700 - accuracy: 0.5986 - val_loss: 0.2456 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2649 - accuracy: 0.5975 - val_loss: 0.3553 - val_accuracy: 0.8519
# Epoch 18/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2683 - accuracy: 0.5986 - val_loss: 0.2147 - val_accuracy: 0.9259
# Epoch 19/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2609 - accuracy: 0.5986 - val_loss: 0.2234 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2691 - accuracy: 0.5964 - val_loss: 0.2075 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2652 - accuracy: 0.5986 - val_loss: 0.2189 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2507 - accuracy: 0.5986 - val_loss: 0.2370 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2574 - accuracy: 0.5986 - val_loss: 0.2723 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2575 - accuracy: 0.5986 - val_loss: 0.2443 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2582 - accuracy: 0.5986 - val_loss: 0.2661 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2558 - accuracy: 0.5986 - val_loss: 0.2979 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2485 - accuracy: 0.5986 - val_loss: 0.2593 - val_accuracy: 0.8889
# Epoch 28/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2569 - accuracy: 0.5986 - val_loss: 0.2486 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2517 - accuracy: 0.5986 - val_loss: 0.2184 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2478 - accuracy: 0.5986 - val_loss: 0.2362 - val_accuracy: 0.8889
# 2/2 [==============================] - 2s 126ms/step - loss: 0.2535 - accuracy: 0.8824
# [0.9588235139846801, 0.9764705657958984, 0.9352941036224365, 0.9235293865203857, 0.941176462173462]
# [0.9518078840994827, 0.9724417426545087, 0.923243934173368, 0.910185816508144, 0.9323616229663816]
# Mean test accuracy is 0.95, mean test f1 score is 0.94, max test accuracy is 0.98, max test f1 score is 0.97, min test accuracy is 0.92, min test f1 score is 0.91, std of test accuracy is 0.02, std of test f1 score is 0.02
# Time elapsed through all process: 7237.15, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.947, mean test f1 score is 0.938, max test accuracy is 0.976, max test f1 score is 0.972, min test accuracy is 0.924, min test f1 score is 0.910, std of test accuracy is 0.019, std of test f1 score is 0.022
