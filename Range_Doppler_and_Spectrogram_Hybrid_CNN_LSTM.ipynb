# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_and_Spectrogram_Hybrid_CNN_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada range-doppler 2D image datası ve spectrogram datası Hybrid CNN-LSTM ile train edildi.
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.942, mean test f1 score is 0.932, max test accuracy is 0.953, max test f1 score is 0.944, min test accuracy is 0.935, min test f1 score is 0.925, std of test accuracy is 0.006, std of test f1 score is 0.006
# Time elapsed through all process: 7108.952, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, AveragePooling1D, MaxPooling1D, BatchNormalization, Normalization, Input, Conv1D, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
from keras.regularizers import l2, l1
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
range_doppler_concat_shuffle_new = np.zeros((170,52,5120,1))
for ii in range(range_doppler_concat_shuffle.shape[0]):
  aa = range_doppler_concat_shuffle[ii,:,:,0]
  range_doppler_concat_shuffle_new[ii,:,:,0] = cv2.resize(aa, (5120, 52),interpolation = cv2.INTER_CUBIC)
  # range_doppler_concat_shuffle = range_doppler_concat_shuffle[:, np.newaxis] 
range_doppler_concat_shuffle = range_doppler_concat_shuffle_new
del aa
del range_doppler_concat_shuffle_new

spectrogram_concat_shuffle_new = np.zeros((170,52,423,1))
for ii in range(spectrogram_concat_shuffle.shape[0]):
  aa = spectrogram_concat_shuffle[ii,:,:,0]
  spectrogram_concat_shuffle_new[ii,:,:,0] = cv2.resize(aa, (423, 52),interpolation = cv2.INTER_CUBIC)
  # range_doppler_concat_shuffle = range_doppler_concat_shuffle[:, np.newaxis] 
spectrogram_concat_shuffle = spectrogram_concat_shuffle_new
del aa
del spectrogram_concat_shuffle_new

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    if repeat_of_mixup != 0:
      for ii in range(repeat_of_mixup):
        # shuffle train dataset
        shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
        images_shuffled_1 = images[shuffle_indx_1,:,:,:]
        range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
        labels_shuffled_1 = labels[shuffle_indx_1,:]

        shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
        images_shuffled_2 = images[shuffle_indx_2,:,:,:]
        range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
        labels_shuffled_2 = labels[shuffle_indx_2,:]

        # Sample lambda and reshape it to do the mixup
        gaussian_mean = 0.2
        gaussian_std = 0.02
        ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
        x_l = np.reshape(ll, (batch_size,1,1,1))
        y_l = np.reshape(ll, (batch_size,1))
        
        # Perform mixup on both images and labels by combining a pair of images/labels
        images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
        images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
        labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
        concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
        concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
        concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.1
repeat_of_mixup = 0
number_of_repeat = 5
unit_number_of_lstm = 16
dense_unit_of_range_doppler_function = 256
dense_unit_of_spectrogram_function = 8
decoder_dense_unit = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    
    # ---------------- Neural Network Architecture ----------------



    def Hybrid_CNN_LSTM_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Conv1D(filters = 256,kernel_size = 9, padding="same", activation='ReLU')(input)
        x = MaxPooling1D(pool_size=2)(x)
        x = Conv1D(filters = 512,kernel_size = 5, padding="same",  activation='ReLU')(x)
        x = LSTM(256, return_sequences=True)(x)
        x = Flatten()(x)
        return Model(input, x)

    def Hybrid_CNN_LSTM_encoder_network_2(input_shape):
        input = Input(shape=input_shape)
        x = Conv1D(filters = 256,kernel_size = 9, padding="same", activation='ReLU')(input)
        x = MaxPooling1D(pool_size=2)(x)
        x = Conv1D(filters = 512,kernel_size = 5, padding="same",  activation='ReLU')(x)
        x = LSTM(256, return_sequences=True)(x)
        x = Flatten()(x)
        return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      # x = BatchNormalization()(input)
      # x = Dense(decoder_dense_unit)(x)
      # x = BatchNormalization()(x)
      # x = Activation('LeakyReLU')(x)
      # x = Dropout(0.3)(x)
      # x = Dense(dense_size)(x)
      # # x = BatchNormalization()(x)
      # x = Activation('LeakyReLU')(x)
      # x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(input)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = Hybrid_CNN_LSTM_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_lstm(range_doppler_input)

    input_shape = spectrogram_concat_shuffle_train.shape[1:3]
    base_network_lstm_2 = Hybrid_CNN_LSTM_encoder_network_2(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_lstm_2(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(base_network_lstm_2.summary())
      print(base_decoder_network.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=25, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image, spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler, validation_spectrogram) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  conv1d (Conv1D)             (None, 5120, 256)         120064
#
#  max_pooling1d (MaxPooling1D  (None, 2560, 256)        0
#  )
#
#  conv1d_1 (Conv1D)           (None, 2560, 512)         655872
#
#  lstm (LSTM)                 (None, 2560, 256)         787456
#
#  flatten (Flatten)           (None, 655360)            0
#
# =================================================================
# Total params: 1,563,392
# Trainable params: 1,563,392
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  conv1d_2 (Conv1D)           (None, 423, 256)          120064
#
#  max_pooling1d_1 (MaxPooling  (None, 211, 256)         0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 211, 512)          655872
#
#  lstm_1 (LSTM)               (None, 211, 256)          787456
#
#  flatten_1 (Flatten)         (None, 54016)             0
#
# =================================================================
# Total params: 1,563,392
# Trainable params: 1,563,392
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 709376)]          0
#
#  dense (Dense)               (None, 1)                 709377
#
# =================================================================
# Total params: 709,377
# Trainable params: 709,377
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 14/14 [==============================] - 17s 372ms/step - loss: 9.7009 - accuracy: 0.4161 - val_loss: 0.3636 - val_accuracy: 0.8148
# Epoch 2/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.4539 - accuracy: 0.6069 - val_loss: 0.2761 - val_accuracy: 0.8519
# Epoch 3/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.3563 - accuracy: 0.6299 - val_loss: 0.1475 - val_accuracy: 0.9259
# Epoch 4/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.2997 - accuracy: 0.6552 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 5/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.2551 - accuracy: 0.6598 - val_loss: 0.1121 - val_accuracy: 1.0000
# Epoch 6/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.2812 - accuracy: 0.6621 - val_loss: 0.2013 - val_accuracy: 0.8889
# Epoch 7/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2450 - accuracy: 0.6667 - val_loss: 0.0795 - val_accuracy: 1.0000
# Epoch 8/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.2372 - accuracy: 0.6667 - val_loss: 0.1130 - val_accuracy: 1.0000
# Epoch 9/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.2242 - accuracy: 0.6690 - val_loss: 0.0764 - val_accuracy: 1.0000
# Epoch 10/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.2216 - accuracy: 0.6690 - val_loss: 0.0589 - val_accuracy: 1.0000
# Epoch 11/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.2204 - accuracy: 0.6690 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 12/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.2156 - accuracy: 0.6690 - val_loss: 0.0626 - val_accuracy: 1.0000
# Epoch 13/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2074 - accuracy: 0.6690 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 14/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.2074 - accuracy: 0.6690 - val_loss: 0.0664 - val_accuracy: 1.0000
# Epoch 15/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.2073 - accuracy: 0.6690 - val_loss: 0.0712 - val_accuracy: 1.0000
# Epoch 16/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2021 - accuracy: 0.6690 - val_loss: 0.1086 - val_accuracy: 0.9630
# Epoch 17/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.2041 - accuracy: 0.6690 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 18/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1950 - accuracy: 0.6690 - val_loss: 0.0660 - val_accuracy: 1.0000
# Epoch 19/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1967 - accuracy: 0.6690 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 20/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1965 - accuracy: 0.6690 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 21/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1994 - accuracy: 0.6690 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 22/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.1981 - accuracy: 0.6690 - val_loss: 0.0949 - val_accuracy: 1.0000
# Epoch 23/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.2204 - accuracy: 0.6690 - val_loss: 0.1102 - val_accuracy: 0.9630
# Epoch 24/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.2224 - accuracy: 0.6690 - val_loss: 0.1209 - val_accuracy: 0.9630
# Epoch 25/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.2336 - accuracy: 0.6690 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 26/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.2157 - accuracy: 0.6667 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 27/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1983 - accuracy: 0.6690 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 28/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1886 - accuracy: 0.6690 - val_loss: 0.0615 - val_accuracy: 1.0000
# Epoch 29/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1885 - accuracy: 0.6690 - val_loss: 0.0567 - val_accuracy: 1.0000
# Epoch 30/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1862 - accuracy: 0.6690 - val_loss: 0.0495 - val_accuracy: 1.0000
# Epoch 31/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1845 - accuracy: 0.6690 - val_loss: 0.0613 - val_accuracy: 1.0000
# Epoch 32/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1870 - accuracy: 0.6690 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 33/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1879 - accuracy: 0.6690 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 34/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1855 - accuracy: 0.6690 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 35/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1847 - accuracy: 0.6690 - val_loss: 0.0538 - val_accuracy: 1.0000
# Epoch 36/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1855 - accuracy: 0.6690 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 37/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1848 - accuracy: 0.6690 - val_loss: 0.0534 - val_accuracy: 1.0000
# Epoch 38/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1842 - accuracy: 0.6690 - val_loss: 0.0539 - val_accuracy: 1.0000
# Epoch 39/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1846 - accuracy: 0.6690 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 40/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1945 - accuracy: 0.6690 - val_loss: 0.0692 - val_accuracy: 1.0000
# Epoch 41/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1935 - accuracy: 0.6690 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 42/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1898 - accuracy: 0.6690 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 43/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1833 - accuracy: 0.6690 - val_loss: 0.0540 - val_accuracy: 1.0000
# Epoch 44/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1855 - accuracy: 0.6690 - val_loss: 0.0720 - val_accuracy: 1.0000
# Epoch 45/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1823 - accuracy: 0.6690 - val_loss: 0.0525 - val_accuracy: 1.0000
# Epoch 46/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1809 - accuracy: 0.6690 - val_loss: 0.0488 - val_accuracy: 1.0000
# Epoch 47/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1812 - accuracy: 0.6690 - val_loss: 0.0496 - val_accuracy: 1.0000
# Epoch 48/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1837 - accuracy: 0.6690 - val_loss: 0.0587 - val_accuracy: 1.0000
# Epoch 49/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1857 - accuracy: 0.6690 - val_loss: 0.0585 - val_accuracy: 1.0000
# Epoch 50/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1904 - accuracy: 0.6690 - val_loss: 0.0679 - val_accuracy: 1.0000
# Epoch 51/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1909 - accuracy: 0.6690 - val_loss: 0.0613 - val_accuracy: 1.0000
# Epoch 52/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1873 - accuracy: 0.6690 - val_loss: 0.0635 - val_accuracy: 1.0000
# Epoch 53/100
# 14/14 [==============================] - 4s 304ms/step - loss: 0.1838 - accuracy: 0.6690 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 54/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1799 - accuracy: 0.6690 - val_loss: 0.0607 - val_accuracy: 1.0000
# Epoch 55/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1782 - accuracy: 0.6690 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 56/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1799 - accuracy: 0.6690 - val_loss: 0.0693 - val_accuracy: 1.0000
# Epoch 57/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1783 - accuracy: 0.6690 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 58/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1804 - accuracy: 0.6690 - val_loss: 0.0564 - val_accuracy: 1.0000
# Epoch 59/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1812 - accuracy: 0.6690 - val_loss: 0.0545 - val_accuracy: 1.0000
# Epoch 60/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1831 - accuracy: 0.6690 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 61/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1842 - accuracy: 0.6690 - val_loss: 0.0724 - val_accuracy: 0.9630
# Epoch 62/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1871 - accuracy: 0.6690 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 63/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1843 - accuracy: 0.6690 - val_loss: 0.0624 - val_accuracy: 1.0000
# Epoch 64/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1880 - accuracy: 0.6690 - val_loss: 0.0715 - val_accuracy: 1.0000
# Epoch 65/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1906 - accuracy: 0.6690 - val_loss: 0.0687 - val_accuracy: 1.0000
# Epoch 66/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1862 - accuracy: 0.6690 - val_loss: 0.0661 - val_accuracy: 1.0000
# Epoch 67/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1864 - accuracy: 0.6690 - val_loss: 0.0811 - val_accuracy: 1.0000
# Epoch 68/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1853 - accuracy: 0.6690 - val_loss: 0.0580 - val_accuracy: 1.0000
# Epoch 69/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1826 - accuracy: 0.6690 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 70/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1789 - accuracy: 0.6690 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 71/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1782 - accuracy: 0.6690 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 72/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1795 - accuracy: 0.6690 - val_loss: 0.0535 - val_accuracy: 1.0000
# Epoch 73/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1767 - accuracy: 0.6690 - val_loss: 0.0526 - val_accuracy: 1.0000
# Epoch 74/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1751 - accuracy: 0.6690 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 75/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1757 - accuracy: 0.6690 - val_loss: 0.0640 - val_accuracy: 1.0000
# Epoch 76/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1780 - accuracy: 0.6690 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 77/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1783 - accuracy: 0.6690 - val_loss: 0.0442 - val_accuracy: 1.0000
# Epoch 78/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1774 - accuracy: 0.6690 - val_loss: 0.0737 - val_accuracy: 0.9630
# Epoch 79/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1822 - accuracy: 0.6690 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 80/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1827 - accuracy: 0.6690 - val_loss: 0.0700 - val_accuracy: 1.0000
# Epoch 81/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1790 - accuracy: 0.6690 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 82/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1776 - accuracy: 0.6690 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 83/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1753 - accuracy: 0.6690 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 84/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1782 - accuracy: 0.6690 - val_loss: 0.0607 - val_accuracy: 1.0000
# Epoch 85/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1834 - accuracy: 0.6690 - val_loss: 0.0667 - val_accuracy: 0.9630
# Epoch 86/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1842 - accuracy: 0.6690 - val_loss: 0.0719 - val_accuracy: 1.0000
# Epoch 87/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1793 - accuracy: 0.6690 - val_loss: 0.0505 - val_accuracy: 1.0000
# Epoch 88/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1784 - accuracy: 0.6690 - val_loss: 0.0678 - val_accuracy: 1.0000
# Epoch 89/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1786 - accuracy: 0.6690 - val_loss: 0.0596 - val_accuracy: 0.9630
# Epoch 90/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1797 - accuracy: 0.6690 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 91/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1805 - accuracy: 0.6690 - val_loss: 0.0658 - val_accuracy: 1.0000
# Epoch 92/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1813 - accuracy: 0.6690 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 93/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1788 - accuracy: 0.6690 - val_loss: 0.0691 - val_accuracy: 1.0000
# Epoch 94/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1768 - accuracy: 0.6690 - val_loss: 0.0735 - val_accuracy: 0.9630
# Epoch 95/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1754 - accuracy: 0.6690 - val_loss: 0.0615 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 80ms/step - loss: 0.1209 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  conv1d (Conv1D)             (None, 5120, 256)         120064
#
#  max_pooling1d (MaxPooling1D  (None, 2560, 256)        0
#  )
#
#  conv1d_1 (Conv1D)           (None, 2560, 512)         655872
#
#  lstm (LSTM)                 (None, 2560, 256)         787456
#
#  flatten (Flatten)           (None, 655360)            0
#
# =================================================================
# Total params: 1,563,392
# Trainable params: 1,563,392
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  conv1d_2 (Conv1D)           (None, 423, 256)          120064
#
#  max_pooling1d_1 (MaxPooling  (None, 211, 256)         0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 211, 512)          655872
#
#  lstm_1 (LSTM)               (None, 211, 256)          787456
#
#  flatten_1 (Flatten)         (None, 54016)             0
#
# =================================================================
# Total params: 1,563,392
# Trainable params: 1,563,392
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 709376)]          0
#
#  dense (Dense)               (None, 1)                 709377
#
# =================================================================
# Total params: 709,377
# Trainable params: 709,377
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 14/14 [==============================] - 8s 368ms/step - loss: 12.7536 - accuracy: 0.4005 - val_loss: 1.6898 - val_accuracy: 0.7407
# Epoch 2/100
# 14/14 [==============================] - 4s 299ms/step - loss: 1.0506 - accuracy: 0.5648 - val_loss: 0.5053 - val_accuracy: 0.8148
# Epoch 3/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.6127 - accuracy: 0.6065 - val_loss: 0.3793 - val_accuracy: 0.8148
# Epoch 4/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.3937 - accuracy: 0.6157 - val_loss: 0.4102 - val_accuracy: 0.8148
# Epoch 5/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.2925 - accuracy: 0.6412 - val_loss: 0.3176 - val_accuracy: 0.8519
# Epoch 6/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.2581 - accuracy: 0.6458 - val_loss: 0.3642 - val_accuracy: 0.8148
# Epoch 7/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.2433 - accuracy: 0.6505 - val_loss: 0.2919 - val_accuracy: 0.8519
# Epoch 8/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.2427 - accuracy: 0.6528 - val_loss: 0.3376 - val_accuracy: 0.8519
# Epoch 9/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.2259 - accuracy: 0.6528 - val_loss: 0.3352 - val_accuracy: 0.8519
# Epoch 10/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.2185 - accuracy: 0.6528 - val_loss: 0.2736 - val_accuracy: 0.8519
# Epoch 11/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0
100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1974 - accuracy: 0.6528 - val_loss: 0.3303 - val_accuracy: 0.8148
# Epoch 38/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1912 - accuracy: 0.6528 - val_loss: 0.3643 - val_accuracy: 0.8148
# Epoch 39/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1903 - accuracy: 0.6528 - val_loss: 0.3350 - val_accuracy: 0.8519
# Epoch 40/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1953 - accuracy: 0.6528 - val_loss: 0.3775 - val_accuracy: 0.8148
# Epoch 41/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1953 - accuracy: 0.6528 - val_loss: 0.3259 - val_accuracy: 0.8148
# Epoch 42/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1949 - accuracy: 0.6528 - val_loss: 0.3521 - val_accuracy: 0.8148
# Epoch 43/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1910 - accuracy: 0.6528 - val_loss: 0.3029 - val_accuracy: 0.8519
# Epoch 44/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1925 - accuracy: 0.6528 - val_loss: 0.3522 - val_accuracy: 0.8148
# Epoch 45/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1887 - accuracy: 0.6528 - val_loss: 0.4606 - val_accuracy: 0.8148
# Epoch 46/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1877 - accuracy: 0.6528 - val_loss: 0.3695 - val_accuracy: 0.8148
# Epoch 47/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1891 - accuracy: 0.6528 - val_loss: 0.4127 - val_accuracy: 0.8148
# Epoch 48/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1882 - accuracy: 0.6528 - val_loss: 0.3991 - val_accuracy: 0.8148
# Epoch 49/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1870 - accuracy: 0.6528 - val_loss: 0.4308 - val_accuracy: 0.8148
# 2/2 [==============================] - 1s 49ms/step - loss: 0.1450 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  conv1d (Conv1D)             (None, 5120, 256)         120064
#
#  max_pooling1d (MaxPooling1D  (None, 2560, 256)        0
#  )
#
#  conv1d_1 (Conv1D)           (None, 2560, 512)         655872
#
#  lstm (LSTM)                 (None, 2560, 256)         787456
#
#  flatten (Flatten)           (None, 655360)            0
#
# =================================================================
# Total params: 1,563,392
# Trainable params: 1,563,392
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  conv1d_2 (Conv1D)           (None, 423, 256)          120064
#
#  max_pooling1d_1 (MaxPooling  (None, 211, 256)         0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 211, 512)          655872
#
#  lstm_1 (LSTM)               (None, 211, 256)          787456
#
#  flatten_1 (Flatten)         (None, 54016)             0
#
# =================================================================
# Total params: 1,563,392
# Trainable params: 1,563,392
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 709376)]          0
#
#  dense (Dense)               (None, 1)                 709377
#
# =================================================================
# Total params: 709,377
# Trainable params: 709,377
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 14/14 [==============================] - 8s 376ms/step - loss: 9.5391 - accuracy: 0.4324 - val_loss: 3.4238 - val_accuracy: 0.5926
# Epoch 2/100
# 14/14 [==============================] - 4s 305ms/step - loss: 1.0635 - accuracy: 0.5901 - val_loss: 0.1760 - val_accuracy: 0.9630
# Epoch 3/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.4027 - accuracy: 0.6261 - val_loss: 0.1026 - val_accuracy: 0.9630
# Epoch 4/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0
100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1860 - accuracy: 0.6667 - val_loss: 0.1355 - val_accuracy: 0.8889
# Epoch 34/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.1842 - accuracy: 0.6667 - val_loss: 0.1737 - val_accuracy: 0.8889
# Epoch 35/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.1890 - accuracy: 0.6667 - val_loss: 0.1599 - val_accuracy: 0.8889
# Epoch 36/100
# 14/14 [==============================] - 4s 304ms/step - loss: 0.1956 - accuracy: 0.6667 - val_loss: 0.1419 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 48ms/step - loss: 0.1942 - accuracy: 0.9118
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  conv1d (Conv1D)             (None, 5120, 256)         120064
#
#  max_pooling1d (MaxPooling1D  (None, 2560, 256)        0
#  )
#
#  conv1d_1 (Conv1D)           (None, 2560, 512)         655872
#
#  lstm (LSTM)                 (None, 2560, 256)         787456
#
#  flatten (Flatten)           (None, 655360)            0
#
# =================================================================
# Total params: 1,563,392
# Trainable params: 1,563,392
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  conv1d_2 (Conv1D)           (None, 423, 256)          120064
#
#  max_pooling1d_1 (MaxPooling  (None, 211, 256)         0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 211, 512)          655872
#
#  lstm_1 (LSTM)               (None, 211, 256)          787456
#
#  flatten_1 (Flatten)         (None, 54016)             0
#
# =================================================================
# Total params: 1,563,392
# Trainable params: 1,563,392
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 709376)]          0
#
#  dense (Dense)               (None, 1)                 709377
#
# =================================================================
# Total params: 709,377
# Trainable params: 709,377
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 14/14 [==============================] - 8s 374ms/step - loss: 8.4755 - accuracy: 0.4921 - val_loss: 0.3333 - val_accuracy: 0.8889
# Epoch 2/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.6680 - accuracy: 0.5714 - val_loss: 0.2019 - val_accuracy: 0.8889
# Epoch 3/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.4253 - accuracy: 0.6190 - val_loss: 0.1988 - val_accuracy: 0.8889
# Epoch 4/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2966 - accuracy: 0.6417 - val_loss: 0.1590 - val_accuracy: 0.8889
# Epoch 5/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.2622 - accuracy: 0.6599 - val_loss: 0.1292 - val_accuracy: 0.9259
# Epoch 6/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2352 - accuracy: 0.6689 - val_loss: 0.1226 - val_accuracy: 0.9630
# Epoch 7/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.2332 - accuracy: 0.6689 - val_loss: 0.0963 - val_accuracy: 1.0000
# Epoch 8/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.2216 - accuracy: 0.6689 - val_loss: 0.1157 - val_accuracy: 0.9259
# Epoch 9/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2174 - accuracy: 0.6689 - val_loss: 0.0925 - val_accuracy: 0.9630
# Epoch 10/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2099 - accuracy: 0.6689 - val_loss: 0.0978 - val_accuracy: 1.0000
# Epoch 11/100
# 14/14 [==============================] - 4s 304ms/step - loss: 0.2054 - accuracy: 0.6689 - val_loss: 0.0911 - val_accuracy: 0.9630
# Epoch 12/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2053 - accuracy: 0.6689 - val_loss: 0.0847 - val_accuracy: 1.0000
# Epoch 13/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.2081 - accuracy: 0.6689 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 14/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.2123 - accuracy: 0.6689 - val_loss: 0.0792 - val_accuracy: 1.0000
# Epoch 15/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.2325 - accuracy: 0.6644 - val_loss: 0.0813 - val_accuracy: 0.9630
# Epoch 16/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.2723 - accuracy: 0.6667 - val_loss: 0.1132 - val_accuracy: 0.9259
# Epoch 17/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.2450 - accuracy: 0.6667 - val_loss: 0.0929 - val_accuracy: 0.9630
# Epoch 18/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2117 - accuracy: 0.6689 - val_loss: 0.0919 - val_accuracy: 1.0000
# Epoch 19/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.2014 - accuracy: 0.6689 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 20/100
# 14/14 [==============================] - 4s 305ms/step - loss: 0.2026 - accuracy: 0.6689 - val_loss: 0.0781 - val_accuracy: 0.9630
# Epoch 21/100
# 14/14 [==============================] - 4s 304ms/step - loss: 0.1952 - accuracy: 0.6689 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 22/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1877 - accuracy: 0.6689 - val_loss: 0.0677 - val_accuracy: 1.0000
# Epoch 23/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1939 - accuracy: 0.6689 - val_loss: 0.0622 - val_accuracy: 1.0000
# Epoch 24/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1880 - accuracy: 0.6689 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 25/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1891 - accuracy: 0.6689 - val_loss: 0.0760 - val_accuracy: 1.0000
# Epoch 26/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.1915 - accuracy: 0.6689 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 27/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1873 - accuracy: 0.6689 - val_loss: 0.0860 - val_accuracy: 0.9630
# Epoch 28/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1925 - accuracy: 0.6689 - val_loss: 0.0663 - val_accuracy: 1.0000
# Epoch 29/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1928 - accuracy: 0.6689 - val_loss: 0.0708 - val_accuracy: 1.0000
# Epoch 30/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1961 - accuracy: 0.6689 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 31/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.1982 - accuracy: 0.6689 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 32/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1930 - accuracy: 0.6689 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 33/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1859 - accuracy: 0.6689 - val_loss: 0.0621 - val_accuracy: 1.0000
# Epoch 34/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1839 - accuracy: 0.6689 - val_loss: 0.0496 - val_accuracy: 1.0000
# Epoch 35/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.1816 - accuracy: 0.6689 - val_loss: 0.0512 - val_accuracy: 0.9630
# Epoch 36/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.1812 - accuracy: 0.6689 - val_loss: 0.0384 - val_accuracy: 1.0000
# Epoch 37/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1817 - accuracy: 0.6689 - val_loss: 0.0521 - val_accuracy: 1.0000
# Epoch 38/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1815 - accuracy: 0.6689 - val_loss: 0.0572 - val_accuracy: 1.0000
# Epoch 39/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1861 - accuracy: 0.6689 - val_loss: 0.0712 - val_accuracy: 0.9630
# Epoch 40/100
# 14/14 [==============================] - 4s 304ms/step - loss: 0.1829 - accuracy: 0.6689 - val_loss: 0.0526 - val_accuracy: 1.0000
# Epoch 41/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1795 - accuracy: 0.6689 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 42/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.1768 - accuracy: 0.6689 - val_loss: 0.0427 - val_accuracy: 1.0000
# Epoch 43/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1775 - accuracy: 0.6689 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 44/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1793 - accuracy: 0.6689 - val_loss: 0.0494 - val_accuracy: 1.0000
# Epoch 45/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1892 - accuracy: 0.6689 - val_loss: 0.0502 - val_accuracy: 1.0000
# Epoch 46/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1898 - accuracy: 0.6689 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 47/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1898 - accuracy: 0.6689 - val_loss: 0.0606 - val_accuracy: 1.0000
# Epoch 48/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1913 - accuracy: 0.6689 - val_loss: 0.0832 - val_accuracy: 1.0000
# Epoch 49/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1947 - accuracy: 0.6689 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 50/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1894 - accuracy: 0.6689 - val_loss: 0.0393 - val_accuracy: 1.0000
# Epoch 51/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1848 - accuracy: 0.6689 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 52/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.1820 - accuracy: 0.6689 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 53/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1808 - accuracy: 0.6689 - val_loss: 0.0567 - val_accuracy: 1.0000
# Epoch 54/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1792 - accuracy: 0.6689 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 55/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1775 - accuracy: 0.6689 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 56/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1793 - accuracy: 0.6689 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 57/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.1786 - accuracy: 0.6689 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 58/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.1782 - accuracy: 0.6689 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 59/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.1778 - accuracy: 0.6689 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 60/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1803 - accuracy: 0.6689 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 61/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.1786 - accuracy: 0.6689 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 62/100
# ...
# Epoch 7/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.2425 - accuracy: 0.6667 - val_loss: 0.1430 - val_accuracy: 0.9259
# Epoch 8/100
# 14/14 [==============================] - 4s 299ms/step - loss: 0.2239 - accuracy: 0.6713 - val_loss: 0.1435 - val_accuracy: 0.9630
# Epoch 9/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0.2159 - accuracy: 0.6713 - val_loss: 0.1276 - val_accuracy: 0.9259
# Epoch 10/100
# 14/14 [==============================] - 4s 303ms/step - loss: 0.2094 - accuracy: 0.6713 - val_loss: 0.1181 - val_accuracy: 0.9630
# Epoch 11/100
# 14/14 [==============================] - 4s 302ms/step - loss: 0.2277 - accuracy: 0.6667 - val_loss: 0.1184 - val_accuracy: 0.9259
# Epoch 12/100
# 14/14 [==============================] - 4s 301ms/step - loss: 0.2242 - accuracy: 0.6713 - val_loss: 0.1127 - val_accuracy: 0.9630
# Epoch 13/100
# 14/14 [==============================] - 4s 300ms/step - loss: 0.2100 - accuracy: 0.6713 - val_loss: 0.1261 - val_accuracy: 0.9259
# Epoch 14/100
# 14/14 [==============================] - 4s 298ms/step - loss: 0
# Epoch 28/100
# 14/14 [==============================] - 4s 294ms/step - loss: 0.1930 - accuracy: 0.6596 - val_loss: 0.1632 - val_accuracy: 0.9259
# Epoch 29/100
# 14/14 [==============================] - 4s 294ms/step - loss: 0.1925 - accuracy: 0.6596 - val_loss: 0.1765 - val_accuracy: 0.9259
# Epoch 30/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1940 - accuracy: 0.6596 - val_loss: 0.1676 - val_accuracy: 0.8889
# Epoch 31/100
# 14/14 [==============================] - 4s 294ms/step - loss: 0.1968 - accuracy: 0.6596 - val_loss: 0.1952 - val_accuracy: 0.8519
# Epoch 32/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1944 - accuracy: 0.6596 - val_loss: 0.1512 - val_accuracy: 0.9630
# Epoch 33/100
# 14/14 [==============================] - 4s 293ms/step - loss: 0.1962 - accuracy: 0.6596 - val_loss: 0.2439 - val_accuracy: 0.8889
# Epoch 34/100
# 14/14 [==============================] - 4s 294ms/step - loss: 0.2025 - accuracy: 0.6596 - val_loss: 0.1879 - val_accuracy: 0.8889
# Epoch 35/100
# 14/14 [==============================] - 4s 294ms/step - loss: 0.2021 - accuracy: 0.6596 - val_loss: 0.1585 - val_accuracy: 0.9259
# Epoch 36/100
# 14/14 [==============================] - 4s 293ms/step - loss: 0.2120 - accuracy: 0.6596 - val_loss: 0.2636 - val_accuracy: 0.8519
# Epoch 37/100
# 14/14 [==============================] - 4s 292ms/step - loss: 0.2017 - accuracy: 0.6596 - val_loss: 0.2087 - val_accuracy: 0.9259
# Epoch 38/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1972 - accuracy: 0.6596 - val_loss: 0.2184 - val_accuracy: 0.8519
# Epoch 39/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1911 - accuracy: 0.6596 - val_loss: 0.1628 - val_accuracy: 0.8889
# Epoch 40/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1981 - accuracy: 0.6596 - val_loss: 0.1856 - val_accuracy: 0.8889
# Epoch 41/100
# 14/14 [==============================] - 4s 292ms/step - loss: 0.1979 - accuracy: 0.6596 - val_loss: 0.1780 - val_accuracy: 0.9259
# Epoch 42/100
# 14/14 [==============================] - 4s 294ms/step - loss: 0.1900 - accuracy: 0.6596 - val_loss: 0.2560 - val_accuracy: 0.8889
# Epoch 43/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1934 - accuracy: 0.6596 - val_loss: 0.1762 - val_accuracy: 0.9259
# Epoch 44/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1974 - accuracy: 0.6596 - val_loss: 0.1973 - val_accuracy: 0.9259
# Epoch 45/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1925 - accuracy: 0.6596 - val_loss: 0.2075 - val_accuracy: 0.8889
# Epoch 46/100
# 14/14 [==============================] - 4s 293ms/step - loss: 0.1878 - accuracy: 0.6596 - val_loss: 0.2208 - val_accuracy: 0.8889
# Epoch 47/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1857 - accuracy: 0.6596 - val_loss: 0.1758 - val_accuracy: 0.8519
# Epoch 48/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1891 - accuracy: 0.6596 - val_loss: 0.2315 - val_accuracy: 0.8889
# Epoch 49/100
# 14/14 [==============================] - 4s 297ms/step - loss: 0.1965 - accuracy: 0.6572 - val_loss: 0.2060 - val_accuracy: 0.9259
# Epoch 50/100
# 14/14 [==============================] - 4s 293ms/step - loss: 0.1917 - accuracy: 0.6596 - val_loss: 0.1881 - val_accuracy: 0.8889
# Epoch 51/100
# 14/14 [==============================] - 4s 294ms/step - loss: 0.1852 - accuracy: 0.6596 - val_loss: 0.2612 - val_accuracy: 0.8889
# Epoch 52/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1855 - accuracy: 0.6596 - val_loss: 0.2135 - val_accuracy: 0.8889
# Epoch 53/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1867 - accuracy: 0.6596 - val_loss: 0.2270 - val_accuracy: 0.8889
# Epoch 54/100
# 14/14 [==============================] - 4s 291ms/step - loss: 0.1870 - accuracy: 0.6596 - val_loss: 0.1830 - val_accuracy: 0.8889
# Epoch 55/100
# 14/14 [==============================] - 4s 294ms/step - loss: 0.1896 - accuracy: 0.6596 - val_loss: 0.2046 - val_accuracy: 0.9259
# Epoch 56/100
# 14/14 [==============================] - 4s 296ms/step - loss: 0.1864 - accuracy: 0.6596 - val_loss: 0.1778 - val_accuracy: 0.9259
# Epoch 57/100
# 14/14 [==============================] - 4s 295ms/step - loss: 0.1842 - accuracy: 0.6596 - val_loss: 0.2599 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 50ms/step - loss: 0.1798 - accuracy: 0.9118
# [0.9529411673545838, 0.9411764502525329, 0.9352941036224365, 0.941176462173462, 0.941176462173462]
# [0.9443210426440934, 0.9316753667239329, 0.9254248344419482, 0.9312296214423874, 0.9296602485806925]
# Mean test accuracy is 0.942, mean test f1 score is 0.932, max test accuracy is 0.953, max test f1 score is 0.944, min test accuracy is 0.935, min test f1 score is 0.925, std of test accuracy is 0.006, std of test f1 score is 0.006
# Time elapsed through all process: 7108.952, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.942, mean test f1 score is 0.932, max test accuracy is 0.953, max test f1 score is 0.944, min test accuracy is 0.935, min test f1 score is 0.925, std of test accuracy is 0.006, std of test f1 score is 0.006
# Time elapsed through all process: 7108.952, sec
