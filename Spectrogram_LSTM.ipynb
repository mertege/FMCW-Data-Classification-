# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Spectrogram_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada sadece spectrogram 2D image datası LSTM ile train edildi.
# 2D image'ın column'ları lstm'e sokuldu ve çıktıları dense layer ile classification moduna getirildi.
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.912, mean test f1 score is 0.894, max test accuracy is 0.929, max test f1 score is 0.915, 
# Min test accuracy is 0.894, min test f1 score is 0.867, std of test accuracy is 0.013, std of test f1 score is 0.018
# Time elapsed through all process: 1300.19, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 16
dense_unit_of_lstm_function = 512
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(spectrogram_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = spectrogram_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(spectrogram_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_spectrogram) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 512)               6930944
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 6,995,968
# Trainable params: 6,967,872
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 512)               6995968
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 7,143,809
# Trainable params: 7,115,713
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 5s 60ms/step - loss: 0.5769 - accuracy: 0.4820 - val_loss: 0.3321 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.4211 - accuracy: 0.5180 - val_loss: 0.4491 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.4155 - accuracy: 0.5304 - val_loss: 0.3567 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3634 - accuracy: 0.5484 - val_loss: 0.3367 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3492 - accuracy: 0.5518 - val_loss: 0.3277 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3445 - accuracy: 0.5541 - val_loss: 0.3192 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3381 - accuracy: 0.5608 - val_loss: 0.2964 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3337 - accuracy: 0.5586 - val_loss: 0.3891 - val_accuracy: 0.8889
# Epoch 9/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3313 - accuracy: 0.5529 - val_loss: 0.3135 - val_accuracy: 0.8889
# Epoch 10/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3124 - accuracy: 0.5608 - val_loss: 0.2859 - val_accuracy: 0.8889
# Epoch 11/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3034 - accuracy: 0.5597 - val_loss: 0.3260 - val_accuracy: 0.8889
# Epoch 12/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3050 - accuracy: 0.5608 - val_loss: 0.3024 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3130 - accuracy: 0.5586 - val_loss: 0.3340 - val_accuracy: 0.8889
# Epoch 14/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3002 - accuracy: 0.5619 - val_loss: 0.2763 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3003 - accuracy: 0.5619 - val_loss: 0.2686 - val_accuracy: 0.8889
# Epoch 16/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2999 - accuracy: 0.5608 - val_loss: 0.2656 - val_accuracy: 0.8889
# Epoch 17/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2875 - accuracy: 0.5619 - val_loss: 0.3361 - val_accuracy: 0.8889
# Epoch 18/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3053 - accuracy: 0.5597 - val_loss: 0.3011 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2936 - accuracy: 0.5631 - val_loss: 0.2935 - val_accuracy: 0.8889
# Epoch 20/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2835 - accuracy: 0.5631 - val_loss: 0.2629 - val_accuracy: 0.8889
# Epoch 21/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2878 - accuracy: 0.5631 - val_loss: 0.3350 - val_accuracy: 0.8889
# Epoch 22/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2925 - accuracy: 0.5631 - val_loss: 0.3253 - val_accuracy: 0.8889
# Epoch 23/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2791 - accuracy: 0.5631 - val_loss: 0.2750 - val_accuracy: 0.8889
# Epoch 24/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2800 - accuracy: 0.5608 - val_loss: 0.2840 - val_accuracy: 0.8889
# Epoch 25/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2841 - accuracy: 0.5631 - val_loss: 0.3467 - val_accuracy: 0.8889
# Epoch 26/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2768 - accuracy: 0.5631 - val_loss: 0.2523 - val_accuracy: 0.8889
# Epoch 27/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2871 - accuracy: 0.5619 - val_loss: 0.2854 - val_accuracy: 0.8889
# Epoch 28/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2793 - accuracy: 0.5631 - val_loss: 0.3191 - val_accuracy: 0.8889
# Epoch 29/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2728 - accuracy: 0.5631 - val_loss: 0.2893 - val_accuracy: 0.8889
# Epoch 30/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2718 - accuracy: 0.5631 - val_loss: 0.3131 - val_accuracy: 0.8889
# Epoch 31/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2713 - accuracy: 0.5631 - val_loss: 0.3230 - val_accuracy: 0.8889
# Epoch 32/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2761 - accuracy: 0.5631 - val_loss: 0.2873 - val_accuracy: 0.8889
# Epoch 33/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2696 - accuracy: 0.5631 - val_loss: 0.2436 - val_accuracy: 0.8889
# Epoch 34/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2665 - accuracy: 0.5631 - val_loss: 0.2999 - val_accuracy: 0.8889
# Epoch 35/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2736 - accuracy: 0.5631 - val_loss: 0.2751 - val_accuracy: 0.8889
# Epoch 36/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2725 - accuracy: 0.5631 - val_loss: 0.2467 - val_accuracy: 0.8889
# Epoch 37/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2691 - accuracy: 0.5631 - val_loss: 0.3048 - val_accuracy: 0.8889
# Epoch 38/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2718 - accuracy: 0.5631 - val_loss: 0.2475 - val_accuracy: 0.8889
# Epoch 39/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2700 - accuracy: 0.5631 - val_loss: 0.2435 - val_accuracy: 0.8889
# Epoch 40/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2697 - accuracy: 0.5631 - val_loss: 0.2503 - val_accuracy: 0.8889
# Epoch 41/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2686 - accuracy: 0.5631 - val_loss: 0.2523 - val_accuracy: 0.8889
# Epoch 42/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2606 - accuracy: 0.5631 - val_loss: 0.2314 - val_accuracy: 0.8889
# Epoch 43/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2715 - accuracy: 0.5631 - val_loss: 0.2988 - val_accuracy: 0.8889
# Epoch 44/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2635 - accuracy: 0.5631 - val_loss: 0.2497 - val_accuracy: 0.8889
# Epoch 45/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2663 - accuracy: 0.5631 - val_loss: 0.2643 - val_accuracy: 0.8889
# Epoch 46/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2661 - accuracy: 0.5631 - val_loss: 0.2673 - val_accuracy: 0.8889
# Epoch 47/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2622 - accuracy: 0.5631 - val_loss: 0.2762 - val_accuracy: 0.8889
# Epoch 48/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2634 - accuracy: 0.5631 - val_loss: 0.2557 - val_accuracy: 0.8889
# Epoch 49/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2614 - accuracy: 0.5631 - val_loss: 0.2588 - val_accuracy: 0.9259
# Epoch 50/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2571 - accuracy: 0.5631 - val_loss: 0.2553 - val_accuracy: 0.8889
# Epoch 51/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2664 - accuracy: 0.5631 - val_loss: 0.3156 - val_accuracy: 0.8889
# Epoch 52/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2619 - accuracy: 0.5631 - val_loss: 0.2485 - val_accuracy: 0.9259
# Epoch 53/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2617 - accuracy: 0.5631 - val_loss: 0.2644 - val_accuracy: 0.8889
# Epoch 54/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2633 - accuracy: 0.5631 - val_loss: 0.2271 - val_accuracy: 0.8889
# Epoch 55/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2570 - accuracy: 0.5631 - val_loss: 0.2266 - val_accuracy: 0.8889
# Epoch 56/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2570 - accuracy: 0.5631 - val_loss: 0.2333 - val_accuracy: 0.8889
# Epoch 57/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2632 - accuracy: 0.5631 - val_loss: 0.2462 - val_accuracy: 0.8889
# Epoch 58/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2562 - accuracy: 0.5631 - val_loss: 0.2472 - val_accuracy: 0.8889
# Epoch 59/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2626 - accuracy: 0.5619 - val_loss: 0.2431 - val_accuracy: 0.9259
# Epoch 60/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2578 - accuracy: 0.5631 - val_loss: 0.2192 - val_accuracy: 0.8889
# Epoch 61/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2569 - accuracy: 0.5631 - val_loss: 0.2223 - val_accuracy: 0.9259
# Epoch 62/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2576 - accuracy: 0.5631 - val_loss: 0.2329 - val_accuracy: 0.9259
# Epoch 63/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2538 - accuracy: 0.5631 - val_loss: 0.2256 - val_accuracy: 0.9259
# Epoch 64/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2601 - accuracy: 0.5631 - val_loss: 0.2625 - val_accuracy: 0.9259
# Epoch 65/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2586 - accuracy: 0.5631 - val_loss: 0.2482 - val_accuracy: 0.8889
# Epoch 66/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2560 - accuracy: 0.5631 - val_loss: 0.2492 - val_accuracy: 0.8889
# Epoch 67/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2648 - accuracy: 0.5619 - val_loss: 0.2503 - val_accuracy: 0.9259
# Epoch 68/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2586 - accuracy: 0.5631 - val_loss: 0.2339 - val_accuracy: 0.8889
# Epoch 69/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2573 - accuracy: 0.5631 - val_loss: 0.2429 - val_accuracy: 0.8889
# Epoch 70/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2483 - accuracy: 0.5631 - val_loss: 0.2484 - val_accuracy: 0.8889
# Epoch 71/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2602 - accuracy: 0.5631 - val_loss: 0.2383 - val_accuracy: 0.8889
# Epoch 72/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2578 - accuracy: 0.5631 - val_loss: 0.2429 - val_accuracy: 0.8889
# Epoch 73/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2583 - accuracy: 0.5631 - val_loss: 0.2657 - val_accuracy: 0.8889
# Epoch 74/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2563 - accuracy: 0.5631 - val_loss: 0.2700 - val_accuracy: 0.8889
# Epoch 75/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2515 - accuracy: 0.5631 - val_loss: 0.2569 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 13ms/step - loss: 0.0981 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 512)               6930944
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 6,995,968
# Trainable params: 6,967,872
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 512)               6995968
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 7,143,809
# Trainable params: 7,115,713
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 5s 61ms/step - loss: 0.5206 - accuracy: 0.5170 - val_loss: 0.6685 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3976 - accuracy: 0.5635 - val_loss: 0.4584 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3790 - accuracy: 0.5612 - val_loss: 0.3828 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3479 - accuracy: 0.5726 - val_loss: 0.3785 - val_accuracy: 0.8519
# Epoch 5/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3231 - accuracy: 0.5850 - val_loss: 0.3569 - val_accuracy: 0.8519
# Epoch 6/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3136 - accuracy: 0.5873 - val_loss: 0.3523 - val_accuracy: 0.8519
# Epoch 7/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3133 - accuracy: 0.5884 - val_loss: 0.3051 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2985 - accuracy: 0.5896 - val_loss: 0.3332 - val_accuracy: 0.8889
# Epoch 9/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2980 - accuracy: 0.5884 - val_loss: 0.3340 - val_accuracy: 0.8519
# Epoch 10/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2931 - accuracy: 0.5907 - val_loss: 0.3668 - val_accuracy: 0.8519
# Epoch 11/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2960 - accuracy: 0.5862 - val_loss: 0.3362 - val_accuracy: 0.8519
# Epoch 12/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2803 - accuracy: 0.5907 - val_loss: 0.3621 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2807 - accuracy: 0.5918 - val_loss: 0.3904 - val_accuracy: 0.8519
# Epoch 14/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2866 - accuracy: 0.5907 - val_loss: 0.4139 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2741 - accuracy: 0.5907 - val_loss: 0.3499 - val_accuracy: 0.8519
# Epoch 16/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2758 - accuracy: 0.5918 - val_loss: 0.3588 - val_accuracy: 0.8519
# Epoch 17/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2721 - accuracy: 0.5884 - val_loss: 0.3640 - val_accuracy: 0.8519
# Epoch 18/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2799 - accuracy: 0.5907 - val_loss: 0.4324 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2669 - accuracy: 0.5918 - val_loss: 0.3778 - val_accuracy: 0.8519
# Epoch 20/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2752 - accuracy: 0.5896 - val_loss: 0.3221 - val_accuracy: 0.8519
# Epoch 21/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2670 - accuracy: 0.5918 - val_loss: 0.3880 - val_accuracy: 0.8519
# Epoch 22/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2661 - accuracy: 0.5918 - val_loss: 0.4301 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 14ms/step - loss: 0.3597 - accuracy: 0.8235
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 512)               6930944
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 6,995,968
# Trainable params: 6,967,872
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 512)               6995968
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 7,143,809
# Trainable params: 7,115,713
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 5s 59ms/step - loss: 0.4947 - accuracy: 0.5391 - val_loss: 0.7329 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.4015 - accuracy: 0.5540 - val_loss: 0.4021 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3670 - accuracy: 0.5678 - val_loss: 0.3353 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3405 - accuracy: 0.5793 - val_loss: 0.3391 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3400 - accuracy: 0.5816 - val_loss: 0.4353 - val_accuracy: 0.8148
# Epoch 6/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3183 - accuracy: 0.5851 - val_loss: 0.3515 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3259 - accuracy: 0.5816 - val_loss: 0.3320 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3105 - accuracy: 0.5828 - val_loss: 0.3204 - val_accuracy: 0.8889
# Epoch 9/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3089 - accuracy: 0.5862 - val_loss: 0.2971 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3001 - accuracy: 0.5874 - val_loss: 0.3180 - val_accuracy: 0.8519
# Epoch 11/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2945 - accuracy: 0.5874 - val_loss: 0.3110 - val_accuracy: 0.8889
# Epoch 12/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3025 - accuracy: 0.5897 - val_loss: 0.2966 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2956 - accuracy: 0.5897 - val_loss: 0.3282 - val_accuracy: 0.8889
# Epoch 14/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2896 - accuracy: 0.5897 - val_loss: 0.3053 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2876 - accuracy: 0.5897 - val_loss: 0.3229 - val_accuracy: 0.8148
# Epoch 16/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2829 - accuracy: 0.5908 - val_loss: 0.3168 - val_accuracy: 0.8148
# Epoch 17/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2823 - accuracy: 0.5885 - val_loss: 0.3305 - val_accuracy: 0.8148
# Epoch 18/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2780 - accuracy: 0.5885 - val_loss: 0.3024 - val_accuracy: 0.8519
# Epoch 19/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2784 - accuracy: 0.5908 - val_loss: 0.3481 - val_accuracy: 0.8148
# Epoch 20/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2844 - accuracy: 0.5897 - val_loss: 0.4020 - val_accuracy: 0.7778
# Epoch 21/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2750 - accuracy: 0.5885 - val_loss: 0.3252 - val_accuracy: 0.8519
# Epoch 22/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2740 - accuracy: 0.5908 - val_loss: 0.2683 - val_accuracy: 0.8519
# Epoch 23/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2797 - accuracy: 0.5897 - val_loss: 0.2976 - val_accuracy: 0.8519
# Epoch 24/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2776 - accuracy: 0.5897 - val_loss: 0.3319 - val_accuracy: 0.8148
# Epoch 25/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2746 - accuracy: 0.5908 - val_loss: 0.2569 - val_accuracy: 0.8519
# Epoch 26/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2765 - accuracy: 0.5908 - val_loss: 0.2666 - val_accuracy: 0.8889
# Epoch 27/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2723 - accuracy: 0.5908 - val_loss: 0.2730 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2687 - accuracy: 0.5897 - val_loss: 0.2703 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2706 - accuracy: 0.5897 - val_loss: 0.2699 - val_accuracy: 0.8519
# Epoch 30/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2618 - accuracy: 0.5908 - val_loss: 0.2808 - val_accuracy: 0.8889
# Epoch 31/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2648 - accuracy: 0.5908 - val_loss: 0.2692 - val_accuracy: 0.8889
# Epoch 32/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2599 - accuracy: 0.5908 - val_loss: 0.2988 - val_accuracy: 0.8519
# Epoch 33/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2623 - accuracy: 0.5897 - val_loss: 0.2775 - val_accuracy: 0.9259
# Epoch 34/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2805 - accuracy: 0.5908 - val_loss: 0.2849 - val_accuracy: 0.8889
# Epoch 35/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2630 - accuracy: 0.5897 - val_loss: 0.3418 - val_accuracy: 0.9259
# Epoch 36/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2643 - accuracy: 0.5897 - val_loss: 0.2852 - val_accuracy: 0.8519
# Epoch 37/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2697 - accuracy: 0.5908 - val_loss: 0.2933 - val_accuracy: 0.8889
# Epoch 38/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2588 - accuracy: 0.5908 - val_loss: 0.3054 - val_accuracy: 0.8148
# Epoch 39/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2565 - accuracy: 0.5908 - val_loss: 0.3600 - val_accuracy: 0.8148
# Epoch 40/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2537 - accuracy: 0.5908 - val_loss: 0.3215 - val_accuracy: 0.8148
# 2/2 [==============================] - 1s 14ms/step - loss: 0.2354 - accuracy: 0.9118
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 512)               6930944
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 6,995,968
# Trainable params: 6,967,872
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 512)               6995968
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 7,143,809
# Trainable params: 7,115,713
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 5s 61ms/step - loss: 0.5287 - accuracy: 0.5282 - val_loss: 0.2192 - val_accuracy: 0.9259
# Epoch 2/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.4138 - accuracy: 0.5709 - val_loss: 0.2592 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3725 - accuracy: 0.5867 - val_loss: 0.2188 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3365 - accuracy: 0.6002 - val_loss: 0.2237 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3123 - accuracy: 0.6047 - val_loss: 0.2658 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3056 - accuracy: 0.6014 - val_loss: 0.1681 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3127 - accuracy: 0.6047 - val_loss: 0.1879 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2925 - accuracy: 0.6081 - val_loss: 0.1842 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2989 - accuracy: 0.6104 - val_loss: 0.1505 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2902 - accuracy: 0.6070 - val_loss: 0.1490 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2852 - accuracy: 0.6115 - val_loss: 0.1745 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2827 - accuracy: 0.6047 - val_loss: 0.1559 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2787 - accuracy: 0.6104 - val_loss: 0.2432 - val_accuracy: 0.8519
# Epoch 14/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2676 - accuracy: 0.6126 - val_loss: 0.1680 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2654 - accuracy: 0.6104 - val_loss: 0.1970 - val_accuracy: 0.8519
# Epoch 16/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2714 - accuracy: 0.6104 - val_loss: 0.2024 - val_accuracy: 0.8519
# Epoch 17/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2639 - accuracy: 0.6126 - val_loss: 0.1343 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2709 - accuracy: 0.6115 - val_loss: 0.1925 - val_accuracy: 0.8519
# Epoch 19/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2707 - accuracy: 0.6104 - val_loss: 0.1413 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2626 - accuracy: 0.6092 - val_loss: 0.1450 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2601 - accuracy: 0.6115 - val_loss: 0.1609 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2626 - accuracy: 0.6126 - val_loss: 0.2169 - val_accuracy: 0.8889
# Epoch 23/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2694 - accuracy: 0.6104 - val_loss: 0.1548 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2549 - accuracy: 0.6126 - val_loss: 0.1799 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2476 - accuracy: 0.6126 - val_loss: 0.1862 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2648 - accuracy: 0.6092 - val_loss: 0.1307 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2616 - accuracy: 0.6126 - val_loss: 0.1520 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2526 - accuracy: 0.6126 - val_loss: 0.1568 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2520 - accuracy: 0.6126 - val_loss: 0.1827 - val_accuracy: 0.8519
# Epoch 30/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2458 - accuracy: 0.6126 - val_loss: 0.3267 - val_accuracy: 0.8519
# Epoch 31/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2524 - accuracy: 0.6126 - val_loss: 0.1916 - val_accuracy: 0.8519
# Epoch 32/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2438 - accuracy: 0.6115 - val_loss: 0.1584 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2453 - accuracy: 0.6126 - val_loss: 0.1938 - val_accuracy: 0.8519
# Epoch 34/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2459 - accuracy: 0.6115 - val_loss: 0.2586 - val_accuracy: 0.8889
# Epoch 35/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2522 - accuracy: 0.6126 - val_loss: 0.3531 - val_accuracy: 0.8519
# Epoch 36/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2465 - accuracy: 0.6126 - val_loss: 0.3240 - val_accuracy: 0.8889
# Epoch 37/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2412 - accuracy: 0.6115 - val_loss: 0.1576 - val_accuracy: 0.9259
# Epoch 38/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2440 - accuracy: 0.6126 - val_loss: 0.1464 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2420 - accuracy: 0.6104 - val_loss: 0.1862 - val_accuracy: 0.9259
# Epoch 40/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2402 - accuracy: 0.6126 - val_loss: 0.2164 - val_accuracy: 0.9259
# Epoch 41/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2447 - accuracy: 0.6115 - val_loss: 0.2451 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 14ms/step - loss: 0.2852 - accuracy: 0.8824
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 512)               6930944
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 6,995,968
# Trainable params: 6,967,872
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 512)               6995968
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 7,143,809
# Trainable params: 7,115,713
# Non-trainable params: 28,096
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 5s 62ms/step - loss: 0.5204 - accuracy: 0.4930 - val_loss: 0.9636 - val_accuracy: 0.6667
# Epoch 2/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4321 - accuracy: 0.5140 - val_loss: 0.5806 - val_accuracy: 0.7407
# Epoch 3/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3844 - accuracy: 0.5431 - val_loss: 0.5200 - val_accuracy: 0.7407
# Epoch 4/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3483 - accuracy: 0.5524 - val_loss: 0.3687 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3439 - accuracy: 0.5536 - val_loss: 0.3422 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3388 - accuracy: 0.5536 - val_loss: 0.2857 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3328 - accuracy: 0.5548 - val_loss: 0.3069 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3214 - accuracy: 0.5594 - val_loss: 0.2728 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3161 - accuracy: 0.5606 - val_loss: 0.2735 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3062 - accuracy: 0.5641 - val_loss: 0.2898 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3095 - accuracy: 0.5618 - val_loss: 0.2800 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3040 - accuracy: 0.5618 - val_loss: 0.2389 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3131 - accuracy: 0.5629 - val_loss: 0.3508 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3044 - accuracy: 0.5629 - val_loss: 0.2218 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3023 - accuracy: 0.5641 - val_loss: 0.2510 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2979 - accuracy: 0.5641 - val_loss: 0.2197 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2959 - accuracy: 0.5629 - val_loss: 0.2409 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2952 - accuracy: 0.5641 - val_loss: 0.2023 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2849 - accuracy: 0.5641 - val_loss: 0.2538 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2983 - accuracy: 0.5641 - val_loss: 0.2401 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2814 - accuracy: 0.5641 - val_loss: 0.2253 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2866 - accuracy: 0.5641 - val_loss: 0.3040 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2904 - accuracy: 0.5641 - val_loss: 0.2040 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2870 - accuracy: 0.5641 - val_loss: 0.2435 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2816 - accuracy: 0.5629 - val_loss: 0.1706 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2855 - accuracy: 0.5641 - val_loss: 0.1813 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2763 - accuracy: 0.5641 - val_loss: 0.1927 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2799 - accuracy: 0.5641 - val_loss: 0.1771 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2720 - accuracy: 0.5641 - val_loss: 0.3075 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2755 - accuracy: 0.5641 - val_loss: 0.2234 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2849 - accuracy: 0.5641 - val_loss: 0.2462 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2744 - accuracy: 0.5641 - val_loss: 0.1973 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2709 - accuracy: 0.5641 - val_loss: 0.1794 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2733 - accuracy: 0.5641 - val_loss: 0.2719 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2859 - accuracy: 0.5629 - val_loss: 0.1998 - val_accuracy: 0.9259
# Epoch 36/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2664 - accuracy: 0.5641 - val_loss: 0.1941 - val_accuracy: 0.9259
# Epoch 37/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2615 - accuracy: 0.5641 - val_loss: 0.2231 - val_accuracy: 0.9259
# Epoch 38/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2641 - accuracy: 0.5641 - val_loss: 0.1595 - val_accuracy: 0.9259
# Epoch 39/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2704 - accuracy: 0.5641 - val_loss: 0.2196 - val_accuracy: 0.9259
# Epoch 40/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2731 - accuracy: 0.5641 - val_loss: 0.2102 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2661 - accuracy: 0.5641 - val_loss: 0.2207 - val_accuracy: 0.9259
# Epoch 42/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2676 - accuracy: 0.5641 - val_loss: 0.1909 - val_accuracy: 0.9259
# Epoch 43/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2642 - accuracy: 0.5641 - val_loss: 0.2322 - val_accuracy: 0.9259
# Epoch 44/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2653 - accuracy: 0.5641 - val_loss: 0.1820 - val_accuracy: 0.9259
# Epoch 45/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2630 - accuracy: 0.5641 - val_loss: 0.1929 - val_accuracy: 0.9259
# Epoch 46/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2670 - accuracy: 0.5641 - val_loss: 0.1886 - val_accuracy: 0.9259
# Epoch 47/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2668 - accuracy: 0.5641 - val_loss: 0.2034 - val_accuracy: 0.9259
# Epoch 48/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2621 - accuracy: 0.5641 - val_loss: 0.2345 - val_accuracy: 0.9259
# Epoch 49/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2615 - accuracy: 0.5641 - val_loss: 0.2190 - val_accuracy: 0.9259
# Epoch 50/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2624 - accuracy: 0.5641 - val_loss: 0.1970 - val_accuracy: 0.9259
# Epoch 51/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2549 - accuracy: 0.5641 - val_loss: 0.1974 - val_accuracy: 0.9259
# Epoch 52/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2600 - accuracy: 0.5641 - val_loss: 0.1748 - val_accuracy: 0.9259
# Epoch 53/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2575 - accuracy: 0.5641 - val_loss: 0.1900 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 14ms/step - loss: 0.2532 - accuracy: 0.8824
# [0.8941176414489747]
# [0.8670561304765745]
# Epoch 1/100
# 27/27 [==============================] - 4s 63ms/step - loss: 0.4688 - accuracy: 0.5428 - val_loss: 0.6095 - val_accuracy: 0.8148
# Epoch 2/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3879 - accuracy: 0.5694 - val_loss: 0.4753 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3617 - accuracy: 0.5764 - val_loss: 0.5114 - val_accuracy: 0.7778
# Epoch 4/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3217 - accuracy: 0.5891 - val_loss: 0.5865 - val_accuracy: 0.7778
# Epoch 5/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3061 - accuracy: 0.5914 - val_loss: 0.5129 - val_accuracy: 0.7778
# Epoch 6/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2986 - accuracy: 0.5972 - val_loss: 0.5330 - val_accuracy: 0.8148
# Epoch 7/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2938 - accuracy: 0.5995 - val_loss: 0.5990 - val_accuracy: 0.7778
# Epoch 8/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2926 - accuracy: 0.5961 - val_loss: 0.4580 - val_accuracy: 0.8148
# Epoch 9/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2838 - accuracy: 0.5972 - val_loss: 0.5367 - val_accuracy: 0.8148
# Epoch 10/100
# ...
# Epoch 35/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2703 - accuracy: 0.5655 - val_loss: 0.3052 - val_accuracy: 0.8519
# Epoch 36/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2746 - accuracy: 0.5655 - val_loss: 0.2612 - val_accuracy: 0.8519
# Epoch 37/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2671 - accuracy: 0.5655 - val_loss: 0.2336 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 18ms/step - loss: 0.1147 - accuracy: 0.9706
# Epoch 1/100
# 28/28 [==============================] - 5s 60ms/step - loss: 0.5830 - accuracy: 0.4932 - val_loss: 0.4337 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.4332 - accuracy: 0.5217 - val_loss: 0.3481 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.4071 - accuracy: 0.5354 - val_loss: 0.2218 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3821 - accuracy: 0.5514 - val_loss: 0.2563 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3477 - accuracy: 0.5616 - val_loss: 0.2944 - val_accuracy: 0.8148
# Epoch 6/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3592 - accuracy: 0.5605 - val_loss: 0.2084 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3251 - accuracy: 0.5651 - val_loss: 0.2224 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3201 - accuracy: 0.5674 - val_loss: 0.1497 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3155 - accuracy: 0.5674 - val_loss: 0.2021 - val_accuracy: 0.8889
# Epoch 10/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3159 - accuracy: 0.5662 - val_loss: 0.1963 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3186 - accuracy: 0.5639 - val_loss: 0.1926 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3111 - accuracy: 0.5651 - val_loss: 0.1497 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3117 - accuracy: 0.5696 - val_loss: 0.1888 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3215 - accuracy: 0.5674 - val_loss: 0.2005 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3008 - accuracy: 0.5685 - val_loss: 0.1636 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3010 - accuracy: 0.5708 - val_loss: 0.1654 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2940 - accuracy: 0.5708 - val_loss: 0.1252 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2991 - accuracy: 0.5696 - val_loss: 0.1330 - val_accuracy: 0.9259
# Epoch 19/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2959 - accuracy: 0.5685 - val_loss: 0.1244 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2901 - accuracy: 0.5708 - val_loss: 0.1348 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2829 - accuracy: 0.5708 - val_loss: 0.1482 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2973 - accuracy: 0.5696 - val_loss: 0.1250 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2884 - accuracy: 0.5708 - val_loss: 0.1275 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2829 - accuracy: 0.5708 - val_loss: 0.1160 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2822 - accuracy: 0.5708 - val_loss: 0.1361 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2840 - accuracy: 0.5696 - val_loss: 0.1718 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2778 - accuracy: 0.5696 - val_loss: 0.1673 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2835 - accuracy: 0.5696 - val_loss: 0.1382 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2870 - accuracy: 0.5708 - val_loss: 0.1698 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2788 - accuracy: 0.5696 - val_loss: 0.1194 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2809 - accuracy: 0.5708 - val_loss: 0.1692 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2820 - accuracy: 0.5708 - val_loss: 0.1091 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2721 - accuracy: 0.5708 - val_loss: 0.1602 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2703 - accuracy: 0.5708 - val_loss: 0.1417 - val_accuracy: 0.9259
# Epoch 35/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2722 - accuracy: 0.5708 - val_loss: 0.1605 - val_accuracy: 0.9259
# Epoch 36/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2702 - accuracy: 0.5708 - val_loss: 0.1141 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2698 - accuracy: 0.5708 - val_loss: 0.1095 - val_accuracy: 0.9259
# Epoch 38/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2775 - accuracy: 0.5696 - val_loss: 0.1048 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2700 - accuracy: 0.5708 - val_loss: 0.0987 - val_accuracy: 0.9630
# Epoch 40/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2608 - accuracy: 0.5708 - val_loss: 0.1328 - val_accuracy: 0.9259
# Epoch 41/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2742 - accuracy: 0.5708 - val_loss: 0.1298 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2702 - accuracy: 0.5708 - val_loss: 0.1335 - val_accuracy: 0.9630
# Epoch 43/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2646 - accuracy: 0.5708 - val_loss: 0.1371 - val_accuracy: 0.9630
# Epoch 44/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2755 - accuracy: 0.5708 - val_loss: 0.1341 - val_accuracy: 0.9259
# Epoch 45/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2727 - accuracy: 0.5685 - val_loss: 0.1939 - val_accuracy: 0.9259
# Epoch 46/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2712 - accuracy: 0.5696 - val_loss: 0.1515 - val_accuracy: 0.9630
# Epoch 47/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2661 - accuracy: 0.5708 - val_loss: 0.1480 - val_accuracy: 0.9630
# Epoch 48/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2556 - accuracy: 0.5708 - val_loss: 0.1326 - val_accuracy: 0.9630
# Epoch 49/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2588 - accuracy: 0.5708 - val_loss: 0.1125 - val_accuracy: 0.9630
# Epoch 50/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2623 - accuracy: 0.5708 - val_loss: 0.1507 - val_accuracy: 0.9630
# Epoch 51/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2639 - accuracy: 0.5708 - val_loss: 0.1278 - val_accuracy: 0.9259
# Epoch 52/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2623 - accuracy: 0.5708 - val_loss: 0.1165 - val_accuracy: 0.9630
# Epoch 53/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2659 - accuracy: 0.5708 - val_loss: 0.1359 - val_accuracy: 0.9259
# Epoch 54/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2632 - accuracy: 0.5708 - val_loss: 0.1297 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 19ms/step - loss: 0.1700 - accuracy: 0.9118
# Epoch 1/100
# 28/28 [==============================] - 5s 60ms/step - loss: 0.5644 - accuracy: 0.5080 - val_loss: 0.4898 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.4344 - accuracy: 0.5483 - val_loss: 0.3639 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3905 - accuracy: 0.5563 - val_loss: 0.2952 - val_accuracy: 0.9259
# Epoch 4/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3732 - accuracy: 0.5598 - val_loss: 0.2812 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3438 - accuracy: 0.5644 - val_loss: 0.2268 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3344 - accuracy: 0.5713 - val_loss: 0.2328 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3256 - accuracy: 0.5724 - val_loss: 0.2561 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.3216 - accuracy: 0.5736 - val_loss: 0.2000 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3173 - accuracy: 0.5747 - val_loss: 0.3286 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3114 - accuracy: 0.5770 - val_loss: 0.3159 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3111 - accuracy: 0.5736 - val_loss: 0.2644 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2997 - accuracy: 0.5770 - val_loss: 0.2718 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3127 - accuracy: 0.5782 - val_loss: 0.2139 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2970 - accuracy: 0.5770 - val_loss: 0.2311 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2954 - accuracy: 0.5793 - val_loss: 0.2058 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2969 - accuracy: 0.5793 - val_loss: 0.1951 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2955 - accuracy: 0.5793 - val_loss: 0.2619 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2965 - accuracy: 0.5759 - val_loss: 0.2086 - val_accuracy: 0.9259
# Epoch 19/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2855 - accuracy: 0.5793 - val_loss: 0.2157 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2920 - accuracy: 0.5793 - val_loss: 0.2458 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2872 - accuracy: 0.5793 - val_loss: 0.2132 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2857 - accuracy: 0.5782 - val_loss: 0.2588 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2794 - accuracy: 0.5793 - val_loss: 0.1831 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2789 - accuracy: 0.5770 - val_loss: 0.1865 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2837 - accuracy: 0.5793 - val_loss: 0.2033 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2805 - accuracy: 0.5793 - val_loss: 0.2372 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2842 - accuracy: 0.5782 - val_loss: 0.2517 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2808 - accuracy: 0.5782 - val_loss: 0.2858 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2733 - accuracy: 0.5793 - val_loss: 0.1939 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2749 - accuracy: 0.5793 - val_loss: 0.2627 - val_accuracy: 0.9259
# Epoch 31/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2793 - accuracy: 0.5770 - val_loss: 0.2664 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2687 - accuracy: 0.5793 - val_loss: 0.2534 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2603 - accuracy: 0.5782 - val_loss: 0.2353 - val_accuracy: 0.9259
# Epoch 34/100
# 28/28 [==============================] - 1s 32ms/step - loss: 0.2714 - accuracy: 0.5770 - val_loss: 0.1919 - val_accuracy: 0.9259
# Epoch 35/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2659 - accuracy: 0.5782 - val_loss: 0.1720 - val_accuracy: 0.8889
# Epoch 36/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2665 - accuracy: 0.5782 - val_loss: 0.1849 - val_accuracy: 0.8889
# Epoch 37/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2657 - accuracy: 0.5793 - val_loss: 0.2261 - val_accuracy: 0.9259
# Epoch 38/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2752 - accuracy: 0.5782 - val_loss: 0.2377 - val_accuracy: 0.9259
# Epoch 39/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2689 - accuracy: 0.5793 - val_loss: 0.2369 - val_accuracy: 0.9259
# Epoch 40/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2692 - accuracy: 0.5759 - val_loss: 0.2541 - val_accuracy: 0.9259
# Epoch 41/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2632 - accuracy: 0.5793 - val_loss: 0.2287 - val_accuracy: 0.9259
# Epoch 42/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2561 - accuracy: 0.5793 - val_loss: 0.3028 - val_accuracy: 0.9259
# Epoch 43/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2549 - accuracy: 0.5793 - val_loss: 0.2655 - val_accuracy: 0.9259
# Epoch 44/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2605 - accuracy: 0.5793 - val_loss: 0.2472 - val_accuracy: 0.9259
# Epoch 45/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2584 - accuracy: 0.5782 - val_loss: 0.2365 - val_accuracy: 0.9259
# Epoch 46/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2580 - accuracy: 0.5793 - val_loss: 0.2824 - val_accuracy: 0.9259
# Epoch 47/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2595 - accuracy: 0.5770 - val_loss: 0.2344 - val_accuracy: 0.9259
# Epoch 48/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2592 - accuracy: 0.5793 - val_loss: 0.2009 - val_accuracy: 0.9259
# Epoch 49/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2519 - accuracy: 0.5793 - val_loss: 0.2245 - val_accuracy: 0.9259
# Epoch 50/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2538 - accuracy: 0.5793 - val_loss: 0.1851 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 14ms/step - loss: 0.2287 - accuracy: 0.8824
# [0.8941176414489747, 0.9, 0.9294117569923401, 0.9176470518112183, 0.9176470398902893]
# [0.8670561304765745, 0.8783337526953087, 0.9148447351805353, 0.9030642722987773, 0.9044230672512061]
# Mean test accuracy is 0.91, mean test f1 score is 0.89, max test accuracy is 0.93, max test f1 score is 0.91, min test accuracy is 0.89, min test f1 score is 0.87, std of test accuracy is 0.01, std of test f1 score is 0.02
# Time elapsed through all process: 1300.19, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# Out:
# Mean test accuracy is 0.912, mean test f1 score is 0.894, max test accuracy is 0.929, max test f1 score is 0.915, min test accuracy is 0.894, min test f1 score is 0.867, std of test accuracy is 0.013, std of test f1 score is 0.018
