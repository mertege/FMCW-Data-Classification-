# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/Range-Doppler-Spectrogram-LSTM/RD_SP_LSTM_denseunit128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5 # 0.
repeat_of_mixup = 5
number_of_repeat = 5
unit_number_of_lstm = 16 #8 16 32
dense_unit_of_range_doppler_function = 128 #128 256 512
dense_unit_of_spectrogram_function = 8
decoder_dense_unit = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_range_doppler_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def lstm_encoder_network_2(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_spectrogram_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense_unit)(input)
      x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_lstm(range_doppler_input)

    input_shape = spectrogram_concat_shuffle_train.shape[1:3]
    base_network_lstm_2 = lstm_encoder_network_2(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_lstm_2(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(base_network_lstm_2.summary())
      print(base_decoder_network.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image, spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler, validation_spectrogram) , (spectrogram_validation_labels)))
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 136)]             0
#
#  dense_2 (Dense)             (None, 256)               35072
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 52,609
# Trainable params: 52,097
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 19s 384ms/step - loss: 0.5393 - accuracy: 0.4988 - val_loss: 0.5891 - val_accuracy: 0.7407
# Epoch 2/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.4267 - accuracy: 0.5343 - val_loss: 0.5870 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3712 - accuracy: 0.5556 - val_loss: 0.4103 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3576 - accuracy: 0.5686 - val_loss: 0.2694 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3518 - accuracy: 0.5745 - val_loss: 0.3395 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3442 - accuracy: 0.5757 - val_loss: 0.1983 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3246 - accuracy: 0.5780 - val_loss: 0.1795 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.3196 - accuracy: 0.5816 - val_loss: 0.1351 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3062 - accuracy: 0.5839 - val_loss: 0.2558 - val_accuracy: 0.8519
# Epoch 10/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2909 - accuracy: 0.5839 - val_loss: 0.1538 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2959 - accuracy: 0.5863 - val_loss: 0.1208 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2910 - accuracy: 0.5839 - val_loss: 0.2340 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2914 - accuracy: 0.5827 - val_loss: 0.2714 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2906 - accuracy: 0.5839 - val_loss: 0.2741 - val_accuracy: 0.8519
# Epoch 15/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2842 - accuracy: 0.5827 - val_loss: 0.2061 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2803 - accuracy: 0.5851 - val_loss: 0.1525 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2752 - accuracy: 0.5863 - val_loss: 0.1379 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2768 - accuracy: 0.5863 - val_loss: 0.2576 - val_accuracy: 0.8889
# Epoch 19/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2754 - accuracy: 0.5863 - val_loss: 0.2345 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2746 - accuracy: 0.5863 - val_loss: 0.2296 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2714 - accuracy: 0.5863 - val_loss: 0.1405 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2701 - accuracy: 0.5863 - val_loss: 0.1713 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2658 - accuracy: 0.5863 - val_loss: 0.1390 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2704 - accuracy: 0.5863 - val_loss: 0.1909 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2714 - accuracy: 0.5851 - val_loss: 0.1704 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2631 - accuracy: 0.5863 - val_loss: 0.2225 - val_accuracy: 0.8889
# 2/2 [==============================] - 2s 126ms/step - loss: 0.1381 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 136)]             0
#
#  dense_2 (Dense)             (None, 256)               35072
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 52,609
# Trainable params: 52,097
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 381ms/step - loss: 0.5096 - accuracy: 0.5141 - val_loss: 0.6136 - val_accuracy: 0.7407
# Epoch 2/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.4158 - accuracy: 0.5528 - val_loss: 0.4878 - val_accuracy: 0.7407
# Epoch 3/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3720 - accuracy: 0.5587 - val_loss: 0.2636 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.3454 - accuracy: 0.5622 - val_loss: 0.2871 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3290 - accuracy: 0.5646 - val_loss: 0.3159 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3341 - accuracy: 0.5669 - val_loss: 0.2348 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3048 - accuracy: 0.5704 - val_loss: 0.2329 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3130 - accuracy: 0.5739 - val_loss: 0.1949 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3043 - accuracy: 0.5728 - val_loss: 0.2106 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2983 - accuracy: 0.5739 - val_loss: 0.1967 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2900 - accuracy: 0.5751 - val_loss: 0.1876 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2937 - accuracy: 0.5751 - val_loss: 0.2101 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2893 - accuracy: 0.5751 - val_loss: 0.1764 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2816 - accuracy: 0.5728 - val_loss: 0.1918 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2825 - accuracy: 0.5728 - val_loss: 0.2008 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2871 - accuracy: 0.5728 - val_loss: 0.2071 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2768 - accuracy: 0.5751 - val_loss: 0.1807 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2869 - accuracy: 0.5751 - val_loss: 0.1813 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2811 - accuracy: 0.5751 - val_loss: 0.1777 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2871 - accuracy: 0.5751 - val_loss: 0.1604 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2737 - accuracy: 0.5739 - val_loss: 0.1594 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2692 - accuracy: 0.5751 - val_loss: 0.2150 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2684 - accuracy: 0.5751 - val_loss: 0.1956 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2711 - accuracy: 0.5751 - val_loss: 0.1526 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2757 - accuracy: 0.5739 - val_loss: 0.2005 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2706 - accuracy: 0.5739 - val_loss: 0.1622 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2664 - accuracy: 0.5751 - val_loss: 0.2191 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2675 - accuracy: 0.5751 - val_loss: 0.1902 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2618 - accuracy: 0.5739 - val_loss: 0.2208 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2651 - accuracy: 0.5751 - val_loss: 0.2026 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2652 - accuracy: 0.5751 - val_loss: 0.2073 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2618 - accuracy: 0.5739 - val_loss: 0.2086 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2646 - accuracy: 0.5751 - val_loss: 0.1517 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2661 - accuracy: 0.5751 - val_loss: 0.1464 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2559 - accuracy: 0.5751 - val_loss: 0.2505 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2646 - accuracy: 0.5751 - val_loss: 0.2301 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2607 - accuracy: 0.5751 - val_loss: 0.2703 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2559 - accuracy: 0.5739 - val_loss: 0.1509 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2566 - accuracy: 0.5751 - val_loss: 0.1727 - val_accuracy: 0.9630
# Epoch 40/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2610 - accuracy: 0.5751 - val_loss: 0.2685 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2530 - accuracy: 0.5751 - val_loss: 0.2033 - val_accuracy: 0.9630
# Epoch 42/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2494 - accuracy: 0.5751 - val_loss: 0.1618 - val_accuracy: 0.9630
# Epoch 43/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2582 - accuracy: 0.5751 - val_loss: 0.2101 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2518 - accuracy: 0.5751 - val_loss: 0.1769 - val_accuracy: 0.9630
# Epoch 45/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2555 - accuracy: 0.5751 - val_loss: 0.1612 - val_accuracy: 0.9630
# Epoch 46/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2587 - accuracy: 0.5751 - val_loss: 0.1756 - val_accuracy: 0.9630
# Epoch 47/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2545 - accuracy: 0.5751 - val_loss: 0.1937 - val_accuracy: 0.9630
# Epoch 48/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2505 - accuracy: 0.5751 - val_loss: 0.1638 - val_accuracy: 0.9630
# Epoch 49/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2497 - accuracy: 0.5751 - val_loss: 0.1928 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 121ms/step - loss: 0.1852 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 136)]             0
#
#  dense_2 (Dense)             (None, 256)               35072
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 52,609
# Trainable params: 52,097
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 17s 379ms/step - loss: 0.5187 - accuracy: 0.4966 - val_loss: 0.1633 - val_accuracy: 0.9630
# Epoch 2/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.4155 - accuracy: 0.5541 - val_loss: 0.1654 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3734 - accuracy: 0.5732 - val_loss: 0.1551 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.3519 - accuracy: 0.5743 - val_loss: 0.1602 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3205 - accuracy: 0.5800 - val_loss: 0.2325 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.3141 - accuracy: 0.5878 - val_loss: 0.1528 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2988 - accuracy: 0.5912 - val_loss: 0.2238 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2925 - accuracy: 0.5912 - val_loss: 0.1815 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3021 - accuracy: 0.5912 - val_loss: 0.1381 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2853 - accuracy: 0.5901 - val_loss: 0.1967 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2945 - accuracy: 0.5890 - val_loss: 0.1640 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2772 - accuracy: 0.5923 - val_loss: 0.1677 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2749 - accuracy: 0.5912 - val_loss: 0.0794 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2719 - accuracy: 0.5923 - val_loss: 0.1135 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2691 - accuracy: 0.5912 - val_loss: 0.1004 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2657 - accuracy: 0.5923 - val_loss: 0.0997 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2591 - accuracy: 0.5923 - val_loss: 0.1277 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2688 - accuracy: 0.5901 - val_loss: 0.1640 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2566 - accuracy: 0.5923 - val_loss: 0.1060 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2549 - accuracy: 0.5923 - val_loss: 0.1147 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2581 - accuracy: 0.5923 - val_loss: 0.1245 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2561 - accuracy: 0.5923 - val_loss: 0.1236 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2582 - accuracy: 0.5923 - val_loss: 0.0835 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2627 - accuracy: 0.5912 - val_loss: 0.0957 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2608 - accuracy: 0.5912 - val_loss: 0.1293 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2501 - accuracy: 0.5923 - val_loss: 0.1163 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2588 - accuracy: 0.5923 - val_loss: 0.1246 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2569 - accuracy: 0.5912 - val_loss: 0.1184 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 124ms/step - loss: 0.0783 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 136)]             0
#
#  dense_2 (Dense)             (None, 256)               35072
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 52,609
# Trainable params: 52,097
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 382ms/step - loss: 0.4808 - accuracy: 0.5233 - val_loss: 0.6297 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3721 - accuracy: 0.5688 - val_loss: 0.4470 - val_accuracy: 0.8519
# Epoch 3/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3436 - accuracy: 0.5909 - val_loss: 0.2767 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.3416 - accuracy: 0.5862 - val_loss: 0.1810 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3196 - accuracy: 0.5909 - val_loss: 0.1788 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.3081 - accuracy: 0.5874 - val_loss: 0.2128 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2937 - accuracy: 0.5991 - val_loss: 0.1232 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2909 - accuracy: 0.6002 - val_loss: 0.1443 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2893 - accuracy: 0.6002 - val_loss: 0.1375 - val_accuracy: 1.0000
# Epoch 10/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2844 - accuracy: 0.5979 - val_loss: 0.1406 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2783 - accuracy: 0.6002 - val_loss: 0.1682 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2732 - accuracy: 0.5991 - val_loss: 0.1536 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2622 - accuracy: 0.6014 - val_loss: 0.1524 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2689 - accuracy: 0.5991 - val_loss: 0.1489 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2575 - accuracy: 0.6014 - val_loss: 0.1203 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2620 - accuracy: 0.6014 - val_loss: 0.1198 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2722 - accuracy: 0.6002 - val_loss: 0.1301 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2689 - accuracy: 0.6014 - val_loss: 0.0941 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2586 - accuracy: 0.6014 - val_loss: 0.0934 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2599 - accuracy: 0.6014 - val_loss: 0.0826 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2572 - accuracy: 0.6014 - val_loss: 0.1735 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2555 - accuracy: 0.6014 - val_loss: 0.1162 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2586 - accuracy: 0.6014 - val_loss: 0.1387 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2595 - accuracy: 0.6014 - val_loss: 0.0984 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2590 - accuracy: 0.6014 - val_loss: 0.1119 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2581 - accuracy: 0.6002 - val_loss: 0.1931 - val_accuracy: 0.8889
# Epoch 27/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2483 - accuracy: 0.6014 - val_loss: 0.2033 - val_accuracy: 0.8889
# Epoch 28/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2496 - accuracy: 0.6014 - val_loss: 0.1366 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2480 - accuracy: 0.6014 - val_loss: 0.1521 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2536 - accuracy: 0.6014 - val_loss: 0.2280 - val_accuracy: 0.8889
# Epoch 31/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2484 - accuracy: 0.6014 - val_loss: 0.1972 - val_accuracy: 0.8889
# Epoch 32/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2505 - accuracy: 0.6014 - val_loss: 0.1152 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2491 - accuracy: 0.6014 - val_loss: 0.1266 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2479 - accuracy: 0.6014 - val_loss: 0.1129 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2457 - accuracy: 0.6014 - val_loss: 0.1258 - val_accuracy: 0.9259
# 2/2 [==============================] - 2s 124ms/step - loss: 0.2483 - accuracy: 0.8824
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 136)]             0
#
#  dense_2 (Dense)             (None, 256)               35072
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 52,609
# Trainable params: 52,097
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 382ms/step - loss: 0.5249 - accuracy: 0.4918 - val_loss: 0.7692 - val_accuracy: 0.6667
# Epoch 2/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.4330 - accuracy: 0.5245 - val_loss: 0.5588 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.4021 - accuracy: 0.5431 - val_loss: 0.2960 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3592 - accuracy: 0.5536 - val_loss: 0.2691 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3435 - accuracy: 0.5606 - val_loss: 0.2375 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3356 - accuracy: 0.5618 - val_loss: 0.2373 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3327 - accuracy: 0.5629 - val_loss: 0.1580 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.3203 - accuracy: 0.5676 - val_loss: 0.1781 - val_accuracy: 0.8519
# Epoch 9/100
# ...
# Epoch 18/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2812 - accuracy: 0.5731 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2835 - accuracy: 0.5731 - val_loss: 0.0467 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2822 - accuracy: 0.5731 - val_loss: 0.0621 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2827 - accuracy: 0.5731 - val_loss: 0.0506 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2739 - accuracy: 0.5731 - val_loss: 0.0612 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2800 - accuracy: 0.5719 - val_loss: 0.0413 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2807 - accuracy: 0.5731 - val_loss: 0.0569 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2763 - accuracy: 0.5731 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2802 - accuracy: 0.5731 - val_loss: 0.0613 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2765 - accuracy: 0.5731 - val_loss: 0.0579 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2726 - accuracy: 0.5731 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2695 - accuracy: 0.5731 - val_loss: 0.0489 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2720 - accuracy: 0.5731 - val_loss: 0.0620 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2658 - accuracy: 0.5731 - val_loss: 0.0485 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2727 - accuracy: 0.5731 - val_loss: 0.0681 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2789 - accuracy: 0.5731 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2649 - accuracy: 0.5731 - val_loss: 0.0475 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2720 - accuracy: 0.5731 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2673 - accuracy: 0.5731 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2661 - accuracy: 0.5731 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2639 - accuracy: 0.5731 - val_loss: 0.0546 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 123ms/step - loss: 0.1223 - accuracy: 0.9412
# Epoch 1/100
# 27/27 [==============================] - 16s 382ms/step - loss: 0.4969 - accuracy: 0.5128 - val_loss: 0.4094 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.4189 - accuracy: 0.5361 - val_loss: 0.3236 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3791 - accuracy: 0.5548 - val_loss: 0.2473 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3480 - accuracy: 0.5606 - val_loss: 0.2319 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3517 - accuracy: 0.5606 - val_loss: 0.2862 - val_accuracy: 0.8148
# Epoch 6/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3271 - accuracy: 0.5711 - val_loss: 0.3675 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3274 - accuracy: 0.5734 - val_loss: 0.2271 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3141 - accuracy: 0.5699 - val_loss: 0.1971 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3091 - accuracy: 0.5711 - val_loss: 0.2632 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.3070 - accuracy: 0.5711 - val_loss: 0.1724 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3048 - accuracy: 0.5723 - val_loss: 0.1848 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.3014 - accuracy: 0.5758 - val_loss: 0.2150 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2912 - accuracy: 0.5746 - val_loss: 0.1408 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2902 - accuracy: 0.5746 - val_loss: 0.1869 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2824 - accuracy: 0.5746 - val_loss: 0.1345 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2788 - accuracy: 0.5758 - val_loss: 0.1611 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2810 - accuracy: 0.5758 - val_loss: 0.1555 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2758 - accuracy: 0.5758 - val_loss: 0.1378 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2806 - accuracy: 0.5758 - val_loss: 0.1617 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2697 - accuracy: 0.5758 - val_loss: 0.0699 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2789 - accuracy: 0.5758 - val_loss: 0.1860 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2734 - accuracy: 0.5758 - val_loss: 0.1230 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2746 - accuracy: 0.5758 - val_loss: 0.0926 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2695 - accuracy: 0.5758 - val_loss: 0.1293 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2651 - accuracy: 0.5758 - val_loss: 0.0869 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2736 - accuracy: 0.5758 - val_loss: 0.1494 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2699 - accuracy: 0.5734 - val_loss: 0.1372 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2690 - accuracy: 0.5758 - val_loss: 0.1229 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2694 - accuracy: 0.5758 - val_loss: 0.1011 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2722 - accuracy: 0.5758 - val_loss: 0.0919 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2576 - accuracy: 0.5758 - val_loss: 0.1314 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2710 - accuracy: 0.5758 - val_loss: 0.2061 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2655 - accuracy: 0.5758 - val_loss: 0.1196 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2570 - accuracy: 0.5758 - val_loss: 0.1195 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2565 - accuracy: 0.5758 - val_loss: 0.1449 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 122ms/step - loss: 0.0947 - accuracy: 1.0000
# Epoch 1/100
# 27/27 [==============================] - 17s 383ms/step - loss: 0.5466 - accuracy: 0.4883 - val_loss: 0.5826 - val_accuracy: 0.7037
# Epoch 2/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.4137 - accuracy: 0.5516 - val_loss: 0.5254 - val_accuracy: 0.7037
# Epoch 3/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3799 - accuracy: 0.5610 - val_loss: 0.3918 - val_accuracy: 0.7778
# Epoch 4/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3461 - accuracy: 0.5739 - val_loss: 0.4229 - val_accuracy: 0.7778
# Epoch 5/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3391 - accuracy: 0.5763 - val_loss: 0.2990 - val_accuracy: 0.8148
# Epoch 6/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3313 - accuracy: 0.5822 - val_loss: 0.2448 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3273 - accuracy: 0.5822 - val_loss: 0.2187 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3092 - accuracy: 0.5822 - val_loss: 0.2633 - val_accuracy: 0.8519
# Epoch 9/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2963 - accuracy: 0.5857 - val_loss: 0.2004 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3013 - accuracy: 0.5857 - val_loss: 0.2396 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.3000 - accuracy: 0.5833 - val_loss: 0.2364 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2831 - accuracy: 0.5857 - val_loss: 0.1945 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2821 - accuracy: 0.5857 - val_loss: 0.1554 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2864 - accuracy: 0.5857 - val_loss: 0.2117 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2849 - accuracy: 0.5857 - val_loss: 0.1688 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2763 - accuracy: 0.5857 - val_loss: 0.2321 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2711 - accuracy: 0.5869 - val_loss: 0.2669 - val_accuracy: 0.8519
# Epoch 18/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2819 - accuracy: 0.5857 - val_loss: 0.2193 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2726 - accuracy: 0.5857 - val_loss: 0.1897 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2794 - accuracy: 0.5857 - val_loss: 0.1806 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2667 - accuracy: 0.5869 - val_loss: 0.2639 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2653 - accuracy: 0.5869 - val_loss: 0.1705 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2666 - accuracy: 0.5869 - val_loss: 0.1713 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2657 - accuracy: 0.5869 - val_loss: 0.1965 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2560 - accuracy: 0.5869 - val_loss: 0.1770 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2656 - accuracy: 0.5869 - val_loss: 0.1913 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2690 - accuracy: 0.5869 - val_loss: 0.2772 - val_accuracy: 0.8519
# Epoch 28/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2651 - accuracy: 0.5869 - val_loss: 0.2202 - val_accuracy: 0.8889
# 2/2 [==============================] - 2s 130ms/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 1/100
# 28/28 [==============================] - 17s 381ms/step - loss: 0.5508 - accuracy: 0.4888 - val_loss: 0.2523 - val_accuracy: 0.9259
# Epoch 2/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.4166 - accuracy: 0.5515 - val_loss: 0.2232 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.3685 - accuracy: 0.5749 - val_loss: 0.1857 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3474 - accuracy: 0.5828 - val_loss: 0.1849 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.3173 - accuracy: 0.5962 - val_loss: 0.1490 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.3141 - accuracy: 0.5951 - val_loss: 0.1383 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.3015 - accuracy: 0.5973 - val_loss: 0.3062 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.3001 - accuracy: 0.5996 - val_loss: 0.1085 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2803 - accuracy: 0.5984 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2857 - accuracy: 0.6018 - val_loss: 0.1096 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2758 - accuracy: 0.5984 - val_loss: 0.1603 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2806 - accuracy: 0.6007 - val_loss: 0.1500 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2783 - accuracy: 0.6018 - val_loss: 0.1963 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2751 - accuracy: 0.6007 - val_loss: 0.1970 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2718 - accuracy: 0.6018 - val_loss: 0.2251 - val_accuracy: 0.8889
# Epoch 16/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2632 - accuracy: 0.6018 - val_loss: 0.1038 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2681 - accuracy: 0.6018 - val_loss: 0.1309 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2602 - accuracy: 0.6007 - val_loss: 0.1240 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2603 - accuracy: 0.6018 - val_loss: 0.1217 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2601 - accuracy: 0.6018 - val_loss: 0.2050 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2605 - accuracy: 0.6018 - val_loss: 0.2588 - val_accuracy: 0.8889
# Epoch 22/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2534 - accuracy: 0.6018 - val_loss: 0.1543 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2647 - accuracy: 0.6018 - val_loss: 0.1545 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2594 - accuracy: 0.6018 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 25/100
# 24/28 [========================>.....] - ETA: 1s - loss: 0.2580 - accuracy: 0.5990

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.960, mean test f1 score is 0.952, max test accuracy is 0.971, max test f1 score is 0.965, min test accuracy is 0.935, min test f1 score is 0.926, std of test accuracy is 0.013, std of test f1 score is 0.013
# Time elapsed through all process: 9692.637, sec

# %%
import numpy as np
import matplotlib.pyplot as plt
def createList(n):
    lst = []
    for i in range(n+1):
        lst.append(i)
    return(lst)


folds = createList(4)
values = [element * 100 for element in test_accuracy_per_fold]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(folds, values, color ='black',
        width = 0.4)
plt.xlabel("Accuracy vs k-run")
plt.ylabel("Accuracy")
plt.show()

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(folds, f1_score_per_fold, color ='black',
        width = 0.4)
plt.xlabel("F1 Score vs k-run")
plt.ylabel("F1 Score")
plt.show()
