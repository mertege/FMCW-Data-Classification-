# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_LSTM_v2_32hiddenunit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# unit_number_of_lstm -32
# 5 repeats- Mean test accuracy is 0.96, mean test f1 score is 0.95, max test accuracy is 0.97, max test f1 score is 0.97, min test accuracy is 0.94, min test f1 score is 0.93, std of test accuracy is 0.01, std of test f1 score is 0.01
#Time elapsed through all process: 9635.15, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resizedv2.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resizedv2.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resizedv2.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 32
dense_unit_of_lstm_function = 256
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 64)         21760
#  l)
#
#  flatten (Flatten)           (None, 327680)            0
#
#  batch_normalization (BatchN  (None, 327680)           1310720
#  ormalization)
#
#  dropout (Dropout)           (None, 327680)            0
#
#  dense (Dense)               (None, 256)               83886336
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 85,219,840
# Trainable params: 84,563,968
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               85219840
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 85,302,145
# Trainable params: 84,646,273
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 16s 356ms/step - loss: 0.5856 - accuracy: 0.4653 - val_loss: 0.2410 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.4202 - accuracy: 0.5313 - val_loss: 0.1887 - val_accuracy: 1.0000
# Epoch 3/100
# 28/28 [==============================] - 9s 308ms/step - loss: 0.3787 - accuracy: 0.5537 - val_loss: 0.3701 - val_accuracy: 0.8148
# Epoch 4/100
# 28/28 [==============================] - 9s 310ms/step - loss: 0.3678 - accuracy: 0.5537 - val_loss: 0.1979 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.3615 - accuracy: 0.5593 - val_loss: 0.2231 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3409 - accuracy: 0.5559 - val_loss: 0.2888 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3178 - accuracy: 0.5626 - val_loss: 0.3131 - val_accuracy: 0.8519
# Epoch 8/100
# 28/28 [==============================] - 9s 315ms/step - loss: 0.3151 - accuracy: 0.5638 - val_loss: 0.1702 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.3100 - accuracy: 0.5638 - val_loss: 0.1720 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 9s 313ms/step - loss: 0.3061 - accuracy: 0.5649 - val_loss: 0.1441 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3001 - accuracy: 0.5649 - val_loss: 0.1658 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 314ms/step - loss: 0.3038 - accuracy: 0.5660 - val_loss: 0.0865 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2978 - accuracy: 0.5626 - val_loss: 0.1379 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2833 - accuracy: 0.5660 - val_loss: 0.1200 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2848 - accuracy: 0.5649 - val_loss: 0.1183 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2872 - accuracy: 0.5660 - val_loss: 0.2258 - val_accuracy: 0.8889
# Epoch 17/100
# 28/28 [==============================] - 9s 308ms/step - loss: 0.2875 - accuracy: 0.5660 - val_loss: 0.1737 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 313ms/step - loss: 0.2898 - accuracy: 0.5660 - val_loss: 0.0845 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2836 - accuracy: 0.5649 - val_loss: 0.1279 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2813 - accuracy: 0.5660 - val_loss: 0.0926 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2791 - accuracy: 0.5660 - val_loss: 0.1322 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2777 - accuracy: 0.5660 - val_loss: 0.1334 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2791 - accuracy: 0.5660 - val_loss: 0.1312 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2799 - accuracy: 0.5649 - val_loss: 0.0956 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.2752 - accuracy: 0.5660 - val_loss: 0.0655 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2723 - accuracy: 0.5660 - val_loss: 0.1418 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2795 - accuracy: 0.5649 - val_loss: 0.0724 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2722 - accuracy: 0.5660 - val_loss: 0.1875 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2770 - accuracy: 0.5660 - val_loss: 0.3680 - val_accuracy: 0.8148
# Epoch 30/100
# 28/28 [==============================] - 9s 308ms/step - loss: 0.2747 - accuracy: 0.5660 - val_loss: 0.1116 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2735 - accuracy: 0.5660 - val_loss: 0.1229 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2679 - accuracy: 0.5660 - val_loss: 0.1322 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2673 - accuracy: 0.5660 - val_loss: 0.1008 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2657 - accuracy: 0.5660 - val_loss: 0.0709 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2650 - accuracy: 0.5660 - val_loss: 0.0776 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 9s 308ms/step - loss: 0.2652 - accuracy: 0.5660 - val_loss: 0.1149 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2588 - accuracy: 0.5660 - val_loss: 0.1909 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2565 - accuracy: 0.5660 - val_loss: 0.2115 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2626 - accuracy: 0.5660 - val_loss: 0.1904 - val_accuracy: 0.9630
# Epoch 40/100
# 28/28 [==============================] - 9s 310ms/step - loss: 0.2640 - accuracy: 0.5660 - val_loss: 0.1037 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 125ms/step - loss: 0.1132 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 64)         21760
#  l)
#
#  flatten (Flatten)           (None, 327680)            0
#
#  batch_normalization (BatchN  (None, 327680)           1310720
#  ormalization)
#
#  dropout (Dropout)           (None, 327680)            0
#
#  dense (Dense)               (None, 256)               83886336
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 85,219,840
# Trainable params: 84,563,968
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               85219840
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 85,302,145
# Trainable params: 84,646,273
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 13s 344ms/step - loss: 0.5846 - accuracy: 0.4817 - val_loss: 0.5006 - val_accuracy: 0.7407
# Epoch 2/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.4500 - accuracy: 0.5365 - val_loss: 0.1955 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3841 - accuracy: 0.5639 - val_loss: 0.2530 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.3690 - accuracy: 0.5674 - val_loss: 0.1734 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3620 - accuracy: 0.5662 - val_loss: 0.1773 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 310ms/step - loss: 0.3435 - accuracy: 0.5742 - val_loss: 0.1558 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.3243 - accuracy: 0.5731 - val_loss: 0.1420 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.3152 - accuracy: 0.5833 - val_loss: 0.1306 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.3191 - accuracy: 0.5822 - val_loss: 0.1558 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.3098 - accuracy: 0.5822 - val_loss: 0.1540 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.2976 - accuracy: 0.5833 - val_loss: 0.1241 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.2889 - accuracy: 0.5856 - val_loss: 0.1183 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.2773 - accuracy: 0.5868 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2886 - accuracy: 0.5856 - val_loss: 0.1164 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2824 - accuracy: 0.5845 - val_loss: 0.1320 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.2790 - accuracy: 0.5845 - val_loss: 0.0701 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.2793 - accuracy: 0.5868 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2795 - accuracy: 0.5833 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2699 - accuracy: 0.5868 - val_loss: 0.0756 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2790 - accuracy: 0.5856 - val_loss: 0.0570 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2691 - accuracy: 0.5868 - val_loss: 0.1027 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2651 - accuracy: 0.5868 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2690 - accuracy: 0.5856 - val_loss: 0.0631 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2635 - accuracy: 0.5868 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.2661 - accuracy: 0.5868 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2609 - accuracy: 0.5868 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2598 - accuracy: 0.5868 - val_loss: 0.0615 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2703 - accuracy: 0.5868 - val_loss: 0.1941 - val_accuracy: 0.8889
# Epoch 29/100
# 28/28 [==============================] - 8s 304ms/step - loss: 0.2615 - accuracy: 0.5868 - val_loss: 0.0939 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2585 - accuracy: 0.5868 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2643 - accuracy: 0.5868 - val_loss: 0.1670 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 9s 304ms/step - loss: 0.2629 - accuracy: 0.5868 - val_loss: 0.0658 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2590 - accuracy: 0.5856 - val_loss: 0.0691 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.2571 - accuracy: 0.5868 - val_loss: 0.0374 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2525 - accuracy: 0.5868 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2531 - accuracy: 0.5868 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2704 - accuracy: 0.5868 - val_loss: 0.0439 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2630 - accuracy: 0.5856 - val_loss: 0.0946 - val_accuracy: 0.9259
# Epoch 39/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2568 - accuracy: 0.5868 - val_loss: 0.0992 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2570 - accuracy: 0.5868 - val_loss: 0.0558 - val_accuracy: 0.9630
# Epoch 41/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2557 - accuracy: 0.5868 - val_loss: 0.0762 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2506 - accuracy: 0.5868 - val_loss: 0.0828 - val_accuracy: 1.0000
# Epoch 43/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.2578 - accuracy: 0.5868 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2527 - accuracy: 0.5868 - val_loss: 0.0546 - val_accuracy: 1.0000
# Epoch 45/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2546 - accuracy: 0.5868 - val_loss: 0.1161 - val_accuracy: 1.0000
# Epoch 46/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2506 - accuracy: 0.5868 - val_loss: 0.0685 - val_accuracy: 0.9630
# Epoch 47/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2483 - accuracy: 0.5868 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 48/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2497 - accuracy: 0.5868 - val_loss: 0.1020 - val_accuracy: 1.0000
# Epoch 49/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2450 - accuracy: 0.5868 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 50/100
# 28/28 [==============================] - 9s 304ms/step - loss: 0.2564 - accuracy: 0.5868 - val_loss: 0.1016 - val_accuracy: 1.0000
# Epoch 51/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2512 - accuracy: 0.5868 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 52/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2479 - accuracy: 0.5868 - val_loss: 0.0966 - val_accuracy: 0.9630
# Epoch 53/100
# 28/28 [==============================] - 9s 304ms/step - loss: 0.2642 - accuracy: 0.5856 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 54/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2438 - accuracy: 0.5868 - val_loss: 0.0754 - val_accuracy: 0.9630
# Epoch 55/100
# 28/28 [==============================] - 9s 304ms/step - loss: 0.2476 - accuracy: 0.5868 - val_loss: 0.0729 - val_accuracy: 1.0000
# Epoch 56/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2438 - accuracy: 0.5868 - val_loss: 0.1392 - val_accuracy: 0.9630
# Epoch 57/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2485 - accuracy: 0.5868 - val_loss: 0.0832 - val_accuracy: 0.9630
# Epoch 58/100
# 28/28 [==============================] - 9s 309ms/step - loss: 0.2467 - accuracy: 0.5868 - val_loss: 0.1582 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 120ms/step - loss: 0.0626 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 64)         21760
#  l)
#
#  flatten (Flatten)           (None, 327680)            0
#
#  batch_normalization (BatchN  (None, 327680)           1310720
#  ormalization)
#
#  dropout (Dropout)           (None, 327680)            0
#
#  dense (Dense)               (None, 256)               83886336
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 85,219,840
# Trainable params: 84,563,968
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               85219840
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 85,302,145
# Trainable params: 84,646,273
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 346ms/step - loss: 0.4686 - accuracy: 0.5211 - val_loss: 0.7759 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.3910 - accuracy: 0.5411 - val_loss: 0.4394 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 8s 313ms/step - loss: 0.3420 - accuracy: 0.5587 - val_loss: 0.2898 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3287 - accuracy: 0.5634 - val_loss: 0.4011 - val_accuracy: 0.7778
# Epoch 5/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.3241 - accuracy: 0.5610 - val_loss: 0.2867 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.3253 - accuracy: 0.5587 - val_loss: 0.2743 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.3157 - accuracy: 0.5669 - val_loss: 0.3400 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.3037 - accuracy: 0.5692 - val_loss: 0.2622 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 8s 305ms/step - loss: 0.2983 - accuracy: 0.5657 - val_loss: 0.2752 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2978 - accuracy: 0.5704 - val_loss: 0.2360 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2879 - accuracy: 0.5704 - val_loss: 0.3408 - val_accuracy: 0.7407
# Epoch 12/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2881 - accuracy: 0.5704 - val_loss: 0.3688 - val_accuracy: 0.8148
# Epoch 13/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2824 - accuracy: 0.5704 - val_loss: 0.2649 - val_accuracy: 0.8519
# Epoch 14/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2863 - accuracy: 0.5681 - val_loss: 0.2236 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 8s 313ms/step - loss: 0.2777 - accuracy: 0.5704 - val_loss: 0.1672 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2714 - accuracy: 0.5704 - val_loss: 0.2159 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2767 - accuracy: 0.5692 - val_loss: 0.1748 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2754 - accuracy: 0.5704 - val_loss: 0.1939 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2766 - accuracy: 0.5704 - val_loss: 0.1678 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 8s 305ms/step - loss: 0.2767 - accuracy: 0.5704 - val_loss: 0.2036 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2709 - accuracy: 0.5704 - val_loss: 0.1848 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2779 - accuracy: 0.5692 - val_loss: 0.1848 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2783 - accuracy: 0.5692 - val_loss: 0.4348 - val_accuracy: 0.7778
# Epoch 24/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2719 - accuracy: 0.5704 - val_loss: 0.2125 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2683 - accuracy: 0.5692 - val_loss: 0.3171 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2654 - accuracy: 0.5704 - val_loss: 0.3411 - val_accuracy: 0.8148
# Epoch 27/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2695 - accuracy: 0.5692 - val_loss: 0.1767 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2612 - accuracy: 0.5704 - val_loss: 0.2351 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2656 - accuracy: 0.5704 - val_loss: 0.2544 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 8s 309ms/step - loss: 0.2640 - accuracy: 0.5704 - val_loss: 0.3705 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 119ms/step - loss: 0.1821 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 64)         21760
#  l)
#
#  flatten (Flatten)           (None, 327680)            0
#
#  batch_normalization (BatchN  (None, 327680)           1310720
#  ormalization)
#
#  dropout (Dropout)           (None, 327680)            0
#
#  dense (Dense)               (None, 256)               83886336
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 85,219,840
# Trainable params: 84,563,968
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               85219840
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 85,302,145
# Trainable params: 84,646,273
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 348ms/step - loss: 0.5620 - accuracy: 0.4792 - val_loss: 0.3034 - val_accuracy: 0.9259
# Epoch 2/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.4125 - accuracy: 0.5451 - val_loss: 0.1841 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3637 - accuracy: 0.5706 - val_loss: 0.2089 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3468 - accuracy: 0.5799 - val_loss: 0.2145 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3279 - accuracy: 0.5764 - val_loss: 0.1887 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3296 - accuracy: 0.5787 - val_loss: 0.1969 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 9s 317ms/step - loss: 0.3298 - accuracy: 0.5787 - val_loss: 0.1765 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.3074 - accuracy: 0.5856 - val_loss: 0.1785 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.3145 - accuracy: 0.5833 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 10/100
# 27/27 [==============================] - 9s 315ms/step - loss: 0.3018 - accuracy: 0.5856 - val_loss: 0.1215 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 8s 313ms/step - loss: 0.3099 - accuracy: 0.5856 - val_loss: 0.1106 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2958 - accuracy: 0.5856 - val_loss: 0.1239 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.2900 - accuracy: 0.5868 - val_loss: 0.1023 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2826 - accuracy: 0.5868 - val_loss: 0.1290 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.2864 - accuracy: 0.5868 - val_loss: 0.0984 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2796 - accuracy: 0.5868 - val_loss: 0.1035 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2767 - accuracy: 0.5856 - val_loss: 0.2419 - val_accuracy: 0.8519
# Epoch 18/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2728 - accuracy: 0.5880 - val_loss: 0.1818 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2841 - accuracy: 0.5868 - val_loss: 0.1269 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2755 - accuracy: 0.5856 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 8s 304ms/step - loss: 0.2777 - accuracy: 0.5880 - val_loss: 0.0863 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2766 - accuracy: 0.5868 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2732 - accuracy: 0.5880 - val_loss: 0.1040 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2602 - accuracy: 0.5880 - val_loss: 0.0628 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2630 - accuracy: 0.5868 - val_loss: 0.1025 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2583 - accuracy: 0.5880 - val_loss: 0.1005 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2590 - accuracy: 0.5880 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2659 - accuracy: 0.5880 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2592 - accuracy: 0.5880 - val_loss: 0.0582 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2625 - accuracy: 0.5880 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2616 - accuracy: 0.5880 - val_loss: 0.0736 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2554 - accuracy: 0.5880 - val_loss: 0.0839 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2625 - accuracy: 0.5880 - val_loss: 0.0702 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2606 - accuracy: 0.5880 - val_loss: 0.0683 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 8s 310ms/step - loss: 0.2635 - accuracy: 0.5880 - val_loss: 0.1214 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 118ms/step - loss: 0.0470 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 64)         21760
#  l)
#
#  flatten (Flatten)           (None, 327680)            0
#
#  batch_normalization (BatchN  (None, 327680)           1310720
#  ormalization)
#
#  dropout (Dropout)           (None, 327680)            0
#
#  dense (Dense)               (None, 256)               83886336
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 85,219,840
# Trainable params: 84,563,968
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               85219840
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 85,302,145
# Trainable params: 84,646,273
# Non-trainable params: 655,872
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 349ms/step - loss: 0.5142 - accuracy: 0.5023 - val_loss: 0.4520 - val_accuracy: 0.8148
# Epoch 2/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.3861 - accuracy: 0.5657 - val_loss: 0.5972 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.3634 - accuracy: 0.5763 - val_loss: 0.4329 - val_accuracy: 0.8148
# Epoch 4/100
# 27/27 [==============================] - 9s 315ms/step - loss: 0.3417 - accuracy: 0.5786 - val_loss: 0.3714 - val_accuracy: 0.7407
# Epoch 5/100
# 27/27 [==============================] - 9s 316ms/step - loss: 0.3244 - accuracy: 0.5880 - val_loss: 0.3467 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 8s 309ms/step - loss: 0.3036 - accuracy: 0.5915 - val_loss: 0.3826 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.3069 - accuracy: 0.5915 - val_loss: 0.3155 - val_accuracy: 0.8519
# Epoch 8/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2973 - accuracy: 0.5915 - val_loss: 0.3574 - val_accuracy: 0.8519
# Epoch 9/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.2880 - accuracy: 0.5939 - val_loss: 0.3141 - val_accuracy: 0.8519
# Epoch 10/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2909 - accuracy: 0.5927 - val_loss: 0.3552 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2868 - accuracy: 0.5904 - val_loss: 0.4016 - val_accuracy: 0.8519
# Epoch 12/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2817 - accuracy: 0.5962 - val_loss: 0.2538 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.2824 - accuracy: 0.5962 - val_loss: 0.2500 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2723 - accuracy: 0.5939 - val_loss: 0.2807 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2707 - accuracy: 0.5962 - val_loss: 0.2592 - val_accuracy: 0.8519
# Epoch 16/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2718 - accuracy: 0.5962 - val_loss: 0.3056 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2674 - accuracy: 0.5951 - val_loss: 0.2707 - val_accuracy: 0.8519
# Epoch 18/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2715 - accuracy: 0.5951 - val_loss: 0.2707 - val_accuracy: 0.8889
# Epoch 19/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2713 - accuracy: 0.5962 - val_loss: 0.2425 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2660 - accuracy: 0.5951 - val_loss: 0.2817 - val_accuracy: 0.8519
# Epoch 21/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2607 - accuracy: 0.5962 - val_loss: 0.3349 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2586 - accuracy: 0.5962 - val_loss: 0.2948 - val_accuracy: 0.8889
# Epoch 23/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2635 - accuracy: 0.5962 - val_loss: 0.3426 - val_accuracy: 0.8889
# Epoch 24/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2565 - accuracy: 0.5962 - val_loss: 0.3003 - val_accuracy: 0.8519
# Epoch 25/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2510 - accuracy: 0.5962 - val_loss: 0.2496 - val_accuracy: 0.8519
# Epoch 26/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2571 - accuracy: 0.5951 - val_loss: 0.3507 - val_accuracy: 0.8519
# Epoch 27/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2578 - accuracy: 0.5951 - val_loss: 0.2747 - val_accuracy: 0.8889
# Epoch 28/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2580 - accuracy: 0.5962 - val_loss: 0.3001 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2479 - accuracy: 0.5962 - val_loss: 0.3205 - val_accuracy: 0.8519
# Epoch 30/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2439 - accuracy: 0.5962 - val_loss: 0.2276 - val_accuracy: 0.8889
# Epoch 31/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2467 - accuracy: 0.5962 - val_loss: 0.3181 - val_accuracy: 0.8889
# Epoch 32/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2477 - accuracy: 0.5962 - val_loss: 0.3389 - val_accuracy: 0.8889
# Epoch 33/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2472 - accuracy: 0.5962 - val_loss: 0.2827 - val_accuracy: 0.8519
# Epoch 34/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2483 - accuracy: 0.5962 - val_loss: 0.2647 - val_accuracy: 0.8519
# Epoch 35/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2457 - accuracy: 0.5962 - val_loss: 0.3722 - val_accuracy: 0.8519
# Epoch 36/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2456 - accuracy: 0.5962 - val_loss: 0.3653 - val_accuracy: 0.8889
# Epoch 37/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2459 - accuracy: 0.5951 - val_loss: 0.2744 - val_accuracy: 0.8889
# Epoch 38/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2415 - accuracy: 0.5962 - val_loss: 0.2840 - val_accuracy: 0.8889
# Epoch 39/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2458 - accuracy: 0.5962 - val_loss: 0.2896 - val_accuracy: 0.8889
# Epoch 40/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2446 - accuracy: 0.5962 - val_loss: 0.3856 - val_accuracy: 0.8889
# Epoch 41/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2436 - accuracy: 0.5962 - val_loss: 0.2343 - val_accuracy: 0.8148
# Epoch 42/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2474 - accuracy: 0.5962 - val_loss: 0.3668 - val_accuracy: 0.8519
# Epoch 43/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2506 - accuracy: 0.5962 - val_loss: 0.4692 - val_accuracy: 0.8889
# Epoch 44/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2397 - accuracy: 0.5962 - val_loss: 0.3275 - val_accuracy: 0.8519
# Epoch 45/100
# 27/27 [==============================] - 8s 311ms/step - loss: 0.2399 - accuracy: 0.5962 - val_loss: 0.2917 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 120ms/step - loss: 0.1176 - accuracy: 0.9706
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd3cd4e85f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.9588235259056092]
# [0.9509299516908213]
# Epoch 1/100
# 27/27 [==============================] - 12s 350ms/step - loss: 0.4809 - accuracy: 0.5428 - val_loss: 0.2772 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.3704 - accuracy: 0.5845 - val_loss: 0.2488 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.3599 - accuracy: 0.5822 - val_loss: 0.3008 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3403 - accuracy: 0.5891 - val_loss: 0.3503 - val_accuracy: 0.8148
# Epoch 5/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.3361 - accuracy: 0.5856 - val_loss: 0.2669 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3308 - accuracy: 0.5949 - val_loss: 0.2887 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 8s 313ms/step - loss: 0.3109 - accuracy: 0.5949 - val_loss: 0.2290 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.3094 - accuracy: 0.5984 - val_loss: 0.2461 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2979 - accuracy: 0.5972 - val_loss: 0.2491 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 316ms/step - loss: 0.2913 - accuracy: 0.5995 - val_loss: 0.2075 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2804 - accuracy: 0.6019 - val_loss: 0.2133 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2796 - accuracy: 0.6042 - val_loss: 0.1933 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.2706 - accuracy: 0.6030 - val_loss: 0.1617 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2697 - accuracy: 0.6019 - val_loss: 0.1298 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2678 - accuracy: 0.6042 - val_loss: 0.1455 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2721 - accuracy: 0.6019 - val_loss: 0.1463 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2766 - accuracy: 0.6042 - val_loss: 0.1568 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2668 - accuracy: 0.6030 - val_loss: 0.0907 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2622 - accuracy: 0.6042 - val_loss: 0.1888 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2561 - accuracy: 0.6042 - val_loss: 0.1798 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2613 - accuracy: 0.6042 - val_loss: 0.0972 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2565 - accuracy: 0.6042 - val_loss: 0.0987 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2574 - accuracy: 0.6042 - val_loss: 0.1020 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2605 - accuracy: 0.6042 - val_loss: 0.1089 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2488 - accuracy: 0.6042 - val_loss: 0.1737 - val_accuracy: 0.9259
# Epoch 26/100
# ...
# Epoch 2/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.4135 - accuracy: 0.5207 - val_loss: 0.1800 - val_accuracy: 1.0000
# Epoch 3/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.3937 - accuracy: 0.5276 - val_loss: 0.1537 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.3694 - accuracy: 0.5333 - val_loss: 0.1392 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 313ms/step - loss: 0.3832 - accuracy: 0.5345 - val_loss: 0.1309 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.3438 - accuracy: 0.5414 - val_loss: 0.1214 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3357 - accuracy: 0.5448 - val_loss: 0.1319 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3201 - accuracy: 0.5483 - val_loss: 0.1341 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3119 - accuracy: 0.5517 - val_loss: 0.1262 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.3166 - accuracy: 0.5506 - val_loss: 0.1225 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.3135 - accuracy: 0.5506 - val_loss: 0.0897 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.3166 - accuracy: 0.5506 - val_loss: 0.0834 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.3099 - accuracy: 0.5460 - val_loss: 0.1114 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.3107 - accuracy: 0.5483 - val_loss: 0.0925 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 9s 310ms/step - loss: 0.2995 - accuracy: 0.5494 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.3042 - accuracy: 0.5517 - val_loss: 0.0552 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.3007 - accuracy: 0.5517 - val_loss: 0.0647 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.2926 - accuracy: 0.5517 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 8s 303ms/step - loss: 0.3007 - accuracy: 0.5517 - val_loss: 0.0937 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 305ms/step - loss: 0.3030 - accuracy: 0.5506 - val_loss: 0.0771 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 311ms/step - loss: 0.3048 - accuracy: 0.5506 - val_loss: 0.0551 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2909 - accuracy: 0.5517 - val_loss: 0.0651 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2913 - accuracy: 0.5506 - val_loss: 0.0606 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2984 - accuracy: 0.5494 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 312ms/step - loss: 0.2871 - accuracy: 0.5517 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2807 - accuracy: 0.5517 - val_loss: 0.0509 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2829 - accuracy: 0.5517 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2765 - accuracy: 0.5517 - val_loss: 0.0721 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2792 - accuracy: 0.5517 - val_loss: 0.1133 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2868 - accuracy: 0.5517 - val_loss: 0.0580 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2844 - accuracy: 0.5517 - val_loss: 0.0750 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2865 - accuracy: 0.5483 - val_loss: 0.0908 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2819 - accuracy: 0.5517 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2756 - accuracy: 0.5517 - val_loss: 0.0948 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2759 - accuracy: 0.5517 - val_loss: 0.0587 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2755 - accuracy: 0.5517 - val_loss: 0.1036 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2838 - accuracy: 0.5517 - val_loss: 0.1139 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 9s 306ms/step - loss: 0.2817 - accuracy: 0.5517 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 9s 307ms/step - loss: 0.2854 - accuracy: 0.5517 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 9s 309ms/step - loss: 0.2830 - accuracy: 0.5517 - val_loss: 0.0651 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 120ms/step - loss: 0.2114 - accuracy: 0.9118
# Epoch 1/100
# 27/27 [==============================] - 12s 349ms/step - loss: 0.5216 - accuracy: 0.5208 - val_loss: 0.2209 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.4107 - accuracy: 0.5509 - val_loss: 0.1704 - val_accuracy: 0.9630
# Epoch 3/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.3631 - accuracy: 0.5625 - val_loss: 0.2277 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.3543 - accuracy: 0.5741 - val_loss: 0.1914 - val_accuracy: 1.0000
# Epoch 5/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3299 - accuracy: 0.5775 - val_loss: 0.2093 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.3154 - accuracy: 0.5799 - val_loss: 0.1818 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 8s 309ms/step - loss: 0.3047 - accuracy: 0.5856 - val_loss: 0.1786 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 315ms/step - loss: 0.3121 - accuracy: 0.5880 - val_loss: 0.1625 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2922 - accuracy: 0.5880 - val_loss: 0.1526 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2827 - accuracy: 0.5880 - val_loss: 0.1583 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2888 - accuracy: 0.5891 - val_loss: 0.1230 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2871 - accuracy: 0.5868 - val_loss: 0.1419 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2848 - accuracy: 0.5880 - val_loss: 0.1620 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2789 - accuracy: 0.5880 - val_loss: 0.1028 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2803 - accuracy: 0.5868 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2655 - accuracy: 0.5903 - val_loss: 0.1107 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2648 - accuracy: 0.5903 - val_loss: 0.1309 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 8s 313ms/step - loss: 0.2733 - accuracy: 0.5903 - val_loss: 0.0931 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2626 - accuracy: 0.5903 - val_loss: 0.0821 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2646 - accuracy: 0.5891 - val_loss: 0.0699 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 8s 313ms/step - loss: 0.2629 - accuracy: 0.5891 - val_loss: 0.0656 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2629 - accuracy: 0.5903 - val_loss: 0.1013 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 8s 310ms/step - loss: 0.2701 - accuracy: 0.5903 - val_loss: 0.0832 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2569 - accuracy: 0.5903 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 8s 310ms/step - loss: 0.2613 - accuracy: 0.5903 - val_loss: 0.1317 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 309ms/step - loss: 0.2572 - accuracy: 0.5903 - val_loss: 0.0838 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 8s 309ms/step - loss: 0.2572 - accuracy: 0.5903 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2511 - accuracy: 0.5903 - val_loss: 0.0861 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2567 - accuracy: 0.5903 - val_loss: 0.1084 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2515 - accuracy: 0.5903 - val_loss: 0.1417 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2654 - accuracy: 0.5880 - val_loss: 0.1827 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2600 - accuracy: 0.5891 - val_loss: 0.1188 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2516 - accuracy: 0.5903 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2602 - accuracy: 0.5903 - val_loss: 0.0981 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2570 - accuracy: 0.5903 - val_loss: 0.1217 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 8s 311ms/step - loss: 0.2470 - accuracy: 0.5903 - val_loss: 0.1995 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 120ms/step - loss: 0.0802 - accuracy: 0.9706
# Epoch 1/100
# 27/27 [==============================] - 12s 350ms/step - loss: 0.5479 - accuracy: 0.4815 - val_loss: 0.2782 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 9s 316ms/step - loss: 0.4142 - accuracy: 0.5370 - val_loss: 0.2543 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3618 - accuracy: 0.5671 - val_loss: 0.3169 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3505 - accuracy: 0.5590 - val_loss: 0.3482 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 8s 313ms/step - loss: 0.3302 - accuracy: 0.5671 - val_loss: 0.2208 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.3218 - accuracy: 0.5718 - val_loss: 0.2058 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3163 - accuracy: 0.5729 - val_loss: 0.2165 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.3061 - accuracy: 0.5741 - val_loss: 0.2159 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.3090 - accuracy: 0.5706 - val_loss: 0.2092 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2886 - accuracy: 0.5764 - val_loss: 0.2132 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2951 - accuracy: 0.5764 - val_loss: 0.2317 - val_accuracy: 0.8519
# Epoch 12/100
# 27/27 [==============================] - 9s 316ms/step - loss: 0.2936 - accuracy: 0.5764 - val_loss: 0.1596 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2816 - accuracy: 0.5764 - val_loss: 0.1782 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 314ms/step - loss: 0.2858 - accuracy: 0.5752 - val_loss: 0.1445 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 8s 309ms/step - loss: 0.2857 - accuracy: 0.5752 - val_loss: 0.1545 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 8s 315ms/step - loss: 0.2959 - accuracy: 0.5764 - val_loss: 0.0954 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2848 - accuracy: 0.5741 - val_loss: 0.1508 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2852 - accuracy: 0.5764 - val_loss: 0.1073 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2780 - accuracy: 0.5764 - val_loss: 0.1384 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2857 - accuracy: 0.5752 - val_loss: 0.1264 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2798 - accuracy: 0.5752 - val_loss: 0.1401 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2711 - accuracy: 0.5764 - val_loss: 0.1541 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 8s 309ms/step - loss: 0.2690 - accuracy: 0.5764 - val_loss: 0.1311 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2752 - accuracy: 0.5764 - val_loss: 0.1223 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 8s 308ms/step - loss: 0.2708 - accuracy: 0.5764 - val_loss: 0.1517 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 309ms/step - loss: 0.2657 - accuracy: 0.5764 - val_loss: 0.1039 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2616 - accuracy: 0.5764 - val_loss: 0.1396 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2677 - accuracy: 0.5752 - val_loss: 0.1418 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 8s 306ms/step - loss: 0.2671 - accuracy: 0.5764 - val_loss: 0.1588 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 8s 307ms/step - loss: 0.2701 - accuracy: 0.5764 - val_loss: 0.1570 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 310ms/step - loss: 0.2621 - accuracy: 0.5764 - val_loss: 0.1614 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 119ms/step - loss: 0.0861 - accuracy: 0.9412
# [0.9588235259056092, 0.9647058606147766, 0.970588231086731, 0.9529411673545838, 0.9411764502525329]
# [0.9509299516908213, 0.9599406780905394, 0.9655050338190948, 0.9437208713272544, 0.9328779920231931]
# Mean test accuracy is 0.96, mean test f1 score is 0.95, max test accuracy is 0.97, max test f1 score is 0.97, min test accuracy is 0.94, min test f1 score is 0.93, std of test accuracy is 0.01, std of test f1 score is 0.01
# Time elapsed through all process: 9635.15, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c9e93521352b> in <module>()
# ----> 1 print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
#       2 # print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
#
# NameError: name 'test_accuracy_per_run' is not defined
