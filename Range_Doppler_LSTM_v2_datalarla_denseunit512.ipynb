# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_LSTM_v2_datalarla_denseunit512.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada  dense_unit_of_lstm_function = 512 seçildi. 
# Mean test accuracy is 0.965, mean test f1 score is 0.960, max test accuracy is 0.971, max test f1 score is 0.967, min test accuracy is 0.953, min test f1 score is 0.945, std of test accuracy is 0.006, std of test f1 score is 0.008
#Time elapsed through all process: 8544.50, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resizedv2.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resizedv2.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resizedv2.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 16
dense_unit_of_lstm_function = 512
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 512)               83886592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 84,552,832
# Trainable params: 84,224,128
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 512)               84552832
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 84,700,673
# Trainable params: 84,371,969
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 15s 340ms/step - loss: 0.5152 - accuracy: 0.5284 - val_loss: 0.1264 - val_accuracy: 1.0000
# Epoch 2/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.3938 - accuracy: 0.5922 - val_loss: 0.2367 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.3673 - accuracy: 0.5910 - val_loss: 0.1290 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.3278 - accuracy: 0.6005 - val_loss: 0.1374 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.3179 - accuracy: 0.6040 - val_loss: 0.1361 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.3229 - accuracy: 0.6005 - val_loss: 0.1337 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.3012 - accuracy: 0.6076 - val_loss: 0.0988 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2945 - accuracy: 0.6087 - val_loss: 0.1027 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2969 - accuracy: 0.6087 - val_loss: 0.0977 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2835 - accuracy: 0.6099 - val_loss: 0.0934 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2848 - accuracy: 0.6087 - val_loss: 0.1240 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2824 - accuracy: 0.6123 - val_loss: 0.1998 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 8s 292ms/step - loss: 0.2827 - accuracy: 0.6111 - val_loss: 0.0915 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2704 - accuracy: 0.6123 - val_loss: 0.0917 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2730 - accuracy: 0.6123 - val_loss: 0.0914 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2785 - accuracy: 0.6076 - val_loss: 0.0828 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2704 - accuracy: 0.6123 - val_loss: 0.0740 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2684 - accuracy: 0.6111 - val_loss: 0.1428 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2634 - accuracy: 0.6123 - val_loss: 0.1149 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2576 - accuracy: 0.6123 - val_loss: 0.1058 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2547 - accuracy: 0.6123 - val_loss: 0.1572 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2572 - accuracy: 0.6111 - val_loss: 0.1439 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2588 - accuracy: 0.6123 - val_loss: 0.1493 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2571 - accuracy: 0.6123 - val_loss: 0.0979 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2554 - accuracy: 0.6123 - val_loss: 0.0942 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2587 - accuracy: 0.6111 - val_loss: 0.1050 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2633 - accuracy: 0.6111 - val_loss: 0.0887 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2535 - accuracy: 0.6123 - val_loss: 0.0924 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2514 - accuracy: 0.6123 - val_loss: 0.1061 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2484 - accuracy: 0.6123 - val_loss: 0.0913 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2467 - accuracy: 0.6123 - val_loss: 0.1038 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 8s 291ms/step - loss: 0.2437 - accuracy: 0.6123 - val_loss: 0.1094 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 119ms/step - loss: 0.1445 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 512)               83886592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 84,552,832
# Trainable params: 84,224,128
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 512)               84552832
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 84,700,673
# Trainable params: 84,371,969
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 12s 323ms/step - loss: 0.6120 - accuracy: 0.5000 - val_loss: 0.3046 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.4425 - accuracy: 0.5556 - val_loss: 0.1797 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3628 - accuracy: 0.5703 - val_loss: 0.1828 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 8s 291ms/step - loss: 0.3407 - accuracy: 0.5828 - val_loss: 0.1599 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3233 - accuracy: 0.5896 - val_loss: 0.1492 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3186 - accuracy: 0.5941 - val_loss: 0.1477 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.3133 - accuracy: 0.5873 - val_loss: 0.1810 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3043 - accuracy: 0.5941 - val_loss: 0.1141 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3062 - accuracy: 0.5952 - val_loss: 0.0903 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2985 - accuracy: 0.5975 - val_loss: 0.0966 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.3016 - accuracy: 0.5952 - val_loss: 0.0985 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2956 - accuracy: 0.5975 - val_loss: 0.0757 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2790 - accuracy: 0.5986 - val_loss: 0.0603 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2812 - accuracy: 0.5964 - val_loss: 0.1328 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2760 - accuracy: 0.5975 - val_loss: 0.1744 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2781 - accuracy: 0.5986 - val_loss: 0.1477 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2703 - accuracy: 0.5986 - val_loss: 0.1181 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2836 - accuracy: 0.5952 - val_loss: 0.1095 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2805 - accuracy: 0.5975 - val_loss: 0.1801 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2687 - accuracy: 0.5986 - val_loss: 0.1611 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2659 - accuracy: 0.5986 - val_loss: 0.2061 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2645 - accuracy: 0.5975 - val_loss: 0.0836 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2636 - accuracy: 0.5986 - val_loss: 0.1170 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2687 - accuracy: 0.5986 - val_loss: 0.0992 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2709 - accuracy: 0.5975 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2528 - accuracy: 0.5986 - val_loss: 0.0747 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2584 - accuracy: 0.5986 - val_loss: 0.0898 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 8s 291ms/step - loss: 0.2587 - accuracy: 0.5986 - val_loss: 0.1770 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 114ms/step - loss: 0.1038 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 512)               83886592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 84,552,832
# Trainable params: 84,224,128
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 512)               84552832
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 84,700,673
# Trainable params: 84,371,969
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 12s 323ms/step - loss: 0.6246 - accuracy: 0.5126 - val_loss: 0.3988 - val_accuracy: 0.8148
# Epoch 2/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.4548 - accuracy: 0.5667 - val_loss: 0.2410 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3802 - accuracy: 0.5805 - val_loss: 0.1910 - val_accuracy: 0.9259
# Epoch 4/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.3588 - accuracy: 0.5874 - val_loss: 0.2168 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3437 - accuracy: 0.5943 - val_loss: 0.1944 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3182 - accuracy: 0.6046 - val_loss: 0.1683 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3060 - accuracy: 0.6046 - val_loss: 0.1579 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3061 - accuracy: 0.6057 - val_loss: 0.1255 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.3246 - accuracy: 0.5989 - val_loss: 0.1939 - val_accuracy: 0.8889
# Epoch 10/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3278 - accuracy: 0.5989 - val_loss: 0.1914 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3030 - accuracy: 0.6023 - val_loss: 0.1168 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.3044 - accuracy: 0.6069 - val_loss: 0.1403 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2825 - accuracy: 0.6092 - val_loss: 0.0929 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2941 - accuracy: 0.6080 - val_loss: 0.1066 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2889 - accuracy: 0.6103 - val_loss: 0.1286 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2831 - accuracy: 0.6080 - val_loss: 0.0967 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2735 - accuracy: 0.6115 - val_loss: 0.0963 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2852 - accuracy: 0.6115 - val_loss: 0.0809 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2680 - accuracy: 0.6103 - val_loss: 0.0859 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2689 - accuracy: 0.6103 - val_loss: 0.0769 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2731 - accuracy: 0.6103 - val_loss: 0.1065 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 8s 291ms/step - loss: 0.2642 - accuracy: 0.6115 - val_loss: 0.0710 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2633 - accuracy: 0.6092 - val_loss: 0.0807 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.2682 - accuracy: 0.6103 - val_loss: 0.0968 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2599 - accuracy: 0.6115 - val_loss: 0.0798 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2576 - accuracy: 0.6115 - val_loss: 0.1553 - val_accuracy: 0.8889
# Epoch 27/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.2582 - accuracy: 0.6115 - val_loss: 0.0842 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2618 - accuracy: 0.6103 - val_loss: 0.1067 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.2526 - accuracy: 0.6115 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.2610 - accuracy: 0.6092 - val_loss: 0.0904 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2698 - accuracy: 0.6092 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2551 - accuracy: 0.6115 - val_loss: 0.0891 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.2506 - accuracy: 0.6115 - val_loss: 0.0624 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2551 - accuracy: 0.6115 - val_loss: 0.0880 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2486 - accuracy: 0.6115 - val_loss: 0.0915 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2549 - accuracy: 0.6103 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2421 - accuracy: 0.6115 - val_loss: 0.0709 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2519 - accuracy: 0.6115 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2425 - accuracy: 0.6115 - val_loss: 0.0903 - val_accuracy: 0.9630
# Epoch 40/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2502 - accuracy: 0.6115 - val_loss: 0.0879 - val_accuracy: 0.9630
# Epoch 41/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.2409 - accuracy: 0.6115 - val_loss: 0.1153 - val_accuracy: 0.9630
# Epoch 42/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2458 - accuracy: 0.6115 - val_loss: 0.0754 - val_accuracy: 0.9630
# Epoch 43/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2462 - accuracy: 0.6115 - val_loss: 0.0672 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2417 - accuracy: 0.6115 - val_loss: 0.0715 - val_accuracy: 1.0000
# Epoch 45/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.2454 - accuracy: 0.6115 - val_loss: 0.0815 - val_accuracy: 1.0000
# Epoch 46/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2482 - accuracy: 0.6115 - val_loss: 0.0961 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 115ms/step - loss: 0.0546 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 512)               83886592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 84,552,832
# Trainable params: 84,224,128
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 512)               84552832
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 84,700,673
# Trainable params: 84,371,969
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 12s 325ms/step - loss: 0.6135 - accuracy: 0.4828 - val_loss: 0.3526 - val_accuracy: 0.8148
# Epoch 2/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.4566 - accuracy: 0.5287 - val_loss: 0.3581 - val_accuracy: 0.7407
# Epoch 3/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.4142 - accuracy: 0.5345 - val_loss: 0.2807 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3664 - accuracy: 0.5517 - val_loss: 0.2556 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3725 - accuracy: 0.5529 - val_loss: 0.2841 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3516 - accuracy: 0.5575 - val_loss: 0.2540 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3524 - accuracy: 0.5563 - val_loss: 0.2816 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3359 - accuracy: 0.5563 - val_loss: 0.1975 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.3308 - accuracy: 0.5655 - val_loss: 0.2423 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.3166 - accuracy: 0.5678 - val_loss: 0.2131 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3150 - accuracy: 0.5667 - val_loss: 0.1882 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3125 - accuracy: 0.5655 - val_loss: 0.1278 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.3040 - accuracy: 0.5701 - val_loss: 0.1515 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2990 - accuracy: 0.5690 - val_loss: 0.1294 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.3005 - accuracy: 0.5690 - val_loss: 0.2355 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3014 - accuracy: 0.5690 - val_loss: 0.0878 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2914 - accuracy: 0.5655 - val_loss: 0.0895 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2976 - accuracy: 0.5678 - val_loss: 0.1019 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2957 - accuracy: 0.5701 - val_loss: 0.1383 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2895 - accuracy: 0.5678 - val_loss: 0.3841 - val_accuracy: 0.7778
# Epoch 21/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2898 - accuracy: 0.5678 - val_loss: 0.1445 - val_accuracy: 0.8889
# Epoch 22/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2805 - accuracy: 0.5690 - val_loss: 0.0708 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2791 - accuracy: 0.5701 - val_loss: 0.1630 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2809 - accuracy: 0.5701 - val_loss: 0.1395 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2854 - accuracy: 0.5678 - val_loss: 0.1244 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2778 - accuracy: 0.5701 - val_loss: 0.1400 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2766 - accuracy: 0.5701 - val_loss: 0.2868 - val_accuracy: 0.7778
# Epoch 28/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2723 - accuracy: 0.5690 - val_loss: 0.2386 - val_accuracy: 0.8519
# Epoch 29/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2755 - accuracy: 0.5701 - val_loss: 0.1816 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2820 - accuracy: 0.5701 - val_loss: 0.1452 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2774 - accuracy: 0.5701 - val_loss: 0.1222 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2658 - accuracy: 0.5701 - val_loss: 0.1358 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2710 - accuracy: 0.5701 - val_loss: 0.1580 - val_accuracy: 0.8889
# Epoch 34/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2668 - accuracy: 0.5701 - val_loss: 0.1521 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2810 - accuracy: 0.5690 - val_loss: 0.1893 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2717 - accuracy: 0.5690 - val_loss: 0.2115 - val_accuracy: 0.9259
# Epoch 37/100
# 28/28 [==============================] - 8s 290ms/step - loss: 0.2740 - accuracy: 0.5690 - val_loss: 0.2338 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 114ms/step - loss: 0.0515 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 512)               83886592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
# =================================================================
# Total params: 84,552,832
# Trainable params: 84,224,128
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 512)               84552832
#
#  model_1 (Functional)        (None, 1)                 147841
#
# =================================================================
# Total params: 84,700,673
# Trainable params: 84,371,969
# Non-trainable params: 328,704
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 328ms/step - loss: 0.6167 - accuracy: 0.4988 - val_loss: 0.3270 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.4260 - accuracy: 0.5505 - val_loss: 0.2558 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3810 - accuracy: 0.5657 - val_loss: 0.2176 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 8s 290ms/step - loss: 0.3500 - accuracy: 0.5786 - val_loss: 0.2557 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3462 - accuracy: 0.5786 - val_loss: 0.1996 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3362 - accuracy: 0.5845 - val_loss: 0.1878 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.3258 - accuracy: 0.5833 - val_loss: 0.2048 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3304 - accuracy: 0.5822 - val_loss: 0.1706 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3275 - accuracy: 0.5822 - val_loss: 0.1322 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.3071 - accuracy: 0.5880 - val_loss: 0.1465 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.3007 - accuracy: 0.5892 - val_loss: 0.2915 - val_accuracy: 0.8519
# Epoch 12/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2989 - accuracy: 0.5892 - val_loss: 0.2199 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2854 - accuracy: 0.5915 - val_loss: 0.2204 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2913 - accuracy: 0.5904 - val_loss: 0.2641 - val_accuracy: 0.8519
# Epoch 15/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2770 - accuracy: 0.5892 - val_loss: 0.1691 - val_accuracy: 0.8889
# Epoch 16/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2798 - accuracy: 0.5915 - val_loss: 0.2061 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2762 - accuracy: 0.5904 - val_loss: 0.1745 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2677 - accuracy: 0.5904 - val_loss: 0.1623 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2897 - accuracy: 0.5915 - val_loss: 0.1823 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2776 - accuracy: 0.5892 - val_loss: 0.1322 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2727 - accuracy: 0.5915 - val_loss: 0.1221 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2676 - accuracy: 0.5915 - val_loss: 0.1500 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2674 - accuracy: 0.5915 - val_loss: 0.1608 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 8s 290ms/step - loss: 0.2618 - accuracy: 0.5915 - val_loss: 0.1747 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2678 - accuracy: 0.5915 - val_loss: 0.2879 - val_accuracy: 0.8519
# Epoch 26/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2634 - accuracy: 0.5915 - val_loss: 0.2253 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2608 - accuracy: 0.5915 - val_loss: 0.2277 - val_accuracy: 0.8889
# Epoch 28/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2601 - accuracy: 0.5915 - val_loss: 0.1708 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2593 - accuracy: 0.5915 - val_loss: 0.1899 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2625 - accuracy: 0.5915 - val_loss: 0.1606 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2629 - accuracy: 0.5915 - val_loss: 0.1386 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2636 - accuracy: 0.5915 - val_loss: 0.1586 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2610 - accuracy: 0.5915 - val_loss: 0.2055 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2575 - accuracy: 0.5915 - val_loss: 0.1824 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 8s 290ms/step - loss: 0.2538 - accuracy: 0.5915 - val_loss: 0.1750 - val_accuracy: 0.9259
# Epoch 36/100
# 27/27 [==============================] - 8s 291ms/step - loss: 0.2470 - accuracy: 0.5915 - val_loss: 0.1694 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 114ms/step - loss: 0.1653 - accuracy: 0.8824
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f718cd92b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.9647058725357056]
# [0.9607828115968726]
# Epoch 1/100
# 28/28 [==============================] - 12s 328ms/step - loss: 0.5926 - accuracy: 0.4829 - val_loss: 0.1613 - val_accuracy: 0.9630
# Epoch 2/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.3982 - accuracy: 0.5468 - val_loss: 0.1813 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3900 - accuracy: 0.5582 - val_loss: 0.1806 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3631 - accuracy: 0.5616 - val_loss: 0.1707 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3545 - accuracy: 0.5731 - val_loss: 0.2501 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3470 - accuracy: 0.5708 - val_loss: 0.1472 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3363 - accuracy: 0.5765 - val_loss: 0.1207 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.3252 - accuracy: 0.5708 - val_loss: 0.1642 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.3116 - accuracy: 0.5776 - val_loss: 0.1213 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3088 - accuracy: 0.5788 - val_loss: 0.1150 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3063 - accuracy: 0.5776 - val_loss: 0.1111 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2962 - accuracy: 0.5788 - val_loss: 0.1229 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2977 - accuracy: 0.5811 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2986 - accuracy: 0.5811 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2933 - accuracy: 0.5799 - val_loss: 0.1288 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2927 - accuracy: 0.5799 - val_loss: 0.1410 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2851 - accuracy: 0.5811 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2848 - accuracy: 0.5822 - val_loss: 0.1137 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2790 - accuracy: 0.5811 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2763 - accuracy: 0.5799 - val_loss: 0.0987 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2761 - accuracy: 0.5822 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2812 - accuracy: 0.5822 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2753 - accuracy: 0.5822 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2754 - accuracy: 0.5811 - val_loss: 0.0568 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2695 - accuracy: 0.5822 - val_loss: 0.0896 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2738 - accuracy: 0.5822 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2740 - accuracy: 0.5822 - val_loss: 0.0677 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2634 - accuracy: 0.5822 - val_loss: 0.0796 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2706 - accuracy: 0.5822 - val_loss: 0.0664 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2626 - accuracy: 0.5822 - val_loss: 0.0863 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2672 - accuracy: 0.5822 - val_loss: 0.1046 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2597 - accuracy: 0.5822 - val_loss: 0.0848 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2666 - accuracy: 0.5822 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2627 - accuracy: 0.5822 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2618 - accuracy: 0.5822 - val_loss: 0.0602 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2610 - accuracy: 0.5822 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2598 - accuracy: 0.5822 - val_loss: 0.1174 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2600 - accuracy: 0.5822 - val_loss: 0.1335 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2648 - accuracy: 0.5822 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2537 - accuracy: 0.5822 - val_loss: 0.0373 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2513 - accuracy: 0.5822 - val_loss: 0.0414 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2599 - accuracy: 0.5822 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 43/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2603 - accuracy: 0.5822 - val_loss: 0.0572 - val_accuracy: 0.9630
# Epoch 44/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2665 - accuracy: 0.5822 - val_loss: 0.1155 - val_accuracy: 1.0000
# Epoch 45/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2667 - accuracy: 0.5822 - val_loss: 0.0398 - val_accuracy: 1.0000
# Epoch 46/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2582 - accuracy: 0.5822 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 47/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2476 - accuracy: 0.5822 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 48/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2479 - accuracy: 0.5822 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 49/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2495 - accuracy: 0.5822 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 50/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2550 - accuracy: 0.5822 - val_loss: 0.0400 - val_accuracy: 1.0000
# Epoch 51/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2543 - accuracy: 0.5822 - val_loss: 0.0398 - val_accuracy: 1.0000
# Epoch 52/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2511 - accuracy: 0.5822 - val_loss: 0.0618 - val_accuracy: 1.0000
# Epoch 53/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2555 - accuracy: 0.5822 - val_loss: 0.0508 - val_accuracy: 1.0000
# Epoch 54/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2520 - accuracy: 0.5822 - val_loss: 0.0531 - val_accuracy: 1.0000
# Epoch 55/100
# ...
# Epoch 8/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.3306 - accuracy: 0.5532 - val_loss: 0.1431 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.3211 - accuracy: 0.5521 - val_loss: 0.1785 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.3136 - accuracy: 0.5532 - val_loss: 0.2306 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.3175 - accuracy: 0.5532 - val_loss: 0.2307 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.3149 - accuracy: 0.5556 - val_loss: 0.2016 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.3046 - accuracy: 0.5532 - val_loss: 0.1716 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.3031 - accuracy: 0.5556 - val_loss: 0.2724 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 8s 290ms/step - loss: 0.3029 - accuracy: 0.5556 - val_loss: 0.3006 - val_accuracy: 0.8148
# Epoch 16/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2907 - accuracy: 0.5556 - val_loss: 0.1191 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2875 - accuracy: 0.5532 - val_loss: 0.1316 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2980 - accuracy: 0.5556 - val_loss: 0.1186 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2892 - accuracy: 0.5556 - val_loss: 0.1420 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2864 - accuracy: 0.5556 - val_loss: 0.0576 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2911 - accuracy: 0.5556 - val_loss: 0.1575 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2941 - accuracy: 0.5521 - val_loss: 0.1902 - val_accuracy: 0.8519
# Epoch 23/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2802 - accuracy: 0.5556 - val_loss: 0.1407 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2870 - accuracy: 0.5532 - val_loss: 0.0797 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2824 - accuracy: 0.5556 - val_loss: 0.0721 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2811 - accuracy: 0.5556 - val_loss: 0.1092 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 8s 290ms/step - loss: 0.2809 - accuracy: 0.5532 - val_loss: 0.1153 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2774 - accuracy: 0.5556 - val_loss: 0.1346 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2808 - accuracy: 0.5544 - val_loss: 0.1434 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2794 - accuracy: 0.5556 - val_loss: 0.2243 - val_accuracy: 0.8519
# Epoch 31/100
# 27/27 [==============================] - 8s 288ms/step - loss: 0.2794 - accuracy: 0.5556 - val_loss: 0.0983 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 8s 290ms/step - loss: 0.2725 - accuracy: 0.5556 - val_loss: 0.1055 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2709 - accuracy: 0.5556 - val_loss: 0.1270 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2751 - accuracy: 0.5556 - val_loss: 0.1458 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 8s 292ms/step - loss: 0.2703 - accuracy: 0.5556 - val_loss: 0.1124 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 114ms/step - loss: 0.0975 - accuracy: 0.9706
# Epoch 1/100
# 28/28 [==============================] - 12s 324ms/step - loss: 0.6023 - accuracy: 0.4897 - val_loss: 0.6929 - val_accuracy: 0.7407
# Epoch 2/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.4517 - accuracy: 0.5368 - val_loss: 0.2954 - val_accuracy: 0.7778
# Epoch 3/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3874 - accuracy: 0.5529 - val_loss: 0.1769 - val_accuracy: 0.9259
# Epoch 4/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3743 - accuracy: 0.5621 - val_loss: 0.2351 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3608 - accuracy: 0.5701 - val_loss: 0.1575 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3376 - accuracy: 0.5736 - val_loss: 0.1191 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3414 - accuracy: 0.5724 - val_loss: 0.1933 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.3318 - accuracy: 0.5690 - val_loss: 0.1726 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.3314 - accuracy: 0.5713 - val_loss: 0.1781 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3110 - accuracy: 0.5747 - val_loss: 0.1261 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2973 - accuracy: 0.5816 - val_loss: 0.1159 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2878 - accuracy: 0.5839 - val_loss: 0.1730 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.3019 - accuracy: 0.5816 - val_loss: 0.1240 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2959 - accuracy: 0.5816 - val_loss: 0.1253 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2850 - accuracy: 0.5839 - val_loss: 0.1047 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2921 - accuracy: 0.5839 - val_loss: 0.0978 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.3026 - accuracy: 0.5816 - val_loss: 0.1374 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2983 - accuracy: 0.5828 - val_loss: 0.1788 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2909 - accuracy: 0.5828 - val_loss: 0.2488 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2851 - accuracy: 0.5828 - val_loss: 0.0657 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2832 - accuracy: 0.5839 - val_loss: 0.1075 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.2810 - accuracy: 0.5839 - val_loss: 0.0935 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2839 - accuracy: 0.5816 - val_loss: 0.1042 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2766 - accuracy: 0.5816 - val_loss: 0.0753 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2695 - accuracy: 0.5828 - val_loss: 0.1783 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2735 - accuracy: 0.5828 - val_loss: 0.0776 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2786 - accuracy: 0.5839 - val_loss: 0.1317 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2851 - accuracy: 0.5828 - val_loss: 0.0956 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2735 - accuracy: 0.5828 - val_loss: 0.1367 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2684 - accuracy: 0.5816 - val_loss: 0.1935 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2651 - accuracy: 0.5839 - val_loss: 0.1277 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2720 - accuracy: 0.5839 - val_loss: 0.0839 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2727 - accuracy: 0.5839 - val_loss: 0.1203 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2685 - accuracy: 0.5828 - val_loss: 0.0684 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 8s 290ms/step - loss: 0.2692 - accuracy: 0.5828 - val_loss: 0.1979 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 112ms/step - loss: 0.1233 - accuracy: 0.9706
# Epoch 1/100
# 28/28 [==============================] - 12s 326ms/step - loss: 0.5869 - accuracy: 0.4989 - val_loss: 0.6513 - val_accuracy: 0.7037
# Epoch 2/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.4317 - accuracy: 0.5525 - val_loss: 0.1808 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3611 - accuracy: 0.5811 - val_loss: 0.1759 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3389 - accuracy: 0.5868 - val_loss: 0.1508 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.3398 - accuracy: 0.5890 - val_loss: 0.1662 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3257 - accuracy: 0.5925 - val_loss: 0.2924 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3194 - accuracy: 0.5902 - val_loss: 0.1326 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3233 - accuracy: 0.5925 - val_loss: 0.2336 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.3004 - accuracy: 0.5913 - val_loss: 0.1794 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3137 - accuracy: 0.5902 - val_loss: 0.1145 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.3150 - accuracy: 0.5925 - val_loss: 0.1929 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2987 - accuracy: 0.5982 - val_loss: 0.1940 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2898 - accuracy: 0.5913 - val_loss: 0.0881 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2870 - accuracy: 0.5982 - val_loss: 0.0834 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2841 - accuracy: 0.5970 - val_loss: 0.0997 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2884 - accuracy: 0.5970 - val_loss: 0.0997 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2759 - accuracy: 0.5982 - val_loss: 0.1282 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2843 - accuracy: 0.5982 - val_loss: 0.0916 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.2741 - accuracy: 0.5970 - val_loss: 0.1279 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2718 - accuracy: 0.5982 - val_loss: 0.0869 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2759 - accuracy: 0.5982 - val_loss: 0.1156 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2706 - accuracy: 0.5982 - val_loss: 0.1165 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2697 - accuracy: 0.5970 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2663 - accuracy: 0.5982 - val_loss: 0.0765 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2653 - accuracy: 0.5970 - val_loss: 0.1518 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2738 - accuracy: 0.5970 - val_loss: 0.2072 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2693 - accuracy: 0.5982 - val_loss: 0.0851 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2604 - accuracy: 0.5982 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.2609 - accuracy: 0.5982 - val_loss: 0.1282 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2608 - accuracy: 0.5982 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2627 - accuracy: 0.5982 - val_loss: 0.0720 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2595 - accuracy: 0.5982 - val_loss: 0.1028 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2561 - accuracy: 0.5982 - val_loss: 0.1191 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2579 - accuracy: 0.5982 - val_loss: 0.1347 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2569 - accuracy: 0.5982 - val_loss: 0.0890 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2508 - accuracy: 0.5982 - val_loss: 0.1114 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2561 - accuracy: 0.5982 - val_loss: 0.0993 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2603 - accuracy: 0.5970 - val_loss: 0.1210 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 8s 288ms/step - loss: 0.2609 - accuracy: 0.5970 - val_loss: 0.1097 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2507 - accuracy: 0.5982 - val_loss: 0.1078 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 8s 286ms/step - loss: 0.2510 - accuracy: 0.5982 - val_loss: 0.1273 - val_accuracy: 0.9259
# Epoch 42/100
# 28/28 [==============================] - 8s 287ms/step - loss: 0.2568 - accuracy: 0.5982 - val_loss: 0.1171 - val_accuracy: 1.0000
# Epoch 43/100
# 28/28 [==============================] - 8s 289ms/step - loss: 0.2490 - accuracy: 0.5982 - val_loss: 0.1167 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 110ms/step - loss: 0.0766 - accuracy: 0.9706
# [0.9647058725357056, 0.970588219165802, 0.9647058725357056, 0.9529411673545838, 0.970588219165802]
# [0.9607828115968726, 0.9655521783181358, 0.9613124464188294, 0.9446043702954723, 0.9667720351392877]
# Mean test accuracy is 0.96, mean test f1 score is 0.96, max test accuracy is 0.97, max test f1 score is 0.97, min test accuracy is 0.95, min test f1 score is 0.94, std of test accuracy is 0.01, std of test f1 score is 0.01
# Time elapsed through all process: 8140.21, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.965, mean test f1 score is 0.960, max test accuracy is 0.971, max test f1 score is 0.967, min test accuracy is 0.953, min test f1 score is 0.945, std of test accuracy is 0.006, std of test f1 score is 0.008
