# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/Range-Doppler-Spectrogram-LSTM/RD_SP_LSTM_denseunit_dropout_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# dropout0.3

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number =   100 # 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.3 # 0.
repeat_of_mixup = 5
number_of_repeat = 5
unit_number_of_lstm = 16 #8 16 32
dense_unit_of_range_doppler_function = 256 #128 256 512
dense_unit_of_spectrogram_function = 8
decoder_dense_unit = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_range_doppler_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def lstm_encoder_network_2(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_spectrogram_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense_unit)(input)
      x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_lstm(range_doppler_input)

    input_shape = spectrogram_concat_shuffle_train.shape[1:3]
    base_network_lstm_2 = lstm_encoder_network_2(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_lstm_2(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(base_network_lstm_2.summary())
      print(base_decoder_network.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image, spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler, validation_spectrogram) , (spectrogram_validation_labels)))
    #plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    #plt.title('model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('epoch')
    plt.legend(['Validation Accuracy'], loc='right')
    #plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='right')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    #plt.title('model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')
    plt.show()

    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    print(confusion_matrix(range_doppler_concat_label_shuffle_test, y_test_predicted_binary))
    print(classification_report(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, digits=3))


    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 19s 377ms/step - loss: 0.4818 - accuracy: 0.5034 - val_loss: 0.7022 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3658 - accuracy: 0.5556 - val_loss: 0.1889 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3390 - accuracy: 0.5692 - val_loss: 0.1584 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.3239 - accuracy: 0.5692 - val_loss: 0.1559 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3045 - accuracy: 0.5760 - val_loss: 0.1150 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2948 - accuracy: 0.5737 - val_loss: 0.1305 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2852 - accuracy: 0.5748 - val_loss: 0.1480 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2858 - accuracy: 0.5760 - val_loss: 0.1264 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 314ms/step - loss: 0.2789 - accuracy: 0.5737 - val_loss: 0.1170 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2840 - accuracy: 0.5726 - val_loss: 0.1147 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2685 - accuracy: 0.5760 - val_loss: 0.1270 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2783 - accuracy: 0.5748 - val_loss: 0.0905 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2775 - accuracy: 0.5737 - val_loss: 0.0960 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2689 - accuracy: 0.5760 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2651 - accuracy: 0.5760 - val_loss: 0.1192 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2677 - accuracy: 0.5760 - val_loss: 0.1035 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2576 - accuracy: 0.5760 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2608 - accuracy: 0.5760 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2634 - accuracy: 0.5760 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2598 - accuracy: 0.5760 - val_loss: 0.0680 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2615 - accuracy: 0.5760 - val_loss: 0.0995 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2625 - accuracy: 0.5760 - val_loss: 0.0589 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2652 - accuracy: 0.5760 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2580 - accuracy: 0.5760 - val_loss: 0.0681 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2577 - accuracy: 0.5760 - val_loss: 0.0784 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2619 - accuracy: 0.5748 - val_loss: 0.0564 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2578 - accuracy: 0.5760 - val_loss: 0.0929 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2539 - accuracy: 0.5760 - val_loss: 0.0834 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2496 - accuracy: 0.5760 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2592 - accuracy: 0.5760 - val_loss: 0.0630 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2508 - accuracy: 0.5760 - val_loss: 0.0985 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2510 - accuracy: 0.5760 - val_loss: 0.0622 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2485 - accuracy: 0.5760 - val_loss: 0.1271 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2469 - accuracy: 0.5760 - val_loss: 0.1034 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2528 - accuracy: 0.5760 - val_loss: 0.0456 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2523 - accuracy: 0.5760 - val_loss: 0.0532 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2478 - accuracy: 0.5760 - val_loss: 0.0793 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2518 - accuracy: 0.5760 - val_loss: 0.0489 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2496 - accuracy: 0.5760 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2511 - accuracy: 0.5760 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2498 - accuracy: 0.5760 - val_loss: 0.0350 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2481 - accuracy: 0.5760 - val_loss: 0.0408 - val_accuracy: 1.0000
# Epoch 43/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2483 - accuracy: 0.5760 - val_loss: 0.1332 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2494 - accuracy: 0.5748 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 45/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2490 - accuracy: 0.5760 - val_loss: 0.1182 - val_accuracy: 0.9630
# Epoch 46/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2514 - accuracy: 0.5748 - val_loss: 0.0712 - val_accuracy: 1.0000
# Epoch 47/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2458 - accuracy: 0.5760 - val_loss: 0.1164 - val_accuracy: 0.9630
# Epoch 48/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2522 - accuracy: 0.5760 - val_loss: 0.0672 - val_accuracy: 1.0000
# Epoch 49/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2450 - accuracy: 0.5760 - val_loss: 0.0545 - val_accuracy: 1.0000
# Epoch 50/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2515 - accuracy: 0.5760 - val_loss: 0.0846 - val_accuracy: 1.0000
# Epoch 51/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2494 - accuracy: 0.5760 - val_loss: 0.0573 - val_accuracy: 1.0000
# Epoch 52/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2438 - accuracy: 0.5760 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 53/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2420 - accuracy: 0.5760 - val_loss: 0.0701 - val_accuracy: 1.0000
# Epoch 54/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2433 - accuracy: 0.5760 - val_loss: 0.0602 - val_accuracy: 1.0000
# Epoch 55/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2403 - accuracy: 0.5760 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 56/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2434 - accuracy: 0.5760 - val_loss: 0.1411 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 128ms/step - loss: 0.0546 - accuracy: 1.0000
# [[23  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#          0.0      1.000     1.000     1.000        23
#          1.0      1.000     1.000     1.000        11
#
#     accuracy                          1.000        34
#    macro avg      1.000     1.000     1.000        34
# weighted avg      1.000     1.000     1.000        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 16s 372ms/step - loss: 0.4800 - accuracy: 0.5091 - val_loss: 0.2089 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3770 - accuracy: 0.5537 - val_loss: 0.1535 - val_accuracy: 1.0000
# Epoch 3/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.3380 - accuracy: 0.5674 - val_loss: 0.1631 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.3304 - accuracy: 0.5742 - val_loss: 0.1665 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.3086 - accuracy: 0.5753 - val_loss: 0.1834 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3037 - accuracy: 0.5776 - val_loss: 0.2163 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3007 - accuracy: 0.5799 - val_loss: 0.1931 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2784 - accuracy: 0.5799 - val_loss: 0.1960 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2732 - accuracy: 0.5822 - val_loss: 0.1680 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2723 - accuracy: 0.5822 - val_loss: 0.1497 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2724 - accuracy: 0.5822 - val_loss: 0.2563 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2760 - accuracy: 0.5822 - val_loss: 0.1667 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2744 - accuracy: 0.5822 - val_loss: 0.2674 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2738 - accuracy: 0.5822 - val_loss: 0.1476 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2609 - accuracy: 0.5822 - val_loss: 0.2935 - val_accuracy: 0.8519
# Epoch 16/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2667 - accuracy: 0.5822 - val_loss: 0.0860 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 9s 316ms/step - loss: 0.2643 - accuracy: 0.5822 - val_loss: 0.1605 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 316ms/step - loss: 0.2604 - accuracy: 0.5822 - val_loss: 0.1069 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 9s 316ms/step - loss: 0.2607 - accuracy: 0.5822 - val_loss: 0.1580 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2548 - accuracy: 0.5822 - val_loss: 0.1324 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2570 - accuracy: 0.5822 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2679 - accuracy: 0.5822 - val_loss: 0.1348 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2538 - accuracy: 0.5822 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 316ms/step - loss: 0.2621 - accuracy: 0.5822 - val_loss: 0.0664 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2641 - accuracy: 0.5811 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2624 - accuracy: 0.5822 - val_loss: 0.0852 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2579 - accuracy: 0.5822 - val_loss: 0.1060 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2603 - accuracy: 0.5822 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2577 - accuracy: 0.5822 - val_loss: 0.0993 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2520 - accuracy: 0.5822 - val_loss: 0.0826 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2495 - accuracy: 0.5822 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2498 - accuracy: 0.5822 - val_loss: 0.1109 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2521 - accuracy: 0.5822 - val_loss: 0.1120 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2617 - accuracy: 0.5822 - val_loss: 0.0676 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2468 - accuracy: 0.5822 - val_loss: 0.0968 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 9s 316ms/step - loss: 0.2449 - accuracy: 0.5822 - val_loss: 0.0890 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2488 - accuracy: 0.5822 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2484 - accuracy: 0.5822 - val_loss: 0.1726 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 129ms/step - loss: 0.0438 - accuracy: 1.0000
# [[23  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#          0.0      1.000     1.000     1.000        23
#          1.0      1.000     1.000     1.000        11
#
#     accuracy                          1.000        34
#    macro avg      1.000     1.000     1.000        34
# weighted avg      1.000     1.000     1.000        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 380ms/step - loss: 0.4589 - accuracy: 0.5210 - val_loss: 0.2834 - val_accuracy: 0.8148
# Epoch 2/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3698 - accuracy: 0.5606 - val_loss: 0.1938 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.3383 - accuracy: 0.5664 - val_loss: 0.2397 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3254 - accuracy: 0.5746 - val_loss: 0.1189 - val_accuracy: 1.0000
# Epoch 5/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.3180 - accuracy: 0.5781 - val_loss: 0.3034 - val_accuracy: 0.8148
# Epoch 6/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2916 - accuracy: 0.5816 - val_loss: 0.0991 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2903 - accuracy: 0.5816 - val_loss: 0.1257 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2843 - accuracy: 0.5816 - val_loss: 0.0952 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2727 - accuracy: 0.5828 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 10/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2668 - accuracy: 0.5828 - val_loss: 0.0923 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2724 - accuracy: 0.5828 - val_loss: 0.1057 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2734 - accuracy: 0.5828 - val_loss: 0.1502 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2638 - accuracy: 0.5816 - val_loss: 0.0719 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2691 - accuracy: 0.5816 - val_loss: 0.0936 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2612 - accuracy: 0.5828 - val_loss: 0.1033 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2608 - accuracy: 0.5828 - val_loss: 0.0980 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2614 - accuracy: 0.5828 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2506 - accuracy: 0.5828 - val_loss: 0.0962 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2650 - accuracy: 0.5828 - val_loss: 0.0808 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2632 - accuracy: 0.5828 - val_loss: 0.0726 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2614 - accuracy: 0.5828 - val_loss: 0.0719 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2557 - accuracy: 0.5816 - val_loss: 0.1452 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2585 - accuracy: 0.5828 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2569 - accuracy: 0.5828 - val_loss: 0.0784 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2570 - accuracy: 0.5828 - val_loss: 0.0999 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2503 - accuracy: 0.5828 - val_loss: 0.0576 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2567 - accuracy: 0.5828 - val_loss: 0.0885 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2536 - accuracy: 0.5828 - val_loss: 0.1499 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2537 - accuracy: 0.5828 - val_loss: 0.0819 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2476 - accuracy: 0.5828 - val_loss: 0.1161 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2554 - accuracy: 0.5828 - val_loss: 0.0752 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2496 - accuracy: 0.5828 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2508 - accuracy: 0.5828 - val_loss: 0.1355 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2415 - accuracy: 0.5828 - val_loss: 0.1408 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2561 - accuracy: 0.5816 - val_loss: 0.1181 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2491 - accuracy: 0.5828 - val_loss: 0.1136 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2475 - accuracy: 0.5828 - val_loss: 0.1233 - val_accuracy: 1.0000
# Epoch 38/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2445 - accuracy: 0.5828 - val_loss: 0.1369 - val_accuracy: 1.0000
# Epoch 39/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2461 - accuracy: 0.5828 - val_loss: 0.1300 - val_accuracy: 0.9630
# Epoch 40/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2415 - accuracy: 0.5828 - val_loss: 0.1199 - val_accuracy: 0.9259
# Epoch 41/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2454 - accuracy: 0.5828 - val_loss: 0.0862 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 122ms/step - loss: 0.0892 - accuracy: 1.0000
# [[23  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#          0.0      1.000     1.000     1.000        23
#          1.0      1.000     1.000     1.000        11
#
#     accuracy                          1.000        34
#    macro avg      1.000     1.000     1.000        34
# weighted avg      1.000     1.000     1.000        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 374ms/step - loss: 0.4173 - accuracy: 0.5594 - val_loss: 0.4229 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3632 - accuracy: 0.5758 - val_loss: 0.1610 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.3199 - accuracy: 0.5932 - val_loss: 0.2381 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.3071 - accuracy: 0.5991 - val_loss: 0.2515 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2957 - accuracy: 0.5967 - val_loss: 0.2745 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2975 - accuracy: 0.5979 - val_loss: 0.3063 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2872 - accuracy: 0.5991 - val_loss: 0.1743 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2683 - accuracy: 0.6014 - val_loss: 0.2048 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2651 - accuracy: 0.6002 - val_loss: 0.2216 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2592 - accuracy: 0.6014 - val_loss: 0.2518 - val_accuracy: 0.8519
# Epoch 11/100
# 27/27 [==============================] - 9s 317ms/step - loss: 0.2606 - accuracy: 0.6014 - val_loss: 0.1886 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2570 - accuracy: 0.6002 - val_loss: 0.1876 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2585 - accuracy: 0.6014 - val_loss: 0.2033 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2585 - accuracy: 0.6002 - val_loss: 0.1800 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2504 - accuracy: 0.6014 - val_loss: 0.1233 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 9s 317ms/step - loss: 0.2484 - accuracy: 0.6014 - val_loss: 0.1791 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2421 - accuracy: 0.6014 - val_loss: 0.2260 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2450 - accuracy: 0.6014 - val_loss: 0.1412 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2443 - accuracy: 0.6014 - val_loss: 0.1452 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2480 - accuracy: 0.6014 - val_loss: 0.1356 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2451 - accuracy: 0.6014 - val_loss: 0.2253 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2441 - accuracy: 0.6014 - val_loss: 0.1484 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2428 - accuracy: 0.6014 - val_loss: 0.1828 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2385 - accuracy: 0.6014 - val_loss: 0.1442 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2363 - accuracy: 0.6014 - val_loss: 0.1292 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2408 - accuracy: 0.6014 - val_loss: 0.2727 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2393 - accuracy: 0.6014 - val_loss: 0.2382 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 9s 320ms/step - loss: 0.2429 - accuracy: 0.6014 - val_loss: 0.1612 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2420 - accuracy: 0.6014 - val_loss: 0.1747 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2351 - accuracy: 0.6014 - val_loss: 0.1611 - val_accuracy: 0.9259
# 2/2 [==============================] - 2s 128ms/step - loss: 0.1389 - accuracy: 0.9412
# [[22  1]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.957     0.957     0.957        23
#          1.0      0.909     0.909     0.909        11
#
#     accuracy                          0.941        34
#    macro avg      0.933     0.933     0.933        34
# weighted avg      0.941     0.941     0.941        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
# ...
# Epoch 25/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2473 - accuracy: 0.5926 - val_loss: 0.2320 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2456 - accuracy: 0.5926 - val_loss: 0.2160 - val_accuracy: 0.8519
# Epoch 27/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2490 - accuracy: 0.5914 - val_loss: 0.2080 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2463 - accuracy: 0.5926 - val_loss: 0.2219 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2470 - accuracy: 0.5914 - val_loss: 0.1709 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2364 - accuracy: 0.5926 - val_loss: 0.2782 - val_accuracy: 0.8889
# Epoch 31/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2481 - accuracy: 0.5926 - val_loss: 0.2562 - val_accuracy: 0.8519
# Epoch 32/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2455 - accuracy: 0.5926 - val_loss: 0.2464 - val_accuracy: 0.9259
# 2/2 [==============================] - 2s 97ms/step - loss: 0.1396 - accuracy: 0.9412
# [[22  1]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.957     0.957     0.957        23
#          1.0      0.909     0.909     0.909        11
#
#     accuracy                          0.941        34
#    macro avg      0.933     0.933     0.933        34
# weighted avg      0.941     0.941     0.941        34
#
# Epoch 1/100
# 28/28 [==============================] - 17s 376ms/step - loss: 0.5187 - accuracy: 0.4717 - val_loss: 0.1222 - val_accuracy: 0.9630
# Epoch 2/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.4045 - accuracy: 0.5249 - val_loss: 0.1315 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.3748 - accuracy: 0.5317 - val_loss: 0.1413 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.3368 - accuracy: 0.5431 - val_loss: 0.1128 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.3366 - accuracy: 0.5397 - val_loss: 0.1339 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.3187 - accuracy: 0.5465 - val_loss: 0.1243 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.3144 - accuracy: 0.5442 - val_loss: 0.2083 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.3104 - accuracy: 0.5465 - val_loss: 0.1861 - val_accuracy: 0.8889
# Epoch 9/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.3197 - accuracy: 0.5442 - val_loss: 0.1001 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3019 - accuracy: 0.5476 - val_loss: 0.0842 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2892 - accuracy: 0.5488 - val_loss: 0.0905 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.3087 - accuracy: 0.5465 - val_loss: 0.1823 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2848 - accuracy: 0.5488 - val_loss: 0.1150 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 9s 317ms/step - loss: 0.2884 - accuracy: 0.5488 - val_loss: 0.1266 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2945 - accuracy: 0.5488 - val_loss: 0.1103 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2835 - accuracy: 0.5488 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 322ms/step - loss: 0.2830 - accuracy: 0.5488 - val_loss: 0.0695 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2825 - accuracy: 0.5476 - val_loss: 0.0819 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2765 - accuracy: 0.5488 - val_loss: 0.0832 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2824 - accuracy: 0.5488 - val_loss: 0.0437 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2750 - accuracy: 0.5488 - val_loss: 0.0911 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2787 - accuracy: 0.5488 - val_loss: 0.0662 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2770 - accuracy: 0.5476 - val_loss: 0.0615 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2737 - accuracy: 0.5488 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2778 - accuracy: 0.5488 - val_loss: 0.1008 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2736 - accuracy: 0.5488 - val_loss: 0.0864 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2769 - accuracy: 0.5488 - val_loss: 0.1073 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2710 - accuracy: 0.5488 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2738 - accuracy: 0.5488 - val_loss: 0.0671 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2724 - accuracy: 0.5488 - val_loss: 0.0923 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 320ms/step - loss: 0.2703 - accuracy: 0.5488 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2764 - accuracy: 0.5488 - val_loss: 0.0531 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2677 - accuracy: 0.5488 - val_loss: 0.0784 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 9s 319ms/step - loss: 0.2760 - accuracy: 0.5488 - val_loss: 0.0535 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 321ms/step - loss: 0.2789 - accuracy: 0.5488 - val_loss: 0.0735 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 125ms/step - loss: 0.0983 - accuracy: 0.9706
# [[23  0]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.958     1.000     0.979        23
#          1.0      1.000     0.909     0.952        11
#
#     accuracy                          0.971        34
#    macro avg      0.979     0.955     0.966        34
# weighted avg      0.972     0.971     0.970        34
#
# Epoch 1/100
# 27/27 [==============================] - 16s 393ms/step - loss: 0.4822 - accuracy: 0.5243 - val_loss: 0.2515 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.3648 - accuracy: 0.5521 - val_loss: 0.2567 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3427 - accuracy: 0.5602 - val_loss: 0.1702 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3172 - accuracy: 0.5671 - val_loss: 0.1999 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3072 - accuracy: 0.5729 - val_loss: 0.1261 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3007 - accuracy: 0.5718 - val_loss: 0.1578 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3026 - accuracy: 0.5741 - val_loss: 0.1412 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2912 - accuracy: 0.5729 - val_loss: 0.2645 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2857 - accuracy: 0.5741 - val_loss: 0.2321 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2881 - accuracy: 0.5741 - val_loss: 0.1083 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2713 - accuracy: 0.5741 - val_loss: 0.2225 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2772 - accuracy: 0.5741 - val_loss: 0.1906 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2679 - accuracy: 0.5741 - val_loss: 0.1966 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2703 - accuracy: 0.5741 - val_loss: 0.1953 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2761 - accuracy: 0.5741 - val_loss: 0.2170 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2667 - accuracy: 0.5741 - val_loss: 0.1115 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2636 - accuracy: 0.5741 - val_loss: 0.2290 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2630 - accuracy: 0.5741 - val_loss: 0.2172 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2566 - accuracy: 0.5741 - val_loss: 0.1243 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2612 - accuracy: 0.5741 - val_loss: 0.2316 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2661 - accuracy: 0.5741 - val_loss: 0.2079 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2626 - accuracy: 0.5741 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2545 - accuracy: 0.5741 - val_loss: 0.1749 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2599 - accuracy: 0.5741 - val_loss: 0.1451 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2522 - accuracy: 0.5741 - val_loss: 0.0960 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2568 - accuracy: 0.5741 - val_loss: 0.1036 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2546 - accuracy: 0.5741 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2592 - accuracy: 0.5741 - val_loss: 0.1235 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2559 - accuracy: 0.5741 - val_loss: 0.1722 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2590 - accuracy: 0.5741 - val_loss: 0.2066 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2563 - accuracy: 0.5741 - val_loss: 0.1177 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2569 - accuracy: 0.5741 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2547 - accuracy: 0.5741 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2479 - accuracy: 0.5741 - val_loss: 0.2620 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2466 - accuracy: 0.5741 - val_loss: 0.1745 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2469 - accuracy: 0.5741 - val_loss: 0.0924 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2562 - accuracy: 0.5741 - val_loss: 0.1619 - val_accuracy: 1.0000
# Epoch 38/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2523 - accuracy: 0.5741 - val_loss: 0.1262 - val_accuracy: 1.0000
# Epoch 39/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2462 - accuracy: 0.5741 - val_loss: 0.1146 - val_accuracy: 1.0000
# Epoch 40/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2493 - accuracy: 0.5741 - val_loss: 0.0646 - val_accuracy: 1.0000
# Epoch 41/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2479 - accuracy: 0.5741 - val_loss: 0.0774 - val_accuracy: 1.0000
# Epoch 42/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2512 - accuracy: 0.5741 - val_loss: 0.0957 - val_accuracy: 1.0000
# Epoch 43/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2471 - accuracy: 0.5741 - val_loss: 0.0676 - val_accuracy: 1.0000
# Epoch 44/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2545 - accuracy: 0.5741 - val_loss: 0.1441 - val_accuracy: 1.0000
# Epoch 45/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2479 - accuracy: 0.5741 - val_loss: 0.1486 - val_accuracy: 1.0000
# Epoch 46/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2456 - accuracy: 0.5741 - val_loss: 0.3197 - val_accuracy: 0.9259
# Epoch 47/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2459 - accuracy: 0.5741 - val_loss: 0.1547 - val_accuracy: 0.9630
# Epoch 48/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2501 - accuracy: 0.5741 - val_loss: 0.1700 - val_accuracy: 0.9630
# Epoch 49/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2478 - accuracy: 0.5741 - val_loss: 0.1447 - val_accuracy: 1.0000
# Epoch 50/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2529 - accuracy: 0.5741 - val_loss: 0.1138 - val_accuracy: 0.9630
# Epoch 51/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2488 - accuracy: 0.5741 - val_loss: 0.1265 - val_accuracy: 0.9630
# Epoch 52/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2471 - accuracy: 0.5741 - val_loss: 0.0877 - val_accuracy: 1.0000
# Epoch 53/100
# 27/27 [==============================] - 9s 318ms/step - loss: 0.2496 - accuracy: 0.5741 - val_loss: 0.1677 - val_accuracy: 1.0000
# Epoch 54/100
# 27/27 [==============================] - 9s 319ms/step - loss: 0.2496 - accuracy: 0.5741 - val_loss: 0.1646 - val_accuracy: 0.9630
# Epoch 55/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2534 - accuracy: 0.5741 - val_loss: 0.1268 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 135ms/step - loss: 0.1422 - accuracy: 0.9706
# [[22  0]
#  [ 1 11]]
#               precision    recall  f1-score   support
#
#          0.0      0.957     1.000     0.978        22
#          1.0      1.000     0.917     0.957        12
#
#     accuracy                          0.971        34
#    macro avg      0.978     0.958     0.967        34
# weighted avg      0.972     0.971     0.970        34
#
# [0.9823529362678528, 0.9647058725357056, 0.9647058725357056, 0.9588235259056092, 0.9647058725357056]
# [0.9799912165129555, 0.9580792938491532, 0.9561761546723954, 0.9513383671524283, 0.9602228642977948]
# Mean test accuracy is 0.967, mean test f1 score is 0.961, max test accuracy is 0.982, max test f1 score is 0.980, min test accuracy is 0.959, min test f1 score is 0.951, std of test accuracy is 0.008, std of test f1 score is 0.010
# Time elapsed through all process: 9153.441, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.967, mean test f1 score is 0.961, max test accuracy is 0.982, max test f1 score is 0.980, min test accuracy is 0.959, min test f1 score is 0.951, std of test accuracy is 0.008, std of test f1 score is 0.010
# Time elapsed through all process: 9153.441, sec

# %%
import numpy as np
import matplotlib.pyplot as plt
def createList(n):
    lst = []
    for i in range(n+1):
        lst.append(i)
    return(lst)


folds = createList(4)
values = [element * 100 for element in test_accuracy_per_fold]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(folds, values, color ='black',
        width = 0.4)
plt.xlabel("Accuracy vs k-run")
plt.ylabel("Accuracy")
plt.show()

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(folds, f1_score_per_fold, color ='black',
        width = 0.4)
plt.xlabel("F1 Score vs k-run")
plt.ylabel("F1 Score")
plt.show()
