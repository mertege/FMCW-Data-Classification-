# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_LSTM_v2_datalarla_dropout01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dropout 0.1 secildi
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.974, mean test f1 score is 0.970, max test accuracy is 0.994, max test f1 score is 0.993, min test accuracy is 0.959, min test f1 score is 0.951, std of test accuracy is 0.012, std of test f1 score is 0.014

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resizedv2.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resizedv2.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resizedv2.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.1
unit_number_of_lstm = 16
dense_unit_of_lstm_function = 256
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 19s 410ms/step - loss: 0.4983 - accuracy: 0.5022 - val_loss: 0.1127 - val_accuracy: 1.0000
# Epoch 2/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3874 - accuracy: 0.5403 - val_loss: 0.1352 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3523 - accuracy: 0.5570 - val_loss: 0.1486 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 11s 375ms/step - loss: 0.3524 - accuracy: 0.5570 - val_loss: 0.3293 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.3393 - accuracy: 0.5604 - val_loss: 0.3139 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.3198 - accuracy: 0.5649 - val_loss: 0.1980 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3131 - accuracy: 0.5694 - val_loss: 0.2040 - val_accuracy: 0.8519
# Epoch 8/100
# 28/28 [==============================] - 11s 378ms/step - loss: 0.3045 - accuracy: 0.5694 - val_loss: 0.1493 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.3117 - accuracy: 0.5694 - val_loss: 0.2544 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3124 - accuracy: 0.5682 - val_loss: 0.1478 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3018 - accuracy: 0.5660 - val_loss: 0.2471 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2835 - accuracy: 0.5694 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2881 - accuracy: 0.5705 - val_loss: 0.1566 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3009 - accuracy: 0.5671 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2891 - accuracy: 0.5705 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2883 - accuracy: 0.5705 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2760 - accuracy: 0.5705 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2896 - accuracy: 0.5682 - val_loss: 0.1645 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2770 - accuracy: 0.5705 - val_loss: 0.1625 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2728 - accuracy: 0.5705 - val_loss: 0.1214 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2778 - accuracy: 0.5705 - val_loss: 0.0515 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] -
100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2751 - accuracy: 0.5925 - val_loss: 0.1808 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 10s 369ms/step - loss: 0.2782 - accuracy: 0.5925 - val_loss: 0.2162 - val_accuracy: 0.8889
# Epoch 14/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.2779 - accuracy: 0.5925 - val_loss: 0.3076 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2785 - accuracy: 0.5936 - val_loss: 0.1761 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2764 - accuracy: 0.5913 - val_loss: 0.1767 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2672 - accuracy: 0.5936 - val_loss: 0.3039 - val_accuracy: 0.8889
# Epoch 18/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2701 - accuracy: 0.5913 - val_loss: 0.2051 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2756 - accuracy: 0.5925 - val_loss: 0.1824 - val_accuracy: 0.8889
# Epoch 20/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2704 - accuracy: 0.5925 - val_loss: 0.2446 - val_accuracy: 0.8889
# Epoch 21/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2693 - accuracy: 0.5936 - val_loss: 0.1795 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2633 - accuracy: 0.5936 - val_loss: 0.1339 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2585 - accuracy: 0.5936 - val_loss: 0.1358 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2550 - accuracy: 0.5925 - val_loss: 0.1608 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2565 - accuracy: 0.5936 - val_loss: 0.2112 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2642 - accuracy: 0.5936 - val_loss: 0.1996 - val_accuracy: 0.8889
# Epoch 27/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2567 - accuracy: 0.5936 - val_loss: 0.2175 - val_accuracy: 0.8889
# Epoch 28/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.2604 - accuracy: 0.5936 - val_loss: 0.2039 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 10s 369ms/step - loss: 0.2524 - accuracy: 0.5936 - val_loss: 0.2539 - val_accuracy: 0.8889
# Epoch 30/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2531 - accuracy: 0.5936 - val_loss: 0.2019 - val_accuracy: 0.8889
# Epoch 31/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.2504 - accuracy: 0.5936 - val_loss: 0.2110 - val_accuracy: 0.8889
# Epoch 32/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.2569 - accuracy: 0.5936 - val_loss: 0.2834 - val_accuracy: 0.8889
# Epoch 33/100
# 28/28 [==============================] - 10s 365ms/step - loss: 0.2521 - accuracy: 0.5936 - val_loss: 0.2614 - val_accuracy: 0.8889
# Epoch 34/100
# 28/28 [==============================] - 10s 365ms/step - loss: 0.2689 - accuracy: 0.5936 - val_loss: 0.1820 - val_accuracy: 0.8889
# Epoch 35/100
# 28/28 [==============================] - 10s 362ms/step - loss: 0.2487 - accuracy: 0.5925 - val_loss: 0.1812 - val_accuracy: 0.9259
# Epoch 36/100
# 28/28 [==============================] - 10s 366ms/step - loss: 0.2545 - accuracy: 0.5936 - val_loss: 0.2385 - val_accuracy: 0.8889
# Epoch 37/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.2531 - accuracy: 0.5936 - val_loss: 0.1793 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 102ms/step - loss: 0.0518 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 15s 410ms/step - loss: 0.5119 - accuracy: 0.5357 - val_loss: 0.3040 - val_accuracy: 0.9630
# Epoch 2/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.3684 - accuracy: 0.6048 - val_loss: 0.3435 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.3504 - accuracy: 0.6095 - val_loss: 0.3933 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.3186 - accuracy: 0.6107 - val_loss: 0.3341 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.2975 - accuracy: 0.6202 - val_loss: 0.4117 - val_accuracy: 0.8148
# Epoch 6/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.2895 - accuracy: 0.6250 - val_loss: 0.3836 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 10s 372ms/step - loss: 0.2778 - accuracy: 0.6286 - val_loss: 0.2634 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.2729 - accuracy: 0.6286 - val_loss: 0.2903 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.2844 - accuracy: 0.6286 - val_loss: 0.3610 - val_accuracy: 0.8148
# Epoch 10/100
# 27/27 [==============================] - 10s 365ms/step - loss: 0.2719 - accuracy: 0.6298 - val_loss: 0.2682 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 10s 368ms/step - loss: 0.2635 - accuracy: 0.6286 - val_loss: 0.2143 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 10s 368ms/step - loss: 0.2643 - accuracy: 0.6286 - val_loss: 0.3128 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.2672 - accuracy: 0.6298 - val_loss: 0.2263 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2698 - accuracy: 0.6310 - val_loss: 0.2573 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 10s 374ms/step - loss: 0.2586 - accuracy: 0.6310 - val_loss: 0.2132 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2660 - accuracy: 0.6286 - val_loss: 0.2961 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.2567 - accuracy: 0.6298 - val_loss: 0.2442 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.2466 - accuracy: 0.6310 - val_loss: 0.2749 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.2469 - accuracy: 0.6310 - val_loss: 0.2733 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2328 - accuracy: 0.6310 - val_loss: 0.2238 - val_accuracy: 0.9259
# Epoch 41/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2366 - accuracy: 0.6310 - val_loss: 0.1934 - val_accuracy: 0.9630
# Epoch 42/100
# 27/27 [==============================] - 10s 368ms/step - loss: 0.2306 - accuracy: 0.6298 - val_loss: 0.2082 - val_accuracy: 0.9630
# Epoch 43/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2307 - accuracy: 0.6310 - val_loss: 0.2509 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2292 - accuracy: 0.6310 - val_loss: 0.1892 - val_accuracy: 0.9630
# Epoch 45/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2260 - accuracy: 0.6310 - val_loss: 0.2746 - val_accuracy: 0.8889
# Epoch 46/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2318 - accuracy: 0.6298 - val_loss: 0.2793 - val_accuracy: 0.9259
# Epoch 47/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2282 - accuracy: 0.6310 - val_loss: 0.2352 - val_accuracy: 0.9259
# Epoch 48/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2299 - accuracy: 0.6310 - val_loss: 0.1986 - val_accuracy: 0.9630
# Epoch 49/100
# 27/27 [==============================] - 10s 372ms/step - loss: 0.2333 - accuracy: 0.6310 - val_loss: 0.2020 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 99ms/step - loss: 0.1432 - accuracy: 0.9118
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f33080aab00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.9764705777168274]
# [0.973400290736091]
# Epoch 1/100
# 28/28 [==============================] - 15s 413ms/step - loss: 0.5360 - accuracy: 0.4909 - val_loss: 0.5005 - val_accuracy: 0.7037
# Epoch 2/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.4088 - accuracy: 0.5548 - val_loss: 0.3533 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3618 - accuracy: 0.5742 - val_loss: 0.3415 - val_accuracy: 0.8148
# Epoch 4/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3439 - accuracy: 0.5731 - val_loss: 0.3249 - val_accuracy: 0.8148
# Epoch 5/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.3144 - accuracy: 0.5833 - val_loss: 0.2745 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.3275 - accuracy: 0.5811 - val_loss: 0.3112 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.3106 - accuracy: 0.5856 - val_loss: 0.2474 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.3029 - accuracy: 0.5845 - val_loss: 0.3058 - val_accuracy: 0.8519
# Epoch 9/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.3047 - accuracy: 0.5845 - val_loss: 0.3079 - val_accuracy: 0.8889
# Epoch 10/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2851 - accuracy: 0.5879 - val_loss: 0.2204 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2911 - accuracy: 0.5868 - val_loss: 0.2428 - val_accuracy: 0.8889
# Epoch 12/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2887 - accuracy: 0.5890 - val_loss: 0.2229 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2841 - accuracy: 0.5868 - val_loss: 0.1702 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2820 - accuracy: 0.5868 - val_loss: 0.3041 - val_accuracy: 0.8519
# Epoch 15/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2864 - accuracy: 0.5890 - val_loss: 0.2319 - val_accuracy: 0.8889
# Epoch 16/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2815 - accuracy: 0.5879 - val_loss: 0.2471 - val_accuracy: 0.8148
# Epoch 17/100
# ...
# Epoch 48/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.2651 - accuracy: 0.5648 - val_loss: 0.1959 - val_accuracy: 0.9630
# Epoch 49/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.2588 - accuracy: 0.5648 - val_loss: 0.1276 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 100ms/step - loss: 0.1615 - accuracy: 0.9118
# Epoch 1/100
# 28/28 [==============================] - 16s 416ms/step - loss: 0.5332 - accuracy: 0.4764 - val_loss: 0.1547 - val_accuracy: 0.9630
# Epoch 2/100
# 28/28 [==============================] - 11s 382ms/step - loss: 0.4128 - accuracy: 0.5507 - val_loss: 0.1546 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 11s 379ms/step - loss: 0.3801 - accuracy: 0.5619 - val_loss: 0.1260 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 11s 378ms/step - loss: 0.3454 - accuracy: 0.5687 - val_loss: 0.1294 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 11s 379ms/step - loss: 0.3414 - accuracy: 0.5698 - val_loss: 0.1049 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3341 - accuracy: 0.5709 - val_loss: 0.1411 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 11s 380ms/step - loss: 0.3142 - accuracy: 0.5766 - val_loss: 0.1101 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3160 - accuracy: 0.5743 - val_loss: 0.1458 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.3177 - accuracy: 0.5721 - val_loss: 0.1568 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.3095 - accuracy: 0.5755 - val_loss: 0.2258 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2935 - accuracy: 0.5777 - val_loss: 0.1203 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2900 - accuracy: 0.5788 - val_loss: 0.0810 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2894 - accuracy: 0.5766 - val_loss: 0.1060 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.3082 - accuracy: 0.5732 - val_loss: 0.1718 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 11s 380ms/step - loss: 0.2959 - accuracy: 0.5777 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 11s 378ms/step - loss: 0.2780 - accuracy: 0.5788 - val_loss: 0.0475 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2817 - accuracy: 0.5788 - val_loss: 0.0543 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2768 - accuracy: 0.5788 - val_loss: 0.1034 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 11s 378ms/step - loss: 0.2790 - accuracy: 0.5788 - val_loss: 0.1342 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 11s 379ms/step - loss: 0.2737 - accuracy: 0.5788 - val_loss: 0.0755 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2786 - accuracy: 0.5788 - val_loss: 0.0710 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2780 - accuracy: 0.5788 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 11s 378ms/step - loss: 0.2753 - accuracy: 0.5788 - val_loss: 0.0439 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2662 - accuracy: 0.5788 - val_loss: 0.0447 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 11s 380ms/step - loss: 0.2674 - accuracy: 0.5788 - val_loss: 0.0678 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2623 - accuracy: 0.5788 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2638 - accuracy: 0.5788 - val_loss: 0.0545 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2634 - accuracy: 0.5788 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2622 - accuracy: 0.5788 - val_loss: 0.0749 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2705 - accuracy: 0.5777 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 11s 379ms/step - loss: 0.2654 - accuracy: 0.5788 - val_loss: 0.0418 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2627 - accuracy: 0.5788 - val_loss: 0.0485 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2575 - accuracy: 0.5788 - val_loss: 0.0577 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2642 - accuracy: 0.5788 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2595 - accuracy: 0.5788 - val_loss: 0.0842 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2609 - accuracy: 0.5777 - val_loss: 0.0753 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2580 - accuracy: 0.5788 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.2625 - accuracy: 0.5788 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2534 - accuracy: 0.5788 - val_loss: 0.0570 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2606 - accuracy: 0.5788 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2590 - accuracy: 0.5788 - val_loss: 0.1186 - val_accuracy: 0.9630
# Epoch 42/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2628 - accuracy: 0.5788 - val_loss: 0.0624 - val_accuracy: 1.0000
# Epoch 43/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2612 - accuracy: 0.5788 - val_loss: 0.0583 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 11s 375ms/step - loss: 0.2492 - accuracy: 0.5788 - val_loss: 0.0555 - val_accuracy: 1.0000
# Epoch 45/100
# 28/28 [==============================] - 11s 375ms/step - loss: 0.2553 - accuracy: 0.5788 - val_loss: 0.0818 - val_accuracy: 1.0000
# Epoch 46/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2603 - accuracy: 0.5788 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 47/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2644 - accuracy: 0.5788 - val_loss: 0.0399 - val_accuracy: 1.0000
# Epoch 48/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2515 - accuracy: 0.5788 - val_loss: 0.0745 - val_accuracy: 1.0000
# Epoch 49/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2535 - accuracy: 0.5788 - val_loss: 0.1160 - val_accuracy: 0.9630
# Epoch 50/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2588 - accuracy: 0.5788 - val_loss: 0.0997 - val_accuracy: 0.9630
# Epoch 51/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2648 - accuracy: 0.5788 - val_loss: 0.1405 - val_accuracy: 0.9630
# Epoch 52/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2567 - accuracy: 0.5788 - val_loss: 0.1160 - val_accuracy: 0.9630
# Epoch 53/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2549 - accuracy: 0.5788 - val_loss: 0.0656 - val_accuracy: 1.0000
# Epoch 54/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2497 - accuracy: 0.5788 - val_loss: 0.0672 - val_accuracy: 1.0000
# Epoch 55/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.2518 - accuracy: 0.5788 - val_loss: 0.0795 - val_accuracy: 1.0000
# Epoch 56/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2519 - accuracy: 0.5788 - val_loss: 0.0413 - val_accuracy: 1.0000
# Epoch 57/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2601 - accuracy: 0.5788 - val_loss: 0.1459 - val_accuracy: 0.9259
# Epoch 58/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2550 - accuracy: 0.5788 - val_loss: 0.1057 - val_accuracy: 0.9630
# Epoch 59/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2492 - accuracy: 0.5788 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 60/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2488 - accuracy: 0.5788 - val_loss: 0.1110 - val_accuracy: 1.0000
# Epoch 61/100
# 28/28 [==============================] - 11s 378ms/step - loss: 0.2480 - accuracy: 0.5788 - val_loss: 0.0678 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 111ms/step - loss: 0.1020 - accuracy: 0.9706
# Epoch 1/100
# 28/28 [==============================] - 16s 413ms/step - loss: 0.5496 - accuracy: 0.5034 - val_loss: 0.3534 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3739 - accuracy: 0.5736 - val_loss: 0.3141 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3533 - accuracy: 0.5816 - val_loss: 0.3365 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3320 - accuracy: 0.5816 - val_loss: 0.2808 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3368 - accuracy: 0.5851 - val_loss: 0.3733 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.3097 - accuracy: 0.5920 - val_loss: 0.2980 - val_accuracy: 0.8519
# Epoch 7/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3058 - accuracy: 0.5931 - val_loss: 0.3236 - val_accuracy: 0.8519
# Epoch 8/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3050 - accuracy: 0.5931 - val_loss: 0.2375 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.3007 - accuracy: 0.5931 - val_loss: 0.5448 - val_accuracy: 0.6296
# Epoch 10/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2944 - accuracy: 0.5954 - val_loss: 0.2515 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2849 - accuracy: 0.5943 - val_loss: 0.3119 - val_accuracy: 0.8519
# Epoch 12/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2915 - accuracy: 0.5966 - val_loss: 0.2628 - val_accuracy: 0.8148
# Epoch 13/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2758 - accuracy: 0.5954 - val_loss: 0.2853 - val_accuracy: 0.8519
# Epoch 14/100
# 28/28 [==============================] - 11s 380ms/step - loss: 0.2854 - accuracy: 0.5954 - val_loss: 0.2246 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2802 - accuracy: 0.5966 - val_loss: 0.2510 - val_accuracy: 0.8519
# Epoch 16/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2796 - accuracy: 0.5954 - val_loss: 0.2858 - val_accuracy: 0.8519
# Epoch 17/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2689 - accuracy: 0.5966 - val_loss: 0.3577 - val_accuracy: 0.8519
# Epoch 18/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2792 - accuracy: 0.5966 - val_loss: 0.2437 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2809 - accuracy: 0.5977 - val_loss: 0.2373 - val_accuracy: 0.8889
# Epoch 20/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2817 - accuracy: 0.5977 - val_loss: 0.2535 - val_accuracy: 0.8519
# Epoch 21/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2699 - accuracy: 0.5977 - val_loss: 0.2572 - val_accuracy: 0.8889
# Epoch 22/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.2694 - accuracy: 0.5977 - val_loss: 0.2644 - val_accuracy: 0.8889
# Epoch 23/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2685 - accuracy: 0.5966 - val_loss: 0.2669 - val_accuracy: 0.8889
# Epoch 24/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2715 - accuracy: 0.5966 - val_loss: 0.2754 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2676 - accuracy: 0.5977 - val_loss: 0.2930 - val_accuracy: 0.8889
# Epoch 26/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2670 - accuracy: 0.5977 - val_loss: 0.3948 - val_accuracy: 0.8148
# Epoch 27/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2971 - accuracy: 0.5931 - val_loss: 0.2293 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.2750 - accuracy: 0.5954 - val_loss: 0.2423 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2616 - accuracy: 0.5977 - val_loss: 0.3736 - val_accuracy: 0.7778
# 2/2 [==============================] - 1s 106ms/step - loss: 0.1269 - accuracy: 0.9412
# Epoch 1/100
# 28/28 [==============================] - 16s 412ms/step - loss: 0.4887 - accuracy: 0.5207 - val_loss: 0.5347 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3821 - accuracy: 0.5552 - val_loss: 0.4043 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3740 - accuracy: 0.5586 - val_loss: 0.3122 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.3465 - accuracy: 0.5644 - val_loss: 0.3226 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3276 - accuracy: 0.5713 - val_loss: 0.3491 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.3258 - accuracy: 0.5667 - val_loss: 0.2427 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3158 - accuracy: 0.5701 - val_loss: 0.2698 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3105 - accuracy: 0.5759 - val_loss: 0.2061 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.3035 - accuracy: 0.5747 - val_loss: 0.2308 - val_accuracy: 0.8889
# Epoch 10/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3009 - accuracy: 0.5701 - val_loss: 0.2066 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2975 - accuracy: 0.5759 - val_loss: 0.1958 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.2904 - accuracy: 0.5747 - val_loss: 0.2519 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.2938 - accuracy: 0.5759 - val_loss: 0.1170 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3007 - accuracy: 0.5724 - val_loss: 0.1474 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.3002 - accuracy: 0.5759 - val_loss: 0.2002 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2847 - accuracy: 0.5770 - val_loss: 0.1611 - val_accuracy: 0.9259
# Epoch 17/100
#  2/28 [=>............................] - ETA: 9s - loss: 0.3263 - accuracy: 0.5000

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.974, mean test f1 score is 0.970, max test accuracy is 0.994, max test f1 score is 0.993, min test accuracy is 0.959, min test f1 score is 0.951, std of test accuracy is 0.012, std of test f1 score is 0.014
