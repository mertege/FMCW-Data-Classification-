# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/Range-Doppler-Spectrogram-LSTM/RD_SP_LSTM_dropout_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  dropout0.3

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number =   100 # 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.1 # 0.
repeat_of_mixup = 5
number_of_repeat = 5
unit_number_of_lstm = 16 #8 16 32
dense_unit_of_range_doppler_function = 256 #128 256 512
dense_unit_of_spectrogram_function = 8
decoder_dense_unit = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_range_doppler_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def lstm_encoder_network_2(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_spectrogram_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense_unit)(input)
      x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_lstm(range_doppler_input)

    input_shape = spectrogram_concat_shuffle_train.shape[1:3]
    base_network_lstm_2 = lstm_encoder_network_2(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_lstm_2(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(base_network_lstm_2.summary())
      print(base_decoder_network.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image, spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler, validation_spectrogram) , (spectrogram_validation_labels)))
    #plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    #plt.title('model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('epoch')
    plt.legend(['Validation Accuracy'], loc='right')
    #plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='right')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    #plt.title('model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')
    plt.show()

    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    print(confusion_matrix(range_doppler_concat_label_shuffle_test, y_test_predicted_binary))
    print(classification_report(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, digits=3))
                  

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 19s 379ms/step - loss: 0.3941 - accuracy: 0.5676 - val_loss: 0.3670 - val_accuracy: 0.8148
# Epoch 2/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.3206 - accuracy: 0.5980 - val_loss: 0.3688 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2858 - accuracy: 0.6059 - val_loss: 0.2718 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2831 - accuracy: 0.6081 - val_loss: 0.1528 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2729 - accuracy: 0.6092 - val_loss: 0.2656 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2712 - accuracy: 0.6081 - val_loss: 0.2021 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2532 - accuracy: 0.6104 - val_loss: 0.1359 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2499 - accuracy: 0.6104 - val_loss: 0.1329 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2479 - accuracy: 0.6092 - val_loss: 0.1417 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2452 - accuracy: 0.6104 - val_loss: 0.2272 - val_accuracy: 0.8889
# Epoch 11/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2526 - accuracy: 0.6104 - val_loss: 0.1175 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2569 - accuracy: 0.6104 - val_loss: 0.1210 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2503 - accuracy: 0.6104 - val_loss: 0.1727 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2504 - accuracy: 0.6104 - val_loss: 0.0871 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2412 - accuracy: 0.6104 - val_loss: 0.0818 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2377 - accuracy: 0.6104 - val_loss: 0.0893 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2334 - accuracy: 0.6104 - val_loss: 0.0667 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2398 - accuracy: 0.6104 - val_loss: 0.1022 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2376 - accuracy: 0.6104 - val_loss: 0.0891 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2376 - accuracy: 0.6104 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2356 - accuracy: 0.6104 - val_loss: 0.0939 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2354 - accuracy: 0.6104 - val_loss: 0.1674 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2309 - accuracy: 0.6104 - val_loss: 0.0752 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2357 - accuracy: 0.6104 - val_loss: 0.1094 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2355 - accuracy: 0.6104 - val_loss: 0.1027 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2303 - accuracy: 0.6104 - val_loss: 0.1031 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2273 - accuracy: 0.6104 - val_loss: 0.1452 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2296 - accuracy: 0.6104 - val_loss: 0.1064 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2327 - accuracy: 0.6104 - val_loss: 0.1163 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2314 - accuracy: 0.6104 - val_loss: 0.1213 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2246 - accuracy: 0.6104 - val_loss: 0.1577 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2254 - accuracy: 0.6104 - val_loss: 0.1853 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 131ms/step - loss: 0.0436 - accuracy: 1.0000
# [[23  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#          0.0      1.000     1.000     1.000        23
#          1.0      1.000     1.000     1.000        11
#
#     accuracy                          1.000        34
#    macro avg      1.000     1.000     1.000        34
# weighted avg      1.000     1.000     1.000        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 16s 378ms/step - loss: 0.4295 - accuracy: 0.5310 - val_loss: 0.0919 - val_accuracy: 1.0000
# Epoch 2/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.3513 - accuracy: 0.5552 - val_loss: 0.1156 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.3214 - accuracy: 0.5690 - val_loss: 0.0710 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.3036 - accuracy: 0.5724 - val_loss: 0.0717 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2887 - accuracy: 0.5759 - val_loss: 0.0621 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2811 - accuracy: 0.5770 - val_loss: 0.0788 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2826 - accuracy: 0.5770 - val_loss: 0.1470 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2870 - accuracy: 0.5770 - val_loss: 0.0724 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2789 - accuracy: 0.5770 - val_loss: 0.0978 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2645 - accuracy: 0.5770 - val_loss: 0.4597 - val_accuracy: 0.7778
# Epoch 11/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2793 - accuracy: 0.5770 - val_loss: 0.0954 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2722 - accuracy: 0.5770 - val_loss: 0.0509 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2676 - accuracy: 0.5770 - val_loss: 0.0729 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2617 - accuracy: 0.5759 - val_loss: 0.1236 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2610 - accuracy: 0.5770 - val_loss: 0.0248 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2636 - accuracy: 0.5770 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2726 - accuracy: 0.5770 - val_loss: 0.1098 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2648 - accuracy: 0.5770 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2675 - accuracy: 0.5770 - val_loss: 0.0638 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2578 - accuracy: 0.5770 - val_loss: 0.0686 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2495 - accuracy: 0.5770 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2568 - accuracy: 0.5770 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2604 - accuracy: 0.5770 - val_loss: 0.0834 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2549 - accuracy: 0.5770 - val_loss: 0.1027 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2534 - accuracy: 0.5770 - val_loss: 0.0549 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2475 - accuracy: 0.5770 - val_loss: 0.0575 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2505 - accuracy: 0.5770 - val_loss: 0.0909 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2564 - accuracy: 0.5770 - val_loss: 0.1775 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2512 - accuracy: 0.5770 - val_loss: 0.0714 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2538 - accuracy: 0.5770 - val_loss: 0.1410 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2529 - accuracy: 0.5770 - val_loss: 0.0683 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2550 - accuracy: 0.5770 - val_loss: 0.1159 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2494 - accuracy: 0.5770 - val_loss: 0.0852 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2461 - accuracy: 0.5770 - val_loss: 0.0785 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2472 - accuracy: 0.5770 - val_loss: 0.0941 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2521 - accuracy: 0.5770 - val_loss: 0.1002 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2553 - accuracy: 0.5759 - val_loss: 0.0356 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 124ms/step - loss: 0.1163 - accuracy: 0.9706
# [[23  0]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.958     1.000     0.979        23
#          1.0      1.000     0.909     0.952        11
#
#     accuracy                          0.971        34
#    macro avg      0.979     0.955     0.966        34
# weighted avg      0.972     0.971     0.970        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 398ms/step - loss: 0.4249 - accuracy: 0.5417 - val_loss: 0.5098 - val_accuracy: 0.7407
# Epoch 2/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.3324 - accuracy: 0.5741 - val_loss: 0.2070 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.3075 - accuracy: 0.5810 - val_loss: 0.2720 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2890 - accuracy: 0.5868 - val_loss: 0.2610 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2796 - accuracy: 0.5880 - val_loss: 0.1594 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2757 - accuracy: 0.5880 - val_loss: 0.1305 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2792 - accuracy: 0.5880 - val_loss: 0.1501 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2703 - accuracy: 0.5880 - val_loss: 0.1157 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2688 - accuracy: 0.5880 - val_loss: 0.1338 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2629 - accuracy: 0.5880 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2564 - accuracy: 0.5880 - val_loss: 0.1543 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2559 - accuracy: 0.5880 - val_loss: 0.1243 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2587 - accuracy: 0.5880 - val_loss: 0.1499 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2506 - accuracy: 0.5880 - val_loss: 0.1065 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2530 - accuracy: 0.5868 - val_loss: 0.1372 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2514 - accuracy: 0.5880 - val_loss: 0.1299 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2455 - accuracy: 0.5880 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2526 - accuracy: 0.5880 - val_loss: 0.1166 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2495 - accuracy: 0.5880 - val_loss: 0.1404 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2492 - accuracy: 0.5880 - val_loss: 0.1177 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2501 - accuracy: 0.5880 - val_loss: 0.1331 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2527 - accuracy: 0.5880 - val_loss: 0.1108 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2428 - accuracy: 0.5880 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2454 - accuracy: 0.5880 - val_loss: 0.0968 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2501 - accuracy: 0.5880 - val_loss: 0.1039 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2444 - accuracy: 0.5880 - val_loss: 0.1085 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2378 - accuracy: 0.5880 - val_loss: 0.1356 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2433 - accuracy: 0.5880 - val_loss: 0.1957 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2503 - accuracy: 0.5880 - val_loss: 0.1364 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2405 - accuracy: 0.5880 - val_loss: 0.1379 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2427 - accuracy: 0.5880 - val_loss: 0.0941 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2406 - accuracy: 0.5880 - val_loss: 0.1535 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2436 - accuracy: 0.5880 - val_loss: 0.1592 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2415 - accuracy: 0.5880 - val_loss: 0.1435 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2388 - accuracy: 0.5880 - val_loss: 0.1859 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2465 - accuracy: 0.5880 - val_loss: 0.1208 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2420 - accuracy: 0.5880 - val_loss: 0.1240 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2427 - accuracy: 0.5880 - val_loss: 0.1287 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2342 - accuracy: 0.5880 - val_loss: 0.1336 - val_accuracy: 0.9630
# Epoch 40/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2336 - accuracy: 0.5880 - val_loss: 0.1565 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2349 - accuracy: 0.5880 - val_loss: 0.1427 - val_accuracy: 0.9630
# Epoch 42/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2329 - accuracy: 0.5880 - val_loss: 0.1663 - val_accuracy: 0.9259
# Epoch 43/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2358 - accuracy: 0.5880 - val_loss: 0.1202 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2366 - accuracy: 0.5880 - val_loss: 0.1350 - val_accuracy: 0.9630
# Epoch 45/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2351 - accuracy: 0.5868 - val_loss: 0.1680 - val_accuracy: 0.9259
# Epoch 46/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2315 - accuracy: 0.5880 - val_loss: 0.2398 - val_accuracy: 0.8519
# 2/2 [==============================] - 2s 120ms/step - loss: 0.1036 - accuracy: 1.0000
# [[23  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#          0.0      1.000     1.000     1.000        23
#          1.0      1.000     1.000     1.000        11
#
#     accuracy                          1.000        34
#    macro avg      1.000     1.000     1.000        34
# weighted avg      1.000     1.000     1.000        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 17s 384ms/step - loss: 0.3882 - accuracy: 0.5765 - val_loss: 0.6063 - val_accuracy: 0.8148
# Epoch 2/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3077 - accuracy: 0.6256 - val_loss: 0.4686 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2709 - accuracy: 0.6313 - val_loss: 0.3022 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2630 - accuracy: 0.6347 - val_loss: 0.1656 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2487 - accuracy: 0.6370 - val_loss: 0.1462 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2519 - accuracy: 0.6370 - val_loss: 0.1792 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2449 - accuracy: 0.6358 - val_loss: 0.1232 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2445 - accuracy: 0.6370 - val_loss: 0.1254 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2540 - accuracy: 0.6358 - val_loss: 0.1612 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2374 - accuracy: 0.6370 - val_loss: 0.1432 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2354 - accuracy: 0.6370 - val_loss: 0.1703 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2383 - accuracy: 0.6358 - val_loss: 0.1470 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2322 - accuracy: 0.6358 - val_loss: 0.0843 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2443 - accuracy: 0.6358 - val_loss: 0.1731 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2236 - accuracy: 0.6370 - val_loss: 0.0944 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2265 - accuracy: 0.6370 - val_loss: 0.0898 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2266 - accuracy: 0.6370 - val_loss: 0.0644 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2202 - accuracy: 0.6370 - val_loss: 0.1581 - val_accuracy: 0.9259
# Epoch 19/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2200 - accuracy: 0.6370 - val_loss: 0.1094 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2186 - accuracy: 0.6370 - val_loss: 0.1358 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2173 - accuracy: 0.6370 - val_loss: 0.1012 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2147 - accuracy: 0.6370 - val_loss: 0.1056 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2161 - accuracy: 0.6370 - val_loss: 0.1963 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2182 - accuracy: 0.6370 - val_loss: 0.1471 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2227 - accuracy: 0.6370 - val_loss: 0.0990 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2150 - accuracy: 0.6370 - val_loss: 0.1103 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2137 - accuracy: 0.6370 - val_loss: 0.1806 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2185 - accuracy: 0.6370 - val_loss: 0.0954 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2173 - accuracy: 0.6370 - val_loss: 0.0596 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2159 - accuracy: 0.6370 - val_loss: 0.1158 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2092 - accuracy: 0.6370 - val_loss: 0.0963 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2098 - accuracy: 0.6370 - val_loss: 0.1182 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2122 - accuracy: 0.6370 - val_loss: 0.1514 - val_accuracy: 0.9259
# Epoch 34/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2179 - accuracy: 0.6370 - val_loss: 0.1233 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2092 - accuracy: 0.6370 - val_loss: 0.1276 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2164 - accuracy: 0.6370 - val_loss: 0.0903 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2171 - accuracy: 0.6370 - val_loss: 0.1040 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2074 - accuracy: 0.6370 - val_loss: 0.0962 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2076 - accuracy: 0.6370 - val_loss: 0.1838 - val_accuracy: 0.8889
# Epoch 40/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2123 - accuracy: 0.6370 - val_loss: 0.1296 - val_accuracy: 0.9259
# Epoch 41/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2077 - accuracy: 0.6370 - val_loss: 0.1186 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2066 - accuracy: 0.6370 - val_loss: 0.0947 - val_accuracy: 1.0000
# Epoch 43/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2103 - accuracy: 0.6370 - val_loss: 0.1219 - val_accuracy: 0.9630
# Epoch 44/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2075 - accuracy: 0.6370 - val_loss: 0.1272 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 125ms/step - loss: 0.1759 - accuracy: 0.9706
# [[23  0]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.958     1.000     0.979        23
#          1.0      1.000     0.909     0.952        11
#
#     accuracy                          0.971        34
#    macro avg      0.979     0.955     0.966        34
# weighted avg      0.972     0.971     0.970        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
# ...
# 27/27 [==============================] - 16s 395ms/step - loss: 0.3998 - accuracy: 0.5463 - val_loss: 0.9709 - val_accuracy: 0.6296
# Epoch 2/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3160 - accuracy: 0.5741 - val_loss: 0.6706 - val_accuracy: 0.6667
# Epoch 3/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3076 - accuracy: 0.5741 - val_loss: 0.5295 - val_accuracy: 0.7037
# Epoch 4/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3010 - accuracy: 0.5810 - val_loss: 0.3603 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2889 - accuracy: 0.5810 - val_loss: 0.3632 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2789 - accuracy: 0.5810 - val_loss: 0.3812 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2769 - accuracy: 0.5810 - val_loss: 0.3131 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2682 - accuracy: 0.5810 - val_loss: 0.2991 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2639 - accuracy: 0.5810 - val_loss: 0.2685 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2637 - accuracy: 0.5810 - val_loss: 0.2280 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2672 - accuracy: 0.5810 - val_loss: 0.2691 - val_accuracy: 0.8148
# Epoch 12/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2578 - accuracy: 0.5810 - val_loss: 0.3720 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2626 - accuracy: 0.5810 - val_loss: 0.3474 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2524 - accuracy: 0.5810 - val_loss: 0.5019 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2571 - accuracy: 0.5810 - val_loss: 0.3352 - val_accuracy: 0.8889
# Epoch 16/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2531 - accuracy: 0.5810 - val_loss: 0.3943 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2532 - accuracy: 0.5810 - val_loss: 0.4533 - val_accuracy: 0.8889
# Epoch 18/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2585 - accuracy: 0.5810 - val_loss: 0.3414 - val_accuracy: 0.8889
# Epoch 19/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2553 - accuracy: 0.5810 - val_loss: 0.4433 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2489 - accuracy: 0.5810 - val_loss: 0.4363 - val_accuracy: 0.8889
# Epoch 21/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2468 - accuracy: 0.5810 - val_loss: 0.4355 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2493 - accuracy: 0.5810 - val_loss: 0.4086 - val_accuracy: 0.8889
# Epoch 23/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2480 - accuracy: 0.5810 - val_loss: 0.3812 - val_accuracy: 0.8889
# Epoch 24/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2425 - accuracy: 0.5810 - val_loss: 0.2888 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2465 - accuracy: 0.5810 - val_loss: 0.5343 - val_accuracy: 0.8889
# 2/2 [==============================] - 2s 121ms/step - loss: 0.1936 - accuracy: 0.9706
# [[23  0]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.958     1.000     0.979        23
#          1.0      1.000     0.909     0.952        11
#
#     accuracy                          0.971        34
#    macro avg      0.979     0.955     0.966        34
# weighted avg      0.972     0.971     0.970        34
#
# Epoch 1/100
# 27/27 [==============================] - 16s 382ms/step - loss: 0.4428 - accuracy: 0.5326 - val_loss: 0.9152 - val_accuracy: 0.7037
# Epoch 2/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3430 - accuracy: 0.5641 - val_loss: 0.3903 - val_accuracy: 0.8519
# Epoch 3/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.3220 - accuracy: 0.5676 - val_loss: 0.2235 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.3088 - accuracy: 0.5769 - val_loss: 0.2044 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2843 - accuracy: 0.5781 - val_loss: 0.2191 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2847 - accuracy: 0.5769 - val_loss: 0.2009 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2774 - accuracy: 0.5781 - val_loss: 0.1950 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2812 - accuracy: 0.5781 - val_loss: 0.1654 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2707 - accuracy: 0.5769 - val_loss: 0.2509 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2727 - accuracy: 0.5769 - val_loss: 0.1478 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2632 - accuracy: 0.5781 - val_loss: 0.1796 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2641 - accuracy: 0.5781 - val_loss: 0.1561 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2586 - accuracy: 0.5781 - val_loss: 0.1718 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2699 - accuracy: 0.5781 - val_loss: 0.2028 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2689 - accuracy: 0.5781 - val_loss: 0.1909 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2619 - accuracy: 0.5781 - val_loss: 0.1974 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2571 - accuracy: 0.5781 - val_loss: 0.1469 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2518 - accuracy: 0.5781 - val_loss: 0.1576 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2554 - accuracy: 0.5769 - val_loss: 0.2228 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2624 - accuracy: 0.5781 - val_loss: 0.1200 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2677 - accuracy: 0.5781 - val_loss: 0.1214 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2503 - accuracy: 0.5781 - val_loss: 0.1251 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2522 - accuracy: 0.5781 - val_loss: 0.1241 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2509 - accuracy: 0.5781 - val_loss: 0.1523 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2455 - accuracy: 0.5781 - val_loss: 0.1498 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2521 - accuracy: 0.5781 - val_loss: 0.1449 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2491 - accuracy: 0.5781 - val_loss: 0.1678 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2458 - accuracy: 0.5781 - val_loss: 0.1408 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2465 - accuracy: 0.5781 - val_loss: 0.1347 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2423 - accuracy: 0.5781 - val_loss: 0.1315 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2464 - accuracy: 0.5781 - val_loss: 0.1614 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2449 - accuracy: 0.5781 - val_loss: 0.1365 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2490 - accuracy: 0.5769 - val_loss: 0.2213 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2502 - accuracy: 0.5781 - val_loss: 0.1351 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2452 - accuracy: 0.5781 - val_loss: 0.2229 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 127ms/step - loss: 0.0779 - accuracy: 1.0000
# [[23  0]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#          0.0      1.000     1.000     1.000        23
#          1.0      1.000     1.000     1.000        11
#
#     accuracy                          1.000        34
#    macro avg      1.000     1.000     1.000        34
# weighted avg      1.000     1.000     1.000        34
#
# Epoch 1/100
# 27/27 [==============================] - 16s 398ms/step - loss: 0.4385 - accuracy: 0.5347 - val_loss: 0.5803 - val_accuracy: 0.7407
# Epoch 2/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3323 - accuracy: 0.5752 - val_loss: 0.2625 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2995 - accuracy: 0.5833 - val_loss: 0.4952 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2937 - accuracy: 0.5845 - val_loss: 0.1947 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2799 - accuracy: 0.5856 - val_loss: 0.1461 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2831 - accuracy: 0.5833 - val_loss: 0.1404 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2808 - accuracy: 0.5856 - val_loss: 0.1489 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2658 - accuracy: 0.5856 - val_loss: 0.1832 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2686 - accuracy: 0.5845 - val_loss: 0.1464 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2629 - accuracy: 0.5856 - val_loss: 0.1535 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2658 - accuracy: 0.5856 - val_loss: 0.1506 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2548 - accuracy: 0.5856 - val_loss: 0.1248 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2620 - accuracy: 0.5856 - val_loss: 0.1501 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2555 - accuracy: 0.5856 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2584 - accuracy: 0.5856 - val_loss: 0.0720 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2524 - accuracy: 0.5856 - val_loss: 0.0856 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2506 - accuracy: 0.5856 - val_loss: 0.0623 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2514 - accuracy: 0.5856 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2463 - accuracy: 0.5856 - val_loss: 0.0634 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2561 - accuracy: 0.5856 - val_loss: 0.0752 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2521 - accuracy: 0.5856 - val_loss: 0.1086 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2473 - accuracy: 0.5856 - val_loss: 0.1001 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2572 - accuracy: 0.5856 - val_loss: 0.1044 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2465 - accuracy: 0.5856 - val_loss: 0.0538 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2479 - accuracy: 0.5856 - val_loss: 0.1206 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2476 - accuracy: 0.5856 - val_loss: 0.0903 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2433 - accuracy: 0.5856 - val_loss: 0.0741 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2431 - accuracy: 0.5856 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2444 - accuracy: 0.5856 - val_loss: 0.1014 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2414 - accuracy: 0.5856 - val_loss: 0.0872 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2409 - accuracy: 0.5856 - val_loss: 0.1532 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2407 - accuracy: 0.5856 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2408 - accuracy: 0.5856 - val_loss: 0.1003 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2354 - accuracy: 0.5856 - val_loss: 0.0819 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2423 - accuracy: 0.5856 - val_loss: 0.1874 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2401 - accuracy: 0.5856 - val_loss: 0.1329 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2364 - accuracy: 0.5856 - val_loss: 0.0928 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2409 - accuracy: 0.5856 - val_loss: 0.1439 - val_accuracy: 1.0000
# Epoch 39/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2355 - accuracy: 0.5856 - val_loss: 0.1071 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 121ms/step - loss: 0.1123 - accuracy: 0.9706
# [[21  1]
#  [ 0 12]]
#               precision    recall  f1-score   support
#
#          0.0      1.000     0.955     0.977        22
#          1.0      0.923     1.000     0.960        12
#
#     accuracy                          0.971        34
#    macro avg      0.962     0.977     0.968        34
# weighted avg      0.973     0.971     0.971        34
#
# [0.970588219165802, 0.9470588088035583, 0.9529411673545838, 0.9529411554336548, 0.9764705657958984]
# [0.9677926870454115, 0.9398429951690821, 0.9460935274510668, 0.9464810654449878, 0.9730057255955327]
# Mean test accuracy is 0.960, mean test f1 score is 0.955, max test accuracy is 0.976, max test f1 score is 0.973, min test accuracy is 0.947, min test f1 score is 0.940, std of test accuracy is 0.011, std of test f1 score is 0.013
# Time elapsed through all process: 8690.475, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.960, mean test f1 score is 0.955, max test accuracy is 0.976, max test f1 score is 0.973, min test accuracy is 0.947, min test f1 score is 0.940, std of test accuracy is 0.011, std of test f1 score is 0.013
# Time elapsed through all process: 8690.475, sec

# %%
import numpy as np
import matplotlib.pyplot as plt
def createList(n):
    lst = []
    for i in range(n+1):
        lst.append(i)
    return(lst)


folds = createList(4)
values = [element * 100 for element in test_accuracy_per_fold]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(folds, values, color ='black',
        width = 0.4)
plt.xlabel("Accuracy vs k-run")
plt.ylabel("Accuracy")
plt.show()

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(folds, f1_score_per_fold, color ='black',
        width = 0.4)
plt.xlabel("F1 Score vs k-run")
plt.ylabel("F1 Score")
plt.show()
