# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_LSTM_v2_datalarla_denseunit128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada  dense_unit_of_lstm_function = 128 seçildi. 
#Mean test accuracy is 0.97, mean test f1 score is 0.97, max test accuracy is 0.98, max test f1 score is 0.98, min test accuracy is 0.95, min test f1 score is 0.95, std of test accuracy is 0.01, std of test f1 score is 0.01
#Time elapsed through all process: 8544.50, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resizedv2.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resizedv2.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resizedv2.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 16
dense_unit_of_lstm_function = 128
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 128)               21636352
#
#  model_1 (Functional)        (None, 1)                 49537
#
# =================================================================
# Total params: 21,685,889
# Trainable params: 21,357,953
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 14s 320ms/step - loss: 0.4815 - accuracy: 0.4906 - val_loss: 0.3741 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.4459 - accuracy: 0.5164 - val_loss: 0.2777 - val_accuracy: 0.8519
# Epoch 3/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.3934 - accuracy: 0.5270 - val_loss: 0.2493 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3621 - accuracy: 0.5423 - val_loss: 0.3311 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3464 - accuracy: 0.5458 - val_loss: 0.2215 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3391 - accuracy: 0.5469 - val_loss: 0.2742 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.3255 - accuracy: 0.5505 - val_loss: 0.2380 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3311 - accuracy: 0.5505 - val_loss: 0.2282 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.3283 - accuracy: 0.5540 - val_loss: 0.1600 - val_accuracy: 1.0000
# Epoch 10/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3171 - accuracy: 0.5540 - val_loss: 0.1433 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3005 - accuracy: 0.5528 - val_loss: 0.1491 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3085 - accuracy: 0.5528 - val_loss: 0.1671 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3074 - accuracy: 0.5540 - val_loss: 0.1971 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2996 - accuracy: 0.5540 - val_loss: 0.1438 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3006 - accuracy: 0.5540 - val_loss: 0.1411 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2967 - accuracy: 0.5516 - val_loss: 0.2491 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2955 - accuracy: 0.5540 - val_loss: 0.1438 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2875 - accuracy: 0.5540 - val_loss: 0.1637 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2898 - accuracy: 0.5540 - val_loss: 0.1849 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2855 - accuracy: 0.5540 - val_loss: 0.1587 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2891 - accuracy: 0.5516 - val_loss: 0.1420 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2987 - accuracy: 0.5528 - val_loss: 0.1115 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2847 - accuracy: 0.5540 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2834 - accuracy: 0.5540 - val_loss: 0.1318 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2821 - accuracy: 0.5528 - val_loss: 0.1431 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2903 - accuracy: 0.5540 - val_loss: 0.1122 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2841 - accuracy: 0.5528 - val_loss: 0.1703 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2804 - accuracy: 0.5540 - val_loss: 0.1193 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2775 - accuracy: 0.5540 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2743 - accuracy: 0.5540 - val_loss: 0.1525 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2787 - accuracy: 0.5540 - val_loss: 0.1899 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2740 - accuracy: 0.5540 - val_loss: 0.1299 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2769 - accuracy: 0.5528 - val_loss: 0.1176 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2794 - accuracy: 0.5540 - val_loss: 0.1228 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2729 - accuracy: 0.5540 - val_loss: 0.1599 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2843 - accuracy: 0.5540 - val_loss: 0.0926 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2788 - accuracy: 0.5540 - val_loss: 0.1480 - val_accuracy: 1.0000
# Epoch 38/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2843 - accuracy: 0.5540 - val_loss: 0.2029 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 8s 281ms/step - loss: 0.2808 - accuracy: 0.5528 - val_loss: 0.1664 - val_accuracy: 0.9259
# Epoch 40/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2674 - accuracy: 0.5540 - val_loss: 0.1510 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2763 - accuracy: 0.5540 - val_loss: 0.1208 - val_accuracy: 1.0000
# Epoch 42/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2712 - accuracy: 0.5528 - val_loss: 0.1170 - val_accuracy: 1.0000
# Epoch 43/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2672 - accuracy: 0.5528 - val_loss: 0.1742 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2722 - accuracy: 0.5540 - val_loss: 0.1217 - val_accuracy: 1.0000
# Epoch 45/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2717 - accuracy: 0.5540 - val_loss: 0.1316 - val_accuracy: 1.0000
# Epoch 46/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2672 - accuracy: 0.5540 - val_loss: 0.1106 - val_accuracy: 1.0000
# Epoch 47/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2684 - accuracy: 0.5540 - val_loss: 0.0890 - val_accuracy: 1.0000
# Epoch 48/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2694 - accuracy: 0.5540 - val_loss: 0.1815 - val_accuracy: 1.0000
# Epoch 49/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2685 - accuracy: 0.5540 - val_loss: 0.1833 - val_accuracy: 1.0000
# Epoch 50/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2704 - accuracy: 0.5540 - val_loss: 0.1756 - val_accuracy: 1.0000
# Epoch 51/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2614 - accuracy: 0.5540 - val_loss: 0.1938 - val_accuracy: 1.0000
# Epoch 52/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2656 - accuracy: 0.5540 - val_loss: 0.1480 - val_accuracy: 1.0000
# Epoch 53/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2716 - accuracy: 0.5540 - val_loss: 0.2106 - val_accuracy: 1.0000
# Epoch 54/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2668 - accuracy: 0.5540 - val_loss: 0.1651 - val_accuracy: 0.9630
# Epoch 55/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2707 - accuracy: 0.5528 - val_loss: 0.1904 - val_accuracy: 1.0000
# Epoch 56/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2682 - accuracy: 0.5540 - val_loss: 0.2080 - val_accuracy: 1.0000
# Epoch 57/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2603 - accuracy: 0.5540 - val_loss: 0.1513 - val_accuracy: 1.0000
# Epoch 58/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2627 - accuracy: 0.5540 - val_loss: 0.1356 - val_accuracy: 1.0000
# Epoch 59/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2675 - accuracy: 0.5540 - val_loss: 0.1694 - val_accuracy: 0.9259
# Epoch 60/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2583 - accuracy: 0.5540 - val_loss: 0.1859 - val_accuracy: 1.0000
# Epoch 61/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2681 - accuracy: 0.5540 - val_loss: 0.1248 - val_accuracy: 1.0000
# Epoch 62/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2724 - accuracy: 0.5540 - val_loss: 0.1981 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 117ms/step - loss: 0.0570 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 128)               21636352
#
#  model_1 (Functional)        (None, 1)                 49537
#
# =================================================================
# Total params: 21,685,889
# Trainable params: 21,357,953
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 11s 313ms/step - loss: 0.5999 - accuracy: 0.4444 - val_loss: 0.6646 - val_accuracy: 0.7037
# Epoch 2/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.4344 - accuracy: 0.5139 - val_loss: 0.2532 - val_accuracy: 0.8519
# Epoch 3/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3861 - accuracy: 0.5359 - val_loss: 0.2678 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3441 - accuracy: 0.5498 - val_loss: 0.2390 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.3450 - accuracy: 0.5463 - val_loss: 0.2099 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3409 - accuracy: 0.5498 - val_loss: 0.2276 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3263 - accuracy: 0.5509 - val_loss: 0.2102 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3128 - accuracy: 0.5521 - val_loss: 0.1705 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3107 - accuracy: 0.5544 - val_loss: 0.1725 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3156 - accuracy: 0.5521 - val_loss: 0.2602 - val_accuracy: 0.8519
# Epoch 11/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.3196 - accuracy: 0.5521 - val_loss: 0.1608 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3087 - accuracy: 0.5544 - val_loss: 0.1229 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2973 - accuracy: 0.5579 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3051 - accuracy: 0.5567 - val_loss: 0.1792 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2903 - accuracy: 0.5579 - val_loss: 0.0984 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2934 - accuracy: 0.5579 - val_loss: 0.1016 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3003 - accuracy: 0.5567 - val_loss: 0.1177 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2881 - accuracy: 0.5579 - val_loss: 0.0839 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2907 - accuracy: 0.5579 - val_loss: 0.1019 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2890 - accuracy: 0.5579 - val_loss: 0.1286 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2854 - accuracy: 0.5579 - val_loss: 0.0877 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2826 - accuracy: 0.5579 - val_loss: 0.1263 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2862 - accuracy: 0.5579 - val_loss: 0.1572 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2791 - accuracy: 0.5579 - val_loss: 0.0920 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2836 - accuracy: 0.5579 - val_loss: 0.0922 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2709 - accuracy: 0.5579 - val_loss: 0.1142 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2760 - accuracy: 0.5579 - val_loss: 0.1088 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2755 - accuracy: 0.5579 - val_loss: 0.1884 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2731 - accuracy: 0.5579 - val_loss: 0.1031 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2789 - accuracy: 0.5579 - val_loss: 0.1281 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2756 - accuracy: 0.5579 - val_loss: 0.1091 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2802 - accuracy: 0.5579 - val_loss: 0.1372 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2747 - accuracy: 0.5579 - val_loss: 0.0770 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2767 - accuracy: 0.5579 - val_loss: 0.1017 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2774 - accuracy: 0.5579 - val_loss: 0.1034 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2844 - accuracy: 0.5579 - val_loss: 0.1130 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2643 - accuracy: 0.5579 - val_loss: 0.0946 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2712 - accuracy: 0.5579 - val_loss: 0.1174 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2697 - accuracy: 0.5579 - val_loss: 0.0915 - val_accuracy: 1.0000
# Epoch 40/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2714 - accuracy: 0.5579 - val_loss: 0.1407 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2672 - accuracy: 0.5579 - val_loss: 0.1108 - val_accuracy: 0.9630
# Epoch 42/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2742 - accuracy: 0.5579 - val_loss: 0.1250 - val_accuracy: 0.9630
# Epoch 43/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2774 - accuracy: 0.5579 - val_loss: 0.0766 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2673 - accuracy: 0.5579 - val_loss: 0.1054 - val_accuracy: 0.9630
# Epoch 45/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2721 - accuracy: 0.5579 - val_loss: 0.1063 - val_accuracy: 0.9630
# Epoch 46/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2641 - accuracy: 0.5579 - val_loss: 0.1597 - val_accuracy: 0.9259
# Epoch 47/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2617 - accuracy: 0.5579 - val_loss: 0.1030 - val_accuracy: 0.9630
# Epoch 48/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2693 - accuracy: 0.5579 - val_loss: 0.1418 - val_accuracy: 0.9630
# Epoch 49/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2694 - accuracy: 0.5579 - val_loss: 0.1337 - val_accuracy: 0.9630
# Epoch 50/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2637 - accuracy: 0.5579 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 51/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2629 - accuracy: 0.5579 - val_loss: 0.1057 - val_accuracy: 1.0000
# Epoch 52/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2639 - accuracy: 0.5579 - val_loss: 0.1276 - val_accuracy: 0.9630
# Epoch 53/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2627 - accuracy: 0.5579 - val_loss: 0.1254 - val_accuracy: 0.9630
# Epoch 54/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2586 - accuracy: 0.5579 - val_loss: 0.1174 - val_accuracy: 0.9630
# Epoch 55/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2560 - accuracy: 0.5579 - val_loss: 0.0960 - val_accuracy: 0.9630
# Epoch 56/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2639 - accuracy: 0.5579 - val_loss: 0.1276 - val_accuracy: 0.9630
# Epoch 57/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2627 - accuracy: 0.5579 - val_loss: 0.1336 - val_accuracy: 0.9630
# Epoch 58/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2592 - accuracy: 0.5579 - val_loss: 0.1111 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 118ms/step - loss: 0.1164 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 128)               21636352
#
#  model_1 (Functional)        (None, 1)                 49537
#
# =================================================================
# Total params: 21,685,889
# Trainable params: 21,357,953
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 11s 312ms/step - loss: 0.4735 - accuracy: 0.5081 - val_loss: 0.4346 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3851 - accuracy: 0.5556 - val_loss: 0.5425 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3562 - accuracy: 0.5590 - val_loss: 0.3404 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3378 - accuracy: 0.5660 - val_loss: 0.2123 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 8s 281ms/step - loss: 0.3294 - accuracy: 0.5694 - val_loss: 0.2285 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3264 - accuracy: 0.5706 - val_loss: 0.1696 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.3072 - accuracy: 0.5729 - val_loss: 0.1787 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3057 - accuracy: 0.5741 - val_loss: 0.1461 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2957 - accuracy: 0.5752 - val_loss: 0.1638 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2978 - accuracy: 0.5764 - val_loss: 0.1446 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2932 - accuracy: 0.5764 - val_loss: 0.1226 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2926 - accuracy: 0.5752 - val_loss: 0.1586 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2875 - accuracy: 0.5741 - val_loss: 0.1093 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2785 - accuracy: 0.5752 - val_loss: 0.1790 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2793 - accuracy: 0.5764 - val_loss: 0.1335 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2742 - accuracy: 0.5741 - val_loss: 0.2367 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2735 - accuracy: 0.5764 - val_loss: 0.0941 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2790 - accuracy: 0.5752 - val_loss: 0.1203 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2764 - accuracy: 0.5764 - val_loss: 0.1076 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2704 - accuracy: 0.5764 - val_loss: 0.1307 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2754 - accuracy: 0.5764 - val_loss: 0.1258 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2716 - accuracy: 0.5764 - val_loss: 0.1142 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2702 - accuracy: 0.5764 - val_loss: 0.1184 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2733 - accuracy: 0.5764 - val_loss: 0.1580 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2702 - accuracy: 0.5764 - val_loss: 0.1058 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2644 - accuracy: 0.5764 - val_loss: 0.1639 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2618 - accuracy: 0.5764 - val_loss: 0.1254 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2719 - accuracy: 0.5764 - val_loss: 0.1286 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2650 - accuracy: 0.5764 - val_loss: 0.1563 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2666 - accuracy: 0.5764 - val_loss: 0.1586 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2611 - accuracy: 0.5764 - val_loss: 0.1465 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2670 - accuracy: 0.5764 - val_loss: 0.2005 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 112ms/step - loss: 0.1234 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 128)               21636352
#
#  model_1 (Functional)        (None, 1)                 49537
#
# =================================================================
# Total params: 21,685,889
# Trainable params: 21,357,953
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 12s 310ms/step - loss: 0.5058 - accuracy: 0.4795 - val_loss: 0.2028 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.4198 - accuracy: 0.5217 - val_loss: 0.1302 - val_accuracy: 1.0000
# Epoch 3/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.3844 - accuracy: 0.5457 - val_loss: 0.1404 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 8s 284ms/step - loss: 0.3570 - accuracy: 0.5559 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.3548 - accuracy: 0.5548 - val_loss: 0.2526 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.3251 - accuracy: 0.5605 - val_loss: 0.1973 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.3331 - accuracy: 0.5605 - val_loss: 0.1173 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 8s 284ms/step - loss: 0.3171 - accuracy: 0.5662 - val_loss: 0.1075 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.3247 - accuracy: 0.5628 - val_loss: 0.0854 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.3150 - accuracy: 0.5616 - val_loss: 0.0930 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.3081 - accuracy: 0.5628 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.3005 - accuracy: 0.5662 - val_loss: 0.0908 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2977 - accuracy: 0.5651 - val_loss: 0.1042 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2891 - accuracy: 0.5639 - val_loss: 0.2076 - val_accuracy: 0.8519
# Epoch 15/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2943 - accuracy: 0.5628 - val_loss: 0.1158 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2993 - accuracy: 0.5651 - val_loss: 0.2874 - val_accuracy: 0.8148
# Epoch 17/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2958 - accuracy: 0.5616 - val_loss: 0.1611 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.2938 - accuracy: 0.5639 - val_loss: 0.0552 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.2879 - accuracy: 0.5662 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2902 - accuracy: 0.5651 - val_loss: 0.1221 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2885 - accuracy: 0.5662 - val_loss: 0.1583 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2833 - accuracy: 0.5651 - val_loss: 0.1612 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2847 - accuracy: 0.5662 - val_loss: 0.0915 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2804 - accuracy: 0.5662 - val_loss: 0.0812 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2764 - accuracy: 0.5662 - val_loss: 0.1235 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2792 - accuracy: 0.5662 - val_loss: 0.0789 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2800 - accuracy: 0.5662 - val_loss: 0.1723 - val_accuracy: 0.8889
# Epoch 28/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2798 - accuracy: 0.5662 - val_loss: 0.1126 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2773 - accuracy: 0.5662 - val_loss: 0.1518 - val_accuracy: 0.8889
# Epoch 30/100
# 28/28 [==============================] - 8s 280ms/step - loss: 0.2777 - accuracy: 0.5662 - val_loss: 0.2067 - val_accuracy: 0.8889
# Epoch 31/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2786 - accuracy: 0.5662 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2751 - accuracy: 0.5662 - val_loss: 0.1097 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2772 - accuracy: 0.5662 - val_loss: 0.0692 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2647 - accuracy: 0.5662 - val_loss: 0.1017 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2651 - accuracy: 0.5662 - val_loss: 0.1157 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2632 - accuracy: 0.5662 - val_loss: 0.1128 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2671 - accuracy: 0.5662 - val_loss: 0.1677 - val_accuracy: 0.9259
# Epoch 38/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2731 - accuracy: 0.5662 - val_loss: 0.1103 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2743 - accuracy: 0.5662 - val_loss: 0.1176 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2678 - accuracy: 0.5662 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2723 - accuracy: 0.5662 - val_loss: 0.0600 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2693 - accuracy: 0.5662 - val_loss: 0.1415 - val_accuracy: 0.9259
# Epoch 43/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2697 - accuracy: 0.5651 - val_loss: 0.0753 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2756 - accuracy: 0.5662 - val_loss: 0.0609 - val_accuracy: 1.0000
# Epoch 45/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2685 - accuracy: 0.5662 - val_loss: 0.0593 - val_accuracy: 1.0000
# Epoch 46/100
# 28/28 [==============================] - 8s 284ms/step - loss: 0.2634 - accuracy: 0.5662 - val_loss: 0.1218 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 113ms/step - loss: 0.0393 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 128)               20971648
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
# =================================================================
# Total params: 21,636,352
# Trainable params: 21,308,416
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 128)               21636352
#
#  model_1 (Functional)        (None, 1)                 49537
#
# =================================================================
# Total params: 21,685,889
# Trainable params: 21,357,953
# Non-trainable params: 327,936
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 11s 314ms/step - loss: 0.4990 - accuracy: 0.4873 - val_loss: 0.4284 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3878 - accuracy: 0.5417 - val_loss: 0.2940 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3414 - accuracy: 0.5625 - val_loss: 0.3211 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3360 - accuracy: 0.5706 - val_loss: 0.3099 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3268 - accuracy: 0.5683 - val_loss: 0.2703 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3144 - accuracy: 0.5718 - val_loss: 0.2766 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3051 - accuracy: 0.5729 - val_loss: 0.3185 - val_accuracy: 0.8519
# Epoch 8/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3053 - accuracy: 0.5741 - val_loss: 0.2837 - val_accuracy: 0.8519
# Epoch 9/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2934 - accuracy: 0.5741 - val_loss: 0.2675 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.3038 - accuracy: 0.5764 - val_loss: 0.2649 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2957 - accuracy: 0.5752 - val_loss: 0.2553 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2892 - accuracy: 0.5741 - val_loss: 0.1990 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2845 - accuracy: 0.5752 - val_loss: 0.2711 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2869 - accuracy: 0.5741 - val_loss: 0.2304 - val_accuracy: 0.8519
# Epoch 15/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2767 - accuracy: 0.5741 - val_loss: 0.2202 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2765 - accuracy: 0.5764 - val_loss: 0.2081 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2751 - accuracy: 0.5764 - val_loss: 0.2198 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2834 - accuracy: 0.5764 - val_loss: 0.2007 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2826 - accuracy: 0.5764 - val_loss: 0.2354 - val_accuracy: 0.8519
# Epoch 20/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2761 - accuracy: 0.5764 - val_loss: 0.2335 - val_accuracy: 0.8519
# Epoch 21/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2671 - accuracy: 0.5764 - val_loss: 0.2353 - val_accuracy: 0.8519
# Epoch 22/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2820 - accuracy: 0.5741 - val_loss: 0.2296 - val_accuracy: 0.8519
# Epoch 23/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2748 - accuracy: 0.5764 - val_loss: 0.2209 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2725 - accuracy: 0.5764 - val_loss: 0.2577 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2707 - accuracy: 0.5752 - val_loss: 0.2419 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2651 - accuracy: 0.5764 - val_loss: 0.2527 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2679 - accuracy: 0.5764 - val_loss: 0.2398 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 113ms/step - loss: 0.1593 - accuracy: 0.9706
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f029779e320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.9823529243469238]
# [0.9796508230180756]
# Epoch 1/100
# 27/27 [==============================] - 11s 315ms/step - loss: 0.5213 - accuracy: 0.4895 - val_loss: 0.1992 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3963 - accuracy: 0.5408 - val_loss: 0.2063 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.3691 - accuracy: 0.5548 - val_loss: 0.1867 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3437 - accuracy: 0.5618 - val_loss: 0.2487 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.3279 - accuracy: 0.5583 - val_loss: 0.1659 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3201 - accuracy: 0.5641 - val_loss: 0.1791 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.3272 - accuracy: 0.5664 - val_loss: 0.1919 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.3210 - accuracy: 0.5641 - val_loss: 0.1621 - val_accuracy: 0.9630
# Epoch 9/100
# ...
# Epoch 10/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2877 - accuracy: 0.6007 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2819 - accuracy: 0.6019 - val_loss: 0.0751 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2899 - accuracy: 0.5995 - val_loss: 0.1357 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2793 - accuracy: 0.6019 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2840 - accuracy: 0.5995 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2820 - accuracy: 0.5995 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2723 - accuracy: 0.5995 - val_loss: 0.0316 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2715 - accuracy: 0.6019 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2728 - accuracy: 0.6019 - val_loss: 0.0963 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2619 - accuracy: 0.6007 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2647 - accuracy: 0.6019 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2586 - accuracy: 0.6019 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2682 - accuracy: 0.6019 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2656 - accuracy: 0.6019 - val_loss: 0.0364 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2504 - accuracy: 0.6019 - val_loss: 0.0299 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2539 - accuracy: 0.6019 - val_loss: 0.0316 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2582 - accuracy: 0.6019 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2529 - accuracy: 0.6019 - val_loss: 0.0435 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2513 - accuracy: 0.6019 - val_loss: 0.0555 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2510 - accuracy: 0.6019 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2528 - accuracy: 0.6019 - val_loss: 0.0494 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2545 - accuracy: 0.6019 - val_loss: 0.0412 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2526 - accuracy: 0.6007 - val_loss: 0.1044 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2515 - accuracy: 0.6007 - val_loss: 0.0333 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2495 - accuracy: 0.6019 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2516 - accuracy: 0.6019 - val_loss: 0.0471 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2556 - accuracy: 0.6019 - val_loss: 0.0443 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2518 - accuracy: 0.6019 - val_loss: 0.0700 - val_accuracy: 1.0000
# Epoch 38/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2444 - accuracy: 0.6019 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 39/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2544 - accuracy: 0.6019 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 40/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2433 - accuracy: 0.6019 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 41/100
# 27/27 [==============================] - 8s 282ms/step - loss: 0.2511 - accuracy: 0.6019 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 42/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2436 - accuracy: 0.6019 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 43/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2439 - accuracy: 0.6019 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 44/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2426 - accuracy: 0.6019 - val_loss: 0.0462 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 112ms/step - loss: 0.0764 - accuracy: 1.0000
# Epoch 1/100
# 27/27 [==============================] - 11s 315ms/step - loss: 0.5047 - accuracy: 0.5116 - val_loss: 0.2446 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3803 - accuracy: 0.5764 - val_loss: 0.3325 - val_accuracy: 0.8519
# Epoch 3/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.3515 - accuracy: 0.5729 - val_loss: 0.2895 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3205 - accuracy: 0.5845 - val_loss: 0.2768 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.3121 - accuracy: 0.5914 - val_loss: 0.3236 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2997 - accuracy: 0.5938 - val_loss: 0.2628 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2939 - accuracy: 0.5949 - val_loss: 0.2837 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2962 - accuracy: 0.5938 - val_loss: 0.3033 - val_accuracy: 0.8519
# Epoch 9/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2913 - accuracy: 0.5949 - val_loss: 0.2642 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 8s 287ms/step - loss: 0.2816 - accuracy: 0.5938 - val_loss: 0.2040 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2784 - accuracy: 0.5949 - val_loss: 0.2221 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 8s 286ms/step - loss: 0.2925 - accuracy: 0.5914 - val_loss: 0.1942 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2800 - accuracy: 0.5949 - val_loss: 0.1809 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2696 - accuracy: 0.5949 - val_loss: 0.2030 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2721 - accuracy: 0.5949 - val_loss: 0.2321 - val_accuracy: 0.8889
# Epoch 16/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2666 - accuracy: 0.5938 - val_loss: 0.2260 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2637 - accuracy: 0.5949 - val_loss: 0.2691 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2805 - accuracy: 0.5914 - val_loss: 0.3157 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2694 - accuracy: 0.5938 - val_loss: 0.3161 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 8s 283ms/step - loss: 0.2609 - accuracy: 0.5949 - val_loss: 0.2441 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2684 - accuracy: 0.5949 - val_loss: 0.1965 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2582 - accuracy: 0.5949 - val_loss: 0.2198 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 8s 285ms/step - loss: 0.2577 - accuracy: 0.5949 - val_loss: 0.2673 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2600 - accuracy: 0.5938 - val_loss: 0.3447 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2583 - accuracy: 0.5949 - val_loss: 0.2574 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2544 - accuracy: 0.5949 - val_loss: 0.2703 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 8s 289ms/step - loss: 0.2587 - accuracy: 0.5949 - val_loss: 0.3100 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 8s 284ms/step - loss: 0.2516 - accuracy: 0.5949 - val_loss: 0.3008 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 115ms/step - loss: 0.1207 - accuracy: 0.9706
# Epoch 1/100
# 28/28 [==============================] - 12s 312ms/step - loss: 0.5272 - accuracy: 0.5218 - val_loss: 0.3125 - val_accuracy: 0.9259
# Epoch 2/100
# 28/28 [==============================] - 8s 285ms/step - loss: 0.4092 - accuracy: 0.5736 - val_loss: 0.2777 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.3629 - accuracy: 0.5851 - val_loss: 0.2653 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.3428 - accuracy: 0.5989 - val_loss: 0.2407 - val_accuracy: 0.8519
# Epoch 5/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.3127 - accuracy: 0.6069 - val_loss: 0.2910 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.3299 - accuracy: 0.5989 - val_loss: 0.2289 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.3184 - accuracy: 0.6011 - val_loss: 0.2713 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.3022 - accuracy: 0.6092 - val_loss: 0.3654 - val_accuracy: 0.8148
# Epoch 9/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.3005 - accuracy: 0.6069 - val_loss: 0.3144 - val_accuracy: 0.8519
# Epoch 10/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2797 - accuracy: 0.6115 - val_loss: 0.3071 - val_accuracy: 0.8519
# Epoch 11/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2779 - accuracy: 0.6138 - val_loss: 0.3229 - val_accuracy: 0.8519
# Epoch 12/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2801 - accuracy: 0.6126 - val_loss: 0.2927 - val_accuracy: 0.8519
# Epoch 13/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2686 - accuracy: 0.6138 - val_loss: 0.6280 - val_accuracy: 0.7037
# Epoch 14/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2795 - accuracy: 0.6138 - val_loss: 0.5255 - val_accuracy: 0.7407
# Epoch 15/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2825 - accuracy: 0.6115 - val_loss: 0.2848 - val_accuracy: 0.8889
# Epoch 16/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2712 - accuracy: 0.6126 - val_loss: 0.3295 - val_accuracy: 0.8519
# Epoch 17/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.2660 - accuracy: 0.6138 - val_loss: 0.1490 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2683 - accuracy: 0.6138 - val_loss: 0.2213 - val_accuracy: 0.9259
# Epoch 19/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2659 - accuracy: 0.6138 - val_loss: 0.2669 - val_accuracy: 0.8519
# Epoch 20/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2618 - accuracy: 0.6126 - val_loss: 0.4672 - val_accuracy: 0.8148
# Epoch 21/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2726 - accuracy: 0.6103 - val_loss: 0.1724 - val_accuracy: 0.8519
# Epoch 22/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2651 - accuracy: 0.6115 - val_loss: 0.2093 - val_accuracy: 0.8519
# Epoch 23/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2601 - accuracy: 0.6138 - val_loss: 0.1714 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2527 - accuracy: 0.6126 - val_loss: 0.2316 - val_accuracy: 0.8889
# Epoch 25/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.2741 - accuracy: 0.6138 - val_loss: 0.1112 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.2563 - accuracy: 0.6126 - val_loss: 0.2243 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.2463 - accuracy: 0.6138 - val_loss: 0.1622 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 8s 284ms/step - loss: 0.2641 - accuracy: 0.6126 - val_loss: 0.1012 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2498 - accuracy: 0.6138 - val_loss: 0.2290 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 8s 283ms/step - loss: 0.2530 - accuracy: 0.6138 - val_loss: 0.2016 - val_accuracy: 0.9259
# Epoch 31/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2585 - accuracy: 0.6138 - val_loss: 0.1798 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2463 - accuracy: 0.6138 - val_loss: 0.1711 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2452 - accuracy: 0.6138 - val_loss: 0.1723 - val_accuracy: 0.9259
# Epoch 34/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2453 - accuracy: 0.6138 - val_loss: 0.1795 - val_accuracy: 0.9259
# Epoch 35/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2524 - accuracy: 0.6138 - val_loss: 0.1402 - val_accuracy: 0.9259
# Epoch 36/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2517 - accuracy: 0.6126 - val_loss: 0.1047 - val_accuracy: 0.9259
# Epoch 37/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2560 - accuracy: 0.6138 - val_loss: 0.2165 - val_accuracy: 0.8889
# Epoch 38/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2560 - accuracy: 0.6138 - val_loss: 0.3821 - val_accuracy: 0.8519
# Epoch 39/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2591 - accuracy: 0.6126 - val_loss: 0.3132 - val_accuracy: 0.8148
# Epoch 40/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2534 - accuracy: 0.6138 - val_loss: 0.2543 - val_accuracy: 0.9259
# Epoch 41/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2581 - accuracy: 0.6138 - val_loss: 0.2831 - val_accuracy: 0.8148
# Epoch 42/100
# 28/28 [==============================] - 8s 281ms/step - loss: 0.2493 - accuracy: 0.6138 - val_loss: 0.2103 - val_accuracy: 0.9259
# Epoch 43/100
# 28/28 [==============================] - 8s 282ms/step - loss: 0.2400 - accuracy: 0.6138 - val_loss: 0.3115 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 109ms/step - loss: 0.0951 - accuracy: 1.0000
# [0.9823529243469238, 0.970588231086731, 0.9764705657958984, 0.9529411673545838, 0.9764705777168274]
# [0.9796508230180756, 0.963207729468599, 0.9734002907360908, 0.9454962503320505, 0.9737666588730418]
# Mean test accuracy is 0.97, mean test f1 score is 0.97, max test accuracy is 0.98, max test f1 score is 0.98, min test accuracy is 0.95, min test f1 score is 0.95, std of test accuracy is 0.01, std of test f1 score is 0.01
# Time elapsed through all process: 8544.50, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
