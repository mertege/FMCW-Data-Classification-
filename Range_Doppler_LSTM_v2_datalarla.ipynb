# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_LSTM_v2_datalarla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada sadece range-doppler 2D image datası LSTM ile train edildi.
# 2D image'ın column'ları lstm'e sokuldu ve çıktıları dense layer ile classification moduna getirildi.
# 3 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.971, mean test f1 score is 0.964, max test accuracy is 0.982, max test f1 score is 0.980
# Min test accuracy is 0.959, min test f1 score is 0.949, std of test accuracy is 0.010, std of test f1 score is 0.013

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resizedv2.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resizedv2.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resizedv2.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 16
dense_unit_of_lstm_function = 256
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 15s 341ms/step - loss: 0.5668 - accuracy: 0.4566 - val_loss: 0.3469 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.4105 - accuracy: 0.5240 - val_loss: 0.2530 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3896 - accuracy: 0.5308 - val_loss: 0.2902 - val_accuracy: 0.9259
# Epoch 4/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3453 - accuracy: 0.5422 - val_loss: 0.2659 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3467 - accuracy: 0.5514 - val_loss: 0.2556 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3394 - accuracy: 0.5525 - val_loss: 0.2885 - val_accuracy: 0.8148
# Epoch 7/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3257 - accuracy: 0.5537 - val_loss: 0.2111 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3172 - accuracy: 0.5548 - val_loss: 0.2988 - val_accuracy: 0.8519
# Epoch 9/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3177 - accuracy: 0.5559 - val_loss: 0.2482 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 8s 300ms/step - loss: 0.3088 - accuracy: 0.5582 - val_loss: 0.1643 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3276 - accuracy: 0.5582 - val_loss: 0.3950 - val_accuracy: 0.8148
# Epoch 12/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3033 - accuracy: 0.5571 - val_loss: 0.2872 - val_accuracy: 0.8519
# Epoch 13/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3038 - accuracy: 0.5582 - val_loss: 0.3074 - val_accuracy: 0.8519
# Epoch 14/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2916 - accuracy: 0.5582 - val_loss: 0.1824 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2885 - accuracy: 0.5594 - val_loss: 0.2048 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2925 - accuracy: 0.5571 - val_loss: 0.2221 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2847 - accuracy: 0.5594 - val_loss: 0.1869 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2858 - accuracy: 0.5594 - val_loss: 0.1763 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2874 - accuracy: 0.5582 - val_loss: 0.1572 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2844 - accuracy: 0.5594 - val_loss: 0.1949 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.2874 - accuracy: 0.5594 - val_loss: 0.1436 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2744 - accuracy: 0.5594 - val_loss: 0.1938 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2811 - accuracy: 0.5594 - val_loss: 0.1615 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2743 - accuracy: 0.5594 - val_loss: 0.1630 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2873 - accuracy: 0.5594 - val_loss: 0.1469 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2849 - accuracy: 0.5582 - val_loss: 0.2160 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2767 - accuracy: 0.5594 - val_loss: 0.1497 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2746 - accuracy: 0.5594 - val_loss: 0.1979 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2715 - accuracy: 0.5594 - val_loss: 0.2179 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2735 - accuracy: 0.5594 - val_loss: 0.2069 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2859 - accuracy: 0.5594 - val_loss: 0.2575 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2764 - accuracy: 0.5594 - val_loss: 0.1779 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2772 - accuracy: 0.5594 - val_loss: 0.1571 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2703 - accuracy: 0.5594 - val_loss: 0.2121 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2729 - accuracy: 0.5594 - val_loss: 0.2293 - val_accuracy: 0.9259
# Epoch 36/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2790 - accuracy: 0.5582 - val_loss: 0.1808 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 120ms/step - loss: 0.0815 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 328ms/step - loss: 0.5245 - accuracy: 0.4894 - val_loss: 0.3184 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.4191 - accuracy: 0.5387 - val_loss: 0.4941 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.3818 - accuracy: 0.5516 - val_loss: 0.2017 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.3768 - accuracy: 0.5599 - val_loss: 0.2907 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3336 - accuracy: 0.5704 - val_loss: 0.1714 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3351 - accuracy: 0.5692 - val_loss: 0.1261 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3160 - accuracy: 0.5751 - val_loss: 0.1916 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.3190 - accuracy: 0.5704 - val_loss: 0.1302 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.3027 - accuracy: 0.5763 - val_loss: 0.2926 - val_accuracy: 0.8519
# Epoch 10/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.3089 - accuracy: 0.5739 - val_loss: 0.1335 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.3039 - accuracy: 0.5739 - val_loss: 0.0710 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2949 - accuracy: 0.5775 - val_loss: 0.0726 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2857 - accuracy: 0.5763 - val_loss: 0.0797 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2842 - accuracy: 0.5775 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2863 - accuracy: 0.5763 - val_loss: 0.0808 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2856 - accuracy: 0.5775 - val_loss: 0.1437 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2846 - accuracy: 0.5763 - val_loss: 0.0891 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2807 - accuracy: 0.5763 - val_loss: 0.1280 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2780 - accuracy: 0.5775 - val_loss: 0.0659 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2807 - accuracy: 0.5775 - val_loss: 0.0913 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2712 - accuracy: 0.5775 - val_loss: 0.0997 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2746 - accuracy: 0.5775 - val_loss: 0.1067 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2742 - accuracy: 0.5739 - val_loss: 0.0988 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2722 - accuracy: 0.5775 - val_loss: 0.0880 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2645 - accuracy: 0.5775 - val_loss: 0.0835 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2704 - accuracy: 0.5763 - val_loss: 0.0862 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2693 - accuracy: 0.5775 - val_loss: 0.0700 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2669 - accuracy: 0.5775 - val_loss: 0.0767 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2590 - accuracy: 0.5775 - val_loss: 0.1544 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 115ms/step - loss: 0.1080 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 329ms/step - loss: 0.4856 - accuracy: 0.5186 - val_loss: 0.3979 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3798 - accuracy: 0.5664 - val_loss: 0.2849 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.3686 - accuracy: 0.5758 - val_loss: 0.4626 - val_accuracy: 0.7037
# Epoch 4/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.3234 - accuracy: 0.5816 - val_loss: 0.2890 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.3198 - accuracy: 0.5862 - val_loss: 0.4014 - val_accuracy: 0.7037
# Epoch 6/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3241 - accuracy: 0.5781 - val_loss: 0.2280 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3046 - accuracy: 0.5886 - val_loss: 0.2619 - val_accuracy: 0.8519
# Epoch 8/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2990 - accuracy: 0.5932 - val_loss: 0.2218 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2999 - accuracy: 0.5921 - val_loss: 0.2521 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2959 - accuracy: 0.5897 - val_loss: 0.2101 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2844 - accuracy: 0.5944 - val_loss: 0.1848 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2809 - accuracy: 0.5944 - val_loss: 0.1744 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2784 - accuracy: 0.5932 - val_loss: 0.1780 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2705 - accuracy: 0.5944 - val_loss: 0.1672 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2654 - accuracy: 0.5944 - val_loss: 0.2669 - val_accuracy: 0.8519
# Epoch 16/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2691 - accuracy: 0.5944 - val_loss: 0.2372 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2654 - accuracy: 0.5932 - val_loss: 0.2309 - val_accuracy: 0.8889
# Epoch 18/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2682 - accuracy: 0.5932 - val_loss: 0.1845 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2716 - accuracy: 0.5944 - val_loss: 0.2185 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2662 - accuracy: 0.5944 - val_loss: 0.1628 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2613 - accuracy: 0.5944 - val_loss: 0.2393 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2568 - accuracy: 0.5944 - val_loss: 0.2031 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2559 - accuracy: 0.5944 - val_loss: 0.3280 - val_accuracy: 0.8889
# Epoch 24/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2596 - accuracy: 0.5932 - val_loss: 0.2635 - val_accuracy: 0.8519
# Epoch 25/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2835 - accuracy: 0.5932 - val_loss: 0.3858 - val_accuracy: 0.8519
# Epoch 26/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2605 - accuracy: 0.5944 - val_loss: 0.2004 - val_accuracy: 0.8889
# Epoch 27/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2597 - accuracy: 0.5944 - val_loss: 0.1792 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2541 - accuracy: 0.5944 - val_loss: 0.2451 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2516 - accuracy: 0.5944 - val_loss: 0.2074 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2517 - accuracy: 0.5944 - val_loss: 0.1729 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2490 - accuracy: 0.5944 - val_loss: 0.2429 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 8s 293ms/step - loss: 0.2528 - accuracy: 0.5944 - val_loss: 0.2485 - val_accuracy: 0.8889
# Epoch 33/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2498 - accuracy: 0.5944 - val_loss: 0.2975 - val_accuracy: 0.8519
# Epoch 34/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2494 - accuracy: 0.5944 - val_loss: 0.3251 - val_accuracy: 0.8519
# Epoch 35/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2496 - accuracy: 0.5944 - val_loss: 0.2634 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 114ms/step - loss: 0.1594 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 12s 325ms/step - loss: 0.6110 - accuracy: 0.4326 - val_loss: 0.3394 - val_accuracy: 0.8148
# Epoch 2/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.4259 - accuracy: 0.5046 - val_loss: 0.2602 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3882 - accuracy: 0.5263 - val_loss: 0.2731 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.3632 - accuracy: 0.5297 - val_loss: 0.2070 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3556 - accuracy: 0.5308 - val_loss: 0.2031 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.3552 - accuracy: 0.5320 - val_loss: 0.2408 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3413 - accuracy: 0.5342 - val_loss: 0.1819 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3378 - accuracy: 0.5342 - val_loss: 0.2237 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3365 - accuracy: 0.5365 - val_loss: 0.1699 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3170 - accuracy: 0.5342 - val_loss: 0.1443 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3213 - accuracy: 0.5354 - val_loss: 0.1519 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3131 - accuracy: 0.5365 - val_loss: 0.2622 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.3141 - accuracy: 0.5354 - val_loss: 0.1025 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.3128 - accuracy: 0.5377 - val_loss: 0.1021 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3041 - accuracy: 0.5388 - val_loss: 0.1224 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3069 - accuracy: 0.5388 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3213 - accuracy: 0.5342 - val_loss: 0.0964 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3073 - accuracy: 0.5365 - val_loss: 0.0957 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2997 - accuracy: 0.5388 - val_loss: 0.1524 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3018 - accuracy: 0.5388 - val_loss: 0.1709 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3144 - accuracy: 0.5388 - val_loss: 0.0581 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3005 - accuracy: 0.5388 - val_loss: 0.1055 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2919 - accuracy: 0.5388 - val_loss: 0.1419 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2886 - accuracy: 0.5388 - val_loss: 0.1289 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2894 - accuracy: 0.5388 - val_loss: 0.0990 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2974 - accuracy: 0.5388 - val_loss: 0.0960 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.2848 - accuracy: 0.5388 - val_loss: 0.1134 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2906 - accuracy: 0.5388 - val_loss: 0.1079 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2907 - accuracy: 0.5388 - val_loss: 0.1970 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2923 - accuracy: 0.5388 - val_loss: 0.1318 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2879 - accuracy: 0.5388 - val_loss: 0.1011 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2855 - accuracy: 0.5388 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2857 - accuracy: 0.5388 - val_loss: 0.1087 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2870 - accuracy: 0.5388 - val_loss: 0.1189 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2895 - accuracy: 0.5388 - val_loss: 0.0961 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2914 - accuracy: 0.5377 - val_loss: 0.0871 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 113ms/step - loss: 0.1168 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 12s 327ms/step - loss: 0.5158 - accuracy: 0.5138 - val_loss: 0.2041 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3819 - accuracy: 0.5632 - val_loss: 0.1685 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3592 - accuracy: 0.5828 - val_loss: 0.2053 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3468 - accuracy: 0.5793 - val_loss: 0.2044 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3253 - accuracy: 0.5839 - val_loss: 0.1775 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3145 - accuracy: 0.5885 - val_loss: 0.1675 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 8s 292ms/step - loss: 0.3108 - accuracy: 0.5920 - val_loss: 0.1706 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3128 - accuracy: 0.5839 - val_loss: 0.1249 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2995 - accuracy: 0.5920 - val_loss: 0.1062 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2950 - accuracy: 0.5908 - val_loss: 0.1290 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2931 - accuracy: 0.5920 - val_loss: 0.1197 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2893 - accuracy: 0.5920 - val_loss: 0.1418 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2910 - accuracy: 0.5954 - val_loss: 0.0776 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2911 - accuracy: 0.5920 - val_loss: 0.0951 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2798 - accuracy: 0.5943 - val_loss: 0.0655 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2881 - accuracy: 0.5931 - val_loss: 0.1017 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2741 - accuracy: 0.5954 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2733 - accuracy: 0.5954 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2680 - accuracy: 0.5954 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2747 - accuracy: 0.5943 - val_loss: 0.0667 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2761 - accuracy: 0.5943 - val_loss: 0.0613 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2653 - accuracy: 0.5943 - val_loss: 0.1147 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2702 - accuracy: 0.5954 - val_loss: 0.0696 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2599 - accuracy: 0.5943 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2632 - accuracy: 0.5954 - val_loss: 0.1410 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2684 - accuracy: 0.5954 - val_loss: 0.1278 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2601 - accuracy: 0.5954 - val_loss: 0.1024 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2626 - accuracy: 0.5954 - val_loss: 0.0925 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2647 - accuracy: 0.5954 - val_loss: 0.0811 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2623 - accuracy: 0.5954 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2539 - accuracy: 0.5954 - val_loss: 0.1212 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2591 - accuracy: 0.5954 - val_loss: 0.1129 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2667 - accuracy: 0.5931 - val_loss: 0.1307 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2671 - accuracy: 0.5954 - val_loss: 0.1345 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2648 - accuracy: 0.5954 - val_loss: 0.0648 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2660 - accuracy: 0.5943 - val_loss: 0.1093 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 112ms/step - loss: 0.1278 - accuracy: 0.9706
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4e1051ef80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.970588231086731]
# [0.9647771023302939]
# Epoch 1/100
# 28/28 [==============================] - 12s 328ms/step - loss: 0.5508 - accuracy: 0.4772 - val_loss: 0.2377 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.4116 - accuracy: 0.5240 - val_loss: 0.1321 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3879 - accuracy: 0.5411 - val_loss: 0.1547 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.3707 - accuracy: 0.5400 - val_loss: 0.1310 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3603 - accuracy: 0.5457 - val_loss: 0.1671 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 8s 300ms/step - loss: 0.3432 - accuracy: 0.5491 - val_loss: 0.1025 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3404 - accuracy: 0.5525 - val_loss: 0.1167 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.3197 - accuracy: 0.5548 - val_loss: 0.0861 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3222 - accuracy: 0.5525 - val_loss: 0.0972 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3183 - accuracy: 0.5525 - val_loss: 0.0971 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3113 - accuracy: 0.5525 - val_loss: 0.1203 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3080 - accuracy: 0.5559 - val_loss: 0.1245 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.2983 - accuracy: 0.5559 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2977 - accuracy: 0.5571 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3100 - accuracy: 0.5559 - val_loss: 0.0506 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2942 - accuracy: 0.5571 - val_loss: 0.0677 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2959 - accuracy: 0.5559 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2908 - accuracy: 0.5571 - val_loss: 0.0475 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2900 - accuracy: 0.5559 - val_loss: 0.1423 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.3016 - accuracy: 0.5559 - val_loss: 0.0705 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2901 - accuracy: 0.5559 - val_loss: 0.1001 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2877 - accuracy: 0.5571 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2809 - accuracy: 0.5571 - val_loss: 0.0342 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2805 - accuracy: 0.5571 - val_loss: 0.0780 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2811 - accuracy: 0.5559 - val_loss: 0.0557 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2808 - accuracy: 0.5571 - val_loss: 0.0902 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2839 - accuracy: 0.5571 - val_loss: 0.0581 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2776 - accuracy: 0.5559 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2766 - accuracy: 0.5571 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2878 - accuracy: 0.5571 - val_loss: 0.0496 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2862 - accuracy: 0.5571 - val_loss: 0.0791 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2788 - accuracy: 0.5571 - val_loss: 0.0505 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2779 - accuracy: 0.5571 - val_loss: 0.0442 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2739 - accuracy: 0.5571 - val_loss: 0.0672 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2729 - accuracy: 0.5571 - val_loss: 0.0575 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2712 - accuracy: 0.5571 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2722 - accuracy: 0.5571 - val_loss: 0.0977 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2729 - accuracy: 0.5571 - val_loss: 0.0909 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 114ms/step - loss: 0.1874 - accuracy: 0.9118
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4d7b43d320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/100
# 28/28 [==============================] - 12s 329ms/step - loss: 0.5600 - accuracy: 0.4886 - val_loss: 0.3167 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.4234 - accuracy: 0.5434 - val_loss: 0.4964 - val_accuracy: 0.7037
# Epoch 3/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.3903 - accuracy: 0.5479 - val_loss: 0.2511 - val_accuracy: 0.9259
# Epoch 4/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3670 - accuracy: 0.5628 - val_loss: 0.3264 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3369 - accuracy: 0.5662 - val_loss: 0.2585 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 8s 300ms/step - loss: 0.3360 - accuracy: 0.5685 - val_loss: 0.2476 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.3260 - accuracy: 0.5708 - val_loss: 0.2536 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.3189 - accuracy: 0.5685 - val_loss: 0.1888 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3196 - accuracy: 0.5674 - val_loss: 0.3594 - val_accuracy: 0.8148
# Epoch 10/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3104 - accuracy: 0.5731 - val_loss: 0.2334 - val_accuracy: 0.8889
# Epoch 11/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3060 - accuracy: 0.5719 - val_loss: 0.2124 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2952 - accuracy: 0.5731 - val_loss: 0.1922 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2898 - accuracy: 0.5753 - val_loss: 0.2722 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2887 - accuracy: 0.5731 - val_loss: 0.1711 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2952 - accuracy: 0.5731 - val_loss: 0.1811 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2824 - accuracy: 0.5731 - val_loss: 0.1883 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2795 - accuracy: 0.5742 - val_loss: 0.2291 - val_accuracy: 0.9259
# Epoch 18/100
# ...
# Epoch 11/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2872 - accuracy: 0.5755 - val_loss: 0.1345 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2985 - accuracy: 0.5766 - val_loss: 0.1452 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2872 - accuracy: 0.5755 - val_loss: 0.1261 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2930 - accuracy: 0.5766 - val_loss: 0.1802 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.2827 - accuracy: 0.5766 - val_loss: 0.1161 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2807 - accuracy: 0.5766 - val_loss: 0.0986 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2713 - accuracy: 0.5766 - val_loss: 0.1308 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2739 - accuracy: 0.5755 - val_loss: 0.1327 - val_accuracy: 0.9259
# Epoch 19/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2737 - accuracy: 0.5766 - val_loss: 0.1528 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2850 - accuracy: 0.5743 - val_loss: 0.1001 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2807 - accuracy: 0.5766 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2674 - accuracy: 0.5743 - val_loss: 0.1326 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2682 - accuracy: 0.5766 - val_loss: 0.1280 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2629 - accuracy: 0.5766 - val_loss: 0.1264 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2713 - accuracy: 0.5766 - val_loss: 0.1123 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 8s 300ms/step - loss: 0.2731 - accuracy: 0.5766 - val_loss: 0.0669 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2714 - accuracy: 0.5766 - val_loss: 0.1439 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2584 - accuracy: 0.5766 - val_loss: 0.1123 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2621 - accuracy: 0.5766 - val_loss: 0.1365 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2623 - accuracy: 0.5766 - val_loss: 0.1696 - val_accuracy: 0.9259
# Epoch 31/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2620 - accuracy: 0.5766 - val_loss: 0.1110 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2578 - accuracy: 0.5766 - val_loss: 0.1173 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2696 - accuracy: 0.5755 - val_loss: 0.1066 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2624 - accuracy: 0.5766 - val_loss: 0.1187 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2616 - accuracy: 0.5766 - val_loss: 0.1017 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2617 - accuracy: 0.5766 - val_loss: 0.1532 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2588 - accuracy: 0.5766 - val_loss: 0.1263 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2576 - accuracy: 0.5766 - val_loss: 0.1276 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2547 - accuracy: 0.5766 - val_loss: 0.1535 - val_accuracy: 0.9259
# Epoch 40/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2554 - accuracy: 0.5766 - val_loss: 0.1614 - val_accuracy: 0.9259
# Epoch 41/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2641 - accuracy: 0.5766 - val_loss: 0.1645 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 107ms/step - loss: 0.1027 - accuracy: 0.9706
# Epoch 1/100
# 27/27 [==============================] - 12s 332ms/step - loss: 0.5538 - accuracy: 0.5047 - val_loss: 0.6471 - val_accuracy: 0.5926
# Epoch 2/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3947 - accuracy: 0.5540 - val_loss: 0.2650 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3693 - accuracy: 0.5587 - val_loss: 0.3173 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3256 - accuracy: 0.5716 - val_loss: 0.3800 - val_accuracy: 0.8148
# Epoch 5/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3314 - accuracy: 0.5681 - val_loss: 0.3229 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3228 - accuracy: 0.5634 - val_loss: 0.3165 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3214 - accuracy: 0.5669 - val_loss: 0.3082 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.3083 - accuracy: 0.5728 - val_loss: 0.2737 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3153 - accuracy: 0.5692 - val_loss: 0.2565 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3051 - accuracy: 0.5751 - val_loss: 0.2246 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3015 - accuracy: 0.5739 - val_loss: 0.2225 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2929 - accuracy: 0.5728 - val_loss: 0.2087 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2876 - accuracy: 0.5751 - val_loss: 0.2372 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2869 - accuracy: 0.5751 - val_loss: 0.1976 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2862 - accuracy: 0.5751 - val_loss: 0.2864 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2927 - accuracy: 0.5751 - val_loss: 0.2317 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2844 - accuracy: 0.5751 - val_loss: 0.2274 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2879 - accuracy: 0.5739 - val_loss: 0.1915 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2739 - accuracy: 0.5751 - val_loss: 0.2174 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2802 - accuracy: 0.5751 - val_loss: 0.1769 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2725 - accuracy: 0.5751 - val_loss: 0.2220 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2732 - accuracy: 0.5751 - val_loss: 0.2025 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2668 - accuracy: 0.5751 - val_loss: 0.2194 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2764 - accuracy: 0.5751 - val_loss: 0.2560 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2639 - accuracy: 0.5751 - val_loss: 0.2818 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2714 - accuracy: 0.5751 - val_loss: 0.2484 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2719 - accuracy: 0.5751 - val_loss: 0.3326 - val_accuracy: 0.8519
# Epoch 28/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2740 - accuracy: 0.5751 - val_loss: 0.3494 - val_accuracy: 0.8519
# Epoch 29/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2611 - accuracy: 0.5751 - val_loss: 0.2535 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2686 - accuracy: 0.5751 - val_loss: 0.2601 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2629 - accuracy: 0.5751 - val_loss: 0.3018 - val_accuracy: 0.8519
# Epoch 32/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2672 - accuracy: 0.5751 - val_loss: 0.2345 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2650 - accuracy: 0.5751 - val_loss: 0.2168 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2621 - accuracy: 0.5739 - val_loss: 0.2996 - val_accuracy: 0.8889
# Epoch 35/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2729 - accuracy: 0.5751 - val_loss: 0.3173 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 114ms/step - loss: 0.2830 - accuracy: 0.8824
# Epoch 1/100
# 27/27 [==============================] - 12s 331ms/step - loss: 0.5215 - accuracy: 0.4977 - val_loss: 0.2199 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.4196 - accuracy: 0.5315 - val_loss: 0.2979 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3818 - accuracy: 0.5431 - val_loss: 0.2271 - val_accuracy: 1.0000
# Epoch 4/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3626 - accuracy: 0.5490 - val_loss: 0.2241 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3540 - accuracy: 0.5478 - val_loss: 0.2117 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3597 - accuracy: 0.5548 - val_loss: 0.2086 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3357 - accuracy: 0.5536 - val_loss: 0.1825 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3257 - accuracy: 0.5559 - val_loss: 0.2118 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3149 - accuracy: 0.5606 - val_loss: 0.1580 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3213 - accuracy: 0.5583 - val_loss: 0.1615 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3206 - accuracy: 0.5583 - val_loss: 0.1601 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3013 - accuracy: 0.5641 - val_loss: 0.1623 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3030 - accuracy: 0.5618 - val_loss: 0.1329 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2937 - accuracy: 0.5618 - val_loss: 0.1546 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3011 - accuracy: 0.5641 - val_loss: 0.1581 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2890 - accuracy: 0.5629 - val_loss: 0.1686 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2908 - accuracy: 0.5629 - val_loss: 0.1771 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2879 - accuracy: 0.5618 - val_loss: 0.1192 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2836 - accuracy: 0.5641 - val_loss: 0.1076 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2878 - accuracy: 0.5629 - val_loss: 0.1206 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2831 - accuracy: 0.5629 - val_loss: 0.1472 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2785 - accuracy: 0.5629 - val_loss: 0.0900 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2728 - accuracy: 0.5641 - val_loss: 0.1702 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2776 - accuracy: 0.5641 - val_loss: 0.1696 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2830 - accuracy: 0.5641 - val_loss: 0.0745 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2847 - accuracy: 0.5641 - val_loss: 0.1300 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2767 - accuracy: 0.5641 - val_loss: 0.1291 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2875 - accuracy: 0.5641 - val_loss: 0.1525 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2811 - accuracy: 0.5629 - val_loss: 0.1734 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2742 - accuracy: 0.5641 - val_loss: 0.1314 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2710 - accuracy: 0.5641 - val_loss: 0.1151 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2672 - accuracy: 0.5641 - val_loss: 0.1431 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2700 - accuracy: 0.5641 - val_loss: 0.1359 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2674 - accuracy: 0.5641 - val_loss: 0.1196 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2817 - accuracy: 0.5641 - val_loss: 0.1540 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2680 - accuracy: 0.5641 - val_loss: 0.1142 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2685 - accuracy: 0.5641 - val_loss: 0.1153 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2648 - accuracy: 0.5641 - val_loss: 0.1011 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2777 - accuracy: 0.5641 - val_loss: 0.1147 - val_accuracy: 0.9630
# Epoch 40/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2675 - accuracy: 0.5641 - val_loss: 0.1627 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 111ms/step - loss: 0.1129 - accuracy: 0.9706
# [0.970588231086731, 0.9588235139846801, 0.9470588207244873, 0.9764705657958984, 0.9588235139846801]
# [0.9647771023302939, 0.9505298199907063, 0.9378996319745626, 0.9727612586817027, 0.9530928686895382]
# Mean test accuracy is 0.96, mean test f1 score is 0.96, max test accuracy is 0.98, max test f1 score is 0.97, min test accuracy is 0.95, min test f1 score is 0.94, std of test accuracy is 0.01, std of test f1 score is 0.01
# Time elapsed through all process: 8529.44, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
