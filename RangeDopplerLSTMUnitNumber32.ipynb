# %%
# Burada sadece range-doppler 2D image datası LSTM ile train edildi.
# 2D image'ın column'ları lstm'e sokuldu ve çıktıları dense layer ile classification moduna getirildi.
# 3 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.971, mean test f1 score is 0.964, max test accuracy is 0.982, max test f1 score is 0.980
# Min test accuracy is 0.959, min test f1 score is 0.949, std of test accuracy is 0.010, std of test f1 score is 0.013

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 32
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 1
lstm_dropout_rate = 0.4
unit_number_of_lstm = 32
dense_unit_of_lstm_function = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(128)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 5120)]        0
#
#  bidirectional (Bidirectiona  (None, 52, 64)           1319168
#  l)
#
#  flatten (Flatten)           (None, 3328)              0
#
#  batch_normalization (BatchN  (None, 3328)             13312
#  ormalization)
#
#  dropout (Dropout)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 2,185,728
# Trainable params: 2,178,560
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 256)               2185728
#
#  model_1 (Functional)        (None, 1)                 37057
#
# =================================================================
# Total params: 2,222,785
# Trainable params: 2,215,617
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 20s 549ms/step - loss: 0.5730 - accuracy: 0.4782 - val_loss: 0.5938 - val_accuracy: 0.7407
# Epoch 2/100
# 28/28 [==============================] - 14s 517ms/step - loss: 0.4251 - accuracy: 0.5310 - val_loss: 0.4097 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 14s 513ms/step - loss: 0.3904 - accuracy: 0.5448 - val_loss: 0.4213 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 14s 517ms/step - loss: 0.3565 - accuracy: 0.5552 - val_loss: 0.4505 - val_accuracy: 0.7407
# Epoch 5/100
# 28/28 [==============================] - 14s 515ms/step - loss: 0.3373 - accuracy: 0.5552 - val_loss: 0.5275 - val_accuracy: 0.7407
# Epoch 6/100
# 28/28 [==============================] - 15s 522ms/step - loss: 0.3436 - accuracy: 0.5517 - val_loss: 0.4035 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 15s 517ms/step - loss: 0.3283 - accuracy: 0.5609 - val_loss: 0.4200 - val_accuracy: 0.8148
# Epoch 8/100
# 28/28 [==============================] - 15s 521ms/step - loss: 0.3111 - accuracy: 0.5621 - val_loss: 0.3963 - val_accuracy: 0.8148
# Epoch 9/100
# 28/28 [==============================] - 15s 524ms/step - loss: 0.3146 - accuracy: 0.5632 - val_loss: 0.5187 - val_accuracy: 0.8148
# Epoch 10/100
# 28/28 [==============================] - 15s 527ms/step - loss: 0.3116 - accuracy: 0.5644 - val_loss: 0.4319 - val_accuracy: 0.8519
# Epoch 11/100
# 28/28 [==============================] - 15s 525ms/step - loss: 0.2994 - accuracy: 0.5655 - val_loss: 0.4651 - val_accuracy: 0.8148
# Epoch 12/100
# 28/28 [==============================] - 15s 533ms/step - loss: 0.3081 - accuracy: 0.5632 - val_loss: 0.5208 - val_accuracy: 0.7407
# Epoch 13/100
# 28/28 [==============================] - 15s 527ms/step - loss: 0.3035 - accuracy: 0.5632 - val_loss: 0.6147 - val_accuracy: 0.7778
# Epoch 14/100
# 28/28 [==============================] - 15s 531ms/step - loss: 0.3027 - accuracy: 0.5644 - val_loss: 0.4105 - val_accuracy: 0.8519
# Epoch 15/100
# 28/28 [==============================] - 15s 530ms/step - loss: 0.3036 - accuracy: 0.5655 - val_loss: 0.4331 - val_accuracy: 0.8148
# Epoch 16/100
# 28/28 [==============================] - 15s 531ms/step - loss: 0.2886 - accuracy: 0.5644 - val_loss: 0.4130 - val_accuracy: 0.8148
# Epoch 17/100
# 28/28 [==============================] - 15s 527ms/step - loss: 0.2879 - accuracy: 0.5644 - val_loss: 0.3982 - val_accuracy: 0.8148
# Epoch 18/100
# 28/28 [==============================] - 15s 525ms/step - loss: 0.2880 - accuracy: 0.5655 - val_loss: 0.5082 - val_accuracy: 0.7778
# 2/2 [==============================] - 1s 37ms/step - loss: 0.1648 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 5120)]        0
#
#  bidirectional (Bidirectiona  (None, 52, 64)           1319168
#  l)
#
#  flatten (Flatten)           (None, 3328)              0
#
#  batch_normalization (BatchN  (None, 3328)             13312
#  ormalization)
#
#  dropout (Dropout)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 2,185,728
# Trainable params: 2,178,560
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 256)               2185728
#
#  model_1 (Functional)        (None, 1)                 37057
#
# =================================================================
# Total params: 2,222,785
# Trainable params: 2,215,617
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 19s 543ms/step - loss: 0.5832 - accuracy: 0.4839 - val_loss: 0.8199 - val_accuracy: 0.6667
# Epoch 2/100
# 28/28 [==============================] - 14s 510ms/step - loss: 0.4250 - accuracy: 0.5425 - val_loss: 0.4169 - val_accuracy: 0.7778
# Epoch 3/100
# 28/28 [==============================] - 14s 510ms/step - loss: 0.3857 - accuracy: 0.5517 - val_loss: 0.3106 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 17s 621ms/step - loss: 0.3555 - accuracy: 0.5632 - val_loss: 0.3025 - val_accuracy: 0.8519
# Epoch 5/100
# 28/28 [==============================] - 17s 559ms/step - loss: 0.3316 - accuracy: 0.5713 - val_loss: 0.2967 - val_accuracy: 0.8519
# Epoch 6/100
# 28/28 [==============================] - 14s 517ms/step - loss: 0.3294 - accuracy: 0.5701 - val_loss: 0.3829 - val_accuracy: 0.7778
# Epoch 7/100
# 28/28 [==============================] - 15s 522ms/step - loss: 0.3227 - accuracy: 0.5759 - val_loss: 0.2988 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 15s 525ms/step - loss: 0.3344 - accuracy: 0.5724 - val_loss: 0.3196 - val_accuracy: 0.8889
# Epoch 9/100
# 28/28 [==============================] - 15s 520ms/step - loss: 0.3081 - accuracy: 0.5759 - val_loss: 0.3730 - val_accuracy: 0.8148
# Epoch 10/100
# 28/28 [==============================] - 15s 524ms/step - loss: 0.2998 - accuracy: 0.5770 - val_loss: 0.2948 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 15s 525ms/step - loss: 0.2966 - accuracy: 0.5782 - val_loss: 1.0287 - val_accuracy: 0.7778
# Epoch 12/100
# 28/28 [==============================] - 15s 522ms/step - loss: 0.2992 - accuracy: 0.5793 - val_loss: 0.2775 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 14s 516ms/step - loss: 0.2899 - accuracy: 0.5782 - val_loss: 0.4509 - val_accuracy: 0.8148
# Epoch 14/100
# 28/28 [==============================] - 15s 523ms/step - loss: 0.2810 - accuracy: 0.5793 - val_loss: 0.3009 - val_accuracy: 0.8148
# Epoch 15/100
# 28/28 [==============================] - 15s 522ms/step - loss: 0.2816 - accuracy: 0.5793 - val_loss: 0.2675 - val_accuracy: 0.8889
# Epoch 16/100
# 28/28 [==============================] - 15s 522ms/step - loss: 0.2722 - accuracy: 0.5793 - val_loss: 0.4021 - val_accuracy: 0.8519
# Epoch 17/100
# 28/28 [==============================] - 15s 524ms/step - loss: 0.2794 - accuracy: 0.5782 - val_loss: 0.3365 - val_accuracy: 0.8519
# Epoch 18/100
# 28/28 [==============================] - 15s 526ms/step - loss: 0.2803 - accuracy: 0.5782 - val_loss: 0.2647 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 14s 515ms/step - loss: 0.2776 - accuracy: 0.5793 - val_loss: 0.2202 - val_accuracy: 0.8889
# Epoch 20/100
# 28/28 [==============================] - 14s 514ms/step - loss: 0.2710 - accuracy: 0.5793 - val_loss: 0.2801 - val_accuracy: 0.8148
# Epoch 21/100
# 28/28 [==============================] - 15s 522ms/step - loss: 0.2811 - accuracy: 0.5793 - val_loss: 0.4617 - val_accuracy: 0.8519
# Epoch 22/100
# 28/28 [==============================] - 14s 509ms/step - loss: 0.2758 - accuracy: 0.5793 - val_loss: 0.2428 - val_accuracy: 0.8519
# Epoch 23/100
# 28/28 [==============================] - 14s 515ms/step - loss: 0.2703 - accuracy: 0.5793 - val_loss: 0.3258 - val_accuracy: 0.8519
# Epoch 24/100
# 28/28 [==============================] - 15s 528ms/step - loss: 0.2701 - accuracy: 0.5793 - val_loss: 0.2948 - val_accuracy: 0.8889
# 28/28 [==============================] - 15s 528ms/step - loss: 0.2701 - accuracy: 0.5793 - val_loss: 0.2948 - val_accuracy: 0.8889
# Epoch 25/100
# Epoch 25/100
# 28/28 [==============================] - 15s 527ms/step - loss: 0.2725 - accuracy: 0.5782 - val_loss: 0.3807 - val_accuracy: 0.8889
# 28/28 [==============================] - 15s 527ms/step - loss: 0.2725 - accuracy: 0.5782 - val_loss: 0.3807 - val_accuracy: 0.8889
# Epoch 26/100
# Epoch 26/100
# 28/28 [==============================] - 15s 525ms/step - loss: 0.2800 - accuracy: 0.5793 - val_loss: 0.3809 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 525ms/step - loss: 0.2800 - accuracy: 0.5793 - val_loss: 0.3809 - val_accuracy: 0.8519
# Epoch 27/100
# Epoch 27/100
# 28/28 [==============================] - 15s 517ms/step - loss: 0.2736 - accuracy: 0.5793 - val_loss: 0.2502 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 517ms/step - loss: 0.2736 - accuracy: 0.5793 - val_loss: 0.2502 - val_accuracy: 0.8519
# Epoch 28/100
# Epoch 28/100
# 28/28 [==============================] - 15s 521ms/step - loss: 0.2699 - accuracy: 0.5793 - val_loss: 0.5420 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 521ms/step - loss: 0.2699 - accuracy: 0.5793 - val_loss: 0.5420 - val_accuracy: 0.8519
# Epoch 29/100
# Epoch 29/100
# 28/28 [==============================] - 15s 523ms/step - loss: 0.2717 - accuracy: 0.5793 - val_loss: 0.2791 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 523ms/step - loss: 0.2717 - accuracy: 0.5793 - val_loss: 0.2791 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 41ms/step - loss: 0.1627 - accuracy: 0.9412
# 2/2 [==============================] - 1s 41ms/step - loss: 0.1627 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 5120)]        0
#
#  bidirectional (Bidirectiona  (None, 52, 64)           1319168
#  l)
#
#  flatten (Flatten)           (None, 3328)              0
#
#  batch_normalization (BatchN  (None, 3328)             13312
#  ormalization)
#
#  dropout (Dropout)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 2,185,728
# Trainable params: 2,178,560
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 256)               2185728
#
#  model_1 (Functional)        (None, 1)                 37057
#
# =================================================================
# Total params: 2,222,785
# Trainable params: 2,215,617
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 5120)]        0
#
#  bidirectional (Bidirectiona  (None, 52, 64)           1319168
#  l)
#
#  flatten (Flatten)           (None, 3328)              0
#
#  batch_normalization (BatchN  (None, 3328)             13312
#  ormalization)
#
#  dropout (Dropout)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 2,185,728
# Trainable params: 2,178,560
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 256)               2185728
#
#  model_1 (Functional)        (None, 1)                 37057
#
# =================================================================
# Total params: 2,222,785
# Trainable params: 2,215,617
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Epoch 1/100
# Epoch 1/100
# 28/28 [==============================] - 20s 552ms/step - loss: 0.5750 - accuracy: 0.4955 - val_loss: 0.5150 - val_accuracy: 0.7407
# 28/28 [==============================] - 20s 552ms/step - loss: 0.5750 - accuracy: 0.4955 - val_loss: 0.5150 - val_accuracy: 0.7407
# Epoch 2/100
# Epoch 2/100
# 28/28 [==============================] - 14s 517ms/step - loss: 0.4131 - accuracy: 0.5635 - val_loss: 0.3099 - val_accuracy: 0.8519
# 28/28 [==============================] - 14s 517ms/step - loss: 0.4131 - accuracy: 0.5635 - val_loss: 0.3099 - val_accuracy: 0.8519
# Epoch 3/100
# Epoch 3/100
# 28/28 [==============================] - 15s 530ms/step - loss: 0.3959 - accuracy: 0.5726 - val_loss: 0.2501 - val_accuracy: 0.8889
# 28/28 [==============================] - 15s 530ms/step - loss: 0.3959 - accuracy: 0.5726 - val_loss: 0.2501 - val_accuracy: 0.8889
# Epoch 4/100
# Epoch 4/100
# 28/28 [==============================] - 15s 527ms/step - loss: 0.3405 - accuracy: 0.5884 - val_loss: 0.2283 - val_accuracy: 0.9259
# 28/28 [==============================] - 15s 527ms/step - loss: 0.3405 - accuracy: 0.5884 - val_loss: 0.2283 - val_accuracy: 0.9259
# Epoch 5/100
# Epoch 5/100
# 28/28 [==============================] - 15s 532ms/step - loss: 0.3273 - accuracy: 0.5986 - val_loss: 0.2675 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 532ms/step - loss: 0.3273 - accuracy: 0.5986 - val_loss: 0.2675 - val_accuracy: 0.8519
# Epoch 6/100
# Epoch 6/100
# 28/28 [==============================] - 15s 530ms/step - loss: 0.3070 - accuracy: 0.5964 - val_loss: 0.1861 - val_accuracy: 0.9630
# 28/28 [==============================] - 15s 530ms/step - loss: 0.3070 - accuracy: 0.5964 - val_loss: 0.1861 - val_accuracy: 0.9630
# Epoch 7/100
# Epoch 7/100
# 28/28 [==============================] - 15s 528ms/step - loss: 0.3085 - accuracy: 0.5975 - val_loss: 0.3847 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 528ms/step - loss: 0.3085 - accuracy: 0.5975 - val_loss: 0.3847 - val_accuracy: 0.8519
# Epoch 8/100
# Epoch 8/100
# 28/28 [==============================] - 15s 530ms/step - loss: 0.2945 - accuracy: 0.6009 - val_loss: 0.3434 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 530ms/step - loss: 0.2945 - accuracy: 0.6009 - val_loss: 0.3434 - val_accuracy: 0.8519
# Epoch 9/100
# Epoch 9/100
# 28/28 [==============================] - 15s 534ms/step - loss: 0.2877 - accuracy: 0.6020 - val_loss: 0.2059 - val_accuracy: 0.9259
# 28/28 [==============================] - 15s 534ms/step - loss: 0.2877 - accuracy: 0.6020 - val_loss: 0.2059 - val_accuracy: 0.9259
# Epoch 10/100
# Epoch 10/100
# 28/28 [==============================] - 15s 536ms/step - loss: 0.3049 - accuracy: 0.5986 - val_loss: 0.8138 - val_accuracy: 0.5556
# 28/28 [==============================] - 15s 536ms/step - loss: 0.3049 - accuracy: 0.5986 - val_loss: 0.8138 - val_accuracy: 0.5556
# Epoch 11/100
# Epoch 11/100
# 28/28 [==============================] - 15s 534ms/step - loss: 0.2920 - accuracy: 0.6020 - val_loss: 0.1888 - val_accuracy: 0.9630
# 28/28 [==============================] - 15s 534ms/step - loss: 0.2920 - accuracy: 0.6020 - val_loss: 0.1888 - val_accuracy: 0.9630
# Epoch 12/100
# Epoch 12/100
# 28/28 [==============================] - 15s 535ms/step - loss: 0.2865 - accuracy: 0.6020 - val_loss: 0.1921 - val_accuracy: 0.9259
# 28/28 [==============================] - 15s 535ms/step - loss: 0.2865 - accuracy: 0.6020 - val_loss: 0.1921 - val_accuracy: 0.9259
# Epoch 13/100
# Epoch 13/100
# 28/28 [==============================] - 15s 537ms/step - loss: 0.2722 - accuracy: 0.6032 - val_loss: 0.2538 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 537ms/step - loss: 0.2722 - accuracy: 0.6032 - val_loss: 0.2538 - val_accuracy: 0.8519
# Epoch 14/100
# Epoch 14/100
# 28/28 [==============================] - 15s 538ms/step - loss: 0.2881 - accuracy: 0.6032 - val_loss: 0.2022 - val_accuracy: 0.9630
# 28/28 [==============================] - 15s 538ms/step - loss: 0.2881 - accuracy: 0.6032 - val_loss: 0.2022 - val_accuracy: 0.9630
# Epoch 15/100
# Epoch 15/100
# 28/28 [==============================] - 19s 687ms/step - loss: 0.2708 - accuracy: 0.6020 - val_loss: 0.2162 - val_accuracy: 0.9630
# 28/28 [==============================] - 19s 687ms/step - loss: 0.2708 - accuracy: 0.6020 - val_loss: 0.2162 - val_accuracy: 0.9630
# Epoch 16/100
# Epoch 16/100
# 28/28 [==============================] - 15s 538ms/step - loss: 0.2699 - accuracy: 0.6032 - val_loss: 0.2550 - val_accuracy: 0.8519
# 28/28 [==============================] - 15s 538ms/step - loss: 0.2699 - accuracy: 0.6032 - val_loss: 0.2550 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 41ms/step - loss: 0.1963 - accuracy: 0.9412
# 2/2 [==============================] - 1s 41ms/step - loss: 0.1963 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 5120)]        0
#
#  bidirectional (Bidirectiona  (None, 52, 64)           1319168
#  l)
#
#  flatten (Flatten)           (None, 3328)              0
#
#  batch_normalization (BatchN  (None, 3328)             13312
#  ormalization)
#
#  dropout (Dropout)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 2,185,728
# Trainable params: 2,178,560
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 256)               2185728
#
#  model_1 (Functional)        (None, 1)                 37057
#
# =================================================================
# Total params: 2,222,785
# Trainable params: 2,215,617
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 5120)]        0
#
#  bidirectional (Bidirectiona  (None, 52, 64)           1319168
#  l)
#
#  flatten (Flatten)           (None, 3328)              0
#
#  batch_normalization (BatchN  (None, 3328)             13312
#  ormalization)
#
#  dropout (Dropout)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 2,185,728
# Trainable params: 2,178,560
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 256)               2185728
#
#  model_1 (Functional)        (None, 1)                 37057
#
# =================================================================
# Total params: 2,222,785
# Trainable params: 2,215,617
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Epoch 1/100
# Epoch 1/100
# 27/27 [==============================] - 20s 586ms/step - loss: 0.5443 - accuracy: 0.4965 - val_loss: 1.2897 - val_accuracy: 0.5926
# 27/27 [==============================] - 20s 586ms/step - loss: 0.5443 - accuracy: 0.4965 - val_loss: 1.2897 - val_accuracy: 0.5926
# Epoch 2/100
# Epoch 2/100
# 27/27 [==============================] - 15s 552ms/step - loss: 0.4341 - accuracy: 0.5315 - val_loss: 0.5036 - val_accuracy: 0.6296
# 27/27 [==============================] - 15s 552ms/step - loss: 0.4341 - accuracy: 0.5315 - val_loss: 0.5036 - val_accuracy: 0.6296
# Epoch 3/100
# Epoch 3/100
# 27/27 [==============================] - 15s 549ms/step - loss: 0.3751 - accuracy: 0.5501 - val_loss: 0.4008 - val_accuracy: 0.7778
# 27/27 [==============================] - 15s 549ms/step - loss: 0.3751 - accuracy: 0.5501 - val_loss: 0.4008 - val_accuracy: 0.7778
# Epoch 4/100
# Epoch 4/100
# 27/27 [==============================] - 15s 553ms/step - loss: 0.3535 - accuracy: 0.5676 - val_loss: 0.4064 - val_accuracy: 0.9630
# 27/27 [==============================] - 15s 553ms/step - loss: 0.3535 - accuracy: 0.5676 - val_loss: 0.4064 - val_accuracy: 0.9630
# Epoch 5/100
# Epoch 5/100
# 27/27 [==============================] - 15s 550ms/step - loss: 0.3396 - accuracy: 0.5653 - val_loss: 0.3630 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 550ms/step - loss: 0.3396 - accuracy: 0.5653 - val_loss: 0.3630 - val_accuracy: 0.9259
# Epoch 6/100
# Epoch 6/100
# 27/27 [==============================] - 15s 560ms/step - loss: 0.3455 - accuracy: 0.5688 - val_loss: 0.3594 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 560ms/step - loss: 0.3455 - accuracy: 0.5688 - val_loss: 0.3594 - val_accuracy: 0.9259
# Epoch 7/100
# Epoch 7/100
# 27/27 [==============================] - 15s 559ms/step - loss: 0.3169 - accuracy: 0.5781 - val_loss: 0.4109 - val_accuracy: 0.7778
# 27/27 [==============================] - 15s 559ms/step - loss: 0.3169 - accuracy: 0.5781 - val_loss: 0.4109 - val_accuracy: 0.7778
# Epoch 8/100
# Epoch 8/100
# 27/27 [==============================] - 15s 558ms/step - loss: 0.3071 - accuracy: 0.5781 - val_loss: 0.3958 - val_accuracy: 0.7407
# 27/27 [==============================] - 15s 558ms/step - loss: 0.3071 - accuracy: 0.5781 - val_loss: 0.3958 - val_accuracy: 0.7407
# Epoch 9/100
# Epoch 9/100
# 27/27 [==============================] - 15s 550ms/step - loss: 0.2992 - accuracy: 0.5769 - val_loss: 0.3338 - val_accuracy: 0.8148
# 27/27 [==============================] - 15s 550ms/step - loss: 0.2992 - accuracy: 0.5769 - val_loss: 0.3338 - val_accuracy: 0.8148
# Epoch 10/100
# Epoch 10/100
# 27/27 [==============================] - 15s 545ms/step - loss: 0.3002 - accuracy: 0.5758 - val_loss: 0.4139 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 545ms/step - loss: 0.3002 - accuracy: 0.5758 - val_loss: 0.4139 - val_accuracy: 0.9259
# Epoch 11/100
# Epoch 11/100
# 27/27 [==============================] - 15s 538ms/step - loss: 0.2966 - accuracy: 0.5758 - val_loss: 0.3603 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 538ms/step - loss: 0.2966 - accuracy: 0.5758 - val_loss: 0.3603 - val_accuracy: 0.9259
# Epoch 12/100
# Epoch 12/100
# 27/27 [==============================] - 15s 540ms/step - loss: 0.2916 - accuracy: 0.5758 - val_loss: 0.2855 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 540ms/step - loss: 0.2916 - accuracy: 0.5758 - val_loss: 0.2855 - val_accuracy: 0.8889
# Epoch 13/100
# Epoch 13/100
# 27/27 [==============================] - 15s 552ms/step - loss: 0.2868 - accuracy: 0.5769 - val_loss: 0.3291 - val_accuracy: 0.8148
# 27/27 [==============================] - 15s 552ms/step - loss: 0.2868 - accuracy: 0.5769 - val_loss: 0.3291 - val_accuracy: 0.8148
# Epoch 14/100
# Epoch 14/100
# 27/27 [==============================] - 15s 547ms/step - loss: 0.2861 - accuracy: 0.5781 - val_loss: 0.2976 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 547ms/step - loss: 0.2861 - accuracy: 0.5781 - val_loss: 0.2976 - val_accuracy: 0.8889
# Epoch 15/100
# Epoch 15/100
# 27/27 [==============================] - 15s 547ms/step - loss: 0.2808 - accuracy: 0.5781 - val_loss: 0.2714 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 547ms/step - loss: 0.2808 - accuracy: 0.5781 - val_loss: 0.2714 - val_accuracy: 0.8889
# Epoch 16/100
# Epoch 16/100
# 27/27 [==============================] - 15s 549ms/step - loss: 0.2770 - accuracy: 0.5781 - val_loss: 0.3071 - val_accuracy: 0.8519
# 27/27 [==============================] - 15s 549ms/step - loss: 0.2770 - accuracy: 0.5781 - val_loss: 0.3071 - val_accuracy: 0.8519
# Epoch 17/100
# Epoch 17/100
# 27/27 [==============================] - 15s 547ms/step - loss: 0.2743 - accuracy: 0.5781 - val_loss: 0.2778 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 547ms/step - loss: 0.2743 - accuracy: 0.5781 - val_loss: 0.2778 - val_accuracy: 0.9259
# Epoch 18/100
# Epoch 18/100
# 27/27 [==============================] - 15s 551ms/step - loss: 0.2775 - accuracy: 0.5769 - val_loss: 0.4255 - val_accuracy: 0.8519
# 27/27 [==============================] - 15s 551ms/step - loss: 0.2775 - accuracy: 0.5769 - val_loss: 0.4255 - val_accuracy: 0.8519
# Epoch 19/100
# Epoch 19/100
# 27/27 [==============================] - 15s 542ms/step - loss: 0.2801 - accuracy: 0.5769 - val_loss: 0.2564 - val_accuracy: 0.8519
# 27/27 [==============================] - 15s 542ms/step - loss: 0.2801 - accuracy: 0.5769 - val_loss: 0.2564 - val_accuracy: 0.8519
# Epoch 20/100
# Epoch 20/100
# 27/27 [==============================] - 15s 541ms/step - loss: 0.2761 - accuracy: 0.5781 - val_loss: 0.4763 - val_accuracy: 0.8148
# 27/27 [==============================] - 15s 541ms/step - loss: 0.2761 - accuracy: 0.5781 - val_loss: 0.4763 - val_accuracy: 0.8148
# Epoch 21/100
# Epoch 21/100
# 27/27 [==============================] - 15s 561ms/step - loss: 0.2717 - accuracy: 0.5781 - val_loss: 0.2961 - val_accuracy: 0.8148
# 27/27 [==============================] - 15s 561ms/step - loss: 0.2717 - accuracy: 0.5781 - val_loss: 0.2961 - val_accuracy: 0.8148
# Epoch 22/100
# Epoch 22/100
# 27/27 [==============================] - 16s 579ms/step - loss: 0.2709 - accuracy: 0.5781 - val_loss: 0.2772 - val_accuracy: 0.9259
# 27/27 [==============================] - 16s 579ms/step - loss: 0.2709 - accuracy: 0.5781 - val_loss: 0.2772 - val_accuracy: 0.9259
# Epoch 23/100
# Epoch 23/100
# 27/27 [==============================] - 15s 571ms/step - loss: 0.2640 - accuracy: 0.5781 - val_loss: 0.2688 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 571ms/step - loss: 0.2640 - accuracy: 0.5781 - val_loss: 0.2688 - val_accuracy: 0.8889
# Epoch 24/100
# Epoch 24/100
# 27/27 [==============================] - 15s 549ms/step - loss: 0.2668 - accuracy: 0.5781 - val_loss: 0.2838 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 549ms/step - loss: 0.2668 - accuracy: 0.5781 - val_loss: 0.2838 - val_accuracy: 0.8889
# Epoch 25/100
# Epoch 25/100
# 27/27 [==============================] - 15s 549ms/step - loss: 0.2664 - accuracy: 0.5781 - val_loss: 0.2566 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 549ms/step - loss: 0.2664 - accuracy: 0.5781 - val_loss: 0.2566 - val_accuracy: 0.8889
# Epoch 26/100
# Epoch 26/100
# 27/27 [==============================] - 15s 552ms/step - loss: 0.2665 - accuracy: 0.5781 - val_loss: 0.2881 - val_accuracy: 0.8148
# 27/27 [==============================] - 15s 552ms/step - loss: 0.2665 - accuracy: 0.5781 - val_loss: 0.2881 - val_accuracy: 0.8148
# Epoch 27/100
# Epoch 27/100
# 27/27 [==============================] - 15s 546ms/step - loss: 0.2676 - accuracy: 0.5781 - val_loss: 0.5038 - val_accuracy: 0.7407
# 27/27 [==============================] - 15s 546ms/step - loss: 0.2676 - accuracy: 0.5781 - val_loss: 0.5038 - val_accuracy: 0.7407
# Epoch 28/100
# Epoch 28/100
# 27/27 [==============================] - 15s 546ms/step - loss: 0.2639 - accuracy: 0.5781 - val_loss: 0.3665 - val_accuracy: 0.7778
# 27/27 [==============================] - 15s 546ms/step - loss: 0.2639 - accuracy: 0.5781 - val_loss: 0.3665 - val_accuracy: 0.7778
# Epoch 29/100
# Epoch 29/100
# 27/27 [==============================] - 15s 548ms/step - loss: 0.2684 - accuracy: 0.5781 - val_loss: 0.2422 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 548ms/step - loss: 0.2684 - accuracy: 0.5781 - val_loss: 0.2422 - val_accuracy: 0.8889
# Epoch 30/100
# Epoch 30/100
# 27/27 [==============================] - 15s 543ms/step - loss: 0.2619 - accuracy: 0.5781 - val_loss: 0.2576 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 543ms/step - loss: 0.2619 - accuracy: 0.5781 - val_loss: 0.2576 - val_accuracy: 0.8889
# Epoch 31/100
# Epoch 31/100
# 27/27 [==============================] - 15s 545ms/step - loss: 0.2670 - accuracy: 0.5781 - val_loss: 0.3157 - val_accuracy: 0.8519
# 27/27 [==============================] - 15s 545ms/step - loss: 0.2670 - accuracy: 0.5781 - val_loss: 0.3157 - val_accuracy: 0.8519
# Epoch 32/100
# Epoch 32/100
# 27/27 [==============================] - 15s 552ms/step - loss: 0.2574 - accuracy: 0.5781 - val_loss: 0.2883 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 552ms/step - loss: 0.2574 - accuracy: 0.5781 - val_loss: 0.2883 - val_accuracy: 0.9259
# Epoch 33/100
# Epoch 33/100
# 27/27 [==============================] - 15s 546ms/step - loss: 0.2590 - accuracy: 0.5781 - val_loss: 0.2444 - val_accuracy: 0.8519
# 27/27 [==============================] - 15s 546ms/step - loss: 0.2590 - accuracy: 0.5781 - val_loss: 0.2444 - val_accuracy: 0.8519
# Epoch 34/100
# Epoch 34/100
# 27/27 [==============================] - 15s 554ms/step - loss: 0.2570 - accuracy: 0.5781 - val_loss: 0.2306 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 554ms/step - loss: 0.2570 - accuracy: 0.5781 - val_loss: 0.2306 - val_accuracy: 0.9259
# Epoch 35/100
# Epoch 35/100
# 27/27 [==============================] - 15s 545ms/step - loss: 0.2574 - accuracy: 0.5781 - val_loss: 0.2483 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 545ms/step - loss: 0.2574 - accuracy: 0.5781 - val_loss: 0.2483 - val_accuracy: 0.8889
# Epoch 36/100
# Epoch 36/100
# 27/27 [==============================] - 15s 549ms/step - loss: 0.2601 - accuracy: 0.5781 - val_loss: 0.7075 - val_accuracy: 0.7407
# 27/27 [==============================] - 15s 549ms/step - loss: 0.2601 - accuracy: 0.5781 - val_loss: 0.7075 - val_accuracy: 0.7407
# Epoch 37/100
# Epoch 37/100
# 27/27 [==============================] - 15s 551ms/step - loss: 0.2578 - accuracy: 0.5781 - val_loss: 0.2182 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 551ms/step - loss: 0.2578 - accuracy: 0.5781 - val_loss: 0.2182 - val_accuracy: 0.8889
# Epoch 38/100
# Epoch 38/100
# 27/27 [==============================] - 19s 697ms/step - loss: 0.2527 - accuracy: 0.5781 - val_loss: 0.2492 - val_accuracy: 0.8889
# 27/27 [==============================] - 19s 697ms/step - loss: 0.2527 - accuracy: 0.5781 - val_loss: 0.2492 - val_accuracy: 0.8889
# Epoch 39/100
# Epoch 39/100
# 27/27 [==============================] - 15s 565ms/step - loss: 0.2593 - accuracy: 0.5781 - val_loss: 0.2391 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 565ms/step - loss: 0.2593 - accuracy: 0.5781 - val_loss: 0.2391 - val_accuracy: 0.9259
# Epoch 40/100
# Epoch 40/100
# 27/27 [==============================] - 15s 566ms/step - loss: 0.2517 - accuracy: 0.5781 - val_loss: 0.3102 - val_accuracy: 0.7778
# 27/27 [==============================] - 15s 566ms/step - loss: 0.2517 - accuracy: 0.5781 - val_loss: 0.3102 - val_accuracy: 0.7778
# Epoch 41/100
# Epoch 41/100
# 27/27 [==============================] - 15s 567ms/step - loss: 0.2554 - accuracy: 0.5781 - val_loss: 0.3126 - val_accuracy: 0.8148
# 27/27 [==============================] - 15s 567ms/step - loss: 0.2554 - accuracy: 0.5781 - val_loss: 0.3126 - val_accuracy: 0.8148
# Epoch 42/100
# Epoch 42/100
# 27/27 [==============================] - 15s 558ms/step - loss: 0.2598 - accuracy: 0.5781 - val_loss: 0.3016 - val_accuracy: 0.8519
# 27/27 [==============================] - 15s 558ms/step - loss: 0.2598 - accuracy: 0.5781 - val_loss: 0.3016 - val_accuracy: 0.8519
# Epoch 43/100
# Epoch 43/100
# 27/27 [==============================] - 15s 556ms/step - loss: 0.2604 - accuracy: 0.5769 - val_loss: 0.2576 - val_accuracy: 0.9630
# 27/27 [==============================] - 15s 556ms/step - loss: 0.2604 - accuracy: 0.5769 - val_loss: 0.2576 - val_accuracy: 0.9630
# Epoch 44/100
# Epoch 44/100
# 27/27 [==============================] - 15s 556ms/step - loss: 0.2599 - accuracy: 0.5781 - val_loss: 0.2546 - val_accuracy: 0.9259
# 27/27 [==============================] - 15s 556ms/step - loss: 0.2599 - accuracy: 0.5781 - val_loss: 0.2546 - val_accuracy: 0.9259
# Epoch 45/100
# Epoch 45/100
# 27/27 [==============================] - 15s 555ms/step - loss: 0.2508 - accuracy: 0.5769 - val_loss: 0.2989 - val_accuracy: 0.8519
# 27/27 [==============================] - 15s 555ms/step - loss: 0.2508 - accuracy: 0.5769 - val_loss: 0.2989 - val_accuracy: 0.8519
# Epoch 46/100
# Epoch 46/100
# 27/27 [==============================] - 15s 555ms/step - loss: 0.2578 - accuracy: 0.5781 - val_loss: 0.2554 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 555ms/step - loss: 0.2578 - accuracy: 0.5781 - val_loss: 0.2554 - val_accuracy: 0.8889
# Epoch 47/100
# Epoch 47/100
# 27/27 [==============================] - 15s 559ms/step - loss: 0.2495 - accuracy: 0.5781 - val_loss: 0.2525 - val_accuracy: 0.8889
# 27/27 [==============================] - 15s 559ms/step - loss: 0.2495 - accuracy: 0.5781 - val_loss: 0.2525 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 46ms/step - loss: 0.3108 - accuracy: 0.9118
# 2/2 [==============================] - 1s 46ms/step - loss: 0.3108 - accuracy: 0.9118
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 5120)]        0
#
#  bidirectional (Bidirectiona  (None, 52, 64)           1319168
#  l)
#
#  flatten (Flatten)           (None, 3328)              0
#
#  batch_normalization (BatchN  (None, 3328)             13312
#  ormalization)
#
#  dropout (Dropout)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 2,185,728
# Trainable params: 2,178,560
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 256)               2185728
#
#  model_1 (Functional)        (None, 1)                 37057
#
# =================================================================
# Total params: 2,222,785
# Trainable params: 2,215,617
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 52, 5120)]        0
#
#  bidirectional (Bidirectiona  (None, 52, 64)           1319168
#  l)
#
#  flatten (Flatten)           (None, 3328)              0
#
#  batch_normalization (BatchN  (None, 3328)             13312
#  ormalization)
#
#  dropout (Dropout)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 2,185,728
# Trainable params: 2,178,560
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 256)               2185728
#
#  model_1 (Functional)        (None, 1)                 37057
#
# =================================================================
# Total params: 2,222,785
# Trainable params: 2,215,617
# Non-trainable params: 7,168
# _________________________________________________________________
# None
# Epoch 1/100
# Epoch 1/100
# 28/28 [==============================] - 20s 558ms/step - loss: 0.6009 - accuracy: 0.4506 - val_loss: 0.3424 - val_accuracy: 0.7037
# 28/28 [==============================] - 20s 558ms/step - loss: 0.6009 - accuracy: 0.4506 - val_loss: 0.3424 - val_accuracy: 0.7037
# Epoch 2/100
# Epoch 2/100
# 28/28 [==============================] - 15s 518ms/step - loss: 0.4203 - accuracy: 0.5345 - val_loss: 0.1611 - val_accuracy: 0.9630
# 28/28 [==============================] - 15s 518ms/step - loss: 0.4203 - accuracy: 0.5345 - val_loss: 0.1611 - val_accuracy: 0.9630
# Epoch 3/100
# Epoch 3/100
# 28/28 [==============================] - 15s 525ms/step - loss: 0.3925 - accuracy: 0.5483 - val_loss: 0.1505 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 525ms/step - loss: 0.3925 - accuracy: 0.5483 - val_loss: 0.1505 - val_accuracy: 1.0000
# Epoch 4/100
# Epoch 4/100
# 28/28 [==============================] - 15s 525ms/step - loss: 0.3735 - accuracy: 0.5540 - val_loss: 0.1554 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 525ms/step - loss: 0.3735 - accuracy: 0.5540 - val_loss: 0.1554 - val_accuracy: 1.0000
# Epoch 5/100
# Epoch 5/100
# 28/28 [==============================] - 15s 532ms/step - loss: 0.3450 - accuracy: 0.5678 - val_loss: 0.1426 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 532ms/step - loss: 0.3450 - accuracy: 0.5678 - val_loss: 0.1426 - val_accuracy: 1.0000
# Epoch 6/100
# Epoch 6/100
# 28/28 [==============================] - 15s 540ms/step - loss: 0.3407 - accuracy: 0.5655 - val_loss: 0.1831 - val_accuracy: 0.9259
# 28/28 [==============================] - 15s 540ms/step - loss: 0.3407 - accuracy: 0.5655 - val_loss: 0.1831 - val_accuracy: 0.9259
# Epoch 7/100
# Epoch 7/100
# 28/28 [==============================] - 15s 534ms/step - loss: 0.3333 - accuracy: 0.5724 - val_loss: 0.1279 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 534ms/step - loss: 0.3333 - accuracy: 0.5724 - val_loss: 0.1279 - val_accuracy: 1.0000
# Epoch 8/100
# Epoch 8/100
# 28/28 [==============================] - 15s 537ms/step - loss: 0.3209 - accuracy: 0.5724 - val_loss: 0.1579 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 537ms/step - loss: 0.3209 - accuracy: 0.5724 - val_loss: 0.1579 - val_accuracy: 1.0000
# Epoch 9/100
# Epoch 9/100
# 28/28 [==============================] - 15s 537ms/step - loss: 0.3121 - accuracy: 0.5747 - val_loss: 0.2825 - val_accuracy: 0.9259
# 28/28 [==============================] - 15s 537ms/step - loss: 0.3121 - accuracy: 0.5747 - val_loss: 0.2825 - val_accuracy: 0.9259
# Epoch 10/100
# Epoch 10/100
# 28/28 [==============================] - 15s 538ms/step - loss: 0.3153 - accuracy: 0.5747 - val_loss: 0.0857 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 538ms/step - loss: 0.3153 - accuracy: 0.5747 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 11/100
# Epoch 11/100
# 28/28 [==============================] - 15s 542ms/step - loss: 0.3092 - accuracy: 0.5736 - val_loss: 0.1496 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 542ms/step - loss: 0.3092 - accuracy: 0.5736 - val_loss: 0.1496 - val_accuracy: 1.0000
# Epoch 12/100
# Epoch 12/100
# 28/28 [==============================] - 15s 537ms/step - loss: 0.3036 - accuracy: 0.5736 - val_loss: 0.1226 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 537ms/step - loss: 0.3036 - accuracy: 0.5736 - val_loss: 0.1226 - val_accuracy: 1.0000
# Epoch 13/100
# Epoch 13/100
# 28/28 [==============================] - 15s 540ms/step - loss: 0.3153 - accuracy: 0.5724 - val_loss: 0.1809 - val_accuracy: 0.9630
# 28/28 [==============================] - 15s 540ms/step - loss: 0.3153 - accuracy: 0.5724 - val_loss: 0.1809 - val_accuracy: 0.9630
# Epoch 14/100
# Epoch 14/100
# 28/28 [==============================] - 15s 538ms/step - loss: 0.2997 - accuracy: 0.5747 - val_loss: 0.1073 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 538ms/step - loss: 0.2997 - accuracy: 0.5747 - val_loss: 0.1073 - val_accuracy: 1.0000
# Epoch 15/100
# Epoch 15/100
# 28/28 [==============================] - 15s 539ms/step - loss: 0.3035 - accuracy: 0.5759 - val_loss: 0.0883 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 539ms/step - loss: 0.3035 - accuracy: 0.5759 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 16/100
# Epoch 16/100
# 28/28 [==============================] - 15s 540ms/step - loss: 0.2886 - accuracy: 0.5770 - val_loss: 0.1179 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 540ms/step - loss: 0.2886 - accuracy: 0.5770 - val_loss: 0.1179 - val_accuracy: 1.0000
# Epoch 17/100
# Epoch 17/100
# 28/28 [==============================] - 15s 540ms/step - loss: 0.2978 - accuracy: 0.5770 - val_loss: 0.0577 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 540ms/step - loss: 0.2978 - accuracy: 0.5770 - val_loss: 0.0577 - val_accuracy: 1.0000
# Epoch 18/100
# Epoch 18/100
# 28/28 [==============================] - 15s 541ms/step - loss: 0.2933 - accuracy: 0.5759 - val_loss: 0.0514 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 541ms/step - loss: 0.2933 - accuracy: 0.5759 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 19/100
# Epoch 19/100
# 28/28 [==============================] - 15s 542ms/step - loss: 0.2836 - accuracy: 0.5770 - val_loss: 0.2454 - val_accuracy: 0.8889
# 28/28 [==============================] - 15s 542ms/step - loss: 0.2836 - accuracy: 0.5770 - val_loss: 0.2454 - val_accuracy: 0.8889
# Epoch 20/100
# Epoch 20/100
# 28/28 [==============================] - 15s 541ms/step - loss: 0.2881 - accuracy: 0.5770 - val_loss: 0.3823 - val_accuracy: 0.8148
# 28/28 [==============================] - 15s 541ms/step - loss: 0.2881 - accuracy: 0.5770 - val_loss: 0.3823 - val_accuracy: 0.8148
# Epoch 21/100
# Epoch 21/100
# 28/28 [==============================] - 15s 539ms/step - loss: 0.2909 - accuracy: 0.5770 - val_loss: 0.0799 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 539ms/step - loss: 0.2909 - accuracy: 0.5770 - val_loss: 0.0799 - val_accuracy: 1.0000
# Epoch 22/100
# Epoch 22/100
# 28/28 [==============================] - 16s 557ms/step - loss: 0.2873 - accuracy: 0.5747 - val_loss: 0.0953 - val_accuracy: 1.0000
# 28/28 [==============================] - 16s 557ms/step - loss: 0.2873 - accuracy: 0.5747 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 23/100
# Epoch 23/100
# 28/28 [==============================] - 15s 538ms/step - loss: 0.2789 - accuracy: 0.5770 - val_loss: 0.1257 - val_accuracy: 0.9259
# 28/28 [==============================] - 15s 538ms/step - loss: 0.2789 - accuracy: 0.5770 - val_loss: 0.1257 - val_accuracy: 0.9259
# Epoch 24/100
# Epoch 24/100
# 28/28 [==============================] - 15s 539ms/step - loss: 0.2773 - accuracy: 0.5770 - val_loss: 0.0958 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 539ms/step - loss: 0.2773 - accuracy: 0.5770 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 25/100
# Epoch 25/100
# 28/28 [==============================] - 15s 535ms/step - loss: 0.2758 - accuracy: 0.5759 - val_loss: 0.0910 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 535ms/step - loss: 0.2758 - accuracy: 0.5759 - val_loss: 0.0910 - val_accuracy: 1.0000
# Epoch 26/100
# Epoch 26/100
# 28/28 [==============================] - 15s 539ms/step - loss: 0.2796 - accuracy: 0.5770 - val_loss: 0.0752 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 539ms/step - loss: 0.2796 - accuracy: 0.5770 - val_loss: 0.0752 - val_accuracy: 1.0000
# Epoch 27/100
# Epoch 27/100
# 28/28 [==============================] - 15s 540ms/step - loss: 0.2724 - accuracy: 0.5770 - val_loss: 0.0472 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 540ms/step - loss: 0.2724 - accuracy: 0.5770 - val_loss: 0.0472 - val_accuracy: 1.0000
# Epoch 28/100
# Epoch 28/100
# 28/28 [==============================] - 15s 539ms/step - loss: 0.2743 - accuracy: 0.5770 - val_loss: 0.1153 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 539ms/step - loss: 0.2743 - accuracy: 0.5770 - val_loss: 0.1153 - val_accuracy: 1.0000
# Epoch 29/100
# Epoch 29/100
# 28/28 [==============================] - 15s 544ms/step - loss: 0.2716 - accuracy: 0.5770 - val_loss: 0.1499 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 544ms/step - loss: 0.2716 - accuracy: 0.5770 - val_loss: 0.1499 - val_accuracy: 1.0000
# Epoch 30/100
# Epoch 30/100
# 28/28 [==============================] - 17s 613ms/step - loss: 0.2803 - accuracy: 0.5770 - val_loss: 0.0422 - val_accuracy: 1.0000
# 28/28 [==============================] - 17s 613ms/step - loss: 0.2803 - accuracy: 0.5770 - val_loss: 0.0422 - val_accuracy: 1.0000
# Epoch 31/100
# Epoch 31/100
# 28/28 [==============================] - 17s 556ms/step - loss: 0.2723 - accuracy: 0.5770 - val_loss: 0.1592 - val_accuracy: 1.0000
# 28/28 [==============================] - 17s 556ms/step - loss: 0.2723 - accuracy: 0.5770 - val_loss: 0.1592 - val_accuracy: 1.0000
# Epoch 32/100
# Epoch 32/100
# 28/28 [==============================] - 15s 553ms/step - loss: 0.2707 - accuracy: 0.5770 - val_loss: 0.0772 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 553ms/step - loss: 0.2707 - accuracy: 0.5770 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 33/100
# Epoch 33/100
# 28/28 [==============================] - 15s 546ms/step - loss: 0.2727 - accuracy: 0.5759 - val_loss: 0.2451 - val_accuracy: 0.8889
# 28/28 [==============================] - 15s 546ms/step - loss: 0.2727 - accuracy: 0.5759 - val_loss: 0.2451 - val_accuracy: 0.8889
# Epoch 34/100
# Epoch 34/100
# 28/28 [==============================] - 15s 545ms/step - loss: 0.2641 - accuracy: 0.5770 - val_loss: 0.0372 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 545ms/step - loss: 0.2641 - accuracy: 0.5770 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 35/100
# Epoch 35/100
# 28/28 [==============================] - 15s 545ms/step - loss: 0.2629 - accuracy: 0.5770 - val_loss: 0.0603 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 545ms/step - loss: 0.2629 - accuracy: 0.5770 - val_loss: 0.0603 - val_accuracy: 1.0000
# Epoch 36/100
# Epoch 36/100
# 28/28 [==============================] - 15s 544ms/step - loss: 0.2708 - accuracy: 0.5770 - val_loss: 0.0208 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 544ms/step - loss: 0.2708 - accuracy: 0.5770 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 37/100
# Epoch 37/100
# 28/28 [==============================] - 15s 546ms/step - loss: 0.2767 - accuracy: 0.5759 - val_loss: 0.1172 - val_accuracy: 0.9630
# 28/28 [==============================] - 15s 546ms/step - loss: 0.2767 - accuracy: 0.5759 - val_loss: 0.1172 - val_accuracy: 0.9630
# Epoch 38/100
# Epoch 38/100
# 28/28 [==============================] - 15s 547ms/step - loss: 0.2730 - accuracy: 0.5770 - val_loss: 0.3682 - val_accuracy: 0.8889
# 28/28 [==============================] - 15s 547ms/step - loss: 0.2730 - accuracy: 0.5770 - val_loss: 0.3682 - val_accuracy: 0.8889
# Epoch 39/100
# Epoch 39/100
# 28/28 [==============================] - 15s 549ms/step - loss: 0.2683 - accuracy: 0.5770 - val_loss: 0.0372 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 549ms/step - loss: 0.2683 - accuracy: 0.5770 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 40/100
# Epoch 40/100
# 28/28 [==============================] - 15s 548ms/step - loss: 0.2731 - accuracy: 0.5770 - val_loss: 0.1041 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 548ms/step - loss: 0.2731 - accuracy: 0.5770 - val_loss: 0.1041 - val_accuracy: 1.0000
# Epoch 41/100
# Epoch 41/100
# 28/28 [==============================] - 15s 546ms/step - loss: 0.2757 - accuracy: 0.5770 - val_loss: 0.1003 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 546ms/step - loss: 0.2757 - accuracy: 0.5770 - val_loss: 0.1003 - val_accuracy: 1.0000
# Epoch 42/100
# Epoch 42/100
# 28/28 [==============================] - 15s 543ms/step - loss: 0.2668 - accuracy: 0.5770 - val_loss: 0.0843 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 543ms/step - loss: 0.2668 - accuracy: 0.5770 - val_loss: 0.0843 - val_accuracy: 1.0000
# Epoch 43/100
# Epoch 43/100
# 28/28 [==============================] - 15s 549ms/step - loss: 0.2716 - accuracy: 0.5759 - val_loss: 0.1829 - val_accuracy: 0.9259
# 28/28 [==============================] - 15s 549ms/step - loss: 0.2716 - accuracy: 0.5759 - val_loss: 0.1829 - val_accuracy: 0.9259
# Epoch 44/100
# Epoch 44/100
# 28/28 [==============================] - 16s 556ms/step - loss: 0.2696 - accuracy: 0.5770 - val_loss: 0.1069 - val_accuracy: 1.0000
# 28/28 [==============================] - 16s 556ms/step - loss: 0.2696 - accuracy: 0.5770 - val_loss: 0.1069 - val_accuracy: 1.0000
# Epoch 45/100
# Epoch 45/100
# 28/28 [==============================] - 15s 552ms/step - loss: 0.2625 - accuracy: 0.5770 - val_loss: 0.1322 - val_accuracy: 1.0000
# 28/28 [==============================] - 15s 552ms/step - loss: 0.2625 - accuracy: 0.5770 - val_loss: 0.1322 - val_accuracy: 1.0000
# Epoch 46/100
# Epoch 46/100
# 28/28 [==============================] - 15s 550ms/step - loss: 0.2658 - accuracy: 0.5770 - val_loss: 0.1099 - val_accuracy: 0.9630
# 28/28 [==============================] - 15s 550ms/step - loss: 0.2658 - accuracy: 0.5770 - val_loss: 0.1099 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 44ms/step - loss: 0.4586 - accuracy: 0.8824
# 2/2 [==============================] - 1s 44ms/step - loss: 0.4586 - accuracy: 0.8824
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f775d7b2320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f775d7b2320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.9352941155433655]
# [0.9261363135784967]
# Mean test accuracy is 0.94, mean test f1 score is 0.93, max test accuracy is 0.94, max test f1 score is 0.93, min test accuracy is 0.94, min test f1 score is 0.93, std of test accuracy is 0.00, std of test f1 score is 0.00
# Time elapsed through all process: 2523.50, sec
# [0.9352941155433655]
# [0.9261363135784967]
# Mean test accuracy is 0.94, mean test f1 score is 0.93, max test accuracy is 0.94, max test f1 score is 0.93, min test accuracy is 0.94, min test f1 score is 0.93, std of test accuracy is 0.00, std of test f1 score is 0.00
# Time elapsed through all process: 2523.50, sec
