# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resized.mat')

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 32
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 8
dense_unit_of_lstm_function = 128
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(64)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 128)               438720
#
#  model_1 (Functional)        (None, 1)                 10369
#
# =================================================================
# Total params: 449,089
# Trainable params: 447,169
# Non-trainable params: 1,920
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 428ms/step - loss: 0.6607 - accuracy: 0.3900 - val_loss: 0.5879 - val_accuracy: 0.6296
# Epoch 2/100
# 27/27 [==============================] - 10s 373ms/step - loss: 0.4841 - accuracy: 0.5023 - val_loss: 0.4423 - val_accuracy: 0.7037
# Epoch 3/100
# 27/27 [==============================] - 10s 375ms/step - loss: 0.4013 - accuracy: 0.5405 - val_loss: 0.3807 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.3793 - accuracy: 0.5509 - val_loss: 0.3511 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 10s 375ms/step - loss: 0.3525 - accuracy: 0.5613 - val_loss: 0.3237 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 10s 375ms/step - loss: 0.3398 - accuracy: 0.5683 - val_loss: 0.3204 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 10s 375ms/step - loss: 0.3369 - accuracy: 0.5706 - val_loss: 0.3983 - val_accuracy: 0.8519
# Epoch 8/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.3305 - accuracy: 0.5694 - val_loss: 0.3972 - val_accuracy: 0.7778
# Epoch 9/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.3211 - accuracy: 0.5706 - val_loss: 0.2790 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 13s 488ms/step - loss: 0.3145 - accuracy: 0.5671 - val_loss: 0.3017 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.3098 - accuracy: 0.5706 - val_loss: 0.4378 - val_accuracy: 0.8148
# Epoch 12/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.3105 - accuracy: 0.5706 - val_loss: 0.2477 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.3043 - accuracy: 0.5694 - val_loss: 0.5353 - val_accuracy: 0.6667
# Epoch 14/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.2963 - accuracy: 0.5706 - val_loss: 0.5385 - val_accuracy: 0.7778
# Epoch 15/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.2950 - accuracy: 0.5718 - val_loss: 0.2190 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 11s 391ms/step - loss: 0.3061 - accuracy: 0.5694 - val_loss: 0.6486 - val_accuracy: 0.7037
# Epoch 17/100
# 27/27 [==============================] - 11s 391ms/step - loss: 0.2961 - accuracy: 0.5718 - val_loss: 0.2339 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2898 - accuracy: 0.5718 - val_loss: 0.2871 - val_accuracy: 0.8889
# Epoch 19/100
# 27/27 [==============================] - 10s 384ms/step - loss: 0.2916 - accuracy: 0.5718 - val_loss: 0.3558 - val_accuracy: 0.8519
# Epoch 20/100
# 27/27 [==============================] - 10s 387ms/step - loss: 0.2795 - accuracy: 0.5718 - val_loss: 0.2626 - val_accuracy: 0.8519
# Epoch 21/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2784 - accuracy: 0.5706 - val_loss: 0.3045 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.2734 - accuracy: 0.5718 - val_loss: 0.4686 - val_accuracy: 0.7778
# Epoch 23/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.2853 - accuracy: 0.5718 - val_loss: 0.2431 - val_accuracy: 0.8519
# Epoch 24/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.2750 - accuracy: 0.5718 - val_loss: 0.2601 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.2882 - accuracy: 0.5718 - val_loss: 0.2617 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 22ms/step - loss: 0.3111 - accuracy: 0.8824
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 128)               438720
#
#  model_1 (Functional)        (None, 1)                 10369
#
# =================================================================
# Total params: 449,089
# Trainable params: 447,169
# Non-trainable params: 1,920
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 15s 412ms/step - loss: 0.7181 - accuracy: 0.3669 - val_loss: 0.5057 - val_accuracy: 0.6667
# Epoch 2/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.5326 - accuracy: 0.4595 - val_loss: 0.4221 - val_accuracy: 0.6667
# Epoch 3/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.4534 - accuracy: 0.5023 - val_loss: 0.3276 - val_accuracy: 0.7778
# Epoch 4/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.4346 - accuracy: 0.5266 - val_loss: 0.3400 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.4178 - accuracy: 0.5266 - val_loss: 0.3119 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 10s 384ms/step - loss: 0.3885 - accuracy: 0.5440 - val_loss: 0.3546 - val_accuracy: 0.8148
# Epoch 7/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.3809 - accuracy: 0.5382 - val_loss: 0.2163 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.3450 - accuracy: 0.5556 - val_loss: 0.1798 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3445 - accuracy: 0.5579 - val_loss: 0.2753 - val_accuracy: 0.8519
# Epoch 10/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3341 - accuracy: 0.5602 - val_loss: 0.1842 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.3241 - accuracy: 0.5613 - val_loss: 0.4192 - val_accuracy: 0.8148
# Epoch 12/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3179 - accuracy: 0.5602 - val_loss: 0.2057 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.3136 - accuracy: 0.5625 - val_loss: 0.3059 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.3249 - accuracy: 0.5590 - val_loss: 0.1302 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.3171 - accuracy: 0.5579 - val_loss: 0.1611 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.3033 - accuracy: 0.5613 - val_loss: 0.1534 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.3008 - accuracy: 0.5625 - val_loss: 0.1548 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 10s 375ms/step - loss: 0.3025 - accuracy: 0.5625 - val_loss: 0.1319 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 10s 372ms/step - loss: 0.3115 - accuracy: 0.5613 - val_loss: 0.1403 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 10s 375ms/step - loss: 0.3093 - accuracy: 0.5613 - val_loss: 0.1574 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 10s 374ms/step - loss: 0.3040 - accuracy: 0.5613 - val_loss: 0.1923 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2918 - accuracy: 0.5625 - val_loss: 0.2625 - val_accuracy: 0.8889
# Epoch 23/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.3064 - accuracy: 0.5613 - val_loss: 0.2970 - val_accuracy: 0.8148
# Epoch 24/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.3054 - accuracy: 0.5625 - val_loss: 0.1835 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 23ms/step - loss: 0.1856 - accuracy: 0.9412
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 128)               438720
#
#  model_1 (Functional)        (None, 1)                 10369
#
# =================================================================
# Total params: 449,089
# Trainable params: 447,169
# Non-trainable params: 1,920
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 17s 424ms/step - loss: 0.6533 - accuracy: 0.4020 - val_loss: 0.4528 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 11s 392ms/step - loss: 0.4473 - accuracy: 0.5248 - val_loss: 0.3443 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 11s 392ms/step - loss: 0.3895 - accuracy: 0.5507 - val_loss: 0.3557 - val_accuracy: 0.8148
# Epoch 4/100
# 28/28 [==============================] - 11s 389ms/step - loss: 0.4017 - accuracy: 0.5484 - val_loss: 0.2936 - val_accuracy: 0.8519
# Epoch 5/100
# 28/28 [==============================] - 11s 393ms/step - loss: 0.3840 - accuracy: 0.5529 - val_loss: 0.2758 - val_accuracy: 0.8519
# Epoch 6/100
# 28/28 [==============================] - 11s 390ms/step - loss: 0.3495 - accuracy: 0.5687 - val_loss: 0.2380 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.3297 - accuracy: 0.5732 - val_loss: 0.2493 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 11s 403ms/step - loss: 0.3162 - accuracy: 0.5743 - val_loss: 0.3331 - val_accuracy: 0.8519
# Epoch 9/100
# 28/28 [==============================] - 13s 449ms/step - loss: 0.3175 - accuracy: 0.5766 - val_loss: 0.2842 - val_accuracy: 0.8519
# Epoch 10/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.3281 - accuracy: 0.5766 - val_loss: 0.2163 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.3022 - accuracy: 0.5777 - val_loss: 0.2207 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2947 - accuracy: 0.5811 - val_loss: 0.2374 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2919 - accuracy: 0.5800 - val_loss: 0.2155 - val_accuracy: 0.8889
# Epoch 14/100
# 28/28 [==============================] - 11s 393ms/step - loss: 0.2920 - accuracy: 0.5800 - val_loss: 0.2104 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 11s 384ms/step - loss: 0.2947 - accuracy: 0.5811 - val_loss: 0.2037 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 11s 391ms/step - loss: 0.2776 - accuracy: 0.5811 - val_loss: 0.1977 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 11s 389ms/step - loss: 0.2822 - accuracy: 0.5811 - val_loss: 0.2289 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 11s 384ms/step - loss: 0.2749 - accuracy: 0.5811 - val_loss: 0.2719 - val_accuracy: 0.8519
# Epoch 19/100
# 28/28 [==============================] - 11s 390ms/step - loss: 0.2849 - accuracy: 0.5811 - val_loss: 0.2786 - val_accuracy: 0.8889
# Epoch 20/100
# 28/28 [==============================] - 11s 385ms/step - loss: 0.2717 - accuracy: 0.5811 - val_loss: 0.2092 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 11s 384ms/step - loss: 0.2720 - accuracy: 0.5800 - val_loss: 0.1649 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 11s 388ms/step - loss: 0.2714 - accuracy: 0.5811 - val_loss: 0.2058 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 11s 391ms/step - loss: 0.2728 - accuracy: 0.5811 - val_loss: 0.2349 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 11s 394ms/step - loss: 0.2717 - accuracy: 0.5800 - val_loss: 0.2239 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 11s 392ms/step - loss: 0.2622 - accuracy: 0.5811 - val_loss: 0.2061 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.2646 - accuracy: 0.5811 - val_loss: 0.1771 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 11s 387ms/step - loss: 0.2682 - accuracy: 0.5811 - val_loss: 0.3012 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 11s 387ms/step - loss: 0.2668 - accuracy: 0.5800 - val_loss: 0.1977 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 11s 390ms/step - loss: 0.2753 - accuracy: 0.5800 - val_loss: 0.1569 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.2695 - accuracy: 0.5811 - val_loss: 0.1163 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 11s 388ms/step - loss: 0.2654 - accuracy: 0.5811 - val_loss: 0.1631 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 11s 392ms/step - loss: 0.2727 - accuracy: 0.5811 - val_loss: 0.2244 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 11s 388ms/step - loss: 0.2630 - accuracy: 0.5811 - val_loss: 0.1593 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 11s 391ms/step - loss: 0.2652 - accuracy: 0.5811 - val_loss: 0.4539 - val_accuracy: 0.7778
# Epoch 35/100
# 28/28 [==============================] - 11s 393ms/step - loss: 0.2651 - accuracy: 0.5811 - val_loss: 0.1512 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 11s 386ms/step - loss: 0.2658 - accuracy: 0.5811 - val_loss: 0.2018 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 11s 390ms/step - loss: 0.2683 - accuracy: 0.5811 - val_loss: 0.2318 - val_accuracy: 0.9259
# Epoch 38/100
# 28/28 [==============================] - 11s 390ms/step - loss: 0.2662 - accuracy: 0.5811 - val_loss: 0.2244 - val_accuracy: 0.9259
# Epoch 39/100
# 28/28 [==============================] - 11s 389ms/step - loss: 0.2651 - accuracy: 0.5811 - val_loss: 0.2730 - val_accuracy: 0.9259
# Epoch 40/100
# 28/28 [==============================] - 11s 389ms/step - loss: 0.2627 - accuracy: 0.5811 - val_loss: 0.2352 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 24ms/step - loss: 0.3271 - accuracy: 0.8235
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 128)               438720
#
#  model_1 (Functional)        (None, 1)                 10369
#
# =================================================================
# Total params: 449,089
# Trainable params: 447,169
# Non-trainable params: 1,920
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 421ms/step - loss: 0.7271 - accuracy: 0.3972 - val_loss: 1.1956 - val_accuracy: 0.5185
# Epoch 2/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.4802 - accuracy: 0.5083 - val_loss: 0.9315 - val_accuracy: 0.5556
# Epoch 3/100
# 27/27 [==============================] - 10s 384ms/step - loss: 0.4215 - accuracy: 0.5296 - val_loss: 0.6910 - val_accuracy: 0.6667
# Epoch 4/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.4222 - accuracy: 0.5272 - val_loss: 0.5021 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3885 - accuracy: 0.5343 - val_loss: 0.4321 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 11s 392ms/step - loss: 0.3611 - accuracy: 0.5414 - val_loss: 0.4235 - val_accuracy: 0.7778
# Epoch 7/100
# 27/27 [==============================] - 11s 391ms/step - loss: 0.3584 - accuracy: 0.5473 - val_loss: 0.2810 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 10s 387ms/step - loss: 0.3464 - accuracy: 0.5508 - val_loss: 0.3431 - val_accuracy: 0.8519
# Epoch 9/100
# 27/27 [==============================] - 10s 388ms/step - loss: 0.3471 - accuracy: 0.5520 - val_loss: 0.3335 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.3338 - accuracy: 0.5520 - val_loss: 0.3348 - val_accuracy: 0.8519
# Epoch 11/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.3140 - accuracy: 0.5567 - val_loss: 0.3574 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 10s 387ms/step - loss: 0.3300 - accuracy: 0.5520 - val_loss: 0.2719 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 10s 389ms/step - loss: 0.3210 - accuracy: 0.5556 - val_loss: 0.3923 - val_accuracy: 0.8519
# Epoch 14/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.3202 - accuracy: 0.5567 - val_loss: 0.3630 - val_accuracy: 0.8148
# Epoch 15/100
# 27/27 [==============================] - 10s 389ms/step - loss: 0.3071 - accuracy: 0.5579 - val_loss: 0.2841 - val_accuracy: 0.8889
# Epoch 16/100
# 27/27 [==============================] - 10s 389ms/step - loss: 0.3102 - accuracy: 0.5579 - val_loss: 0.4422 - val_accuracy: 0.8519
# Epoch 17/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.3112 - accuracy: 0.5579 - val_loss: 0.3293 - val_accuracy: 0.8519
# Epoch 18/100
# 27/27 [==============================] - 11s 390ms/step - loss: 0.2991 - accuracy: 0.5579 - val_loss: 0.3047 - val_accuracy: 0.8889
# Epoch 19/100
# 27/27 [==============================] - 10s 389ms/step - loss: 0.3006 - accuracy: 0.5579 - val_loss: 0.2766 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.3021 - accuracy: 0.5567 - val_loss: 0.3851 - val_accuracy: 0.8889
# Epoch 21/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.2920 - accuracy: 0.5579 - val_loss: 0.3043 - val_accuracy: 0.8519
# Epoch 22/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2992 - accuracy: 0.5579 - val_loss: 0.3146 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 29ms/step - loss: 0.3706 - accuracy: 0.8824
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 52, 5120)]        0
#
#  model (Functional)          (None, 128)               438720
#
#  model_1 (Functional)        (None, 1)                 10369
#
# =================================================================
# Total params: 449,089
# Trainable params: 447,169
# Non-trainable params: 1,920
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 429ms/step - loss: 0.6748 - accuracy: 0.4289 - val_loss: 0.7645 - val_accuracy: 0.6667
# Epoch 2/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.4822 - accuracy: 0.5303 - val_loss: 0.4013 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.4362 - accuracy: 0.5501 - val_loss: 0.3723 - val_accuracy: 0.7778
# Epoch 4/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.4155 - accuracy: 0.5606 - val_loss: 0.2466 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 10s 387ms/step - loss: 0.3887 - accuracy: 0.5664 - val_loss: 0.3943 - val_accuracy: 0.7778
# Epoch 6/100
# 27/27 [==============================] - 10s 384ms/step - loss: 0.4043 - accuracy: 0.5711 - val_loss: 0.3108 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 10s 388ms/step - loss: 0.3373 - accuracy: 0.5874 - val_loss: 0.2309 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.3273 - accuracy: 0.5897 - val_loss: 0.2254 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3445 - accuracy: 0.5862 - val_loss: 0.3344 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3084 - accuracy: 0.5921 - val_loss: 0.3764 - val_accuracy: 0.8519
# Epoch 11/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.2992 - accuracy: 0.5909 - val_loss: 0.1583 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2982 - accuracy: 0.5932 - val_loss: 0.1721 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 10s 387ms/step - loss: 0.3078 - accuracy: 0.5921 - val_loss: 0.1770 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3007 - accuracy: 0.5897 - val_loss: 0.1646 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2870 - accuracy: 0.5921 - val_loss: 0.2233 - val_accuracy: 0.8889
# Epoch 16/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2924 - accuracy: 0.5944 - val_loss: 0.3045 - val_accuracy: 0.8519
# Epoch 17/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.2923 - accuracy: 0.5944 - val_loss: 0.2838 - val_accuracy: 0.8519
# Epoch 18/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2901 - accuracy: 0.5944 - val_loss: 0.1960 - val_accuracy: 0.8889
# Epoch 19/100
# 27/27 [==============================] - 10s 388ms/step - loss: 0.2793 - accuracy: 0.5944 - val_loss: 0.2636 - val_accuracy: 0.8519
# Epoch 20/100
# 27/27 [==============================] - 11s 391ms/step - loss: 0.2766 - accuracy: 0.5944 - val_loss: 0.2759 - val_accuracy: 0.8519
# Epoch 21/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2775 - accuracy: 0.5944 - val_loss: 0.2438 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 28ms/step - loss: 0.2469 - accuracy: 0.8529
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f129bf63d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.8764705896377564]
# [0.8640162673036478]
# Epoch 1/100
# 28/28 [==============================] - 17s 432ms/step - loss: 0.6619 - accuracy: 0.4308 - val_loss: 0.4452 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 11s 389ms/step - loss: 0.5021 - accuracy: 0.5215 - val_loss: 0.3664 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 11s 394ms/step - loss: 0.4006 - accuracy: 0.5544 - val_loss: 0.4015 - val_accuracy: 0.8148
# Epoch 4/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.3788 - accuracy: 0.5601 - val_loss: 0.4239 - val_accuracy: 0.7407
# Epoch 5/100
# 28/28 [==============================] - 11s 403ms/step - loss: 0.3545 - accuracy: 0.5669 - val_loss: 0.3025 - val_accuracy: 0.8519
# Epoch 6/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.3455 - accuracy: 0.5646 - val_loss: 0.3653 - val_accuracy: 0.8519
# Epoch 7/100
# 28/28 [==============================] - 13s 458ms/step - loss: 0.3357 - accuracy: 0.5748 - val_loss: 0.3171 - val_accuracy: 0.8519
# Epoch 8/100
# 28/28 [==============================] - 12s 440ms/step - loss: 0.3271 - accuracy: 0.5771 - val_loss: 0.4009 - val_accuracy: 0.8148
# Epoch 9/100
# 28/28 [==============================] - 11s 408ms/step - loss: 0.3168 - accuracy: 0.5760 - val_loss: 0.4375 - val_accuracy: 0.7778
# Epoch 10/100
# 28/28 [==============================] - 11s 400ms/step - loss: 0.3209 - accuracy: 0.5760 - val_loss: 0.2933 - val_accuracy: 0.8889
# Epoch 11/100
# 28/28 [==============================] - 11s 408ms/step - loss: 0.3297 - accuracy: 0.5748 - val_loss: 0.4333 - val_accuracy: 0.7778
# Epoch 12/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.3277 - accuracy: 0.5771 - val_loss: 0.3929 - val_accuracy: 0.7778
# Epoch 13/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.2962 - accuracy: 0.5794 - val_loss: 0.3453 - val_accuracy: 0.8519
# Epoch 14/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.2862 - accuracy: 0.5794 - val_loss: 0.2682 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 11s 390ms/step - loss: 0.2947 - accuracy: 0.5805 - val_loss: 0.3368 - val_accuracy: 0.8889
# Epoch 16/100
# 28/28 [==============================] - 11s 388ms/step - loss: 0.2987 - accuracy: 0.5771 - val_loss: 0.6382 - val_accuracy: 0.8148
# Epoch 17/100
# 28/28 [==============================] - 11s 389ms/step - loss: 0.2886 - accuracy: 0.5805 - val_loss: 0.4420 - val_accuracy: 0.8148
# Epoch 18/100
# 28/28 [==============================] - 11s 391ms/step - loss: 0.2898 - accuracy: 0.5794 - val_loss: 0.3718 - val_accuracy: 0.8519
# Epoch 19/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.3025 - accuracy: 0.5794 - val_loss: 0.4363 - val_accuracy: 0.8148
# Epoch 20/100
# 28/28 [==============================] - 11s 390ms/step - loss: 0.2947 - accuracy: 0.5805 - val_loss: 0.5747 - val_accuracy: 0.8148
# Epoch 21/100
# 28/28 [==============================] - 11s 386ms/step - loss: 0.2890 - accuracy: 0.5794 - val_loss: 0.3693 - val_accuracy: 0.8148
# Epoch 22/100
# 28/28 [==============================] - 11s 385ms/step - loss: 0.2878 - accuracy: 0.5794 - val_loss: 0.5388 - val_accuracy: 0.7778
# Epoch 23/100
# 28/28 [==============================] - 11s 387ms/step - loss: 0.2890 - accuracy: 0.5805 - val_loss: 0.4477 - val_accuracy: 0.7778
# Epoch 24/100
# 28/28 [==============================] - 11s 394ms/step - loss: 0.2830 - accuracy: 0.5805 - val_loss: 0.3541 - val_accuracy: 0.8148
# 2/2 [==============================] - 1s 23ms/step - loss: 0.2899 - accuracy: 0.8824
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f129a2325f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 1/100
# 28/28 [==============================] - 16s 406ms/step - loss: 0.7027 - accuracy: 0.4144 - val_loss: 0.4439 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.4774 - accuracy: 0.5126 - val_loss: 0.3716 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.4262 - accuracy: 0.5274 - val_loss: 0.3600 - val_accuracy: 0.8148
# Epoch 4/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.4006 - accuracy: 0.5400 - val_loss: 0.3442 - val_accuracy: 0.7778
# Epoch 5/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.3694 - accuracy: 0.5651 - val_loss: 0.3303 - val_accuracy: 0.8148
# Epoch 6/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.3667 - accuracy: 0.5571 - val_loss: 0.3613 - val_accuracy: 0.8148
# Epoch 7/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.3411 - accuracy: 0.5651 - val_loss: 0.2822 - val_accuracy: 0.8519
# Epoch 8/100
# 28/28 [==============================] - 10s 369ms/step - loss: 0.3368 - accuracy: 0.5628 - val_loss: 0.4955 - val_accuracy: 0.7037
# Epoch 9/100
# 28/28 [==============================] - 10s 364ms/step - loss: 0.3404 - accuracy: 0.5662 - val_loss: 0.4158 - val_accuracy: 0.7407
# Epoch 10/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.3272 - accuracy: 0.5708 - val_loss: 0.3620 - val_accuracy: 0.7778
# Epoch 11/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3168 - accuracy: 0.5731 - val_loss: 0.3634 - val_accuracy: 0.7778
# Epoch 12/100
# 28/28 [==============================] - 10s 364ms/step - loss: 0.3113 - accuracy: 0.5731 - val_loss: 0.3106 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.2980 - accuracy: 0.5731 - val_loss: 0.3297 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 10s 366ms/step - loss: 0.3079 - accuracy: 0.5731 - val_loss: 0.3858 - val_accuracy: 0.6667
# Epoch 15/100
# 28/28 [==============================] - 10s 366ms/step - loss: 0.3100 - accuracy: 0.5708 - val_loss: 0.3757 - val_accuracy: 0.8148
# Epoch 16/100
# 28/28 [==============================] - 10s 369ms/step - loss: 0.3049 - accuracy: 0.5685 - val_loss: 0.3024 - val_accuracy: 0.8889
# Epoch 17/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.2988 - accuracy: 0.5719 - val_loss: 0.3405 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 23ms/step - loss: 0.2653 - accuracy: 0.9118
# Epoch 1/100
# 29/29 [==============================] - 17s 420ms/step - loss: 0.6682 - accuracy: 0.4243 - val_loss: 0.2600 - val_accuracy: 0.9259
# Epoch 2/100
# 29/29 [==============================] - 11s 381ms/step - loss: 0.4394 - accuracy: 0.5417 - val_loss: 0.2024 - val_accuracy: 0.9259
# Epoch 3/100
# 29/29 [==============================] - 11s 374ms/step - loss: 0.3872 - accuracy: 0.5537 - val_loss: 0.2065 - val_accuracy: 0.9259
# Epoch 4/100
# 29/29 [==============================] - 11s 377ms/step - loss: 0.3806 - accuracy: 0.5658 - val_loss: 0.1899 - val_accuracy: 0.9630
# Epoch 5/100
# 29/29 [==============================] - 11s 372ms/step - loss: 0.3539 - accuracy: 0.5789 - val_loss: 0.2478 - val_accuracy: 0.9259
# Epoch 6/100
# 29/29 [==============================] - 11s 372ms/step - loss: 0.3402 - accuracy: 0.5844 - val_loss: 0.3026 - val_accuracy: 0.8148
# Epoch 7/100
# 29/29 [==============================] - 11s 374ms/step - loss: 0.3277 - accuracy: 0.5855 - val_loss: 0.3163 - val_accuracy: 0.8519
# Epoch 8/100
# 29/29 [==============================] - 11s 372ms/step - loss: 0.3115 - accuracy: 0.5943 - val_loss: 0.2765 - val_accuracy: 0.8889
# Epoch 9/100
# 29/29 [==============================] - 11s 366ms/step - loss: 0.3011 - accuracy: 0.5954 - val_loss: 0.2526 - val_accuracy: 0.8889
# Epoch 10/100
# 29/29 [==============================] - 11s 368ms/step - loss: 0.3079 - accuracy: 0.5921 - val_loss: 0.2591 - val_accuracy: 0.9259
# Epoch 11/100
# 29/29 [==============================] - 11s 368ms/step - loss: 0.3130 - accuracy: 0.5921 - val_loss: 0.2436 - val_accuracy: 0.9259
# Epoch 12/100
# 29/29 [==============================] - 11s 368ms/step - loss: 0.3015 - accuracy: 0.5943 - val_loss: 0.1878 - val_accuracy: 0.9630
# Epoch 13/100
# 29/29 [==============================] - 11s 380ms/step - loss: 0.2976 - accuracy: 0.5932 - val_loss: 0.3517 - val_accuracy: 0.7778
# Epoch 14/100
# 29/29 [==============================] - 11s 371ms/step - loss: 0.2870 - accuracy: 0.5954 - val_loss: 0.3556 - val_accuracy: 0.8148
# Epoch 15/100
# 29/29 [==============================] - 11s 370ms/step - loss: 0.2910 - accuracy: 0.5965 - val_loss: 0.7297 - val_accuracy: 0.7778
# Epoch 16/100
# 29/29 [==============================] - 11s 381ms/step - loss: 0.2817 - accuracy: 0.5954 - val_loss: 0.4234 - val_accuracy: 0.7778
# Epoch 17/100
# 29/29 [==============================] - 11s 377ms/step - loss: 0.2733 - accuracy: 0.5954 - val_loss: 0.2098 - val_accuracy: 0.9630
# Epoch 18/100
# 29/29 [==============================] - 11s 375ms/step - loss: 0.2827 - accuracy: 0.5965 - val_loss: 0.4727 - val_accuracy: 0.7778
# Epoch 19/100
# 29/29 [==============================] - 11s 387ms/step - loss: 0.2729 - accuracy: 0.5965 - val_loss: 0.3362 - val_accuracy: 0.7778
# Epoch 20/100
# 29/29 [==============================] - 11s 371ms/step - loss: 0.2702 - accuracy: 0.5965 - val_loss: 0.4719 - val_accuracy: 0.7778
# Epoch 21/100
# 29/29 [==============================] - 11s 372ms/step - loss: 0.2678 - accuracy: 0.5965 - val_loss: 0.2177 - val_accuracy: 0.8889
# Epoch 22/100
# 29/29 [==============================] - 11s 371ms/step - loss: 0.2920 - accuracy: 0.5965 - val_loss: 0.3582 - val_accuracy: 0.8148
# 2/2 [==============================] - 1s 24ms/step - loss: 0.4375 - accuracy: 0.8529
# Epoch 1/100
# 28/28 [==============================] - 16s 401ms/step - loss: 0.7036 - accuracy: 0.3989 - val_loss: 0.4341 - val_accuracy: 0.9259
# Epoch 2/100
# 28/28 [==============================] - 10s 363ms/step - loss: 0.5146 - accuracy: 0.4885 - val_loss: 0.3168 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 10s 369ms/step - loss: 0.4460 - accuracy: 0.5184 - val_loss: 0.3197 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.4271 - accuracy: 0.5253 - val_loss: 0.2662 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.4045 - accuracy: 0.5368 - val_loss: 0.2252 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3892 - accuracy: 0.5425 - val_loss: 0.4732 - val_accuracy: 0.7407
# Epoch 7/100
# 28/28 [==============================] - 10s 369ms/step - loss: 0.3761 - accuracy: 0.5460 - val_loss: 0.3098 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.3650 - accuracy: 0.5448 - val_loss: 0.4285 - val_accuracy: 0.7407
# Epoch 9/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.3653 - accuracy: 0.5437 - val_loss: 0.2992 - val_accuracy: 0.8148
# Epoch 10/100
# 28/28 [==============================] - 10s 369ms/step - loss: 0.3581 - accuracy: 0.5483 - val_loss: 0.1783 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 14s 511ms/step - loss: 0.3388 - accuracy: 0.5540 - val_loss: 0.1933 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.3459 - accuracy: 0.5517 - val_loss: 0.3462 - val_accuracy: 0.8519
# Epoch 13/100
# 28/28 [==============================] - 10s 366ms/step - loss: 0.3389 - accuracy: 0.5598 - val_loss: 0.2193 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.3280 - accuracy: 0.5609 - val_loss: 0.4269 - val_accuracy: 0.7407
# Epoch 15/100
# 28/28 [==============================] - 10s 366ms/step - loss: 0.3272 - accuracy: 0.5644 - val_loss: 0.6571 - val_accuracy: 0.6296
# Epoch 16/100
# 28/28 [==============================] - 10s 365ms/step - loss: 0.3157 - accuracy: 0.5609 - val_loss: 0.1962 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.3080 - accuracy: 0.5655 - val_loss: 0.1112 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.3047 - accuracy: 0.5655 - val_loss: 0.1388 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 11s 387ms/step - loss: 0.3079 - accuracy: 0.5655 - val_loss: 0.1376 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.2939 - accuracy: 0.5655 - val_loss: 0.1566 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.2848 - accuracy: 0.5655 - val_loss: 0.2358 - val_accuracy: 0.8519
# Epoch 22/100
# 28/28 [==============================] - 10s 364ms/step - loss: 0.3082 - accuracy: 0.5632 - val_loss: 0.2601 - val_accuracy: 0.8519
# Epoch 23/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.2960 - accuracy: 0.5655 - val_loss: 0.1080 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 11s 378ms/step - loss: 0.2928 - accuracy: 0.5655 - val_loss: 0.1434 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 10s 366ms/step - loss: 0.2866 - accuracy: 0.5655 - val_loss: 0.1308 - val_accuracy: 0.8889
# Epoch 26/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.2959 - accuracy: 0.5632 - val_loss: 0.1356 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.3006 - accuracy: 0.5655 - val_loss: 0.3164 - val_accuracy: 0.8519
# Epoch 28/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.2915 - accuracy: 0.5644 - val_loss: 0.1226 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.2941 - accuracy: 0.5655 - val_loss: 0.3009 - val_accuracy: 0.8889
# Epoch 30/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.2938 - accuracy: 0.5644 - val_loss: 0.1863 - val_accuracy: 0.9259
# Epoch 31/100
# 28/28 [==============================] - 10s 369ms/step - loss: 0.2927 - accuracy: 0.5644 - val_loss: 0.2117 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 10s 368ms/step - loss: 0.2900 - accuracy: 0.5655 - val_loss: 0.3002 - val_accuracy: 0.8519
# Epoch 33/100
# 28/28 [==============================] - 10s 367ms/step - loss: 0.2890 - accuracy: 0.5644 - val_loss: 0.2408 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 25ms/step - loss: 0.1937 - accuracy: 0.9706
# Epoch 1/100
# 27/27 [==============================] - 16s 416ms/step - loss: 0.6586 - accuracy: 0.4266 - val_loss: 0.6227 - val_accuracy: 0.6296
# Epoch 2/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.4769 - accuracy: 0.5280 - val_loss: 0.4273 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 11s 390ms/step - loss: 0.4305 - accuracy: 0.5501 - val_loss: 0.3537 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.3890 - accuracy: 0.5618 - val_loss: 0.3036 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3710 - accuracy: 0.5758 - val_loss: 0.2548 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3433 - accuracy: 0.5909 - val_loss: 0.3106 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.3303 - accuracy: 0.5944 - val_loss: 0.2361 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.3186 - accuracy: 0.5944 - val_loss: 0.2170 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 10s 388ms/step - loss: 0.3156 - accuracy: 0.5967 - val_loss: 0.1738 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 10s 387ms/step - loss: 0.3189 - accuracy: 0.5979 - val_loss: 0.2761 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.3029 - accuracy: 0.5991 - val_loss: 0.2126 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.3011 - accuracy: 0.6002 - val_loss: 0.1666 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.2969 - accuracy: 0.5991 - val_loss: 0.4327 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.2941 - accuracy: 0.5991 - val_loss: 0.1874 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.2868 - accuracy: 0.5991 - val_loss: 0.2416 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.2808 - accuracy: 0.6014 - val_loss: 0.2081 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 10s 387ms/step - loss: 0.2801 - accuracy: 0.6014 - val_loss: 0.1847 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2742 - accuracy: 0.6014 - val_loss: 0.2084 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2819 - accuracy: 0.6014 - val_loss: 0.2163 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.2774 - accuracy: 0.6014 - val_loss: 0.2650 - val_accuracy: 0.8889
# Epoch 21/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.2781 - accuracy: 0.6002 - val_loss: 0.1951 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 10s 386ms/step - loss: 0.2736 - accuracy: 0.6014 - val_loss: 0.2760 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 27ms/step - loss: 0.1909 - accuracy: 0.9412
# [0.8764705896377564, 0.9117646932601928]
# [0.8640162673036478, 0.8908431630886874]
# Epoch 1/100
# 27/27 [==============================] - 16s 418ms/step - loss: 0.6714 - accuracy: 0.4406 - val_loss: 0.5059 - val_accuracy: 0.8148
# Epoch 2/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.5144 - accuracy: 0.5093 - val_loss: 0.4329 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 11s 413ms/step - loss: 0.4768 - accuracy: 0.5210 - val_loss: 0.3499 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.4438 - accuracy: 0.5350 - val_loss: 0.3659 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.4290 - accuracy: 0.5443 - val_loss: 0.3392 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.4044 - accuracy: 0.5524 - val_loss: 0.3790 - val_accuracy: 0.8148
# Epoch 7/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.3947 - accuracy: 0.5723 - val_loss: 0.3045 - val_accuracy: 0.8519
# Epoch 8/100
# 27/27 [==============================] - 13s 498ms/step - loss: 0.3601 - accuracy: 0.5734 - val_loss: 0.2196 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.3427 - accuracy: 0.5839 - val_loss: 0.2296 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 11s 388ms/step - loss: 0.3666 - accuracy: 0.5746 - val_loss: 0.1599 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3332 - accuracy: 0.5804 - val_loss: 0.1613 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.3246 - accuracy: 0.5874 - val_loss: 0.1193 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.3085 - accuracy: 0.5921 - val_loss: 0.1209 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3032 - accuracy: 0.5921 - val_loss: 0.2540 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3025 - accuracy: 0.5932 - val_loss: 0.0926 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2974 - accuracy: 0.5897 - val_loss: 0.1207 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 10s 384ms/step - loss: 0.3059 - accuracy: 0.5886 - val_loss: 0.1630 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.2854 - accuracy: 0.5932 - val_loss: 0.2996 - val_accuracy: 0.8519
# Epoch 19/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.2876 - accuracy: 0.5932 - val_loss: 0.2074 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.2926 - accuracy: 0.5944 - val_loss: 0.2588 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.2777 - accuracy: 0.5921 - val_loss: 0.3032 - val_accuracy: 0.8519
# Epoch 22/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.2890 - accuracy: 0.5944 - val_loss: 0.2519 - val_accuracy: 0.8148
# Epoch 23/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.2801 - accuracy: 0.5944 - val_loss: 0.2288 - val_accuracy: 0.8519
# Epoch 24/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.2841 - accuracy: 0.5932 - val_loss: 0.1437 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.2836 - accuracy: 0.5944 - val_loss: 0.3066 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 31ms/step - loss: 0.2000 - accuracy: 0.8824
# Epoch 1/100
# 28/28 [==============================] - 16s 408ms/step - loss: 0.6281 - accuracy: 0.4475 - val_loss: 0.5057 - val_accuracy: 0.7407
# Epoch 2/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.4435 - accuracy: 0.5491 - val_loss: 0.3741 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.4232 - accuracy: 0.5594 - val_loss: 0.3633 - val_accuracy: 0.9259
# Epoch 4/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.4109 - accuracy: 0.5708 - val_loss: 0.3219 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 11s 378ms/step - loss: 0.3678 - accuracy: 0.5811 - val_loss: 0.3171 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3681 - accuracy: 0.5856 - val_loss: 0.3847 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.3308 - accuracy: 0.5947 - val_loss: 0.5743 - val_accuracy: 0.7407
# Epoch 8/100
# 28/28 [==============================] - 10s 372ms/step - loss: 0.3156 - accuracy: 0.5982 - val_loss: 0.3362 - val_accuracy: 0.8519
# Epoch 9/100
# 28/28 [==============================] - 10s 374ms/step - loss: 0.3120 - accuracy: 0.5993 - val_loss: 0.3786 - val_accuracy: 0.8148
# Epoch 10/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.3035 - accuracy: 0.5970 - val_loss: 0.4576 - val_accuracy: 0.8148
# Epoch 11/100
# ...
# Epoch 7/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.3696 - accuracy: 0.5449 - val_loss: 0.3556 - val_accuracy: 0.8148
# Epoch 8/100
# 27/27 [==============================] - 10s 372ms/step - loss: 0.3294 - accuracy: 0.5544 - val_loss: 0.3037 - val_accuracy: 0.8519
# Epoch 9/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.3295 - accuracy: 0.5544 - val_loss: 0.3918 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 10s 375ms/step - loss: 0.3242 - accuracy: 0.5520 - val_loss: 0.4552 - val_accuracy: 0.7778
# Epoch 11/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3193 - accuracy: 0.5544 - val_loss: 0.4120 - val_accuracy: 0.8519
# Epoch 12/100
# 27/27 [==============================] - 10s 374ms/step - loss: 0.3174 - accuracy: 0.5544 - val_loss: 0.2989 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.3052 - accuracy: 0.5579 - val_loss: 0.3280 - val_accuracy: 0.8519
# Epoch 14/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.3061 - accuracy: 0.5579 - val_loss: 0.3136 - val_accuracy: 0.8519
# Epoch 15/100
# 27/27 [==============================] - 14s 528ms/step - loss: 0.3037 - accuracy: 0.5579 - val_loss: 0.2853 - val_accuracy: 0.8889
# Epoch 16/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3058 - accuracy: 0.5567 - val_loss: 0.3203 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.3092 - accuracy: 0.5579 - val_loss: 0.3982 - val_accuracy: 0.8148
# Epoch 18/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.2959 - accuracy: 0.5579 - val_loss: 0.3893 - val_accuracy: 0.8519
# Epoch 19/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.3016 - accuracy: 0.5567 - val_loss: 0.3067 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.2940 - accuracy: 0.5579 - val_loss: 0.6766 - val_accuracy: 0.7037
# Epoch 21/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.2920 - accuracy: 0.5579 - val_loss: 0.3665 - val_accuracy: 0.8519
# Epoch 22/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.2968 - accuracy: 0.5579 - val_loss: 0.2952 - val_accuracy: 0.8889
# Epoch 23/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.3094 - accuracy: 0.5567 - val_loss: 0.3305 - val_accuracy: 0.8519
# Epoch 24/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.2918 - accuracy: 0.5567 - val_loss: 0.7138 - val_accuracy: 0.7778
# Epoch 25/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2913 - accuracy: 0.5579 - val_loss: 0.3627 - val_accuracy: 0.8148
# 2/2 [==============================] - 1s 28ms/step - loss: 0.2637 - accuracy: 0.8529
# Epoch 1/100
# 28/28 [==============================] - 16s 412ms/step - loss: 0.6565 - accuracy: 0.4338 - val_loss: 0.4823 - val_accuracy: 0.7037
# Epoch 2/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.5211 - accuracy: 0.5000 - val_loss: 0.3220 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.4714 - accuracy: 0.5320 - val_loss: 0.2645 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.4294 - accuracy: 0.5388 - val_loss: 0.2647 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 10s 375ms/step - loss: 0.4004 - accuracy: 0.5571 - val_loss: 0.4315 - val_accuracy: 0.7778
# Epoch 6/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3753 - accuracy: 0.5582 - val_loss: 0.4064 - val_accuracy: 0.7778
# Epoch 7/100
# 28/28 [==============================] - 10s 371ms/step - loss: 0.3580 - accuracy: 0.5662 - val_loss: 0.3543 - val_accuracy: 0.8519
# Epoch 8/100
# 28/28 [==============================] - 10s 370ms/step - loss: 0.3436 - accuracy: 0.5742 - val_loss: 0.5235 - val_accuracy: 0.7407
# Epoch 9/100
# 28/28 [==============================] - 11s 376ms/step - loss: 0.3330 - accuracy: 0.5833 - val_loss: 0.2761 - val_accuracy: 0.8889
# Epoch 10/100
# 28/28 [==============================] - 10s 373ms/step - loss: 0.3231 - accuracy: 0.5799 - val_loss: 0.2834 - val_accuracy: 0.8889
# Epoch 11/100
# 28/28 [==============================] - 11s 375ms/step - loss: 0.3204 - accuracy: 0.5776 - val_loss: 0.2935 - val_accuracy: 0.8889
# Epoch 12/100
# 28/28 [==============================] - 11s 377ms/step - loss: 0.3134 - accuracy: 0.5822 - val_loss: 0.2908 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 11s 375ms/step - loss: 0.3094 - accuracy: 0.5856 - val_loss: 0.4257 - val_accuracy: 0.7778
# 2/2 [==============================] - 1s 30ms/step - loss: 0.2719 - accuracy: 0.9118
# Epoch 1/100
# 27/27 [==============================] - 16s 408ms/step - loss: 0.6721 - accuracy: 0.4359 - val_loss: 0.3809 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.4837 - accuracy: 0.5373 - val_loss: 0.2923 - val_accuracy: 0.9630
# Epoch 3/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.4329 - accuracy: 0.5548 - val_loss: 0.3183 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3803 - accuracy: 0.5828 - val_loss: 0.2455 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 10s 374ms/step - loss: 0.3720 - accuracy: 0.5828 - val_loss: 0.2778 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.3449 - accuracy: 0.5862 - val_loss: 0.2075 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.3517 - accuracy: 0.5932 - val_loss: 0.2181 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.3209 - accuracy: 0.5956 - val_loss: 0.3220 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.3104 - accuracy: 0.5991 - val_loss: 0.2269 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 10s 377ms/step - loss: 0.3092 - accuracy: 0.6026 - val_loss: 0.2091 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3001 - accuracy: 0.6026 - val_loss: 0.2434 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.3076 - accuracy: 0.6014 - val_loss: 0.2766 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 10s 374ms/step - loss: 0.2934 - accuracy: 0.6014 - val_loss: 0.2424 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.2823 - accuracy: 0.6037 - val_loss: 0.3128 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 10s 376ms/step - loss: 0.2818 - accuracy: 0.6037 - val_loss: 0.4630 - val_accuracy: 0.8148
# Epoch 16/100
# 27/27 [==============================] - 10s 373ms/step - loss: 0.2713 - accuracy: 0.6037 - val_loss: 0.3339 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 30ms/step - loss: 0.2884 - accuracy: 0.9118
# Epoch 1/100
# 27/27 [==============================] - 16s 423ms/step - loss: 0.6166 - accuracy: 0.4303 - val_loss: 0.7820 - val_accuracy: 0.5185
# Epoch 2/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.4498 - accuracy: 0.5236 - val_loss: 0.4479 - val_accuracy: 0.7037
# Epoch 3/100
# 27/27 [==============================] - 10s 380ms/step - loss: 0.4026 - accuracy: 0.5485 - val_loss: 0.5720 - val_accuracy: 0.6296
# Epoch 4/100
# 27/27 [==============================] - 10s 384ms/step - loss: 0.4001 - accuracy: 0.5426 - val_loss: 0.2779 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 10s 388ms/step - loss: 0.3701 - accuracy: 0.5544 - val_loss: 0.2328 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 10s 384ms/step - loss: 0.3617 - accuracy: 0.5615 - val_loss: 0.2655 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.3469 - accuracy: 0.5662 - val_loss: 0.2133 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 10s 378ms/step - loss: 0.3277 - accuracy: 0.5626 - val_loss: 0.2308 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3214 - accuracy: 0.5733 - val_loss: 0.2583 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 10s 387ms/step - loss: 0.3186 - accuracy: 0.5768 - val_loss: 0.2338 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.3228 - accuracy: 0.5757 - val_loss: 0.1996 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3101 - accuracy: 0.5745 - val_loss: 0.2990 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.2977 - accuracy: 0.5757 - val_loss: 0.2366 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.2980 - accuracy: 0.5745 - val_loss: 0.2588 - val_accuracy: 0.8519
# Epoch 15/100
# 27/27 [==============================] - 14s 524ms/step - loss: 0.2962 - accuracy: 0.5757 - val_loss: 0.2259 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 10s 389ms/step - loss: 0.2839 - accuracy: 0.5768 - val_loss: 0.2190 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 10s 383ms/step - loss: 0.2984 - accuracy: 0.5768 - val_loss: 0.3066 - val_accuracy: 0.8889
# Epoch 18/100
# 27/27 [==============================] - 10s 382ms/step - loss: 0.2910 - accuracy: 0.5768 - val_loss: 0.2044 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 10s 385ms/step - loss: 0.2974 - accuracy: 0.5745 - val_loss: 0.2625 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 10s 379ms/step - loss: 0.2915 - accuracy: 0.5733 - val_loss: 0.2755 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 10s 384ms/step - loss: 0.2924 - accuracy: 0.5768 - val_loss: 0.2493 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 28ms/step - loss: 0.4383 - accuracy: 0.7647
# Epoch 1/100
# 27/27 [==============================] - 16s 406ms/step - loss: 0.6812 - accuracy: 0.3904 - val_loss: 0.5330 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 10s 363ms/step - loss: 0.5246 - accuracy: 0.4755 - val_loss: 0.3215 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 10s 363ms/step - loss: 0.4275 - accuracy: 0.5268 - val_loss: 0.3355 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 10s 365ms/step - loss: 0.3888 - accuracy: 0.5513 - val_loss: 0.2260 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 10s 362ms/step - loss: 0.3665 - accuracy: 0.5664 - val_loss: 0.2261 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 10s 372ms/step - loss: 0.3543 - accuracy: 0.5664 - val_loss: 0.4154 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 10s 364ms/step - loss: 0.3457 - accuracy: 0.5641 - val_loss: 0.2446 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 10s 362ms/step - loss: 0.3330 - accuracy: 0.5676 - val_loss: 0.2729 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.3237 - accuracy: 0.5734 - val_loss: 0.2112 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 10s 362ms/step - loss: 0.3144 - accuracy: 0.5723 - val_loss: 0.1986 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.3036 - accuracy: 0.5746 - val_loss: 0.2163 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.3080 - accuracy: 0.5734 - val_loss: 0.2137 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2939 - accuracy: 0.5758 - val_loss: 0.2040 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.3021 - accuracy: 0.5746 - val_loss: 0.2110 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.2973 - accuracy: 0.5746 - val_loss: 0.1962 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2936 - accuracy: 0.5746 - val_loss: 0.1989 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2879 - accuracy: 0.5746 - val_loss: 0.2074 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 10s 368ms/step - loss: 0.2839 - accuracy: 0.5758 - val_loss: 0.2165 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.2913 - accuracy: 0.5758 - val_loss: 0.2047 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2824 - accuracy: 0.5758 - val_loss: 0.1982 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 10s 363ms/step - loss: 0.2820 - accuracy: 0.5758 - val_loss: 0.2040 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 10s 367ms/step - loss: 0.2828 - accuracy: 0.5746 - val_loss: 0.2608 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.2848 - accuracy: 0.5746 - val_loss: 0.2039 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 10s 368ms/step - loss: 0.2906 - accuracy: 0.5758 - val_loss: 0.1813 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2797 - accuracy: 0.5758 - val_loss: 0.1781 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 10s 362ms/step - loss: 0.2806 - accuracy: 0.5758 - val_loss: 0.1815 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 10s 368ms/step - loss: 0.2732 - accuracy: 0.5758 - val_loss: 0.1808 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 10s 363ms/step - loss: 0.2780 - accuracy: 0.5758 - val_loss: 0.2223 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 10s 369ms/step - loss: 0.2738 - accuracy: 0.5758 - val_loss: 0.2021 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2773 - accuracy: 0.5758 - val_loss: 0.1878 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 10s 368ms/step - loss: 0.2729 - accuracy: 0.5758 - val_loss: 0.2034 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 10s 371ms/step - loss: 0.2714 - accuracy: 0.5758 - val_loss: 0.1939 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 10s 366ms/step - loss: 0.2786 - accuracy: 0.5758 - val_loss: 0.2522 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2707 - accuracy: 0.5758 - val_loss: 0.2247 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 10s 370ms/step - loss: 0.2702 - accuracy: 0.5758 - val_loss: 0.2048 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 30ms/step - loss: 0.6363 - accuracy: 0.8235
# [0.8764705896377564, 0.9117646932601928, 0.8941176533699036, 0.9294117450714111, 0.8529411673545837]
# [0.8640162673036478, 0.8908431630886874, 0.8783794466403162, 0.9178962380511873, 0.83324750953023]
# Mean test accuracy is 0.89, mean test f1 score is 0.88, max test accuracy is 0.93, max test f1 score is 0.92, min test accuracy is 0.85, min test f1 score is 0.83, std of test accuracy is 0.03, std of test f1 score is 0.03
# Time elapsed through all process: 7295.75, sec
