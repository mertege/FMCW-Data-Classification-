# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_and_Spectrogram_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada sadece range-doppler 2D image datası ve spectrogram datası LSTM ile train edildi.
# 2D image'ın column'ları lstm'e sokuldu ve çıktıları dense layer ile classification moduna getirildi.
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.965, mean test f1 score is 0.959, max test accuracy is 0.976, max test f1 score is 0.972, min test accuracy is 0.953, min test f1 score is 0.945, std of test accuracy is 0.010, std of test f1 score is 0.011
# Time elapsed through all process: 10433.200, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
unit_number_of_lstm = 16
dense_unit_of_range_doppler_function = 256
dense_unit_of_spectrogram_function = 8
decoder_dense_unit = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_range_doppler_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def lstm_encoder_network_2(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_spectrogram_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense_unit)(input)
      x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_lstm(range_doppler_input)

    input_shape = spectrogram_concat_shuffle_train.shape[1:3]
    base_network_lstm_2 = lstm_encoder_network_2(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_lstm_2(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(base_network_lstm_2.summary())
      print(base_decoder_network.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image, spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler, validation_spectrogram) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 19s 381ms/step - loss: 0.5268 - accuracy: 0.4943 - val_loss: 0.6945 - val_accuracy: 0.7407
# Epoch 2/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.4087 - accuracy: 0.5431 - val_loss: 0.1905 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.3812 - accuracy: 0.5556 - val_loss: 0.2013 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3456 - accuracy: 0.5760 - val_loss: 0.1466 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.3316 - accuracy: 0.5794 - val_loss: 0.1664 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.3271 - accuracy: 0.5839 - val_loss: 0.1362 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.3211 - accuracy: 0.5794 - val_loss: 0.1737 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3062 - accuracy: 0.5839 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2984 - accuracy: 0.5850 - val_loss: 0.1003 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2837 - accuracy: 0.5873 - val_loss: 0.1494 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2894 - accuracy: 0.5839 - val_loss: 0.2576 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2869 - accuracy: 0.5862 - val_loss: 0.3441 - val_accuracy: 0.8148
# Epoch 13/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2799 - accuracy: 0.5873 - val_loss: 0.3155 - val_accuracy: 0.8148
# Epoch 14/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2774 - accuracy: 0.5873 - val_loss: 0.2460 - val_accuracy: 0.8519
# Epoch 15/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2797 - accuracy: 0.5862 - val_loss: 0.1089 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2813 - accuracy: 0.5862 - val_loss: 0.1631 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2716 - accuracy: 0.5873 - val_loss: 0.1035 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2722 - accuracy: 0.5873 - val_loss: 0.2338 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2748 - accuracy: 0.5873 - val_loss: 0.0944 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2725 - accuracy: 0.5873 - val_loss: 0.1450 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2675 - accuracy: 0.5873 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2662 - accuracy: 0.5873 - val_loss: 0.1745 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2671 - accuracy: 0.5862 - val_loss: 0.1757 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2643 - accuracy: 0.5873 - val_loss: 0.1973 - val_accuracy: 0.8889
# Epoch 25/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2622 - accuracy: 0.5873 - val_loss: 0.1885 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2600 - accuracy: 0.5873 - val_loss: 0.1416 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2585 - accuracy: 0.5873 - val_loss: 0.1259 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2664 - accuracy: 0.5873 - val_loss: 0.1401 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2585 - accuracy: 0.5873 - val_loss: 0.1535 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2579 - accuracy: 0.5873 - val_loss: 0.2053 - val_accuracy: 0.8889
# Epoch 31/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2646 - accuracy: 0.5873 - val_loss: 0.1865 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2615 - accuracy: 0.5873 - val_loss: 0.1060 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2566 - accuracy: 0.5873 - val_loss: 0.1920 - val_accuracy: 0.8889
# Epoch 34/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2600 - accuracy: 0.5873 - val_loss: 0.1726 - val_accuracy: 0.9259
# 2/2 [==============================] - 2s 131ms/step - loss: 0.1123 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 17s 383ms/step - loss: 0.4934 - accuracy: 0.5126 - val_loss: 0.8283 - val_accuracy: 0.7037
# Epoch 2/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.4049 - accuracy: 0.5582 - val_loss: 0.3127 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.3556 - accuracy: 0.5708 - val_loss: 0.3334 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3444 - accuracy: 0.5731 - val_loss: 0.1922 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.3231 - accuracy: 0.5811 - val_loss: 0.2319 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.3184 - accuracy: 0.5868 - val_loss: 0.2447 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2997 - accuracy: 0.5856 - val_loss: 0.2411 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.3014 - accuracy: 0.5868 - val_loss: 0.1425 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.3023 - accuracy: 0.5845 - val_loss: 0.1802 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2802 - accuracy: 0.5890 - val_loss: 0.1395 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2724 - accuracy: 0.5890 - val_loss: 0.1522 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2805 - accuracy: 0.5856 - val_loss: 0.1147 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2798 - accuracy: 0.5856 - val_loss: 0.1255 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2796 - accuracy: 0.5890 - val_loss: 0.1163 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2802 - accuracy: 0.5868 - val_loss: 0.1412 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2715 - accuracy: 0.5890 - val_loss: 0.1292 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2739 - accuracy: 0.5879 - val_loss: 0.1435 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2703 - accuracy: 0.5890 - val_loss: 0.1474 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2709 - accuracy: 0.5890 - val_loss: 0.1305 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2628 - accuracy: 0.5890 - val_loss: 0.1400 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2596 - accuracy: 0.5890 - val_loss: 0.1211 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2593 - accuracy: 0.5890 - val_loss: 0.1358 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2616 - accuracy: 0.5890 - val_loss: 0.1319 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2596 - accuracy: 0.5890 - val_loss: 0.1233 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2643 - accuracy: 0.5890 - val_loss: 0.1141 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2634 - accuracy: 0.5890 - val_loss: 0.1011 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2605 - accuracy: 0.5890 - val_loss: 0.1018 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2550 - accuracy: 0.5890 - val_loss: 0.1073 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2499 - accuracy: 0.5890 - val_loss: 0.1307 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2503 - accuracy: 0.5890 - val_loss: 0.1332 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2494 - accuracy: 0.5890 - val_loss: 0.1284 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2566 - accuracy: 0.5890 - val_loss: 0.1178 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2539 - accuracy: 0.5890 - val_loss: 0.1204 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2499 - accuracy: 0.5890 - val_loss: 0.1381 - val_accuracy: 0.9259
# Epoch 35/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2518 - accuracy: 0.5890 - val_loss: 0.1091 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2450 - accuracy: 0.5890 - val_loss: 0.1078 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2444 - accuracy: 0.5890 - val_loss: 0.1166 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2442 - accuracy: 0.5890 - val_loss: 0.1158 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2545 - accuracy: 0.5890 - val_loss: 0.1295 - val_accuracy: 0.9630
# Epoch 40/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2523 - accuracy: 0.5890 - val_loss: 0.1079 - val_accuracy: 0.9630
# Epoch 41/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2564 - accuracy: 0.5890 - val_loss: 0.1157 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 127ms/step - loss: 0.1071 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 399ms/step - loss: 0.5385 - accuracy: 0.4873 - val_loss: 0.2930 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.4235 - accuracy: 0.5347 - val_loss: 0.3017 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.3738 - accuracy: 0.5625 - val_loss: 0.2619 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.3382 - accuracy: 0.5718 - val_loss: 0.1801 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.3308 - accuracy: 0.5729 - val_loss: 0.2557 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.3115 - accuracy: 0.5752 - val_loss: 0.1618 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.3089 - accuracy: 0.5729 - val_loss: 0.1335 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2994 - accuracy: 0.5729 - val_loss: 0.1559 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.3029 - accuracy: 0.5741 - val_loss: 0.1467 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3046 - accuracy: 0.5741 - val_loss: 0.1593 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2848 - accuracy: 0.5764 - val_loss: 0.1360 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2859 - accuracy: 0.5764 - val_loss: 0.1424 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2876 - accuracy: 0.5764 - val_loss: 0.1734 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2799 - accuracy: 0.5764 - val_loss: 0.1397 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2951 - accuracy: 0.5741 - val_loss: 0.2128 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2762 - accuracy: 0.5752 - val_loss: 0.1204 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2805 - accuracy: 0.5752 - val_loss: 0.1196 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2772 - accuracy: 0.5752 - val_loss: 0.1320 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2751 - accuracy: 0.5764 - val_loss: 0.1771 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2797 - accuracy: 0.5764 - val_loss: 0.1989 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2696 - accuracy: 0.5764 - val_loss: 0.1770 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2766 - accuracy: 0.5752 - val_loss: 0.1510 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2703 - accuracy: 0.5764 - val_loss: 0.1695 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2681 - accuracy: 0.5764 - val_loss: 0.1304 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2680 - accuracy: 0.5764 - val_loss: 0.2002 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2680 - accuracy: 0.5764 - val_loss: 0.1284 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2611 - accuracy: 0.5764 - val_loss: 0.1068 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2684 - accuracy: 0.5764 - val_loss: 0.1770 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2653 - accuracy: 0.5764 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2627 - accuracy: 0.5764 - val_loss: 0.1418 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2588 - accuracy: 0.5752 - val_loss: 0.1332 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2629 - accuracy: 0.5764 - val_loss: 0.1448 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2688 - accuracy: 0.5752 - val_loss: 0.1510 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2631 - accuracy: 0.5764 - val_loss: 0.1904 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2650 - accuracy: 0.5764 - val_loss: 0.1118 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2595 - accuracy: 0.5764 - val_loss: 0.1607 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2624 - accuracy: 0.5764 - val_loss: 0.1569 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2591 - accuracy: 0.5764 - val_loss: 0.2465 - val_accuracy: 0.8889
# Epoch 39/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2606 - accuracy: 0.5764 - val_loss: 0.1303 - val_accuracy: 0.9630
# Epoch 40/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2609 - accuracy: 0.5764 - val_loss: 0.1259 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2624 - accuracy: 0.5764 - val_loss: 0.1824 - val_accuracy: 0.9259
# Epoch 42/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2557 - accuracy: 0.5764 - val_loss: 0.1777 - val_accuracy: 0.9259
# Epoch 43/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2562 - accuracy: 0.5764 - val_loss: 0.1401 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2588 - accuracy: 0.5764 - val_loss: 0.1459 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 121ms/step - loss: 0.0778 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 17s 381ms/step - loss: 0.4884 - accuracy: 0.5091 - val_loss: 0.6473 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.4255 - accuracy: 0.5537 - val_loss: 0.3782 - val_accuracy: 0.8148
# Epoch 3/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.3748 - accuracy: 0.5559 - val_loss: 0.1568 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.3628 - accuracy: 0.5594 - val_loss: 0.1630 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3344 - accuracy: 0.5685 - val_loss: 0.1509 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.3152 - accuracy: 0.5708 - val_loss: 0.1551 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3247 - accuracy: 0.5742 - val_loss: 0.1338 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.3082 - accuracy: 0.5753 - val_loss: 0.1272 - val_accuracy: 0.8889
# Epoch 9/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3050 - accuracy: 0.5788 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2938 - accuracy: 0.5799 - val_loss: 0.1009 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2962 - accuracy: 0.5799 - val_loss: 0.1346 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2853 - accuracy: 0.5799 - val_loss: 0.1054 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2871 - accuracy: 0.5788 - val_loss: 0.1121 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2882 - accuracy: 0.5776 - val_loss: 0.0921 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2856 - accuracy: 0.5799 - val_loss: 0.0874 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2692 - accuracy: 0.5799 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2778 - accuracy: 0.5799 - val_loss: 0.0829 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2769 - accuracy: 0.5799 - val_loss: 0.1351 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2673 - accuracy: 0.5799 - val_loss: 0.1020 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2733 - accuracy: 0.5788 - val_loss: 0.1013 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2770 - accuracy: 0.5788 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2696 - accuracy: 0.5799 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2642 - accuracy: 0.5788 - val_loss: 0.0637 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2728 - accuracy: 0.5799 - val_loss: 0.1323 - val_accuracy: 0.8889
# Epoch 25/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2673 - accuracy: 0.5799 - val_loss: 0.0676 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2682 - accuracy: 0.5799 - val_loss: 0.0582 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2587 - accuracy: 0.5799 - val_loss: 0.0948 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2639 - accuracy: 0.5799 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2629 - accuracy: 0.5799 - val_loss: 0.0543 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2626 - accuracy: 0.5799 - val_loss: 0.0431 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2635 - accuracy: 0.5799 - val_loss: 0.1010 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2619 - accuracy: 0.5799 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2643 - accuracy: 0.5799 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2703 - accuracy: 0.5788 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2672 - accuracy: 0.5799 - val_loss: 0.0601 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2584 - accuracy: 0.5799 - val_loss: 0.0667 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2617 - accuracy: 0.5799 - val_loss: 0.0728 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2522 - accuracy: 0.5799 - val_loss: 0.0842 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2608 - accuracy: 0.5799 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2613 - accuracy: 0.5799 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2582 - accuracy: 0.5799 - val_loss: 0.1090 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2535 - accuracy: 0.5799 - val_loss: 0.0959 - val_accuracy: 0.9630
# Epoch 43/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2611 - accuracy: 0.5776 - val_loss: 0.0654 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2517 - accuracy: 0.5799 - val_loss: 0.0877 - val_accuracy: 1.0000
# Epoch 45/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2507 - accuracy: 0.5799 - val_loss: 0.0987 - val_accuracy: 0.9630
# Epoch 46/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2619 - accuracy: 0.5799 - val_loss: 0.0830 - val_accuracy: 1.0000
# Epoch 47/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2545 - accuracy: 0.5799 - val_loss: 0.0756 - val_accuracy: 1.0000
# Epoch 48/100
# 28/28 [==============================] - 9s 327ms/step - loss: 0.2534 - accuracy: 0.5799 - val_loss: 0.1157 - val_accuracy: 0.9259
# Epoch 49/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2468 - accuracy: 0.5799 - val_loss: 0.1325 - val_accuracy: 0.8889
# 2/2 [==============================] - 2s 120ms/step - loss: 0.0509 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
# ...
# Epoch 21/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2635 - accuracy: 0.5896 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2641 - accuracy: 0.5896 - val_loss: 0.0494 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2633 - accuracy: 0.5896 - val_loss: 0.0463 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2667 - accuracy: 0.5896 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2592 - accuracy: 0.5884 - val_loss: 0.0404 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2609 - accuracy: 0.5896 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2623 - accuracy: 0.5884 - val_loss: 0.0767 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2586 - accuracy: 0.5896 - val_loss: 0.0596 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2563 - accuracy: 0.5896 - val_loss: 0.0836 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2549 - accuracy: 0.5896 - val_loss: 0.0728 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2545 - accuracy: 0.5896 - val_loss: 0.0635 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2563 - accuracy: 0.5896 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2496 - accuracy: 0.5896 - val_loss: 0.0800 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 9s 326ms/step - loss: 0.2624 - accuracy: 0.5884 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2538 - accuracy: 0.5896 - val_loss: 0.0863 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2507 - accuracy: 0.5896 - val_loss: 0.0366 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2514 - accuracy: 0.5896 - val_loss: 0.0447 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2514 - accuracy: 0.5884 - val_loss: 0.0784 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2509 - accuracy: 0.5896 - val_loss: 0.0626 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2517 - accuracy: 0.5896 - val_loss: 0.0605 - val_accuracy: 0.9630
# Epoch 41/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2457 - accuracy: 0.5896 - val_loss: 0.0538 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2431 - accuracy: 0.5896 - val_loss: 0.0970 - val_accuracy: 1.0000
# Epoch 43/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2479 - accuracy: 0.5896 - val_loss: 0.0887 - val_accuracy: 0.9630
# Epoch 44/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2442 - accuracy: 0.5896 - val_loss: 0.0589 - val_accuracy: 0.9630
# Epoch 45/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2480 - accuracy: 0.5896 - val_loss: 0.0706 - val_accuracy: 0.9630
# Epoch 46/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2463 - accuracy: 0.5896 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 47/100
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2533 - accuracy: 0.5896 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 48/100
# 28/28 [==============================] - 9s 323ms/step - loss: 0.2415 - accuracy: 0.5896 - val_loss: 0.0783 - val_accuracy: 0.9630
# Epoch 49/100
# 28/28 [==============================] - 9s 325ms/step - loss: 0.2447 - accuracy: 0.5896 - val_loss: 0.0707 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 122ms/step - loss: 0.1271 - accuracy: 0.9706
# Epoch 1/100
# 27/27 [==============================] - 18s 388ms/step - loss: 0.5418 - accuracy: 0.5319 - val_loss: 2.0758 - val_accuracy: 0.5185
# Epoch 2/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.4117 - accuracy: 0.5839 - val_loss: 0.4148 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.3721 - accuracy: 0.5993 - val_loss: 0.3489 - val_accuracy: 0.8148
# Epoch 4/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3228 - accuracy: 0.6135 - val_loss: 0.4115 - val_accuracy: 0.7778
# Epoch 5/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3041 - accuracy: 0.6182 - val_loss: 0.2989 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2994 - accuracy: 0.6170 - val_loss: 0.2588 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2944 - accuracy: 0.6217 - val_loss: 0.1908 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3076 - accuracy: 0.6158 - val_loss: 0.1926 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2804 - accuracy: 0.6182 - val_loss: 0.1761 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2757 - accuracy: 0.6217 - val_loss: 0.1774 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2762 - accuracy: 0.6194 - val_loss: 0.1596 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2805 - accuracy: 0.6206 - val_loss: 0.1923 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2659 - accuracy: 0.6241 - val_loss: 0.1759 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2585 - accuracy: 0.6241 - val_loss: 0.1703 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2627 - accuracy: 0.6229 - val_loss: 0.4331 - val_accuracy: 0.8519
# Epoch 16/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2647 - accuracy: 0.6241 - val_loss: 0.2695 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2581 - accuracy: 0.6241 - val_loss: 0.2503 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2562 - accuracy: 0.6241 - val_loss: 0.2209 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 9s 321ms/step - loss: 0.2549 - accuracy: 0.6241 - val_loss: 0.1611 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2468 - accuracy: 0.6241 - val_loss: 0.1749 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2532 - accuracy: 0.6241 - val_loss: 0.1678 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2499 - accuracy: 0.6241 - val_loss: 0.1652 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2446 - accuracy: 0.6241 - val_loss: 0.1499 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2431 - accuracy: 0.6229 - val_loss: 0.1656 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2492 - accuracy: 0.6229 - val_loss: 0.1856 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2447 - accuracy: 0.6229 - val_loss: 0.3013 - val_accuracy: 0.8889
# Epoch 27/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2504 - accuracy: 0.6229 - val_loss: 0.2055 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2450 - accuracy: 0.6241 - val_loss: 0.2674 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2498 - accuracy: 0.6241 - val_loss: 0.2504 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2410 - accuracy: 0.6241 - val_loss: 0.2144 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2377 - accuracy: 0.6241 - val_loss: 0.2384 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2334 - accuracy: 0.6241 - val_loss: 0.1740 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2386 - accuracy: 0.6241 - val_loss: 0.1669 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2380 - accuracy: 0.6241 - val_loss: 0.1824 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2478 - accuracy: 0.6241 - val_loss: 0.2910 - val_accuracy: 0.8889
# Epoch 36/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2392 - accuracy: 0.6241 - val_loss: 0.2022 - val_accuracy: 0.9259
# Epoch 37/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2462 - accuracy: 0.6241 - val_loss: 0.2602 - val_accuracy: 0.8889
# Epoch 38/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2372 - accuracy: 0.6241 - val_loss: 0.2093 - val_accuracy: 0.9259
# 2/2 [==============================] - 2s 116ms/step - loss: 0.1276 - accuracy: 0.9706
# Epoch 1/100
# 27/27 [==============================] - 18s 388ms/step - loss: 0.4907 - accuracy: 0.5143 - val_loss: 1.7419 - val_accuracy: 0.5556
# Epoch 2/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.4221 - accuracy: 0.5536 - val_loss: 0.9275 - val_accuracy: 0.6667
# Epoch 3/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3770 - accuracy: 0.5643 - val_loss: 0.6679 - val_accuracy: 0.6667
# Epoch 4/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3485 - accuracy: 0.5857 - val_loss: 0.3073 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.3264 - accuracy: 0.5833 - val_loss: 0.2947 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.3132 - accuracy: 0.5869 - val_loss: 0.2878 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.3083 - accuracy: 0.5893 - val_loss: 0.3133 - val_accuracy: 0.8519
# Epoch 8/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2975 - accuracy: 0.5881 - val_loss: 0.1643 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3075 - accuracy: 0.5869 - val_loss: 0.1798 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.3040 - accuracy: 0.5893 - val_loss: 0.1663 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2880 - accuracy: 0.5917 - val_loss: 0.1616 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2870 - accuracy: 0.5917 - val_loss: 0.1132 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2950 - accuracy: 0.5869 - val_loss: 0.1270 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 9s 322ms/step - loss: 0.2792 - accuracy: 0.5917 - val_loss: 0.1447 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2744 - accuracy: 0.5905 - val_loss: 0.1016 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2734 - accuracy: 0.5905 - val_loss: 0.1844 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2747 - accuracy: 0.5917 - val_loss: 0.1316 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2731 - accuracy: 0.5905 - val_loss: 0.1072 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2644 - accuracy: 0.5905 - val_loss: 0.0940 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2712 - accuracy: 0.5929 - val_loss: 0.0939 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 9s 323ms/step - loss: 0.2726 - accuracy: 0.5929 - val_loss: 0.1593 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2672 - accuracy: 0.5929 - val_loss: 0.0923 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2607 - accuracy: 0.5929 - val_loss: 0.1185 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2601 - accuracy: 0.5929 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2610 - accuracy: 0.5929 - val_loss: 0.0765 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2678 - accuracy: 0.5905 - val_loss: 0.1008 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2628 - accuracy: 0.5929 - val_loss: 0.0886 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2693 - accuracy: 0.5929 - val_loss: 0.0931 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 9s 327ms/step - loss: 0.2615 - accuracy: 0.5929 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2620 - accuracy: 0.5917 - val_loss: 0.2167 - val_accuracy: 0.8889
# Epoch 31/100
# 27/27 [==============================] - 9s 324ms/step - loss: 0.2556 - accuracy: 0.5929 - val_loss: 0.1315 - val_accuracy: 0.8889
# Epoch 32/100
# 27/27 [==============================] - 9s 325ms/step - loss: 0.2529 - accuracy: 0.5929 - val_loss: 0.1079 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2571 - accuracy: 0.5929 - val_loss: 0.0843 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2719 - accuracy: 0.5929 - val_loss: 0.1263 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2547 - accuracy: 0.5929 - val_loss: 0.1133 - val_accuracy: 0.9259
# Epoch 36/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2564 - accuracy: 0.5929 - val_loss: 0.1265 - val_accuracy: 0.9259
# Epoch 37/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2493 - accuracy: 0.5929 - val_loss: 0.1005 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2515 - accuracy: 0.5929 - val_loss: 0.1160 - val_accuracy: 0.9259
# Epoch 39/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2513 - accuracy: 0.5929 - val_loss: 0.1360 - val_accuracy: 0.8889
# 2/2 [==============================] - 2s 126ms/step - loss: 0.0819 - accuracy: 0.9706
# [0.9764705777168274, 0.970588231086731, 0.9529411673545838, 0.9529411673545838, 0.970588207244873]
# [0.9723737206877818, 0.963207729468599, 0.9466841668969328, 0.9453282661423273, 0.9658716943453299]
# Mean test accuracy is 0.965, mean test f1 score is 0.959, max test accuracy is 0.976, max test f1 score is 0.972, min test accuracy is 0.953, min test f1 score is 0.945, std of test accuracy is 0.010, std of test f1 score is 0.011
# Time elapsed through all process: 10433.200, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.965, mean test f1 score is 0.959, max test accuracy is 0.976, max test f1 score is 0.972, min test accuracy is 0.953, min test f1 score is 0.945, std of test accuracy is 0.010, std of test f1 score is 0.011
# Time elapsed through all process: 10433.200, sec
