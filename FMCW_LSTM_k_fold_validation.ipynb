# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/FMCW_LSTM_k_fold_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# K fold validation ile sonuca bakılıyor.

# %%
import numpy as np
from keras.preprocessing import sequence
import scipy.io
import keras
import tensorflow as tf
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten,Input, Lambda, Activation, Concatenate, LSTM, Embedding, Bidirectional, GRU, BatchNormalization, LayerNormalization, Normalization
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import backend as K
from tensorflow.keras import layers, regularizers
from keras.callbacks import EarlyStopping
from matplotlib import pyplot as plt
from tensorflow import keras
import time
from sklearn.model_selection import KFold, StratifiedKFold

# %%
pip install -q -U keras-tuner
import keras_tuner as kt
# Out:
#      |████████████████████████████████| 97 kB 3.7 MB/s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
training_and_val_data = scipy.io.loadmat('/content/drive/MyDrive/training_and_val_data.mat')  
training_and_val_label = scipy.io.loadmat('/content/drive/MyDrive/training_and_val_label.mat')

# %%
# Convert mat. data to ndarray
training_and_validation_dataset = training_and_val_data['training_and_val_data']  
training_and_validation_label = training_and_val_label['training_and_val_label']

# %%
X_1 = training_and_validation_dataset[:,1,:]
X_2 = training_and_validation_dataset[:,2,:]
X_3 = training_and_validation_dataset[:,3,:]
X_4 = training_and_validation_dataset[:,4,:]
X_5 = training_and_validation_dataset[:,5,:]
X_6 = training_and_validation_dataset[:,6,:]
X_7 = training_and_validation_dataset[:,7,:]
X_8 = training_and_validation_dataset[:,8,:]
X_9 = training_and_validation_dataset[:,9,:]
X_10 = training_and_validation_dataset[:,10,:]
X_11 = training_and_validation_dataset[:,11,:]
X_12 = training_and_validation_dataset[:,12,:]
X_13 = training_and_validation_dataset[:,13,:]
X_14 = training_and_validation_dataset[:,14,:]
X_15 = training_and_validation_dataset[:,0,:]

y_label = training_and_validation_label[:,0]

# %%
std_X1 = np.std(X_1, axis=-1)
mean_X1 = np.mean(X_1, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_1_reshaped = (X_1 - mean_X1) / std_X1
# --
std_X1 = np.std(X_2, axis=-1)
mean_X1 = np.mean(X_2, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_2_reshaped = (X_2 - mean_X1) / std_X1
# --
std_X1 = np.std(X_3, axis=-1)
mean_X1 = np.mean(X_3, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_3_reshaped = (X_3 - mean_X1) / std_X1
# --
std_X1 = np.std(X_4, axis=-1)
mean_X1 = np.mean(X_4, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_4_reshaped = (X_4 - mean_X1) / std_X1
# --
std_X1 = np.std(X_5, axis=-1)
mean_X1 = np.mean(X_5, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_5_reshaped = (X_5 - mean_X1) / std_X1
# --
std_X1 = np.std(X_6, axis=-1)
mean_X1 = np.mean(X_6, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_6_reshaped = (X_6 - mean_X1) / std_X1
# --
std_X1 = np.std(X_7, axis=-1)
mean_X1 = np.mean(X_7, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_7_reshaped = (X_7 - mean_X1) / std_X1
# --
std_X1 = np.std(X_8, axis=-1)
mean_X1 = np.mean(X_8, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_8_reshaped = (X_8 - mean_X1) / std_X1
# --
std_X1 = np.std(X_9, axis=-1)
mean_X1 = np.mean(X_9, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_9_reshaped = (X_9 - mean_X1) / std_X1
# --
std_X1 = np.std(X_10, axis=-1)
mean_X1 = np.mean(X_10, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_10_reshaped = (X_10 - mean_X1) / std_X1
# --
std_X1 = np.std(X_11, axis=-1)
mean_X1 = np.mean(X_11, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_11_reshaped = (X_11 - mean_X1) / std_X1
# --
std_X1 = np.std(X_12, axis=-1)
mean_X1 = np.mean(X_12, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_12_reshaped = (X_12 - mean_X1) / std_X1
# --
std_X1 = np.std(X_13, axis=-1)
mean_X1 = np.mean(X_13, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_13_reshaped = (X_13 - mean_X1) / std_X1
# --
std_X1 = np.std(X_14, axis=-1)
mean_X1 = np.mean(X_14, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_14_reshaped = (X_14 - mean_X1) / std_X1
# --
std_X1 = np.std(X_15, axis=-1)
mean_X1 = np.mean(X_15, axis=-1)
std_X1 = std_X1[:,np.newaxis] 
mean_X1 = mean_X1[:,np.newaxis] 
X_15_reshaped = (X_15 - mean_X1) / std_X1

# %%
# FMCW Learning with Function API GRU

from keras import backend as K
t = time.time()

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

LSTM_hidden_units = 8
dense_input_unit = LSTM_hidden_units*14
top_words = 4225
max_review_length = 4225
embedding_vecor_length = 16
def summation(vects):
    x, y = vects
    return x+y
def summation_shape(shapes):
    shape1, shape2 = shapes
    return (shape1)


def create_base_network1(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)

def create_base_network2(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)
def create_base_network3(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)

def create_base_network4(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)
# def create_base_network5(input_shape):
 
#     input = Input(shape=input_shape)
#     x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
#     x = (Dropout(0.2))(x)
#     x = GRU(LSTM_hidden_units)(x)
#     x = (Dropout(0.2))(x)
#     return Model(input, x)

def create_base_network6(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)
def create_base_network7(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)

def create_base_network8(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)
def create_base_network9(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)

def create_base_network10(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)
def create_base_network11(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)

def create_base_network12(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)
def create_base_network13(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)

def create_base_network14(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)

def create_base_network15(input_shape):
 
    input = Input(shape=input_shape)
    x = Embedding(top_words, embedding_vecor_length, input_length=max_review_length)(input)
    x = (Dropout(0.2))(x)
    x = GRU(LSTM_hidden_units)(x)
    x = (Dropout(0.2))(x)
    return Model(input, x)

def decoder(input_shape):
    input = Input(shape=input_shape)    
    x = (Dropout(0.2))(input)
    x = Dense(16, activation="sigmoid")(x)        # --  kernel_regularizer='l2'
    
    out = Dense(1, activation="sigmoid")(x)
    return Model(input, out)

# Define the K-fold Cross Validator
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True)
fold_no = 1
acc_per_fold = []
loss_per_fold = []
for train, test in kfold.split(X_1_reshaped,y_label):   

  input_shape = ((4225))
  base_network1 = create_base_network1(input_shape)
  base_network2 = create_base_network2(input_shape)
  base_network3 = create_base_network3(input_shape)
  base_network4 = create_base_network4(input_shape)
  # base_network5 = create_base_network5(input_shape)
  base_network6 = create_base_network6(input_shape)
  base_network7 = create_base_network7(input_shape)
  base_network8 = create_base_network8(input_shape)
  base_network9 = create_base_network9(input_shape)
  base_network10 = create_base_network10(input_shape)
  base_network11 = create_base_network11(input_shape)
  base_network12 = create_base_network12(input_shape)
  base_network13 = create_base_network13(input_shape)
  base_network14 = create_base_network14(input_shape)
  base_network15 = create_base_network15(input_shape)

  input_1  = Input(shape=input_shape)
  input_2  = Input(shape=input_shape)
  input_3  = Input(shape=input_shape)
  input_4  = Input(shape=input_shape)
  # input_5  = Input(shape=input_shape)
  input_6  = Input(shape=input_shape)
  input_7  = Input(shape=input_shape)
  input_8  = Input(shape=input_shape)
  input_9  = Input(shape=input_shape)
  input_10 = Input(shape=input_shape)
  input_11 = Input(shape=input_shape)
  input_12 = Input(shape=input_shape)
  input_13 = Input(shape=input_shape)
  input_14 = Input(shape=input_shape)
  input_15 = Input(shape=input_shape)

  processed_1  = base_network1(input_1 )
  processed_2  = base_network2(input_2 )
  processed_3  = base_network1(input_3 )
  processed_4  = base_network2(input_4 )
  # processed_5  = base_network1(input_5 )
  processed_6  = base_network2(input_6 )
  processed_7  = base_network1(input_7 )
  processed_8  = base_network2(input_8 )
  processed_9  = base_network1(input_9 )
  processed_10 = base_network2(input_10)
  processed_11 = base_network1(input_11)
  processed_12 = base_network2(input_12)
  processed_13 = base_network1(input_13)
  processed_14 = base_network2(input_14)
  processed_15 = base_network1(input_15)


  # sum_shape = X_train1.shape
  # aa = Lambda(summation,
  #                   output_shape=sum_shape)([processed_a, processed_b])
  aa = Concatenate()([processed_1, processed_2,processed_3, processed_4, processed_6,processed_7, processed_8,processed_9, processed_10,processed_11, processed_12,processed_13, processed_14,processed_15])

  base_decoder_network = decoder((dense_input_unit))
  out1 = base_decoder_network(aa)
  # out2 = base_decoder_network(aa)


  model = Model(inputs=[input_1, input_2,input_3, input_4, input_6,input_7, input_8,input_9, input_10,input_11, input_12,input_13, input_14,input_15], outputs=[out1])       


  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy',f1_m,precision_m, recall_m])
  model.summary()
  earlyStopping = EarlyStopping(monitor='val_loss', patience=6, verbose=0,restore_best_weights=True, mode='min')

  filepath_checkpoint = "mymodel"
  model_checkpoint_callback =  keras.callbacks.ModelCheckpoint(
          # Path where to save the model
          # The two parameters below mean that we will overwrite
          # the current checkpoint if and only if
          # the `val_loss` score has improved.
          # The saved model name will include the current epoch.
          filepath= filepath_checkpoint,
          save_weights_only=True,
          mode="min",
          save_best_only=True,  # Only save a model if `val_loss` has improved.
          monitor="val_loss",
          verbose=1,
      )

  history = model.fit((X_1_reshaped[train] ,X_2_reshaped[train] ,X_3_reshaped[train] ,X_4_reshaped[train]  ,X_6_reshaped[train],X_7_reshaped[train] ,X_8_reshaped[train] ,
                  X_9_reshaped[train] ,X_10_reshaped[train],X_11_reshaped[train],X_12_reshaped[train],X_13_reshaped[train],X_14_reshaped[train],X_15_reshaped[train]), (y_label[train]),
                  epochs=30,
                  batch_size=8)

  # Generate generalization metrics
  test_loss, test_accuracy, test_f1_score, test_precision, test_recall = model.evaluate((X_1_reshaped[test],X_2_reshaped[test],X_3_reshaped[test],X_4_reshaped[test],
                                                              X_6_reshaped[test],X_7_reshaped[test],X_8_reshaped[test],X_9_reshaped[test],X_10_reshaped[test],X_11_reshaped[test],
                                                              X_12_reshaped[test],X_13_reshaped[test],X_14_reshaped[test],X_15_reshaped[test]) ,y_label[test], batch_size=8)

  print(f'Score for fold {fold_no}: loss is {test_loss}, accuracy is {test_accuracy}, f1_score is {test_f1_score}, precision is {test_precision}, recall is {test_recall}')
  acc_per_fold.append(test_accuracy)
  loss_per_fold.append(test_f1_score)

  # Increase fold number
  fold_no = fold_no + 1


# plt.plot(history.history['test_loss'])
# # plt.plot(history.history['val_loss'])
# plt.title('Test Loss')
# plt.ylabel('test_loss')
# plt.xlabel('num_folds')
# plt.legend(['test'], loc='upper left')
# plt.show()
elapsed = time.time() - t
print(elapsed)
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_19 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_21 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_22 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_25 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# model (Functional)              (None, 8)            68224       input_15[0][0]
#                                                                  input_17[0][0]
#                                                                  input_20[0][0]
#                                                                  input_22[0][0]
#                                                                  input_24[0][0]
#                                                                  input_26[0][0]
#                                                                  input_28[0][0]
# __________________________________________________________________________________________________
# model_1 (Functional)            (None, 8)            68224       input_16[0][0]
#                                                                  input_18[0][0]
#                                                                  input_19[0][0]
#                                                                  input_21[0][0]
#                                                                  input_23[0][0]
#                                                                  input_25[0][0]
#                                                                  input_27[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 112)          0           model[0][0]
#                                                                  model_1[0][0]
#                                                                  model[1][0]
#                                                                  model_1[1][0]
#                                                                  model_1[2][0]
#                                                                  model[2][0]
#                                                                  model_1[3][0]
#                                                                  model[3][0]
#                                                                  model_1[4][0]
#                                                                  model[4][0]
#                                                                  model_1[5][0]
#                                                                  model[5][0]
#                                                                  model_1[6][0]
#                                                                  model[6][0]
# __________________________________________________________________________________________________
# model_14 (Functional)           (None, 1)            1825        concatenate[0][0]
# ==================================================================================================
# Total params: 138,273
# Trainable params: 138,273
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 21/21 [==============================] - 136s 5s/step - loss: 0.8547 - accuracy: 0.5000 - f1_m: 0.6505 - precision_m: 0.5000 - recall_m: 1.0000
# Epoch 2/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.7763 - accuracy: 0.5000 - f1_m: 0.6433 - precision_m: 0.5000 - recall_m: 1.0000
# Epoch 3/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.7113 - accuracy: 0.5181 - f1_m: 0.6506 - precision_m: 0.5133 - recall_m: 0.9905
# Epoch 4/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6969 - accuracy: 0.5241 - f1_m: 0.3728 - precision_m: 0.5373 - recall_m: 0.3973
# Epoch 5/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6836 - accuracy: 0.5542 - f1_m: 0.5462 - precision_m: 0.5234 - recall_m: 0.6075
# Epoch 6/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6805 - accuracy: 0.6084 - f1_m: 0.6621 - precision_m: 0.6017 - recall_m: 0.8056
# Epoch 7/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6760 - accuracy: 0.5904 - f1_m: 0.5583 - precision_m: 0.5841 - recall_m: 0.6094
# Epoch 8/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6746 - accuracy: 0.6145 - f1_m: 0.4767 - precision_m: 0.6508 - recall_m: 0.4160
# Epoch 9/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6667 - accuracy: 0.6386 - f1_m: 0.5414 - precision_m: 0.7159 - recall_m: 0.5036
# Epoch 10/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6577 - accuracy: 0.6807 - f1_m: 0.6498 - precision_m: 0.7129 - recall_m: 0.6476
# Epoch 11/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6585 - accuracy: 0.6747 - f1_m: 0.6527 - precision_m: 0.7063 - recall_m: 0.6871
# Epoch 12/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6637 - accuracy: 0.5964 - f1_m: 0.5353 - precision_m: 0.5799 - recall_m: 0.5603
# Epoch 13/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6433 - accuracy: 0.6446 - f1_m: 0.6201 - precision_m: 0.6414 - recall_m: 0.6508
# Epoch 14/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6379 - accuracy: 0.6386 - f1_m: 0.6608 - precision_m: 0.6540 - recall_m: 0.7333
# Epoch 15/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6260 - accuracy: 0.6627 - f1_m: 0.6198 - precision_m: 0.6734 - recall_m: 0.6483
# Epoch 16/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6111 - accuracy: 0.7108 - f1_m: 0.6853 - precision_m: 0.6778 - recall_m: 0.7621
# Epoch 17/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5993 - accuracy: 0.6687 - f1_m: 0.6602 - precision_m: 0.6921 - recall_m: 0.6984
# Epoch 18/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5761 - accuracy: 0.7470 - f1_m: 0.7319 - precision_m: 0.7333 - recall_m: 0.7995
# Epoch 19/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5742 - accuracy: 0.6988 - f1_m: 0.6940 - precision_m: 0.7054 - recall_m: 0.7744
# Epoch 20/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5727 - accuracy: 0.6928 - f1_m: 0.6931 - precision_m: 0.6687 - recall_m: 0.7603
# Epoch 21/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5544 - accuracy: 0.7229 - f1_m: 0.7016 - precision_m: 0.6960 - recall_m: 0.7540
# Epoch 22/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5563 - accuracy: 0.7048 - f1_m: 0.7139 - precision_m: 0.7251 - recall_m: 0.7548
# Epoch 23/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5458 - accuracy: 0.7410 - f1_m: 0.6995 - precision_m: 0.6825 - recall_m: 0.7317
# Epoch 24/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5435 - accuracy: 0.7229 - f1_m: 0.7210 - precision_m: 0.7586 - recall_m: 0.7262
# Epoch 25/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5258 - accuracy: 0.7410 - f1_m: 0.7372 - precision_m: 0.7627 - recall_m: 0.7510
# Epoch 26/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5160 - accuracy: 0.7651 - f1_m: 0.7472 - precision_m: 0.7646 - recall_m: 0.7875
# Epoch 27/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5354 - accuracy: 0.7229 - f1_m: 0.6776 - precision_m: 0.7046 - recall_m: 0.7405
# Epoch 28/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5246 - accuracy: 0.7470 - f1_m: 0.7233 - precision_m: 0.7091 - recall_m: 0.8050
# Epoch 29/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5240 - accuracy: 0.7108 - f1_m: 0.7077 - precision_m: 0.6848 - recall_m: 0.7825
# Epoch 30/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5398 - accuracy: 0.7349 - f1_m: 0.7156 - precision_m: 0.7349 - recall_m: 0.7756
# 6/6 [==============================] - 18s 2s/step - loss: 0.5370 - accuracy: 0.7143 - f1_m: 0.5696 - precision_m: 0.6056 - recall_m: 0.5417
# Score for fold 1: loss is 0.5370470881462097, accuracy is 0.7142857313156128, f1_score is 0.5696247816085815, precision is 0.605555534362793, recall is 0.5416666865348816
# Model: "model_31"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_44 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_45 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_46 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_47 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_48 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_49 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_50 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_51 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_52 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_53 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_54 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_55 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_56 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_57 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# model_16 (Functional)           (None, 8)            68224       input_44[0][0]
#                                                                  input_46[0][0]
#                                                                  input_49[0][0]
#                                                                  input_51[0][0]
#                                                                  input_53[0][0]
#                                                                  input_55[0][0]
#                                                                  input_57[0][0]
# __________________________________________________________________________________________________
# model_17 (Functional)           (None, 8)            68224       input_45[0][0]
#                                                                  input_47[0][0]
#                                                                  input_48[0][0]
#                                                                  input_50[0][0]
#                                                                  input_52[0][0]
#                                                                  input_54[0][0]
#                                                                  input_56[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 112)          0           model_16[0][0]
#                                                                  model_17[0][0]
#                                                                  model_16[1][0]
#                                                                  model_17[1][0]
#                                                                  model_17[2][0]
#                                                                  model_16[2][0]
#                                                                  model_17[3][0]
#                                                                  model_16[3][0]
#                                                                  model_17[4][0]
#                                                                  model_16[4][0]
#                                                                  model_17[5][0]
#                                                                  model_16[5][0]
#                                                                  model_17[6][0]
#                                                                  model_16[6][0]
# __________________________________________________________________________________________________
# model_30 (Functional)           (None, 1)            1825        concatenate_1[0][0]
# ==================================================================================================
# Total params: 138,273
# Trainable params: 138,273
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 21/21 [==============================] - 131s 5s/step - loss: 0.6941 - accuracy: 0.4578 - f1_m: 0.5109 - precision_m: 0.4689 - recall_m: 0.6976
# Epoch 2/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6914 - accuracy: 0.5723 - f1_m: 0.6613 - precision_m: 0.5489 - recall_m: 0.8849
# Epoch 3/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6907 - accuracy: 0.5663 - f1_m: 0.5150 - precision_m: 0.5802 - recall_m: 0.5492
# Epoch 4/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6864 - accuracy: 0.6205 - f1_m: 0.6254 - precision_m: 0.6740 - recall_m: 0.7332
# Epoch 5/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6797 - accuracy: 0.6747 - f1_m: 0.6540 - precision_m: 0.6663 - recall_m: 0.6929
# Epoch 6/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6621 - accuracy: 0.6687 - f1_m: 0.5279 - precision_m: 0.7460 - recall_m: 0.4690
# Epoch 7/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6383 - accuracy: 0.7169 - f1_m: 0.6467 - precision_m: 0.7150 - recall_m: 0.6389
# Epoch 8/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6000 - accuracy: 0.7048 - f1_m: 0.6388 - precision_m: 0.6944 - recall_m: 0.6294
# Epoch 9/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5644 - accuracy: 0.7229 - f1_m: 0.6997 - precision_m: 0.7500 - recall_m: 0.7048
# Epoch 10/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5491 - accuracy: 0.7108 - f1_m: 0.6899 - precision_m: 0.6770 - recall_m: 0.7286
# Epoch 11/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5327 - accuracy: 0.7349 - f1_m: 0.7159 - precision_m: 0.7190 - recall_m: 0.7732
# Epoch 12/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5218 - accuracy: 0.7711 - f1_m: 0.7580 - precision_m: 0.7357 - recall_m: 0.8256
# Epoch 13/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5080 - accuracy: 0.7831 - f1_m: 0.7813 - precision_m: 0.7476 - recall_m: 0.8615
# Epoch 14/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5125 - accuracy: 0.7470 - f1_m: 0.7430 - precision_m: 0.7079 - recall_m: 0.8397
# Epoch 15/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4936 - accuracy: 0.7530 - f1_m: 0.7466 - precision_m: 0.7371 - recall_m: 0.8333
# Epoch 16/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5150 - accuracy: 0.7771 - f1_m: 0.7676 - precision_m: 0.7518 - recall_m: 0.8254
# Epoch 17/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4962 - accuracy: 0.7651 - f1_m: 0.7464 - precision_m: 0.7294 - recall_m: 0.8278
# Epoch 18/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4906 - accuracy: 0.7651 - f1_m: 0.7634 - precision_m: 0.7489 - recall_m: 0.8307
# Epoch 19/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4904 - accuracy: 0.7892 - f1_m: 0.7555 - precision_m: 0.7550 - recall_m: 0.7896
# Epoch 20/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4819 - accuracy: 0.7711 - f1_m: 0.7752 - precision_m: 0.7916 - recall_m: 0.8159
# Epoch 21/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4985 - accuracy: 0.7771 - f1_m: 0.7644 - precision_m: 0.7383 - recall_m: 0.8575
# Epoch 22/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4997 - accuracy: 0.7831 - f1_m: 0.7624 - precision_m: 0.7603 - recall_m: 0.8300
# Epoch 23/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4715 - accuracy: 0.7892 - f1_m: 0.7779 - precision_m: 0.7595 - recall_m: 0.8478
# Epoch 24/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4601 - accuracy: 0.8193 - f1_m: 0.8201 - precision_m: 0.8087 - recall_m: 0.8734
# Epoch 25/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4707 - accuracy: 0.7711 - f1_m: 0.7598 - precision_m: 0.7474 - recall_m: 0.8145
# Epoch 26/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4676 - accuracy: 0.7892 - f1_m: 0.7327 - precision_m: 0.7540 - recall_m: 0.7484
# Epoch 27/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4524 - accuracy: 0.7952 - f1_m: 0.7813 - precision_m: 0.7559 - recall_m: 0.8595
# Epoch 28/30
# 21/21 [==============================] - 107s 5s/step - loss: 0.4820 - accuracy: 0.7711 - f1_m: 0.7598 - precision_m: 0.7421 - recall_m: 0.8198
# Epoch 29/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4815 - accuracy: 0.7771 - f1_m: 0.7327 - precision_m: 0.7467 - recall_m: 0.7833
# Epoch 30/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4666 - accuracy: 0.8072 - f1_m: 0.7763 - precision_m: 0.7913 - recall_m: 0.8638
# 6/6 [==============================] - 19s 2s/step - loss: 0.7728 - accuracy: 0.6429 - f1_m: 0.3611 - precision_m: 0.5000 - recall_m: 0.2857
# Score for fold 2: loss is 0.7728047966957092, accuracy is 0.6428571343421936, f1_score is 0.3611110746860504, precision is 0.5, recall is 0.2857142984867096
# Model: "model_47"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_73 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_74 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_75 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_76 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_77 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_78 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_79 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_80 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_81 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_82 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_83 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_84 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_85 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_86 (InputLayer)           [(None, 4225)]       0
# __________________________________________________________________________________________________
# model_32 (Functional)           (None, 8)            68224       input_73[0][0]
#                                                                  input_75[0][0]
#                                                                  input_78[0][0]
#                                                                  input_80[0][0]
#                                                                  input_82[0][0]
#                                                                  input_84[0][0]
#                                                                  input_86[0][0]
# __________________________________________________________________________________________________
# model_33 (Functional)           (None, 8)            68224       input_74[0][0]
#                                                                  input_76[0][0]
#                                                                  input_77[0][0]
#                                                                  input_79[0][0]
#                                                                  input_81[0][0]
#                                                                  input_83[0][0]
#                                                                  input_85[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 112)          0           model_32[0][0]
#                                                                  model_33[0][0]
#                                                                  model_32[1][0]
#                                                                  model_33[1][0]
#                                                                  model_33[2][0]
#                                                                  model_32[2][0]
#                                                                  model_33[3][0]
#                                                                  model_32[3][0]
#                                                                  model_33[4][0]
#                                                                  model_32[4][0]
#                                                                  model_33[5][0]
#                                                                  model_32[5][0]
#                                                                  model_33[6][0]
#                                                                  model_32[6][0]
# __________________________________________________________________________________________________
# model_46 (Functional)           (None, 1)            1825        concatenate_2[0][0]
# ==================================================================================================
# Total params: 138,273
# Trainable params: 138,273
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 21/21 [==============================] - 132s 5s/step - loss: 0.7366 - accuracy: 0.5000 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 2/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.7078 - accuracy: 0.5000 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 3/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6960 - accuracy: 0.4880 - f1_m: 0.2528 - precision_m: 0.2817 - recall_m: 0.2730
# Epoch 4/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6943 - accuracy: 0.4458 - f1_m: 0.1311 - precision_m: 0.2159 - recall_m: 0.1242
# Epoch 5/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6925 - accuracy: 0.5301 - f1_m: 0.4901 - precision_m: 0.5619 - recall_m: 0.5190
# Epoch 6/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6824 - accuracy: 0.6024 - f1_m: 0.6122 - precision_m: 0.5812 - recall_m: 0.6889
# Epoch 7/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6789 - accuracy: 0.6024 - f1_m: 0.6132 - precision_m: 0.5902 - recall_m: 0.6881
# Epoch 8/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6623 - accuracy: 0.6024 - f1_m: 0.5943 - precision_m: 0.6333 - recall_m: 0.6271
# Epoch 9/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6281 - accuracy: 0.6627 - f1_m: 0.6536 - precision_m: 0.6659 - recall_m: 0.6915
# Epoch 10/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6106 - accuracy: 0.6687 - f1_m: 0.6708 - precision_m: 0.6517 - recall_m: 0.7183
# Epoch 11/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5767 - accuracy: 0.7289 - f1_m: 0.7175 - precision_m: 0.7015 - recall_m: 0.7929
# Epoch 12/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5821 - accuracy: 0.6747 - f1_m: 0.6879 - precision_m: 0.6344 - recall_m: 0.8071
# Epoch 13/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5603 - accuracy: 0.7289 - f1_m: 0.7180 - precision_m: 0.7019 - recall_m: 0.7825
# Epoch 14/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5579 - accuracy: 0.7470 - f1_m: 0.7393 - precision_m: 0.7020 - recall_m: 0.8511
# Epoch 15/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5585 - accuracy: 0.7349 - f1_m: 0.7545 - precision_m: 0.7096 - recall_m: 0.8594
# Epoch 16/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5648 - accuracy: 0.7108 - f1_m: 0.7016 - precision_m: 0.7014 - recall_m: 0.7825
# Epoch 17/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5534 - accuracy: 0.7108 - f1_m: 0.7106 - precision_m: 0.6575 - recall_m: 0.8027
# Epoch 18/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5412 - accuracy: 0.7410 - f1_m: 0.7434 - precision_m: 0.7476 - recall_m: 0.7960
# Epoch 19/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5644 - accuracy: 0.6807 - f1_m: 0.6933 - precision_m: 0.6580 - recall_m: 0.7667
# Epoch 20/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5422 - accuracy: 0.7470 - f1_m: 0.7411 - precision_m: 0.6845 - recall_m: 0.8432
# Epoch 21/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5617 - accuracy: 0.7711 - f1_m: 0.7669 - precision_m: 0.7321 - recall_m: 0.8778
# Epoch 22/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5569 - accuracy: 0.7349 - f1_m: 0.7481 - precision_m: 0.7144 - recall_m: 0.8317
# Epoch 23/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5109 - accuracy: 0.8072 - f1_m: 0.8211 - precision_m: 0.7959 - recall_m: 0.8740
# Epoch 24/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5416 - accuracy: 0.7470 - f1_m: 0.7373 - precision_m: 0.6840 - recall_m: 0.8571
# Epoch 25/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5108 - accuracy: 0.7651 - f1_m: 0.7675 - precision_m: 0.7351 - recall_m: 0.8452
# Epoch 26/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5179 - accuracy: 0.7952 - f1_m: 0.8020 - precision_m: 0.7941 - recall_m: 0.8460
# Epoch 27/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5413 - accuracy: 0.7470 - f1_m: 0.7261 - precision_m: 0.7540 - recall_m: 0.7340
# Epoch 28/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5195 - accuracy: 0.7470 - f1_m: 0.6975 - precision_m: 0.7463 - recall_m: 0.7056
# Epoch 29/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5076 - accuracy: 0.8012 - f1_m: 0.7905 - precision_m: 0.7579 - recall_m: 0.8627
# Epoch 30/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5009 - accuracy: 0.7952 - f1_m: 0.7960 - precision_m: 0.7598 - recall_m: 0.8516
# 6/6 [==============================] - 18s 2s/step - loss: 0.4753 - accuracy: 0.8333 - f1_m: 0.6012 - precision_m: 0.6000 - recall_m: 0.6250
# Score for fold 3: loss is 0.47532686591148376, accuracy is 0.8333333134651184, f1_score is 0.601190447807312, precision is 0.5999999642372131, recall is 0.625
# Model: "model_63"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_102 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_103 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_104 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_105 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_106 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_107 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_108 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_109 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_110 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_111 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_112 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_113 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_114 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_115 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# model_48 (Functional)           (None, 8)            68224       input_102[0][0]
#                                                                  input_104[0][0]
#                                                                  input_107[0][0]
#                                                                  input_109[0][0]
#                                                                  input_111[0][0]
#                                                                  input_113[0][0]
#                                                                  input_115[0][0]
# __________________________________________________________________________________________________
# model_49 (Functional)           (None, 8)            68224       input_103[0][0]
#                                                                  input_105[0][0]
#                                                                  input_106[0][0]
#                                                                  input_108[0][0]
#                                                                  input_110[0][0]
#                                                                  input_112[0][0]
#                                                                  input_114[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 112)          0           model_48[0][0]
#                                                                  model_49[0][0]
#                                                                  model_48[1][0]
#                                                                  model_49[1][0]
#                                                                  model_49[2][0]
#                                                                  model_48[2][0]
#                                                                  model_49[3][0]
#                                                                  model_48[3][0]
#                                                                  model_49[4][0]
#                                                                  model_48[4][0]
#                                                                  model_49[5][0]
#                                                                  model_48[5][0]
#                                                                  model_49[6][0]
#                                                                  model_48[6][0]
# __________________________________________________________________________________________________
# model_62 (Functional)           (None, 1)            1825        concatenate_3[0][0]
# ==================================================================================================
# Total params: 138,273
# Trainable params: 138,273
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 21/21 [==============================] - 132s 5s/step - loss: 0.6975 - accuracy: 0.4970 - f1_m: 0.6476 - precision_m: 0.4991 - recall_m: 1.0000
# Epoch 2/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6914 - accuracy: 0.4970 - f1_m: 0.6541 - precision_m: 0.4983 - recall_m: 1.0000
# Epoch 3/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6898 - accuracy: 0.5389 - f1_m: 0.6350 - precision_m: 0.5427 - recall_m: 0.9087
# Epoch 4/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6853 - accuracy: 0.5928 - f1_m: 0.6367 - precision_m: 0.5777 - recall_m: 0.8246
# Epoch 5/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6759 - accuracy: 0.6228 - f1_m: 0.6329 - precision_m: 0.5867 - recall_m: 0.7389
# Epoch 6/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6668 - accuracy: 0.6587 - f1_m: 0.6653 - precision_m: 0.6469 - recall_m: 0.7794
# Epoch 7/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6411 - accuracy: 0.6766 - f1_m: 0.6590 - precision_m: 0.6146 - recall_m: 0.7616
# Epoch 8/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6159 - accuracy: 0.6707 - f1_m: 0.6649 - precision_m: 0.6554 - recall_m: 0.7241
# Epoch 9/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5765 - accuracy: 0.7246 - f1_m: 0.7114 - precision_m: 0.6635 - recall_m: 0.8000
# Epoch 10/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6035 - accuracy: 0.7126 - f1_m: 0.7214 - precision_m: 0.6900 - recall_m: 0.8230
# Epoch 11/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5704 - accuracy: 0.7425 - f1_m: 0.7064 - precision_m: 0.7361 - recall_m: 0.7669
# Epoch 12/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5699 - accuracy: 0.7246 - f1_m: 0.7286 - precision_m: 0.7168 - recall_m: 0.8197
# Epoch 13/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5625 - accuracy: 0.7365 - f1_m: 0.7562 - precision_m: 0.7167 - recall_m: 0.8524
# Epoch 14/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5455 - accuracy: 0.7485 - f1_m: 0.7343 - precision_m: 0.7177 - recall_m: 0.8007
# Epoch 15/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5710 - accuracy: 0.7186 - f1_m: 0.7164 - precision_m: 0.7029 - recall_m: 0.7746
# Epoch 16/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5508 - accuracy: 0.7545 - f1_m: 0.7584 - precision_m: 0.7416 - recall_m: 0.8008
# Epoch 17/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5548 - accuracy: 0.7665 - f1_m: 0.7298 - precision_m: 0.7746 - recall_m: 0.7443
# Epoch 18/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5599 - accuracy: 0.7365 - f1_m: 0.7340 - precision_m: 0.7071 - recall_m: 0.8056
# Epoch 19/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5673 - accuracy: 0.7186 - f1_m: 0.7410 - precision_m: 0.6827 - recall_m: 0.8492
# Epoch 20/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5458 - accuracy: 0.7365 - f1_m: 0.7298 - precision_m: 0.7421 - recall_m: 0.7794
# Epoch 21/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5465 - accuracy: 0.7485 - f1_m: 0.7283 - precision_m: 0.7286 - recall_m: 0.7421
# Epoch 22/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5541 - accuracy: 0.7365 - f1_m: 0.7205 - precision_m: 0.7048 - recall_m: 0.7662
# Epoch 23/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5499 - accuracy: 0.7305 - f1_m: 0.7187 - precision_m: 0.7325 - recall_m: 0.7587
# Epoch 24/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5630 - accuracy: 0.7006 - f1_m: 0.6673 - precision_m: 0.6429 - recall_m: 0.7246
# Epoch 25/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5468 - accuracy: 0.7066 - f1_m: 0.7043 - precision_m: 0.6865 - recall_m: 0.7825
# Epoch 26/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5417 - accuracy: 0.7545 - f1_m: 0.7408 - precision_m: 0.7016 - recall_m: 0.8325
# Epoch 27/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5409 - accuracy: 0.7485 - f1_m: 0.7311 - precision_m: 0.7395 - recall_m: 0.7635
# Epoch 28/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5377 - accuracy: 0.7305 - f1_m: 0.7224 - precision_m: 0.7313 - recall_m: 0.7556
# Epoch 29/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5333 - accuracy: 0.7365 - f1_m: 0.7269 - precision_m: 0.7484 - recall_m: 0.7692
# Epoch 30/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5225 - accuracy: 0.7305 - f1_m: 0.7337 - precision_m: 0.7377 - recall_m: 0.7991
# 6/6 [==============================] - 18s 2s/step - loss: 0.4948 - accuracy: 0.7561 - f1_m: 0.5139 - precision_m: 0.5556 - recall_m: 0.5524
# Score for fold 4: loss is 0.49475428462028503, accuracy is 0.7560975551605225, f1_score is 0.5138888955116272, precision is 0.5555555820465088, recall is 0.5523809790611267
# Model: "model_79"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_131 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_132 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_133 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_134 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_135 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_136 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_137 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_138 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_139 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_140 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_141 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_142 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_143 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# input_144 (InputLayer)          [(None, 4225)]       0
# __________________________________________________________________________________________________
# model_64 (Functional)           (None, 8)            68224       input_131[0][0]
#                                                                  input_133[0][0]
#                                                                  input_136[0][0]
#                                                                  input_138[0][0]
#                                                                  input_140[0][0]
#                                                                  input_142[0][0]
#                                                                  input_144[0][0]
# __________________________________________________________________________________________________
# model_65 (Functional)           (None, 8)            68224       input_132[0][0]
#                                                                  input_134[0][0]
#                                                                  input_135[0][0]
#                                                                  input_137[0][0]
#                                                                  input_139[0][0]
#                                                                  input_141[0][0]
#                                                                  input_143[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 112)          0           model_64[0][0]
#                                                                  model_65[0][0]
#                                                                  model_64[1][0]
#                                                                  model_65[1][0]
#                                                                  model_65[2][0]
#                                                                  model_64[2][0]
#                                                                  model_65[3][0]
#                                                                  model_64[3][0]
#                                                                  model_65[4][0]
#                                                                  model_64[4][0]
#                                                                  model_65[5][0]
#                                                                  model_64[5][0]
#                                                                  model_65[6][0]
#                                                                  model_64[6][0]
# __________________________________________________________________________________________________
# model_78 (Functional)           (None, 1)            1825        concatenate_4[0][0]
# ==================================================================================================
# Total params: 138,273
# Trainable params: 138,273
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 21/21 [==============================] - 131s 5s/step - loss: 0.7071 - accuracy: 0.4970 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 2/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.6973 - accuracy: 0.4970 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 3/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.6922 - accuracy: 0.4970 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 4/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.6845 - accuracy: 0.5928 - f1_m: 0.2814 - precision_m: 0.4127 - recall_m: 0.2294
# Epoch 5/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.6811 - accuracy: 0.6587 - f1_m: 0.6758 - precision_m: 0.6351 - recall_m: 0.8071
# Epoch 6/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.6686 - accuracy: 0.6766 - f1_m: 0.6459 - precision_m: 0.6680 - recall_m: 0.6968
# Epoch 7/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.6532 - accuracy: 0.6527 - f1_m: 0.6424 - precision_m: 0.6706 - recall_m: 0.6984
# Epoch 8/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.6212 - accuracy: 0.7126 - f1_m: 0.6710 - precision_m: 0.7429 - recall_m: 0.7060
# Epoch 9/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.5896 - accuracy: 0.7365 - f1_m: 0.7220 - precision_m: 0.7429 - recall_m: 0.7548
# Epoch 10/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.5660 - accuracy: 0.7305 - f1_m: 0.7250 - precision_m: 0.7212 - recall_m: 0.7857
# Epoch 11/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.5413 - accuracy: 0.7784 - f1_m: 0.7860 - precision_m: 0.7806 - recall_m: 0.8392
# Epoch 12/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.5419 - accuracy: 0.7605 - f1_m: 0.7429 - precision_m: 0.7226 - recall_m: 0.8159
# Epoch 13/30
# 21/21 [==============================] - 110s 5s/step - loss: 0.5839 - accuracy: 0.6946 - f1_m: 0.6119 - precision_m: 0.7297 - recall_m: 0.6160
# Epoch 14/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5653 - accuracy: 0.7305 - f1_m: 0.7488 - precision_m: 0.7405 - recall_m: 0.8071
# Epoch 15/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5135 - accuracy: 0.7545 - f1_m: 0.7431 - precision_m: 0.7345 - recall_m: 0.8175
# Epoch 16/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5405 - accuracy: 0.7425 - f1_m: 0.6678 - precision_m: 0.6653 - recall_m: 0.7237
# Epoch 17/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5242 - accuracy: 0.7425 - f1_m: 0.6757 - precision_m: 0.6763 - recall_m: 0.7261
# Epoch 18/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5122 - accuracy: 0.7665 - f1_m: 0.7451 - precision_m: 0.7317 - recall_m: 0.7921
# Epoch 19/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5236 - accuracy: 0.7485 - f1_m: 0.7526 - precision_m: 0.7730 - recall_m: 0.7865
# Epoch 20/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5092 - accuracy: 0.7605 - f1_m: 0.7501 - precision_m: 0.7535 - recall_m: 0.7837
# Epoch 21/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5048 - accuracy: 0.7665 - f1_m: 0.7521 - precision_m: 0.7493 - recall_m: 0.8217
# Epoch 22/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5062 - accuracy: 0.7425 - f1_m: 0.7247 - precision_m: 0.7396 - recall_m: 0.7484
# Epoch 23/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5026 - accuracy: 0.7605 - f1_m: 0.7298 - precision_m: 0.7341 - recall_m: 0.7732
# Epoch 24/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5116 - accuracy: 0.7425 - f1_m: 0.7218 - precision_m: 0.7198 - recall_m: 0.7484
# Epoch 25/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5059 - accuracy: 0.7246 - f1_m: 0.7184 - precision_m: 0.7062 - recall_m: 0.7729
# Epoch 26/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5084 - accuracy: 0.7425 - f1_m: 0.7180 - precision_m: 0.7024 - recall_m: 0.7849
# Epoch 27/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.4904 - accuracy: 0.7665 - f1_m: 0.7557 - precision_m: 0.7840 - recall_m: 0.7964
# Epoch 28/30
# 21/21 [==============================] - 108s 5s/step - loss: 0.5081 - accuracy: 0.7904 - f1_m: 0.7778 - precision_m: 0.7579 - recall_m: 0.8373
# Epoch 29/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5066 - accuracy: 0.7485 - f1_m: 0.7402 - precision_m: 0.7619 - recall_m: 0.7706
# Epoch 30/30
# 21/21 [==============================] - 109s 5s/step - loss: 0.5028 - accuracy: 0.7665 - f1_m: 0.7355 - precision_m: 0.7548 - recall_m: 0.7540
# 6/6 [==============================] - 18s 2s/step - loss: 0.6223 - accuracy: 0.6585 - f1_m: 0.4338 - precision_m: 0.4524 - recall_m: 0.4246
# Score for fold 5: loss is 0.6223406791687012, accuracy is 0.6585366129875183, f1_score is 0.4337606728076935, precision is 0.4523809850215912, recall is 0.4246031939983368
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-46b3dcc09e69> in <module>()
#     279
#     280
# --> 281 plt.plot(history.history['test_loss'])
#     282 # plt.plot(history.history['val_loss'])
#     283 plt.title('Test Loss')
#
# KeyError: 'test_loss'

# %%
print(acc_per_fold)
print(loss_per_fold) # f_1 score
# Out:
# [0.7142857313156128, 0.6428571343421936, 0.8333333134651184, 0.7560975551605225, 0.6585366129875183]
# [0.5696247816085815, 0.3611110746860504, 0.601190447807312, 0.5138888955116272, 0.4337606728076935]

# %%
print(sum(acc_per_fold)/5)
print(sum(loss_per_fold)/5)
# Out:
# 0.7210220694541931
# 0.49591517448425293

# %%
# model.load_weights(filepath_checkpoint)
loss, accuracy, f1_score, precision, recall = model.evaluate((X_test1_reshaped,X_test2_reshaped,X_test3_reshaped,X_test4_reshaped,
                                                              X_test6_reshaped,X_test7_reshaped,X_test8_reshaped,X_test9_reshaped,X_test10_reshaped,X_test11_reshaped,
                                                              X_test12_reshaped,X_test13_reshaped,X_test14_reshaped,X_test15_reshaped) ,y_test, batch_size=8)
print("test loss:", loss)
print("test acc:", accuracy)
print("f1_score:", f1_score)
# Out:
# 3/3 [==============================] - 7s 2s/step - loss: 0.6138 - accuracy: 0.6000 - f1_m: 0.4444 - precision_m: 0.5000 - recall_m: 0.5000
# test loss: 0.6137851476669312
# test acc: 0.6000000238418579
# f1_score: 0.4444444179534912
