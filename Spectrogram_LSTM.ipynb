# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Spectrogram_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada sadece spectrogram 2D image datası LSTM ile train edildi.
# 2D image'ın column'ları lstm'e sokuldu ve çıktıları dense layer ile classification moduna getirildi.
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.905, mean test f1 score is 0.885, max test accuracy is 0.918, max test f1 score is 0.902, 
# min test accuracy is 0.888, min test f1 score is 0.865, std of test accuracy is 0.011, std of test f1 score is 0.014
# Time elapsed through all process: 1174.74, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 16
dense_unit_of_lstm_function = 256
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(spectrogram_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = spectrogram_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(spectrogram_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_spectrogram) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 256)               3465472
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 3,529,472
# Trainable params: 3,501,888
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 256)               3529472
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 3,611,777
# Trainable params: 3,584,193
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 4s 63ms/step - loss: 0.5132 - accuracy: 0.4931 - val_loss: 0.5811 - val_accuracy: 0.8148
# Epoch 2/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.4317 - accuracy: 0.5231 - val_loss: 0.4369 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3872 - accuracy: 0.5382 - val_loss: 0.4214 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3640 - accuracy: 0.5463 - val_loss: 0.3116 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3354 - accuracy: 0.5521 - val_loss: 0.3284 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3304 - accuracy: 0.5556 - val_loss: 0.3329 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3194 - accuracy: 0.5567 - val_loss: 0.3057 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3073 - accuracy: 0.5602 - val_loss: 0.2991 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3108 - accuracy: 0.5613 - val_loss: 0.2726 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3161 - accuracy: 0.5590 - val_loss: 0.3269 - val_accuracy: 0.8519
# Epoch 11/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3148 - accuracy: 0.5602 - val_loss: 0.3229 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3033 - accuracy: 0.5579 - val_loss: 0.3591 - val_accuracy: 0.8519
# Epoch 13/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3031 - accuracy: 0.5613 - val_loss: 0.2864 - val_accuracy: 0.8519
# Epoch 14/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2956 - accuracy: 0.5613 - val_loss: 0.2900 - val_accuracy: 0.8519
# Epoch 15/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2941 - accuracy: 0.5613 - val_loss: 0.2737 - val_accuracy: 0.8889
# Epoch 16/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2875 - accuracy: 0.5625 - val_loss: 0.2895 - val_accuracy: 0.8519
# Epoch 17/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2928 - accuracy: 0.5625 - val_loss: 0.2622 - val_accuracy: 0.8889
# Epoch 18/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2858 - accuracy: 0.5625 - val_loss: 0.3210 - val_accuracy: 0.8519
# Epoch 19/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2922 - accuracy: 0.5625 - val_loss: 0.2610 - val_accuracy: 0.8519
# Epoch 20/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2802 - accuracy: 0.5625 - val_loss: 0.3211 - val_accuracy: 0.8889
# Epoch 21/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2893 - accuracy: 0.5613 - val_loss: 0.3408 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2771 - accuracy: 0.5625 - val_loss: 0.3692 - val_accuracy: 0.8519
# Epoch 23/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2791 - accuracy: 0.5613 - val_loss: 0.3470 - val_accuracy: 0.8889
# Epoch 24/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2805 - accuracy: 0.5613 - val_loss: 0.3523 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2726 - accuracy: 0.5625 - val_loss: 0.4180 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2771 - accuracy: 0.5625 - val_loss: 0.4419 - val_accuracy: 0.8889
# Epoch 27/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2781 - accuracy: 0.5625 - val_loss: 0.5098 - val_accuracy: 0.8889
# Epoch 28/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2703 - accuracy: 0.5625 - val_loss: 0.3505 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2791 - accuracy: 0.5625 - val_loss: 0.3059 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2806 - accuracy: 0.5613 - val_loss: 0.3061 - val_accuracy: 0.8889
# Epoch 31/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2750 - accuracy: 0.5625 - val_loss: 0.3079 - val_accuracy: 0.8889
# Epoch 32/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2710 - accuracy: 0.5625 - val_loss: 0.3409 - val_accuracy: 0.8519
# Epoch 33/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2718 - accuracy: 0.5625 - val_loss: 0.3226 - val_accuracy: 0.8519
# Epoch 34/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2706 - accuracy: 0.5613 - val_loss: 0.2978 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 13ms/step - loss: 0.2133 - accuracy: 0.9118
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 256)               3465472
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 3,529,472
# Trainable params: 3,501,888
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 256)               3529472
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 3,611,777
# Trainable params: 3,584,193
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 5s 60ms/step - loss: 0.4994 - accuracy: 0.5093 - val_loss: 1.0334 - val_accuracy: 0.7037
# Epoch 2/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4069 - accuracy: 0.5408 - val_loss: 0.7629 - val_accuracy: 0.7037
# Epoch 3/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3604 - accuracy: 0.5571 - val_loss: 0.5389 - val_accuracy: 0.7407
# Epoch 4/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3396 - accuracy: 0.5699 - val_loss: 0.5388 - val_accuracy: 0.7778
# Epoch 5/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3437 - accuracy: 0.5664 - val_loss: 0.5929 - val_accuracy: 0.7778
# Epoch 6/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3117 - accuracy: 0.5734 - val_loss: 0.4533 - val_accuracy: 0.8148
# Epoch 7/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3173 - accuracy: 0.5699 - val_loss: 0.4238 - val_accuracy: 0.8148
# Epoch 8/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3168 - accuracy: 0.5769 - val_loss: 0.4284 - val_accuracy: 0.8148
# Epoch 9/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3002 - accuracy: 0.5758 - val_loss: 0.4557 - val_accuracy: 0.8148
# Epoch 10/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3028 - accuracy: 0.5746 - val_loss: 0.3673 - val_accuracy: 0.8148
# Epoch 11/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2876 - accuracy: 0.5781 - val_loss: 0.5009 - val_accuracy: 0.8148
# Epoch 12/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2940 - accuracy: 0.5781 - val_loss: 0.4333 - val_accuracy: 0.8148
# Epoch 13/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2854 - accuracy: 0.5781 - val_loss: 0.3973 - val_accuracy: 0.8519
# Epoch 14/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2970 - accuracy: 0.5769 - val_loss: 0.4592 - val_accuracy: 0.8148
# Epoch 15/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2881 - accuracy: 0.5781 - val_loss: 0.6306 - val_accuracy: 0.7778
# Epoch 16/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2854 - accuracy: 0.5781 - val_loss: 0.5230 - val_accuracy: 0.8148
# Epoch 17/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2784 - accuracy: 0.5781 - val_loss: 0.5334 - val_accuracy: 0.8148
# Epoch 18/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2770 - accuracy: 0.5781 - val_loss: 0.5215 - val_accuracy: 0.8148
# Epoch 19/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2754 - accuracy: 0.5781 - val_loss: 0.4097 - val_accuracy: 0.8148
# Epoch 20/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2821 - accuracy: 0.5781 - val_loss: 0.4788 - val_accuracy: 0.8148
# Epoch 21/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2687 - accuracy: 0.5769 - val_loss: 0.3658 - val_accuracy: 0.8148
# Epoch 22/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2677 - accuracy: 0.5781 - val_loss: 0.4921 - val_accuracy: 0.8148
# Epoch 23/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2718 - accuracy: 0.5781 - val_loss: 0.3644 - val_accuracy: 0.8519
# Epoch 24/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2660 - accuracy: 0.5781 - val_loss: 0.3971 - val_accuracy: 0.7778
# Epoch 25/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2690 - accuracy: 0.5781 - val_loss: 0.3866 - val_accuracy: 0.8148
# Epoch 26/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2636 - accuracy: 0.5781 - val_loss: 0.5847 - val_accuracy: 0.8148
# Epoch 27/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2747 - accuracy: 0.5769 - val_loss: 0.6726 - val_accuracy: 0.8148
# Epoch 28/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2694 - accuracy: 0.5769 - val_loss: 0.4065 - val_accuracy: 0.8148
# Epoch 29/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2658 - accuracy: 0.5781 - val_loss: 0.5219 - val_accuracy: 0.8148
# Epoch 30/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2571 - accuracy: 0.5781 - val_loss: 0.4104 - val_accuracy: 0.8148
# Epoch 31/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2621 - accuracy: 0.5781 - val_loss: 0.4656 - val_accuracy: 0.8148
# Epoch 32/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2734 - accuracy: 0.5769 - val_loss: 0.4664 - val_accuracy: 0.8148
# Epoch 33/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2562 - accuracy: 0.5781 - val_loss: 0.3631 - val_accuracy: 0.8519
# Epoch 34/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2523 - accuracy: 0.5781 - val_loss: 0.3976 - val_accuracy: 0.8148
# Epoch 35/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2637 - accuracy: 0.5781 - val_loss: 0.4426 - val_accuracy: 0.8148
# Epoch 36/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2578 - accuracy: 0.5781 - val_loss: 0.5263 - val_accuracy: 0.8148
# Epoch 37/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2555 - accuracy: 0.5781 - val_loss: 0.4499 - val_accuracy: 0.8148
# Epoch 38/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2528 - accuracy: 0.5781 - val_loss: 0.3954 - val_accuracy: 0.8148
# Epoch 39/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2641 - accuracy: 0.5781 - val_loss: 0.3706 - val_accuracy: 0.7778
# Epoch 40/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2528 - accuracy: 0.5781 - val_loss: 0.4532 - val_accuracy: 0.8148
# Epoch 41/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2556 - accuracy: 0.5781 - val_loss: 0.5158 - val_accuracy: 0.8148
# Epoch 42/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2569 - accuracy: 0.5781 - val_loss: 0.5103 - val_accuracy: 0.8148
# Epoch 43/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2545 - accuracy: 0.5781 - val_loss: 0.5797 - val_accuracy: 0.8148
# Epoch 44/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2561 - accuracy: 0.5769 - val_loss: 0.3551 - val_accuracy: 0.8519
# Epoch 45/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2538 - accuracy: 0.5781 - val_loss: 0.3502 - val_accuracy: 0.8148
# Epoch 46/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2540 - accuracy: 0.5781 - val_loss: 0.3681 - val_accuracy: 0.8148
# Epoch 47/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2481 - accuracy: 0.5781 - val_loss: 0.5969 - val_accuracy: 0.8148
# Epoch 48/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2520 - accuracy: 0.5769 - val_loss: 0.5491 - val_accuracy: 0.8148
# Epoch 49/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2596 - accuracy: 0.5781 - val_loss: 0.4890 - val_accuracy: 0.8148
# Epoch 50/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2542 - accuracy: 0.5781 - val_loss: 0.4089 - val_accuracy: 0.8148
# Epoch 51/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2493 - accuracy: 0.5781 - val_loss: 0.4967 - val_accuracy: 0.8148
# Epoch 52/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2577 - accuracy: 0.5781 - val_loss: 0.3748 - val_accuracy: 0.7407
# Epoch 53/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2512 - accuracy: 0.5781 - val_loss: 0.6603 - val_accuracy: 0.8148
# Epoch 54/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2601 - accuracy: 0.5769 - val_loss: 0.4745 - val_accuracy: 0.8148
# Epoch 55/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2510 - accuracy: 0.5781 - val_loss: 0.3565 - val_accuracy: 0.8519
# Epoch 56/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2482 - accuracy: 0.5781 - val_loss: 0.4582 - val_accuracy: 0.8148
# Epoch 57/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2508 - accuracy: 0.5769 - val_loss: 0.5613 - val_accuracy: 0.8148
# Epoch 58/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2516 - accuracy: 0.5769 - val_loss: 0.3414 - val_accuracy: 0.8889
# Epoch 59/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2511 - accuracy: 0.5781 - val_loss: 0.3944 - val_accuracy: 0.8148
# Epoch 60/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2542 - accuracy: 0.5781 - val_loss: 0.4980 - val_accuracy: 0.8148
# Epoch 61/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2431 - accuracy: 0.5781 - val_loss: 0.4158 - val_accuracy: 0.8148
# Epoch 62/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2438 - accuracy: 0.5781 - val_loss: 0.3739 - val_accuracy: 0.8148
# Epoch 63/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2430 - accuracy: 0.5781 - val_loss: 0.5190 - val_accuracy: 0.8148
# Epoch 64/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2420 - accuracy: 0.5781 - val_loss: 0.3470 - val_accuracy: 0.8519
# Epoch 65/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2428 - accuracy: 0.5781 - val_loss: 0.4542 - val_accuracy: 0.8148
# Epoch 66/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2430 - accuracy: 0.5781 - val_loss: 0.3571 - val_accuracy: 0.8148
# Epoch 67/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2473 - accuracy: 0.5781 - val_loss: 0.3524 - val_accuracy: 0.8519
# Epoch 68/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2420 - accuracy: 0.5781 - val_loss: 0.4267 - val_accuracy: 0.8148
# Epoch 69/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2501 - accuracy: 0.5769 - val_loss: 0.4823 - val_accuracy: 0.8148
# Epoch 70/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2434 - accuracy: 0.5781 - val_loss: 0.4110 - val_accuracy: 0.8148
# Epoch 71/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2457 - accuracy: 0.5769 - val_loss: 0.3794 - val_accuracy: 0.7778
# Epoch 72/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2489 - accuracy: 0.5781 - val_loss: 0.3981 - val_accuracy: 0.8148
# Epoch 73/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2411 - accuracy: 0.5781 - val_loss: 0.3671 - val_accuracy: 0.8519
# 2/2 [==============================] - 1s 15ms/step - loss: 0.1850 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 256)               3465472
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 3,529,472
# Trainable params: 3,501,888
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 256)               3529472
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 3,611,777
# Trainable params: 3,584,193
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 5s 60ms/step - loss: 0.5016 - accuracy: 0.5338 - val_loss: 0.5763 - val_accuracy: 0.7407
# Epoch 2/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.4100 - accuracy: 0.5746 - val_loss: 0.3891 - val_accuracy: 0.7778
# Epoch 3/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3485 - accuracy: 0.6002 - val_loss: 0.3527 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3367 - accuracy: 0.5991 - val_loss: 0.2541 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3281 - accuracy: 0.6049 - val_loss: 0.2645 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2977 - accuracy: 0.6131 - val_loss: 0.3688 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3092 - accuracy: 0.6072 - val_loss: 0.2538 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2910 - accuracy: 0.6189 - val_loss: 0.2122 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3014 - accuracy: 0.6142 - val_loss: 0.2019 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2759 - accuracy: 0.6189 - val_loss: 0.2249 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2795 - accuracy: 0.6166 - val_loss: 0.2340 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2725 - accuracy: 0.6200 - val_loss: 0.2088 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2714 - accuracy: 0.6166 - val_loss: 0.2238 - val_accuracy: 0.8519
# Epoch 14/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2691 - accuracy: 0.6166 - val_loss: 0.2533 - val_accuracy: 0.8519
# Epoch 15/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2735 - accuracy: 0.6200 - val_loss: 0.3027 - val_accuracy: 0.8889
# Epoch 16/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2670 - accuracy: 0.6200 - val_loss: 0.1957 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2659 - accuracy: 0.6177 - val_loss: 0.2066 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2619 - accuracy: 0.6200 - val_loss: 0.3441 - val_accuracy: 0.8148
# Epoch 19/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2629 - accuracy: 0.6200 - val_loss: 0.2862 - val_accuracy: 0.8519
# Epoch 20/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2633 - accuracy: 0.6189 - val_loss: 0.2071 - val_accuracy: 0.8889
# Epoch 21/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2622 - accuracy: 0.6189 - val_loss: 0.2046 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2612 - accuracy: 0.6177 - val_loss: 0.1931 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2639 - accuracy: 0.6177 - val_loss: 0.2228 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2588 - accuracy: 0.6189 - val_loss: 0.2037 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2526 - accuracy: 0.6200 - val_loss: 0.2154 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2546 - accuracy: 0.6200 - val_loss: 0.2440 - val_accuracy: 0.8889
# Epoch 27/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2619 - accuracy: 0.6189 - val_loss: 0.2057 - val_accuracy: 0.8889
# Epoch 28/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2519 - accuracy: 0.6200 - val_loss: 0.2234 - val_accuracy: 0.8519
# Epoch 29/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2501 - accuracy: 0.6177 - val_loss: 0.1852 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2554 - accuracy: 0.6189 - val_loss: 0.1802 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2505 - accuracy: 0.6200 - val_loss: 0.2423 - val_accuracy: 0.8889
# Epoch 32/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2570 - accuracy: 0.6166 - val_loss: 0.2201 - val_accuracy: 0.8889
# Epoch 33/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2484 - accuracy: 0.6200 - val_loss: 0.2191 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2514 - accuracy: 0.6177 - val_loss: 0.1995 - val_accuracy: 0.8889
# Epoch 35/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2460 - accuracy: 0.6200 - val_loss: 0.2023 - val_accuracy: 0.8889
# Epoch 36/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2408 - accuracy: 0.6200 - val_loss: 0.1891 - val_accuracy: 0.9259
# Epoch 37/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2485 - accuracy: 0.6189 - val_loss: 0.2196 - val_accuracy: 0.9259
# Epoch 38/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2507 - accuracy: 0.6200 - val_loss: 0.2074 - val_accuracy: 0.9259
# Epoch 39/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2481 - accuracy: 0.6189 - val_loss: 0.2824 - val_accuracy: 0.8889
# Epoch 40/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2415 - accuracy: 0.6200 - val_loss: 0.2520 - val_accuracy: 0.8889
# Epoch 41/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2399 - accuracy: 0.6200 - val_loss: 0.2431 - val_accuracy: 0.8889
# Epoch 42/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2421 - accuracy: 0.6200 - val_loss: 0.2840 - val_accuracy: 0.8889
# Epoch 43/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2482 - accuracy: 0.6200 - val_loss: 0.2473 - val_accuracy: 0.8519
# Epoch 44/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2444 - accuracy: 0.6200 - val_loss: 0.2197 - val_accuracy: 0.9259
# Epoch 45/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2384 - accuracy: 0.6200 - val_loss: 0.2602 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 16ms/step - loss: 0.0688 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 256)               3465472
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 3,529,472
# Trainable params: 3,501,888
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 256)               3529472
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 3,611,777
# Trainable params: 3,584,193
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 4s 63ms/step - loss: 0.4830 - accuracy: 0.5046 - val_loss: 0.3924 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.4135 - accuracy: 0.5243 - val_loss: 0.2635 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3560 - accuracy: 0.5498 - val_loss: 0.2016 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3499 - accuracy: 0.5521 - val_loss: 0.2373 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3384 - accuracy: 0.5579 - val_loss: 0.2183 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3246 - accuracy: 0.5625 - val_loss: 0.1562 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3208 - accuracy: 0.5637 - val_loss: 0.2014 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3088 - accuracy: 0.5648 - val_loss: 0.1909 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3060 - accuracy: 0.5648 - val_loss: 0.1440 - val_accuracy: 1.0000
# Epoch 10/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.3092 - accuracy: 0.5660 - val_loss: 0.1345 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2967 - accuracy: 0.5671 - val_loss: 0.1633 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.3040 - accuracy: 0.5637 - val_loss: 0.1553 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2979 - accuracy: 0.5660 - val_loss: 0.1270 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2992 - accuracy: 0.5637 - val_loss: 0.1786 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2914 - accuracy: 0.5660 - val_loss: 0.1231 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2915 - accuracy: 0.5660 - val_loss: 0.0987 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2892 - accuracy: 0.5671 - val_loss: 0.1169 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2945 - accuracy: 0.5625 - val_loss: 0.1035 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2785 - accuracy: 0.5648 - val_loss: 0.1122 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2834 - accuracy: 0.5671 - val_loss: 0.1322 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2779 - accuracy: 0.5671 - val_loss: 0.1062 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2897 - accuracy: 0.5660 - val_loss: 0.0876 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2802 - accuracy: 0.5671 - val_loss: 0.1074 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2784 - accuracy: 0.5671 - val_loss: 0.1137 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2760 - accuracy: 0.5671 - val_loss: 0.1205 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2836 - accuracy: 0.5660 - val_loss: 0.1047 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2791 - accuracy: 0.5671 - val_loss: 0.1164 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2795 - accuracy: 0.5660 - val_loss: 0.1302 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2709 - accuracy: 0.5671 - val_loss: 0.1374 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2715 - accuracy: 0.5671 - val_loss: 0.1631 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2742 - accuracy: 0.5671 - val_loss: 0.1529 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2773 - accuracy: 0.5660 - val_loss: 0.1873 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2729 - accuracy: 0.5660 - val_loss: 0.1141 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2702 - accuracy: 0.5660 - val_loss: 0.1147 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2693 - accuracy: 0.5671 - val_loss: 0.1312 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 1s 34ms/step - loss: 0.2650 - accuracy: 0.5671 - val_loss: 0.1217 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 1s 33ms/step - loss: 0.2719 - accuracy: 0.5671 - val_loss: 0.1081 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 15ms/step - loss: 0.3924 - accuracy: 0.8529
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional (Bidirectiona  (None, 423, 32)          8832
#  l)
#
#  flatten (Flatten)           (None, 13536)             0
#
#  batch_normalization (BatchN  (None, 13536)            54144
#  ormalization)
#
#  dropout (Dropout)           (None, 13536)             0
#
#  dense (Dense)               (None, 256)               3465472
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 3,529,472
# Trainable params: 3,501,888
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 423, 52)]         0
#
#  model (Functional)          (None, 256)               3529472
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 3,611,777
# Trainable params: 3,584,193
# Non-trainable params: 27,584
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 5s 61ms/step - loss: 0.5030 - accuracy: 0.5070 - val_loss: 0.6657 - val_accuracy: 0.7407
# Epoch 2/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3847 - accuracy: 0.5446 - val_loss: 0.3957 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3563 - accuracy: 0.5681 - val_loss: 0.2882 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3458 - accuracy: 0.5704 - val_loss: 0.3220 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3366 - accuracy: 0.5646 - val_loss: 0.3381 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3250 - accuracy: 0.5798 - val_loss: 0.3058 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3180 - accuracy: 0.5810 - val_loss: 0.3843 - val_accuracy: 0.8519
# Epoch 8/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3100 - accuracy: 0.5798 - val_loss: 0.3541 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3053 - accuracy: 0.5833 - val_loss: 0.3509 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3069 - accuracy: 0.5810 - val_loss: 0.2728 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2949 - accuracy: 0.5822 - val_loss: 0.2240 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2987 - accuracy: 0.5833 - val_loss: 0.2462 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2948 - accuracy: 0.5810 - val_loss: 0.2507 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2858 - accuracy: 0.5845 - val_loss: 0.2853 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2964 - accuracy: 0.5822 - val_loss: 0.2705 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2830 - accuracy: 0.5845 - val_loss: 0.2532 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2864 - accuracy: 0.5845 - val_loss: 0.2804 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2804 - accuracy: 0.5833 - val_loss: 0.2481 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2747 - accuracy: 0.5845 - val_loss: 0.2494 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2762 - accuracy: 0.5833 - val_loss: 0.2645 - val_accuracy: 0.8889
# Epoch 21/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2744 - accuracy: 0.5833 - val_loss: 0.2699 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2810 - accuracy: 0.5833 - val_loss: 0.2387 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2720 - accuracy: 0.5833 - val_loss: 0.2496 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2700 - accuracy: 0.5845 - val_loss: 0.2855 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2754 - accuracy: 0.5845 - val_loss: 0.3135 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2705 - accuracy: 0.5833 - val_loss: 0.3887 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 14ms/step - loss: 0.3251 - accuracy: 0.8824
# [0.9176470518112183]
# [0.9003560850177392]
# Epoch 1/100
# 28/28 [==============================] - 5s 58ms/step - loss: 0.5152 - accuracy: 0.5101 - val_loss: 0.6275 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.4091 - accuracy: 0.5484 - val_loss: 0.4007 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3678 - accuracy: 0.5586 - val_loss: 0.3913 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3300 - accuracy: 0.5788 - val_loss: 0.3272 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3164 - accuracy: 0.5800 - val_loss: 0.3644 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3130 - accuracy: 0.5822 - val_loss: 0.4464 - val_accuracy: 0.8148
# Epoch 7/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3002 - accuracy: 0.5856 - val_loss: 0.4162 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.3110 - accuracy: 0.5845 - val_loss: 0.4235 - val_accuracy: 0.8889
# Epoch 9/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3034 - accuracy: 0.5856 - val_loss: 0.3958 - val_accuracy: 0.8148
# Epoch 10/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3049 - accuracy: 0.5845 - val_loss: 0.4756 - val_accuracy: 0.7778
# Epoch 11/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2880 - accuracy: 0.5901 - val_loss: 0.4940 - val_accuracy: 0.7778
# Epoch 12/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2863 - accuracy: 0.5878 - val_loss: 0.4929 - val_accuracy: 0.7778
# Epoch 13/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2808 - accuracy: 0.5901 - val_loss: 0.4931 - val_accuracy: 0.8148
# Epoch 14/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2812 - accuracy: 0.5878 - val_loss: 0.4862 - val_accuracy: 0.8519
# Epoch 15/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2813 - accuracy: 0.5878 - val_loss: 0.4920 - val_accuracy: 0.7778
# Epoch 16/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2818 - accuracy: 0.5901 - val_loss: 0.6121 - val_accuracy: 0.7407
# Epoch 17/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2738 - accuracy: 0.5890 - val_loss: 0.5616 - val_accuracy: 0.8148
# Epoch 18/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2759 - accuracy: 0.5901 - val_loss: 0.5242 - val_accuracy: 0.8148
# Epoch 19/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2659 - accuracy: 0.5890 - val_loss: 0.4940 - val_accuracy: 0.8148
# 2/2 [==============================] - 1s 14ms/step - loss: 0.1720 - accuracy: 0.9412
# Epoch 1/100
# 28/28 [==============================] - 5s 60ms/step - loss: 0.5455 - accuracy: 0.4874 - val_loss: 0.2526 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.4264 - accuracy: 0.5228 - val_loss: 0.1985 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3630 - accuracy: 0.5559 - val_loss: 0.1841 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3618 - accuracy: 0.5548 - val_loss: 0.1649 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3312 - accuracy: 0.5651 - val_loss: 0.1369 - val_accuracy: 1.0000
# Epoch 6/100
# ...
# Epoch 33/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2742 - accuracy: 0.5776 - val_loss: 0.0704 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2692 - accuracy: 0.5765 - val_loss: 0.0470 - val_accuracy: 1.0000
# Epoch 35/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2635 - accuracy: 0.5776 - val_loss: 0.0945 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2621 - accuracy: 0.5776 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2617 - accuracy: 0.5776 - val_loss: 0.0796 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2706 - accuracy: 0.5765 - val_loss: 0.1232 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2669 - accuracy: 0.5776 - val_loss: 0.0243 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2556 - accuracy: 0.5776 - val_loss: 0.0802 - val_accuracy: 0.9630
# Epoch 41/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2674 - accuracy: 0.5776 - val_loss: 0.0901 - val_accuracy: 0.9630
# Epoch 42/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2671 - accuracy: 0.5776 - val_loss: 0.1085 - val_accuracy: 0.9630
# Epoch 43/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2581 - accuracy: 0.5776 - val_loss: 0.0573 - val_accuracy: 0.9630
# Epoch 44/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2649 - accuracy: 0.5776 - val_loss: 0.0932 - val_accuracy: 0.9630
# Epoch 45/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2565 - accuracy: 0.5776 - val_loss: 0.0757 - val_accuracy: 1.0000
# Epoch 46/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2639 - accuracy: 0.5776 - val_loss: 0.1075 - val_accuracy: 1.0000
# Epoch 47/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2611 - accuracy: 0.5776 - val_loss: 0.1497 - val_accuracy: 0.9630
# Epoch 48/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2602 - accuracy: 0.5776 - val_loss: 0.0803 - val_accuracy: 0.9630
# Epoch 49/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2599 - accuracy: 0.5776 - val_loss: 0.1071 - val_accuracy: 0.9630
# Epoch 50/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2615 - accuracy: 0.5765 - val_loss: 0.1768 - val_accuracy: 0.9630
# Epoch 51/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2608 - accuracy: 0.5776 - val_loss: 0.1500 - val_accuracy: 0.9630
# Epoch 52/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2556 - accuracy: 0.5776 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 53/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2615 - accuracy: 0.5776 - val_loss: 0.1506 - val_accuracy: 0.9630
# Epoch 54/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2512 - accuracy: 0.5753 - val_loss: 0.1308 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 18ms/step - loss: 0.3616 - accuracy: 0.8529
# Epoch 1/100
# 27/27 [==============================] - 5s 61ms/step - loss: 0.5084 - accuracy: 0.5059 - val_loss: 1.5456 - val_accuracy: 0.5926
# Epoch 2/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.4035 - accuracy: 0.5423 - val_loss: 0.9025 - val_accuracy: 0.5926
# Epoch 3/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3520 - accuracy: 0.5728 - val_loss: 0.7022 - val_accuracy: 0.6667
# Epoch 4/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.3496 - accuracy: 0.5669 - val_loss: 0.4334 - val_accuracy: 0.7407
# Epoch 5/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3253 - accuracy: 0.5822 - val_loss: 0.3398 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3308 - accuracy: 0.5739 - val_loss: 0.4785 - val_accuracy: 0.8148
# Epoch 7/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3114 - accuracy: 0.5763 - val_loss: 0.4985 - val_accuracy: 0.7778
# Epoch 8/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3096 - accuracy: 0.5810 - val_loss: 0.5288 - val_accuracy: 0.7407
# Epoch 9/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3024 - accuracy: 0.5822 - val_loss: 0.4836 - val_accuracy: 0.7778
# Epoch 10/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3061 - accuracy: 0.5775 - val_loss: 0.4632 - val_accuracy: 0.8148
# Epoch 11/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.3030 - accuracy: 0.5763 - val_loss: 0.6762 - val_accuracy: 0.8148
# Epoch 12/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2930 - accuracy: 0.5822 - val_loss: 0.4670 - val_accuracy: 0.8148
# Epoch 13/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2990 - accuracy: 0.5775 - val_loss: 0.6562 - val_accuracy: 0.7778
# Epoch 14/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2932 - accuracy: 0.5798 - val_loss: 0.7526 - val_accuracy: 0.7778
# Epoch 15/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2839 - accuracy: 0.5810 - val_loss: 0.5348 - val_accuracy: 0.8148
# Epoch 16/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2781 - accuracy: 0.5822 - val_loss: 0.3994 - val_accuracy: 0.8148
# Epoch 17/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2822 - accuracy: 0.5786 - val_loss: 0.4795 - val_accuracy: 0.8148
# Epoch 18/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2890 - accuracy: 0.5822 - val_loss: 0.5476 - val_accuracy: 0.8148
# Epoch 19/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2772 - accuracy: 0.5798 - val_loss: 0.3828 - val_accuracy: 0.8148
# Epoch 20/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2858 - accuracy: 0.5822 - val_loss: 0.3089 - val_accuracy: 0.8148
# Epoch 21/100
# 27/27 [==============================] - 1s 32ms/step - loss: 0.2737 - accuracy: 0.5822 - val_loss: 0.2965 - val_accuracy: 0.8148
# Epoch 22/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2726 - accuracy: 0.5822 - val_loss: 0.3546 - val_accuracy: 0.8148
# Epoch 23/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2901 - accuracy: 0.5798 - val_loss: 0.4494 - val_accuracy: 0.8148
# Epoch 24/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2781 - accuracy: 0.5810 - val_loss: 0.3940 - val_accuracy: 0.8148
# Epoch 25/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2797 - accuracy: 0.5798 - val_loss: 0.3892 - val_accuracy: 0.8148
# Epoch 26/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2744 - accuracy: 0.5822 - val_loss: 0.3931 - val_accuracy: 0.8148
# Epoch 27/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2687 - accuracy: 0.5798 - val_loss: 0.4183 - val_accuracy: 0.8148
# Epoch 28/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2776 - accuracy: 0.5822 - val_loss: 0.3479 - val_accuracy: 0.8148
# Epoch 29/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2750 - accuracy: 0.5822 - val_loss: 0.3743 - val_accuracy: 0.8148
# Epoch 30/100
# 27/27 [==============================] - 1s 30ms/step - loss: 0.2685 - accuracy: 0.5810 - val_loss: 0.3591 - val_accuracy: 0.8148
# Epoch 31/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2761 - accuracy: 0.5810 - val_loss: 0.5002 - val_accuracy: 0.8148
# Epoch 32/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2651 - accuracy: 0.5822 - val_loss: 0.2837 - val_accuracy: 0.8148
# Epoch 33/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2632 - accuracy: 0.5822 - val_loss: 0.4750 - val_accuracy: 0.8148
# Epoch 34/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2614 - accuracy: 0.5798 - val_loss: 0.3072 - val_accuracy: 0.8148
# Epoch 35/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2686 - accuracy: 0.5822 - val_loss: 0.4560 - val_accuracy: 0.8148
# Epoch 36/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2709 - accuracy: 0.5822 - val_loss: 0.3158 - val_accuracy: 0.8148
# Epoch 37/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2645 - accuracy: 0.5822 - val_loss: 0.2846 - val_accuracy: 0.8519
# Epoch 38/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2595 - accuracy: 0.5822 - val_loss: 0.3570 - val_accuracy: 0.8148
# Epoch 39/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2610 - accuracy: 0.5822 - val_loss: 0.5246 - val_accuracy: 0.8148
# Epoch 40/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2597 - accuracy: 0.5798 - val_loss: 0.3023 - val_accuracy: 0.8148
# Epoch 41/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2609 - accuracy: 0.5822 - val_loss: 0.3070 - val_accuracy: 0.8148
# Epoch 42/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2614 - accuracy: 0.5822 - val_loss: 0.3319 - val_accuracy: 0.8519
# Epoch 43/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2690 - accuracy: 0.5822 - val_loss: 0.2932 - val_accuracy: 0.8148
# Epoch 44/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2619 - accuracy: 0.5822 - val_loss: 0.3040 - val_accuracy: 0.8148
# Epoch 45/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2519 - accuracy: 0.5822 - val_loss: 0.4511 - val_accuracy: 0.8148
# Epoch 46/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2558 - accuracy: 0.5822 - val_loss: 0.3649 - val_accuracy: 0.8148
# Epoch 47/100
# 27/27 [==============================] - 1s 31ms/step - loss: 0.2568 - accuracy: 0.5822 - val_loss: 0.3399 - val_accuracy: 0.8148
# 2/2 [==============================] - 1s 17ms/step - loss: 0.0903 - accuracy: 1.0000
# Epoch 1/100
# 28/28 [==============================] - 5s 59ms/step - loss: 0.4912 - accuracy: 0.4862 - val_loss: 0.4659 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.4061 - accuracy: 0.5207 - val_loss: 0.3692 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3963 - accuracy: 0.5241 - val_loss: 0.3017 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3599 - accuracy: 0.5345 - val_loss: 0.2221 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3458 - accuracy: 0.5425 - val_loss: 0.2219 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3262 - accuracy: 0.5448 - val_loss: 0.2201 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3286 - accuracy: 0.5448 - val_loss: 0.3030 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3296 - accuracy: 0.5483 - val_loss: 0.1996 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.3128 - accuracy: 0.5494 - val_loss: 0.2162 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3174 - accuracy: 0.5483 - val_loss: 0.1659 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.3231 - accuracy: 0.5506 - val_loss: 0.2552 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3057 - accuracy: 0.5506 - val_loss: 0.1600 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3040 - accuracy: 0.5506 - val_loss: 0.1549 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2974 - accuracy: 0.5494 - val_loss: 0.1564 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3163 - accuracy: 0.5494 - val_loss: 0.1409 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3060 - accuracy: 0.5517 - val_loss: 0.1171 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.3015 - accuracy: 0.5494 - val_loss: 0.1440 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.3002 - accuracy: 0.5517 - val_loss: 0.1149 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.3019 - accuracy: 0.5517 - val_loss: 0.1337 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2955 - accuracy: 0.5517 - val_loss: 0.1910 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.3002 - accuracy: 0.5517 - val_loss: 0.1153 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2906 - accuracy: 0.5517 - val_loss: 0.1292 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2953 - accuracy: 0.5517 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2888 - accuracy: 0.5517 - val_loss: 0.1405 - val_accuracy: 0.9259
# Epoch 25/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2879 - accuracy: 0.5517 - val_loss: 0.1302 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2917 - accuracy: 0.5517 - val_loss: 0.1221 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2899 - accuracy: 0.5517 - val_loss: 0.1608 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2878 - accuracy: 0.5517 - val_loss: 0.1903 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2866 - accuracy: 0.5517 - val_loss: 0.1746 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2836 - accuracy: 0.5506 - val_loss: 0.1144 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2902 - accuracy: 0.5517 - val_loss: 0.1660 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2844 - accuracy: 0.5506 - val_loss: 0.1299 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2796 - accuracy: 0.5506 - val_loss: 0.1427 - val_accuracy: 0.9259
# Epoch 34/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2819 - accuracy: 0.5506 - val_loss: 0.1900 - val_accuracy: 0.9259
# Epoch 35/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2915 - accuracy: 0.5494 - val_loss: 0.1668 - val_accuracy: 0.9259
# Epoch 36/100
# 28/28 [==============================] - 1s 30ms/step - loss: 0.2845 - accuracy: 0.5517 - val_loss: 0.1523 - val_accuracy: 0.9259
# Epoch 37/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2774 - accuracy: 0.5517 - val_loss: 0.1300 - val_accuracy: 0.9259
# Epoch 38/100
# 28/28 [==============================] - 1s 31ms/step - loss: 0.2791 - accuracy: 0.5517 - val_loss: 0.1606 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 15ms/step - loss: 0.2904 - accuracy: 0.8529
# [0.9176470518112183, 0.9176470518112183, 0.8882352828979492, 0.9, 0.899999988079071]
# [0.9003560850177392, 0.9019959473150964, 0.8648895227152117, 0.8779681081918934, 0.8784698689757422]
# Mean test accuracy is 0.90, mean test f1 score is 0.88, max test accuracy is 0.92, max test f1 score is 0.90, min test accuracy is 0.89, min test f1 score is 0.86, std of test accuracy is 0.01, std of test f1 score is 0.01
# Time elapsed through all process: 1174.74, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# Out:
# Mean test accuracy is 0.905, mean test f1 score is 0.885, max test accuracy is 0.918, max test f1 score is 0.902, min test accuracy is 0.888, min test f1 score is 0.865, std of test accuracy is 0.011, std of test f1 score is 0.014
