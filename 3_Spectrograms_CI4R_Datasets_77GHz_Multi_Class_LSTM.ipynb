# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/3_Spectrograms_CI4R_Datasets_77GHz_Multi_Class_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada CI4R dataseti ile Multi Class Classification yapıldı.
# Sadece 77GHz train ve test edildi.
# Training datasına 5 kere MixUp augmentation yapıldı.
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.755, max test accuracy is 0.773,
# Min test accuracy is 0.730,  std of test accuracy is 0.016.
# Time elapsed through all process: 1077.37 sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 77 GHz
bending_77GHz                 = np.load('/content/drive/MyDrive/bending_77Ghz.npy')
label_bending_77GHz           = np.zeros((bending_77GHz.shape[0],1))
label_bending_77GHz[:]        = 1
crawling_77GHz                = np.load('/content/drive/MyDrive/crawling_77Ghz.npy')
label_crawling_77GHz          = np.zeros((crawling_77GHz.shape[0],1))
label_crawling_77GHz[:]       = 2
kneeling_77GHz                = np.load('/content/drive/MyDrive/kneeling_77Ghz.npy')
label_kneeling_77GHz          = np.zeros((kneeling_77GHz.shape[0],1))
label_kneeling_77GHz[:]       = 3
limping_with_RL_Stiff_77GHz   = np.load('/content/drive/MyDrive/limping_with_RL_Stiff_77Ghz.npy')
label_limping_with_RL_Stiff_77GHz           = np.zeros((limping_with_RL_Stiff_77GHz.shape[0],1))
label_limping_with_RL_Stiff_77GHz[:]        = 4
picking_up_an_object_77GHz    = np.load('/content/drive/MyDrive/picking_up_an_object_77Ghz.npy')
label_picking_up_an_object_77GHz          = np.zeros((picking_up_an_object_77GHz.shape[0],1))
label_picking_up_an_object_77GHz[:]       = 5
scissors_gait_77GHz           = np.load('/content/drive/MyDrive/scissors_gait_77Ghz.npy')
label_scissors_gait_77GHz          = np.zeros((scissors_gait_77GHz.shape[0],1))
label_scissors_gait_77GHz[:]       = 6
short_steps_77GHz             = np.load('/content/drive/MyDrive/short_steps_77Ghz.npy')
label_short_steps_77GHz          = np.zeros((short_steps_77GHz.shape[0],1))
label_short_steps_77GHz[:]       = 7
sitting_77GHz                 = np.load('/content/drive/MyDrive/sitting_77Ghz.npy')
label_sitting_77GHz          = np.zeros((sitting_77GHz.shape[0],1))
label_sitting_77GHz[:]       = 8
walking_away_from_Radar_77GHz = np.load('/content/drive/MyDrive/walking_away_from_Radar_77Ghz.npy')
label_walking_away_from_Radar_77GHz         = np.zeros((walking_away_from_Radar_77GHz.shape[0],1))
label_walking_away_from_Radar_77GHz[:]       = 9
Walking_on_both_toes_77GHz    = np.load('/content/drive/MyDrive/Walking_on_both_toes_77Ghz.npy')
label_Walking_on_both_toes_77GHz         = np.zeros((Walking_on_both_toes_77GHz.shape[0],1))
label_Walking_on_both_toes_77GHz[:]       = 10
Walking_towards_radar_77GHz   = np.load('/content/drive/MyDrive/Walking_towards_radar_77Ghz.npy')
label_Walking_towards_radar_77GHz          = np.zeros((Walking_towards_radar_77GHz.shape[0],1))
label_Walking_towards_radar_77GHz[:]       = 11
# 24 GHz
bending_24GHz                 = np.load('/content/drive/MyDrive/bending_24GHz.npy')
label_bending_24GHz           = np.zeros((bending_24GHz.shape[0],1))
label_bending_24GHz[:]        = 1
crawling_24GHz                = np.load('/content/drive/MyDrive/crawling_24GHz.npy')
label_crawling_24GHz          = np.zeros((crawling_24GHz.shape[0],1))
label_crawling_24GHz[:]       = 2
kneeling_24GHz                = np.load('/content/drive/MyDrive/kneeling_24GHz.npy')
label_kneeling_24GHz          = np.zeros((kneeling_24GHz.shape[0],1))
label_kneeling_24GHz[:]       = 3
limping_with_RL_Stiff_24GHz   = np.load('/content/drive/MyDrive/limping with right stiff_24GHz.npy')
label_limping_with_RL_Stiff_24GHz           = np.zeros((limping_with_RL_Stiff_24GHz.shape[0],1))
label_limping_with_RL_Stiff_24GHz[:]        = 4
picking_up_an_object_24GHz    = np.load('/content/drive/MyDrive/picking up object_24GHz.npy')
label_picking_up_an_object_24GHz          = np.zeros((picking_up_an_object_24GHz.shape[0],1))
label_picking_up_an_object_24GHz[:]       = 5
scissors_gait_24GHz           = np.load('/content/drive/MyDrive/scissors gait_24GHz.npy')
label_scissors_gait_24GHz          = np.zeros((scissors_gait_24GHz.shape[0],1))
label_scissors_gait_24GHz[:]       = 6
short_steps_24GHz             = np.load('/content/drive/MyDrive/short steps_24GHz.npy')
label_short_steps_24GHz          = np.zeros((short_steps_24GHz.shape[0],1))
label_short_steps_24GHz[:]       = 7
sitting_24GHz                 = np.load('/content/drive/MyDrive/sitting_24GHz.npy')
label_sitting_24GHz          = np.zeros((sitting_24GHz.shape[0],1))
label_sitting_24GHz[:]       = 8
walking_away_from_Radar_24GHz = np.load('/content/drive/MyDrive/walking away from radar_24GHz.npy')
label_walking_away_from_Radar_24GHz         = np.zeros((walking_away_from_Radar_24GHz.shape[0],1))
label_walking_away_from_Radar_24GHz[:]       = 9
Walking_on_both_toes_24GHz    = np.load('/content/drive/MyDrive/walking on toes both_24GHz.npy')
label_Walking_on_both_toes_24GHz         = np.zeros((Walking_on_both_toes_24GHz.shape[0],1))
label_Walking_on_both_toes_24GHz[:]       = 10
Walking_towards_radar_24GHz   = np.load('/content/drive/MyDrive/walking towards radar_24GHz.npy')
label_Walking_towards_radar_24GHz          = np.zeros((Walking_towards_radar_24GHz.shape[0],1))
label_Walking_towards_radar_24GHz[:]       = 11
# Xethru
bending_Xethru                 = np.load('/content/drive/MyDrive/bending_Xethru.npy')
label_bending_Xethru           = np.zeros((bending_Xethru.shape[0],1))
label_bending_Xethru[:]        = 1
crawling_Xethru                = np.load('/content/drive/MyDrive/crawling_Xethru.npy')
label_crawling_Xethru          = np.zeros((crawling_Xethru.shape[0],1))
label_crawling_Xethru[:]       = 2
kneeling_Xethru                = np.load('/content/drive/MyDrive/kneeling_Xethru.npy')
label_kneeling_Xethru          = np.zeros((kneeling_Xethru.shape[0],1))
label_kneeling_Xethru[:]       = 3
limping_with_RL_Stiff_Xethru   = np.load('/content/drive/MyDrive/limping with right leg stiff_Xethru.npy')
label_limping_with_RL_Stiff_Xethru           = np.zeros((limping_with_RL_Stiff_Xethru.shape[0],1))
label_limping_with_RL_Stiff_Xethru[:]        = 4
picking_up_an_object_Xethru    = np.load('/content/drive/MyDrive/ picking up an object_Xethru.npy')
label_picking_up_an_object_Xethru          = np.zeros((picking_up_an_object_Xethru.shape[0],1))
label_picking_up_an_object_Xethru[:]       = 5
scissors_gait_Xethru           = np.load('/content/drive/MyDrive/scissor Gait_Xethru.npy')
label_scissors_gait_Xethru          = np.zeros((scissors_gait_Xethru.shape[0],1))
label_scissors_gait_Xethru[:]       = 6
short_steps_Xethru             = np.load('/content/drive/MyDrive/short Step_Xethru.npy')
label_short_steps_Xethru          = np.zeros((short_steps_Xethru.shape[0],1))
label_short_steps_Xethru[:]       = 7
sitting_Xethru                 = np.load('/content/drive/MyDrive/sitting_Xethru.npy')
label_sitting_Xethru          = np.zeros((sitting_Xethru.shape[0],1))
label_sitting_Xethru[:]       = 8
walking_away_from_Radar_Xethru = np.load('/content/drive/MyDrive/Walking away from radar_Xethru.npy')
label_walking_away_from_Radar_Xethru         = np.zeros((walking_away_from_Radar_Xethru.shape[0],1))
label_walking_away_from_Radar_Xethru[:]       = 9
Walking_on_both_toes_Xethru    = np.load('/content/drive/MyDrive/walking on both toes_Xethru.npy')
label_Walking_on_both_toes_Xethru         = np.zeros((Walking_on_both_toes_Xethru.shape[0],1))
label_Walking_on_both_toes_Xethru[:]       = 10
Walking_towards_radar_Xethru   = np.load('/content/drive/MyDrive/Walking towards the radar_Xethru.npy')
label_Walking_towards_radar_Xethru          = np.zeros((Walking_towards_radar_Xethru.shape[0],1))
label_Walking_towards_radar_Xethru[:]       = 11

# %%
min_length = min(label_bending_77GHz.shape[0],label_bending_24GHz.shape[0],label_bending_Xethru.shape[0])
label_concat = label_bending_77GHz[:min_length]
bending_77GHz = bending_77GHz[:min_length,:,:,:]
bending_24GHz = bending_24GHz[:min_length,:,:,:]
bending_Xethru = bending_Xethru[:min_length,:,:,:]

min_length = min(label_crawling_77GHz.shape[0],label_crawling_24GHz.shape[0],label_crawling_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_crawling_77GHz[:min_length]),axis=0)  
crawling_77GHz = crawling_77GHz[:min_length,:,:,:]
crawling_24GHz = crawling_24GHz[:min_length,:,:,:]
crawling_Xethru = crawling_Xethru[:min_length,:,:,:]

min_length = min(label_kneeling_77GHz.shape[0],label_kneeling_24GHz.shape[0],label_kneeling_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_kneeling_77GHz[:min_length]),axis=0)  
kneeling_77GHz = kneeling_77GHz[:min_length,:,:,:]
kneeling_24GHz = kneeling_24GHz[:min_length,:,:,:]
kneeling_Xethru = kneeling_Xethru[:min_length,:,:,:]

min_length = min(label_limping_with_RL_Stiff_77GHz.shape[0],label_limping_with_RL_Stiff_24GHz.shape[0],label_limping_with_RL_Stiff_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_limping_with_RL_Stiff_77GHz[:min_length]),axis=0)  
limping_with_RL_Stiff_77GHz = limping_with_RL_Stiff_77GHz[:min_length,:,:,:]
limping_with_RL_Stiff_24GHz = limping_with_RL_Stiff_24GHz[:min_length,:,:,:]
limping_with_RL_Stiff_Xethru = limping_with_RL_Stiff_Xethru[:min_length,:,:,:]

min_length = min(label_picking_up_an_object_77GHz.shape[0],label_picking_up_an_object_24GHz.shape[0],label_picking_up_an_object_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_picking_up_an_object_77GHz[:min_length]),axis=0)  
picking_up_an_object_77GHz = picking_up_an_object_77GHz[:min_length,:,:,:]
picking_up_an_object_24GHz = picking_up_an_object_24GHz[:min_length,:,:,:]
picking_up_an_object_Xethru = picking_up_an_object_Xethru[:min_length,:,:,:]

min_length = min(label_scissors_gait_77GHz.shape[0],label_scissors_gait_24GHz.shape[0],label_scissors_gait_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_scissors_gait_77GHz[:min_length]),axis=0)  
scissors_gait_77GHz = scissors_gait_77GHz[:min_length,:,:,:]
scissors_gait_24GHz = scissors_gait_24GHz[:min_length,:,:,:]
scissors_gait_Xethru = scissors_gait_Xethru[:min_length,:,:,:]

min_length = min(label_short_steps_77GHz.shape[0],label_short_steps_24GHz.shape[0],label_short_steps_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_short_steps_77GHz[:min_length]),axis=0)  
short_steps_77GHz = short_steps_77GHz[:min_length,:,:,:]
short_steps_24GHz = short_steps_24GHz[:min_length,:,:,:]
short_steps_Xethru = short_steps_Xethru[:min_length,:,:,:]

min_length = min(label_sitting_77GHz.shape[0],label_sitting_24GHz.shape[0],label_sitting_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_sitting_77GHz[:min_length]),axis=0)  
sitting_77GHz = sitting_77GHz[:min_length,:,:,:]
sitting_24GHz = sitting_24GHz[:min_length,:,:,:]
sitting_Xethru = sitting_Xethru[:min_length,:,:,:]

min_length = min(label_walking_away_from_Radar_77GHz.shape[0],label_walking_away_from_Radar_24GHz.shape[0],label_walking_away_from_Radar_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_walking_away_from_Radar_77GHz[:min_length]),axis=0)  
walking_away_from_Radar_77GHz = walking_away_from_Radar_77GHz[:min_length,:,:,:]
walking_away_from_Radar_24GHz = walking_away_from_Radar_24GHz[:min_length,:,:,:]
walking_away_from_Radar_Xethru = walking_away_from_Radar_Xethru[:min_length,:,:,:]

min_length = min(label_Walking_on_both_toes_77GHz.shape[0],label_Walking_on_both_toes_24GHz.shape[0],label_Walking_on_both_toes_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_Walking_on_both_toes_77GHz[:min_length]),axis=0)  
Walking_on_both_toes_77GHz = Walking_on_both_toes_77GHz[:min_length,:,:,:]
Walking_on_both_toes_24GHz = Walking_on_both_toes_24GHz[:min_length,:,:,:]
Walking_on_both_toes_Xethru = Walking_on_both_toes_Xethru[:min_length,:,:,:]

min_length = min(label_Walking_towards_radar_77GHz.shape[0],label_Walking_towards_radar_24GHz.shape[0],label_Walking_towards_radar_Xethru.shape[0])
label_concat = np.concatenate((label_concat,label_Walking_towards_radar_77GHz[:min_length]),axis=0)  
Walking_towards_radar_77GHz = Walking_towards_radar_77GHz[:min_length,:,:,:]
Walking_towards_radar_24GHz = Walking_towards_radar_24GHz[:min_length,:,:,:]
Walking_towards_radar_Xethru = Walking_towards_radar_Xethru[:min_length,:,:,:]

# %%
# 77 GHz
spectrogram_77GHz_concat = np.concatenate((bending_77GHz,crawling_77GHz),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,kneeling_77GHz               ),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,limping_with_RL_Stiff_77GHz  ),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,picking_up_an_object_77GHz   ),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,scissors_gait_77GHz          ),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,short_steps_77GHz            ),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,sitting_77GHz                ),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,walking_away_from_Radar_77GHz),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,Walking_on_both_toes_77GHz   ),axis=0)
spectrogram_77GHz_concat = np.concatenate((spectrogram_77GHz_concat,Walking_towards_radar_77GHz  ),axis=0)

# 24 GHz
spectrogram_24GHz_concat = np.concatenate((bending_24GHz,crawling_24GHz),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,kneeling_24GHz               ),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,limping_with_RL_Stiff_24GHz  ),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,picking_up_an_object_24GHz   ),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,scissors_gait_24GHz          ),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,short_steps_24GHz            ),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,sitting_24GHz                ),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,walking_away_from_Radar_24GHz),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,Walking_on_both_toes_24GHz   ),axis=0)
spectrogram_24GHz_concat = np.concatenate((spectrogram_24GHz_concat,Walking_towards_radar_24GHz  ),axis=0)


# Xethru
spectrogram_Xethru_concat = np.concatenate((bending_Xethru,crawling_Xethru),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,kneeling_Xethru               ),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,limping_with_RL_Stiff_Xethru  ),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,picking_up_an_object_Xethru   ),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,scissors_gait_Xethru          ),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,short_steps_Xethru            ),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,sitting_Xethru                ),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,walking_away_from_Radar_Xethru),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,Walking_on_both_toes_Xethru   ),axis=0)
spectrogram_Xethru_concat = np.concatenate((spectrogram_Xethru_concat,Walking_towards_radar_Xethru  ),axis=0)

# %%
# One-Hot Encode Label
# integer encode
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(label_concat)
# binary encode
onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
onehot_encoded_labels = onehot_encoder.fit_transform(integer_encoded)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Concat range-doppler data
range_doppler_concat = spectrogram_77GHz_concat
range_doppler_concat_label = label_concat
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = spectrogram_24GHz_concat
spectrogram_concat_label = onehot_encoded_labels
# Shuffle concat range doppler
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]
# Third Spectrogram
third_spectrogram_concat = spectrogram_Xethru_concat
third_spectrogram_concat_shuffle = third_spectrogram_concat[shuffle_indx,:,:,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
def mixup_augmentation(images,range_doppler_training_data,third_spectrogram_training_data, labels, repeat_of_mixup, alpha, beta):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_third_spectrogram = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))

    if repeat_of_mixup == 0:
      concat_images = images
      concat_images_range_doppler = range_doppler_training_data
      concat_images_third_spectrogram = third_spectrogram_training_data
      concat_label = labels      
    else:
      for ii in range(repeat_of_mixup):
        # shuffle train dataset
        shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
        images_shuffled_1 = images[shuffle_indx_1,:,:,:]
        range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
        third_spectrogram_training_data_shuffled_1 = third_spectrogram_training_data[shuffle_indx_1,:,:,:]
        labels_shuffled_1 = labels[shuffle_indx_1,:]

        shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
        images_shuffled_2 = images[shuffle_indx_2,:,:,:]
        range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
        third_spectrogram_training_data_shuffled_2 = third_spectrogram_training_data[shuffle_indx_2,:,:,:]
        labels_shuffled_2 = labels[shuffle_indx_2,:]

        shuffle_indx_3 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
        images_shuffled_3 = images[shuffle_indx_3,:,:,:]
        range_doppler_training_data_shuffled_3 = range_doppler_training_data[shuffle_indx_3,:,:,:]
        third_spectrogram_training_data_shuffled_3 = third_spectrogram_training_data[shuffle_indx_3,:,:,:]
        labels_shuffled_3 = labels[shuffle_indx_3,:]

        shuffle_indx_4 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
        images_shuffled_4 = images[shuffle_indx_4,:,:,:]
        range_doppler_training_data_shuffled_4 = range_doppler_training_data[shuffle_indx_4,:,:,:]
        third_spectrogram_training_data_shuffled_4 = third_spectrogram_training_data[shuffle_indx_4,:,:,:]
        labels_shuffled_4 = labels[shuffle_indx_4,:]

        # Sample lambda and reshape it to do the mixup
        # ll = np.random.beta(alpha, beta, (batch_size,1,1,1))
        gaussian_mean = 0.11
        gaussian_std = 0.02
        ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
        x_l = np.reshape(ll, (batch_size,1,1,1))
        y_l = np.reshape(ll, (batch_size,1))
      
        ll_2 = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
        x_l_2 = np.reshape(ll_2, (batch_size,1,1,1))
        y_l_2 = np.reshape(ll_2, (batch_size,1))

        ll_3 = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
        x_l_3 = np.reshape(ll_3, (batch_size,1,1,1))
        y_l_3 = np.reshape(ll_3, (batch_size,1))

        
        # Perform mixup on both images and labels by combining a pair of images/labels
        images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * x_l_2 + images_shuffled_3 * x_l_3 + images_shuffled_4 * (1 - x_l - x_l_2 - x_l_3)
        images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * x_l_2 +\
        range_doppler_training_data_shuffled_3 * x_l_3 + range_doppler_training_data_shuffled_4 * (1 - x_l - x_l_2 - x_l_3)
        images_mixup_third_spectrogram = third_spectrogram_training_data_shuffled_1 * x_l + third_spectrogram_training_data_shuffled_2 * x_l_2 +\
        third_spectrogram_training_data_shuffled_3 * x_l_3 + third_spectrogram_training_data_shuffled_4 * (1 - x_l - x_l_2 - x_l_3)
        labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * y_l_2  + labels_shuffled_3 * y_l_3 + labels_shuffled_4 * (1 - y_l - y_l_2 - y_l_3)

        # images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
        # images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
        # images_mixup_third_spectrogram = third_spectrogram_training_data_shuffled_1 * x_l + third_spectrogram_training_data_shuffled_2 * (1 - x_l)
        # labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)

        concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
        concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
        concat_images_third_spectrogram[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_third_spectrogram
        concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

      concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
      concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
      concat_images_third_spectrogram[repeat_of_mixup*batch_size:,:,:,:] = third_spectrogram_training_data
      concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler,concat_images_third_spectrogram, concat_label)

def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,third_spectrogram,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  # to split train and validation with same distribution
  alpha = 0.1
  beta = 5
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # size_of_validation = int(0.2*spectrogram_concat_shuffle_train.shape[0])
  # # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  third_spectrogram_validation_data = third_spectrogram[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  third_spectrogram_training_data = third_spectrogram[randomlist_for_train_indx,:,:,:]
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  (spectrogram_augmented_image,range_doppler_augmented_image,third_spectrogram_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data,third_spectrogram_training_data, spectrogram_training_labels, repeat_of_mixup, alpha, beta)

  return (spectrogram_augmented_image,range_doppler_augmented_image,third_spectrogram_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data,third_spectrogram_validation_data, spectrogram_validation_labels)



def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
third_spectrogram_concat_shuffle = normalize_inputs(third_spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)
third_spectrogram_concat_shuffle = np.float32(third_spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3)) 
third_spectrogram_concat_shuffle = np.transpose(third_spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.3
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 64
dense_unit_of_lstm_function = 256
decoder_dense = 128
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  for train, test in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()

    randomlist_for_test_indx = test
    randomlist_for_train_indx = train
    # test data
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_label_shuffle_test = spectrogram_concat_label_shuffle[randomlist_for_test_indx,:]
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    third_spectrogram_concat_shuffle_test = third_spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    #train data
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    third_spectrogram_concat_shuffle_train = third_spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    # ---------------- Split labels to equal them during augmentation for Validation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,third_spectrogram_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler,validation_third_spectrogram, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,third_spectrogram_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)


    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(dense_size)(x)
      x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(11, activation="softmax")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm_1 = lstm_encoder_network_1(input_shape)
    lstm_input_1  = Input(shape=input_shape)
    processed_lstm_1  = base_network_lstm_1(lstm_input_1)

    # input_shape = spectrogram_concat_shuffle.shape[1:3]
    # base_network_lstm_2 = lstm_encoder_network_2(input_shape)
    # lstm_input_2  = Input(shape=input_shape)
    # processed_lstm_2  = base_network_lstm_2(lstm_input_2)

    # input_shape = third_spectrogram_concat_shuffle.shape[1:3]
    # base_network_lstm_3 = lstm_encoder_network_3(input_shape)
    # lstm_input_3  = Input(shape=input_shape)
    # processed_lstm_3  = base_network_lstm_3(lstm_input_3)

    # concat_layer = Concatenate()([processed_lstm_1, processed_lstm_2, processed_lstm_3])

    base_decoder_network = decoder_for_concat((processed_lstm_1.shape[1]))
    out = base_decoder_network(processed_lstm_1)

    model = Model(inputs=[lstm_input_1], outputs=[out])

    print(base_network_lstm_1.summary())
    print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0,restore_best_weights=True, mode='min')
    # earlyStopping = EarlyStopping(monitor='val_accuracy', patience=15, verbose=0,restore_best_weights=True, mode='max')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    tf.keras.models.load_model
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [spectrogram_concat_label_shuffle_test],
                  batch_size=batch_size)
    # ---------------- Get Test Results ----------------
    # y_test_predicted = model.predict((range_doppler_concat_shuffle_test,spectrogram_concat_shuffle_test,third_spectrogram_concat_shuffle_test), batch_size=batch_size)
    # # ----- Binarize y_test_predicted values -----
    # y_test_predicted_binary = np.zeros(y_test_predicted.shape[0])
    # for ii in range(y_test_predicted.shape[0]):
    #   if argmax(y_test_predicted[ii,:]) == 0:
    #     y_test_predicted_binary[ii] = 0
    #   elif argmax(y_test_predicted[ii,:]) == 1:
    #     y_test_predicted_binary[ii] = 1
    #   else:
    #     y_test_predicted_binary[ii] = 2
    # range_doppler_concat_label_shuffle_test1 = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    # test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test1, y_test_predicted_binary, average='macro')
    # ----------------------------------------------------------------------------------------------------------
    test_accuracy_per_fold.append(test_accuracy)
    # f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  # f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  # print(f1_score_per_run)

print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)},\
 max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))},\
 min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, \
 std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}.')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.7157 - accuracy: 0.6320 - val_loss: 1.0906 - val_accuracy: 0.6800
# Epoch 2/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3550 - accuracy: 0.8672 - val_loss: 1.1275 - val_accuracy: 0.7400
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2393 - accuracy: 0.9299 - val_loss: 1.0107 - val_accuracy: 0.7500
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1997 - accuracy: 0.9460 - val_loss: 0.8627 - val_accuracy: 0.7800
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1698 - accuracy: 0.9563 - val_loss: 0.8674 - val_accuracy: 0.7300
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1445 - accuracy: 0.9658 - val_loss: 0.8516 - val_accuracy: 0.7300
# Epoch 7/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.1181 - accuracy: 0.9744 - val_loss: 0.8599 - val_accuracy: 0.6800
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1025 - accuracy: 0.9781 - val_loss: 0.8629 - val_accuracy: 0.7500
# Epoch 9/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0998 - accuracy: 0.9686 - val_loss: 0.8464 - val_accuracy: 0.7300
# Epoch 10/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0723 - accuracy: 0.9785 - val_loss: 0.8117 - val_accuracy: 0.7900
# Epoch 11/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0677 - accuracy: 0.9744 - val_loss: 0.7824 - val_accuracy: 0.7200
# Epoch 12/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0634 - accuracy: 0.9761 - val_loss: 0.8503 - val_accuracy: 0.7500
# Epoch 13/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0447 - accuracy: 0.9814 - val_loss: 0.8640 - val_accuracy: 0.7300
# Epoch 14/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0367 - accuracy: 0.9785 - val_loss: 0.8791 - val_accuracy: 0.7400
# Epoch 15/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0372 - accuracy: 0.9732 - val_loss: 0.8708 - val_accuracy: 0.7500
# Epoch 16/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0232 - accuracy: 0.9827 - val_loss: 0.8626 - val_accuracy: 0.7500
# Epoch 17/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0257 - accuracy: 0.9777 - val_loss: 0.9165 - val_accuracy: 0.7400
# Epoch 18/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0226 - accuracy: 0.9802 - val_loss: 0.8593 - val_accuracy: 0.7500
# Epoch 19/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0152 - accuracy: 0.9744 - val_loss: 0.8331 - val_accuracy: 0.7200
# Epoch 20/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0054 - accuracy: 0.9785 - val_loss: 0.8483 - val_accuracy: 0.7000
# Epoch 21/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0027 - accuracy: 0.9740 - val_loss: 0.8493 - val_accuracy: 0.7200
# 4/4 [==============================] - 1s 10ms/step - loss: 0.8155 - accuracy: 0.7619
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.7356 - accuracy: 0.5953 - val_loss: 1.1091 - val_accuracy: 0.7700
# Epoch 2/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.3563 - accuracy: 0.8672 - val_loss: 1.2497 - val_accuracy: 0.7300
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2384 - accuracy: 0.9241 - val_loss: 1.0608 - val_accuracy: 0.7900
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1913 - accuracy: 0.9538 - val_loss: 0.8892 - val_accuracy: 0.8000
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1593 - accuracy: 0.9608 - val_loss: 0.8169 - val_accuracy: 0.7900
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1342 - accuracy: 0.9666 - val_loss: 0.7800 - val_accuracy: 0.7900
# Epoch 7/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1100 - accuracy: 0.9724 - val_loss: 0.6933 - val_accuracy: 0.8000
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0956 - accuracy: 0.9736 - val_loss: 0.7185 - val_accuracy: 0.7800
# Epoch 9/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0780 - accuracy: 0.9711 - val_loss: 0.7452 - val_accuracy: 0.7400
# Epoch 10/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0722 - accuracy: 0.9715 - val_loss: 0.7106 - val_accuracy: 0.7900
# Epoch 11/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0635 - accuracy: 0.9740 - val_loss: 0.6805 - val_accuracy: 0.8100
# Epoch 12/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0508 - accuracy: 0.9715 - val_loss: 0.7377 - val_accuracy: 0.7400
# Epoch 13/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0524 - accuracy: 0.9691 - val_loss: 0.6743 - val_accuracy: 0.7900
# Epoch 14/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0315 - accuracy: 0.9744 - val_loss: 0.6916 - val_accuracy: 0.7800
# Epoch 15/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0325 - accuracy: 0.9757 - val_loss: 0.6992 - val_accuracy: 0.7800
# Epoch 16/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0233 - accuracy: 0.9736 - val_loss: 0.7086 - val_accuracy: 0.7600
# Epoch 17/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0172 - accuracy: 0.9765 - val_loss: 0.6842 - val_accuracy: 0.7800
# Epoch 18/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0105 - accuracy: 0.9752 - val_loss: 0.6759 - val_accuracy: 0.7900
# Epoch 19/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0076 - accuracy: 0.9781 - val_loss: 0.6862 - val_accuracy: 0.7700
# Epoch 20/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0030 - accuracy: 0.9790 - val_loss: 0.7220 - val_accuracy: 0.8000
# Epoch 21/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0028 - accuracy: 0.9765 - val_loss: 0.7093 - val_accuracy: 0.7800
# Epoch 22/100
# 76/76 [==============================] - 2s 20ms/step - loss: 0.9929 - accuracy: 0.9769 - val_loss: 0.6858 - val_accuracy: 0.7500
# Epoch 23/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9898 - accuracy: 0.9744 - val_loss: 0.6934 - val_accuracy: 0.7800
# 4/4 [==============================] - 1s 10ms/step - loss: 0.8444 - accuracy: 0.7698
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.7573 - accuracy: 0.6159 - val_loss: 1.1684 - val_accuracy: 0.6900
# Epoch 2/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3564 - accuracy: 0.8597 - val_loss: 1.0421 - val_accuracy: 0.7900
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2665 - accuracy: 0.9175 - val_loss: 0.9325 - val_accuracy: 0.8300
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2053 - accuracy: 0.9460 - val_loss: 0.8774 - val_accuracy: 0.8300
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1693 - accuracy: 0.9608 - val_loss: 0.8454 - val_accuracy: 0.8000
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1447 - accuracy: 0.9625 - val_loss: 0.7644 - val_accuracy: 0.8200
# Epoch 7/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1311 - accuracy: 0.9707 - val_loss: 0.7060 - val_accuracy: 0.8200
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1136 - accuracy: 0.9703 - val_loss: 0.6774 - val_accuracy: 0.8200
# Epoch 9/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0959 - accuracy: 0.9752 - val_loss: 0.7035 - val_accuracy: 0.8000
# Epoch 10/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0817 - accuracy: 0.9699 - val_loss: 0.7445 - val_accuracy: 0.8100
# Epoch 11/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0833 - accuracy: 0.9686 - val_loss: 0.7111 - val_accuracy: 0.8000
# Epoch 12/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0711 - accuracy: 0.9781 - val_loss: 0.7364 - val_accuracy: 0.7600
# Epoch 13/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0589 - accuracy: 0.9740 - val_loss: 0.7646 - val_accuracy: 0.8000
# Epoch 14/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0472 - accuracy: 0.9765 - val_loss: 0.7136 - val_accuracy: 0.8100
# Epoch 15/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0400 - accuracy: 0.9752 - val_loss: 0.6914 - val_accuracy: 0.7900
# Epoch 16/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0370 - accuracy: 0.9790 - val_loss: 0.7587 - val_accuracy: 0.8000
# Epoch 17/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0271 - accuracy: 0.9773 - val_loss: 0.7368 - val_accuracy: 0.7900
# Epoch 18/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0289 - accuracy: 0.9752 - val_loss: 0.7222 - val_accuracy: 0.8100
# 4/4 [==============================] - 1s 11ms/step - loss: 0.7137 - accuracy: 0.7778
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.7365 - accuracy: 0.6436 - val_loss: 1.0659 - val_accuracy: 0.7900
# Epoch 2/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3507 - accuracy: 0.8779 - val_loss: 1.1603 - val_accuracy: 0.8000
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2489 - accuracy: 0.9352 - val_loss: 0.9434 - val_accuracy: 0.7900
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1927 - accuracy: 0.9542 - val_loss: 0.8530 - val_accuracy: 0.7800
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1691 - accuracy: 0.9592 - val_loss: 0.8348 - val_accuracy: 0.7600
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1379 - accuracy: 0.9719 - val_loss: 0.8097 - val_accuracy: 0.7600
# Epoch 7/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1219 - accuracy: 0.9715 - val_loss: 0.7899 - val_accuracy: 0.7800
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1061 - accuracy: 0.9773 - val_loss: 0.7570 - val_accuracy: 0.7900
# Epoch 9/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0926 - accuracy: 0.9732 - val_loss: 0.7916 - val_accuracy: 0.7500
# Epoch 10/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0796 - accuracy: 0.9802 - val_loss: 0.8446 - val_accuracy: 0.7500
# Epoch 11/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0710 - accuracy: 0.9740 - val_loss: 0.7840 - val_accuracy: 0.7400
# Epoch 12/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0648 - accuracy: 0.9744 - val_loss: 0.7667 - val_accuracy: 0.7500
# Epoch 13/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0572 - accuracy: 0.9794 - val_loss: 0.7878 - val_accuracy: 0.7500
# Epoch 14/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0418 - accuracy: 0.9794 - val_loss: 0.7867 - val_accuracy: 0.7500
# Epoch 15/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0373 - accuracy: 0.9781 - val_loss: 0.7627 - val_accuracy: 0.7600
# Epoch 16/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0301 - accuracy: 0.9806 - val_loss: 0.7655 - val_accuracy: 0.7500
# Epoch 17/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0216 - accuracy: 0.9769 - val_loss: 0.6998 - val_accuracy: 0.7800
# Epoch 18/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0125 - accuracy: 0.9802 - val_loss: 0.8029 - val_accuracy: 0.7500
# Epoch 19/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0132 - accuracy: 0.9732 - val_loss: 0.7755 - val_accuracy: 0.7700
# Epoch 20/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0116 - accuracy: 0.9761 - val_loss: 0.7343 - val_accuracy: 0.7800
# Epoch 21/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0061 - accuracy: 0.9806 - val_loss: 0.7874 - val_accuracy: 0.7600
# Epoch 22/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0075 - accuracy: 0.9777 - val_loss: 0.7437 - val_accuracy: 0.7800
# Epoch 23/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0001 - accuracy: 0.9790 - val_loss: 0.7265 - val_accuracy: 0.7800
# Epoch 24/100
# 76/76 [==============================] - 2s 20ms/step - loss: 0.9924 - accuracy: 0.9785 - val_loss: 0.7912 - val_accuracy: 0.7700
# Epoch 25/100
# 76/76 [==============================] - 2s 20ms/step - loss: 0.9924 - accuracy: 0.9785 - val_loss: 0.8172 - val_accuracy: 0.7200
# Epoch 26/100
# 76/76 [==============================] - 2s 20ms/step - loss: 0.9880 - accuracy: 0.9839 - val_loss: 0.7971 - val_accuracy: 0.7500
# Epoch 27/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9872 - accuracy: 0.9744 - val_loss: 0.7355 - val_accuracy: 0.7700
# 4/4 [==============================] - 1s 11ms/step - loss: 0.6621 - accuracy: 0.7857
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.7547 - accuracy: 0.6172 - val_loss: 1.1522 - val_accuracy: 0.6800
# Epoch 2/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3520 - accuracy: 0.8688 - val_loss: 1.1435 - val_accuracy: 0.7800
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2605 - accuracy: 0.9245 - val_loss: 0.9662 - val_accuracy: 0.7800
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1999 - accuracy: 0.9497 - val_loss: 0.8825 - val_accuracy: 0.7600
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1671 - accuracy: 0.9641 - val_loss: 0.8530 - val_accuracy: 0.7500
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1469 - accuracy: 0.9633 - val_loss: 0.7575 - val_accuracy: 0.7600
# Epoch 7/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.1256 - accuracy: 0.9703 - val_loss: 0.7704 - val_accuracy: 0.7600
# Epoch 8/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.1067 - accuracy: 0.9748 - val_loss: 0.7607 - val_accuracy: 0.7400
# Epoch 9/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0923 - accuracy: 0.9724 - val_loss: 0.8325 - val_accuracy: 0.7300
# Epoch 10/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0742 - accuracy: 0.9843 - val_loss: 0.8256 - val_accuracy: 0.7500
# Epoch 11/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0661 - accuracy: 0.9806 - val_loss: 0.8379 - val_accuracy: 0.7200
# Epoch 12/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0559 - accuracy: 0.9757 - val_loss: 0.8364 - val_accuracy: 0.7000
# Epoch 13/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0541 - accuracy: 0.9810 - val_loss: 0.9244 - val_accuracy: 0.7500
# Epoch 14/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0420 - accuracy: 0.9790 - val_loss: 0.9378 - val_accuracy: 0.7100
# Epoch 15/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0332 - accuracy: 0.9765 - val_loss: 0.8785 - val_accuracy: 0.7200
# Epoch 16/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0340 - accuracy: 0.9744 - val_loss: 0.8565 - val_accuracy: 0.7400
# 4/4 [==============================] - 1s 10ms/step - loss: 0.8060 - accuracy: 0.7540
# [0.7698412656784057]
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.7631 - accuracy: 0.6134 - val_loss: 1.1408 - val_accuracy: 0.7000
# Epoch 2/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.3521 - accuracy: 0.8564 - val_loss: 1.1412 - val_accuracy: 0.7600
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2601 - accuracy: 0.9171 - val_loss: 0.9954 - val_accuracy: 0.7500
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2003 - accuracy: 0.9427 - val_loss: 0.8940 - val_accuracy: 0.7500
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1722 - accuracy: 0.9575 - val_loss: 0.8324 - val_accuracy: 0.7700
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1387 - accuracy: 0.9695 - val_loss: 0.7807 - val_accuracy: 0.7800
# Epoch 7/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.1229 - accuracy: 0.9715 - val_loss: 0.8440 - val_accuracy: 0.7700
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1044 - accuracy: 0.9728 - val_loss: 0.8526 - val_accuracy: 0.7700
# Epoch 9/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0959 - accuracy: 0.9682 - val_loss: 0.7647 - val_accuracy: 0.7700
# Epoch 10/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0776 - accuracy: 0.9773 - val_loss: 0.8903 - val_accuracy: 0.7300
# Epoch 11/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0723 - accuracy: 0.9715 - val_loss: 0.8587 - val_accuracy: 0.7500
# Epoch 12/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0626 - accuracy: 0.9761 - val_loss: 0.8911 - val_accuracy: 0.7600
# Epoch 13/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0433 - accuracy: 0.9806 - val_loss: 0.8502 - val_accuracy: 0.7800
# Epoch 14/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0492 - accuracy: 0.9736 - val_loss: 0.8689 - val_accuracy: 0.7700
# Epoch 15/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0360 - accuracy: 0.9744 - val_loss: 0.9290 - val_accuracy: 0.7500
# Epoch 16/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0346 - accuracy: 0.9736 - val_loss: 0.9234 - val_accuracy: 0.7400
# Epoch 17/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0271 - accuracy: 0.9691 - val_loss: 0.9040 - val_accuracy: 0.7400
# Epoch 18/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0180 - accuracy: 0.9740 - val_loss: 0.8820 - val_accuracy: 0.7600
# Epoch 19/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0140 - accuracy: 0.9761 - val_loss: 0.8724 - val_accuracy: 0.7300
# 4/4 [==============================] - 1s 10ms/step - loss: 0.6099 - accuracy: 0.8095
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.6878 - accuracy: 0.6423 - val_loss: 1.1292 - val_accuracy: 0.7300
# Epoch 2/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3370 - accuracy: 0.8700 - val_loss: 1.0083 - val_accuracy: 0.7400
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2362 - accuracy: 0.9282 - val_loss: 0.9922 - val_accuracy: 0.6800
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1834 - accuracy: 0.9443 - val_loss: 0.9562 - val_accuracy: 0.7700
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1538 - accuracy: 0.9592 - val_loss: 0.8905 - val_accuracy: 0.7400
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1228 - accuracy: 0.9653 - val_loss: 0.9093 - val_accuracy: 0.7300
# Epoch 7/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1018 - accuracy: 0.9724 - val_loss: 0.8670 - val_accuracy: 0.7300
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0920 - accuracy: 0.9715 - val_loss: 0.9490 - val_accuracy: 0.7000
# Epoch 9/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0808 - accuracy: 0.9695 - val_loss: 0.9289 - val_accuracy: 0.7500
# Epoch 10/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0584 - accuracy: 0.9769 - val_loss: 0.8640 - val_accuracy: 0.7500
# Epoch 11/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0496 - accuracy: 0.9757 - val_loss: 0.9310 - val_accuracy: 0.7400
# Epoch 12/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0499 - accuracy: 0.9790 - val_loss: 0.8666 - val_accuracy: 0.7500
# Epoch 13/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0439 - accuracy: 0.9732 - val_loss: 0.9296 - val_accuracy: 0.6900
# Epoch 14/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0348 - accuracy: 0.9724 - val_loss: 0.9419 - val_accuracy: 0.7700
# Epoch 15/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0235 - accuracy: 0.9765 - val_loss: 0.9065 - val_accuracy: 0.7300
# Epoch 16/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0223 - accuracy: 0.9724 - val_loss: 0.9385 - val_accuracy: 0.7200
# Epoch 17/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0118 - accuracy: 0.9744 - val_loss: 0.9073 - val_accuracy: 0.7100
# Epoch 18/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0088 - accuracy: 0.9781 - val_loss: 0.9284 - val_accuracy: 0.7500
# Epoch 19/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0012 - accuracy: 0.9810 - val_loss: 0.8737 - val_accuracy: 0.7200
# Epoch 20/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9918 - accuracy: 0.9827 - val_loss: 0.8921 - val_accuracy: 0.7500
# 4/4 [==============================] - 1s 10ms/step - loss: 0.6377 - accuracy: 0.7937
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 32ms/step - loss: 1.7390 - accuracy: 0.6279 - val_loss: 0.9605 - val_accuracy: 0.7600
# Epoch 2/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3594 - accuracy: 0.8684 - val_loss: 1.0568 - val_accuracy: 0.8000
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2537 - accuracy: 0.9245 - val_loss: 0.9315 - val_accuracy: 0.8300
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2124 - accuracy: 0.9517 - val_loss: 0.7507 - val_accuracy: 0.8300
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1724 - accuracy: 0.9625 - val_loss: 0.6737 - val_accuracy: 0.7900
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1435 - accuracy: 0.9678 - val_loss: 0.5978 - val_accuracy: 0.8500
# Epoch 7/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.1211 - accuracy: 0.9785 - val_loss: 0.6350 - val_accuracy: 0.8300
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1161 - accuracy: 0.9728 - val_loss: 0.5230 - val_accuracy: 0.8500
# Epoch 9/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0973 - accuracy: 0.9761 - val_loss: 0.5892 - val_accuracy: 0.8300
# Epoch 10/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0872 - accuracy: 0.9781 - val_loss: 0.5538 - val_accuracy: 0.8300
# Epoch 11/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0831 - accuracy: 0.9777 - val_loss: 0.5805 - val_accuracy: 0.8400
# Epoch 12/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0694 - accuracy: 0.9785 - val_loss: 0.5481 - val_accuracy: 0.8100
# Epoch 13/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0552 - accuracy: 0.9794 - val_loss: 0.5747 - val_accuracy: 0.8300
# Epoch 14/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0468 - accuracy: 0.9802 - val_loss: 0.5738 - val_accuracy: 0.8200
# Epoch 15/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0444 - accuracy: 0.9814 - val_loss: 0.5572 - val_accuracy: 0.8300
# Epoch 16/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.0407 - accuracy: 0.9740 - val_loss: 0.6022 - val_accuracy: 0.8000
# Epoch 17/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0367 - accuracy: 0.9777 - val_loss: 0.5930 - val_accuracy: 0.8000
# Epoch 18/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0242 - accuracy: 0.9785 - val_loss: 0.5879 - val_accuracy: 0.7800
# 4/4 [==============================] - 1s 10ms/step - loss: 0.7779 - accuracy: 0.7381
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.7235 - accuracy: 0.6229 - val_loss: 1.1295 - val_accuracy: 0.7300
# Epoch 2/100
# 76/76 [==============================] - 2s 20ms/step - loss: 1.3575 - accuracy: 0.8618 - val_loss: 1.1515 - val_accuracy: 0.7000
# Epoch 3/100
# ...
# Epoch 7/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1224 - accuracy: 0.9740 - val_loss: 0.7937 - val_accuracy: 0.7300
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1073 - accuracy: 0.9765 - val_loss: 0.7532 - val_accuracy: 0.7300
# Epoch 9/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0963 - accuracy: 0.9765 - val_loss: 0.7382 - val_accuracy: 0.7500
# Epoch 10/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0825 - accuracy: 0.9790 - val_loss: 0.8018 - val_accuracy: 0.7400
# Epoch 11/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0807 - accuracy: 0.9761 - val_loss: 0.8014 - val_accuracy: 0.7000
# Epoch 12/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0618 - accuracy: 0.9856 - val_loss: 0.7209 - val_accuracy: 0.7300
# Epoch 13/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0574 - accuracy: 0.9736 - val_loss: 0.8162 - val_accuracy: 0.7700
# Epoch 14/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0494 - accuracy: 0.9748 - val_loss: 0.7691 - val_accuracy: 0.7000
# Epoch 15/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0436 - accuracy: 0.9711 - val_loss: 0.7756 - val_accuracy: 0.7400
# Epoch 16/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0345 - accuracy: 0.9769 - val_loss: 0.6859 - val_accuracy: 0.7500
# Epoch 17/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0291 - accuracy: 0.9757 - val_loss: 0.8467 - val_accuracy: 0.7200
# Epoch 18/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0194 - accuracy: 0.9794 - val_loss: 0.7558 - val_accuracy: 0.7500
# Epoch 19/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0149 - accuracy: 0.9790 - val_loss: 0.8141 - val_accuracy: 0.7400
# Epoch 20/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0181 - accuracy: 0.9744 - val_loss: 0.7603 - val_accuracy: 0.7400
# Epoch 21/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0082 - accuracy: 0.9744 - val_loss: 0.7919 - val_accuracy: 0.7400
# Epoch 22/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0067 - accuracy: 0.9777 - val_loss: 0.7221 - val_accuracy: 0.7400
# Epoch 23/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0020 - accuracy: 0.9765 - val_loss: 0.8137 - val_accuracy: 0.7400
# Epoch 24/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9986 - accuracy: 0.9769 - val_loss: 0.8072 - val_accuracy: 0.7400
# Epoch 25/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9926 - accuracy: 0.9790 - val_loss: 0.7961 - val_accuracy: 0.7400
# Epoch 26/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9876 - accuracy: 0.9818 - val_loss: 0.8443 - val_accuracy: 0.7400
# 4/4 [==============================] - 1s 10ms/step - loss: 0.6830 - accuracy: 0.7937
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 32ms/step - loss: 1.7421 - accuracy: 0.6275 - val_loss: 1.1574 - val_accuracy: 0.7400
# Epoch 2/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3384 - accuracy: 0.8816 - val_loss: 1.1095 - val_accuracy: 0.7600
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2484 - accuracy: 0.9282 - val_loss: 0.9536 - val_accuracy: 0.7300
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2021 - accuracy: 0.9501 - val_loss: 0.9312 - val_accuracy: 0.7700
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1654 - accuracy: 0.9629 - val_loss: 0.8130 - val_accuracy: 0.7500
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1390 - accuracy: 0.9645 - val_loss: 0.7178 - val_accuracy: 0.7700
# Epoch 7/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1252 - accuracy: 0.9711 - val_loss: 0.7640 - val_accuracy: 0.7700
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1109 - accuracy: 0.9691 - val_loss: 0.7486 - val_accuracy: 0.7700
# Epoch 9/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0869 - accuracy: 0.9732 - val_loss: 0.8139 - val_accuracy: 0.7600
# Epoch 10/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0802 - accuracy: 0.9757 - val_loss: 0.7731 - val_accuracy: 0.7500
# Epoch 11/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0701 - accuracy: 0.9806 - val_loss: 0.8198 - val_accuracy: 0.7700
# Epoch 12/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0649 - accuracy: 0.9752 - val_loss: 0.8019 - val_accuracy: 0.7300
# Epoch 13/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0476 - accuracy: 0.9748 - val_loss: 0.7764 - val_accuracy: 0.7500
# Epoch 14/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0406 - accuracy: 0.9798 - val_loss: 0.7854 - val_accuracy: 0.7500
# Epoch 15/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0368 - accuracy: 0.9777 - val_loss: 0.7209 - val_accuracy: 0.7800
# Epoch 16/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0323 - accuracy: 0.9736 - val_loss: 0.7902 - val_accuracy: 0.7400
# 4/4 [==============================] - 1s 12ms/step - loss: 0.8608 - accuracy: 0.7063
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 100)]        0
#
#  bidirectional_1 (Bidirectio  (None, 200, 128)         84480
#  nal)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  batch_normalization_1 (Batc  (None, 25600)            102400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 25600)             0
#
#  dense (Dense)               (None, 256)               6553856
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 6,741,760
# Trainable params: 6,690,048
# Non-trainable params: 51,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 100)]        0
#
#  model (Functional)          (None, 256)               6741760
#
#  model_1 (Functional)        (None, 11)                42635
#
# =================================================================
# Total params: 6,784,395
# Trainable params: 6,732,299
# Non-trainable params: 52,096
# _________________________________________________________________
# None
# Epoch 1/100
# 76/76 [==============================] - 6s 31ms/step - loss: 1.7163 - accuracy: 0.6209 - val_loss: 1.0009 - val_accuracy: 0.7900
# Epoch 2/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3574 - accuracy: 0.8544 - val_loss: 1.0065 - val_accuracy: 0.8000
# Epoch 3/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2657 - accuracy: 0.9187 - val_loss: 0.8418 - val_accuracy: 0.8400
# Epoch 4/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.2006 - accuracy: 0.9501 - val_loss: 0.7053 - val_accuracy: 0.8400
# Epoch 5/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1706 - accuracy: 0.9554 - val_loss: 0.6520 - val_accuracy: 0.8100
# Epoch 6/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1611 - accuracy: 0.9554 - val_loss: 0.6285 - val_accuracy: 0.8400
# Epoch 7/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1305 - accuracy: 0.9773 - val_loss: 0.6980 - val_accuracy: 0.8500
# Epoch 8/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1163 - accuracy: 0.9752 - val_loss: 0.5974 - val_accuracy: 0.8300
# Epoch 9/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0911 - accuracy: 0.9707 - val_loss: 0.6631 - val_accuracy: 0.8400
# Epoch 10/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0838 - accuracy: 0.9769 - val_loss: 0.6163 - val_accuracy: 0.7900
# Epoch 11/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0800 - accuracy: 0.9777 - val_loss: 0.6242 - val_accuracy: 0.8500
# Epoch 12/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0681 - accuracy: 0.9773 - val_loss: 0.5935 - val_accuracy: 0.7900
# Epoch 13/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0630 - accuracy: 0.9724 - val_loss: 0.6306 - val_accuracy: 0.8100
# Epoch 14/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0538 - accuracy: 0.9798 - val_loss: 0.6464 - val_accuracy: 0.8000
# Epoch 15/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0406 - accuracy: 0.9806 - val_loss: 0.6494 - val_accuracy: 0.8000
# Epoch 16/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0337 - accuracy: 0.9785 - val_loss: 0.5796 - val_accuracy: 0.8300
# Epoch 17/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0281 - accuracy: 0.9752 - val_loss: 0.6445 - val_accuracy: 0.7700
# Epoch 18/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0251 - accuracy: 0.9769 - val_loss: 0.6160 - val_accuracy: 0.8000
# Epoch 19/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0227 - accuracy: 0.9794 - val_loss: 0.6900 - val_accuracy: 0.7900
# Epoch 20/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0160 - accuracy: 0.9823 - val_loss: 0.6345 - val_accuracy: 0.8100
# Epoch 21/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0094 - accuracy: 0.9744 - val_loss: 0.6566 - val_accuracy: 0.7800
# Epoch 22/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0055 - accuracy: 0.9827 - val_loss: 0.6968 - val_accuracy: 0.7900
# Epoch 23/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0000 - accuracy: 0.9790 - val_loss: 0.6323 - val_accuracy: 0.7900
# Epoch 24/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9979 - accuracy: 0.9806 - val_loss: 0.6067 - val_accuracy: 0.8100
# Epoch 25/100
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0010 - accuracy: 0.9769 - val_loss: 0.5622 - val_accuracy: 0.8100
# Epoch 26/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9907 - accuracy: 0.9769 - val_loss: 0.6369 - val_accuracy: 0.7800
# Epoch 27/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9940 - accuracy: 0.9773 - val_loss: 0.5826 - val_accuracy: 0.8100
# Epoch 28/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9860 - accuracy: 0.9806 - val_loss: 0.6274 - val_accuracy: 0.8200
# Epoch 29/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9827 - accuracy: 0.9777 - val_loss: 0.6656 - val_accuracy: 0.8000
# Epoch 30/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9781 - accuracy: 0.9781 - val_loss: 0.6445 - val_accuracy: 0.7900
# Epoch 31/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9792 - accuracy: 0.9732 - val_loss: 0.5868 - val_accuracy: 0.8200
# Epoch 32/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9731 - accuracy: 0.9810 - val_loss: 0.6187 - val_accuracy: 0.7600
# Epoch 33/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9771 - accuracy: 0.9773 - val_loss: 0.6165 - val_accuracy: 0.8000
# Epoch 34/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9696 - accuracy: 0.9798 - val_loss: 0.6548 - val_accuracy: 0.7900
# Epoch 35/100
# 76/76 [==============================] - 2s 21ms/step - loss: 0.9663 - accuracy: 0.9765 - val_loss: 0.6362 - val_accuracy: 0.7900
# 4/4 [==============================] - 1s 12ms/step - loss: 0.8280 - accuracy: 0.7063
# [0.7698412656784057, 0.7730158805847168, 0.7428571462631226, 0.7603174686431885, 0.7301587224006653]
# Mean test accuracy is 0.755, max test accuracy is 0.773, min test accuracy is 0.730,  std of test accuracy is 0.016.
# Time elapsed through all process: 1077.37, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)},\
 max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))},')
print(f'Min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, \
 std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}.')
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)} sec')
# Out:
# Mean test accuracy is 0.755, max test accuracy is 0.773,
# Min test accuracy is 0.730,  std of test accuracy is 0.016.
# Time elapsed through all process: 1077.37, sec
