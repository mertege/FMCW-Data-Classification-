# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_LSTM_v2_8hiddenunit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada unit_number_of_lstm = 8 seçildi. 
# Mean test accuracy is 0.961, mean test f1 score is 0.956, max test accuracy is 0.976, max test f1 score is 0.973, min test accuracy is 0.941, min test f1 score is 0.935, std of test accuracy is 0.013, std of test f1 score is 0.014

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resizedv2.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resizedv2.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resizedv2.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.4
unit_number_of_lstm = 8
dense_unit_of_lstm_function = 256
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 16)         3904
#  l)
#
#  flatten (Flatten)           (None, 81920)             0
#
#  batch_normalization (BatchN  (None, 81920)            327680
#  ormalization)
#
#  dropout (Dropout)           (None, 81920)             0
#
#  dense (Dense)               (None, 256)               20971776
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 21,304,384
# Trainable params: 21,140,032
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               21304384
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 21,386,689
# Trainable params: 21,222,337
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 19s 444ms/step - loss: 0.5138 - accuracy: 0.5153 - val_loss: 0.4706 - val_accuracy: 0.8148
# Epoch 2/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.4165 - accuracy: 0.5434 - val_loss: 0.5514 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.3471 - accuracy: 0.5739 - val_loss: 0.3035 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.3570 - accuracy: 0.5716 - val_loss: 0.3318 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.3290 - accuracy: 0.5798 - val_loss: 0.4106 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.3241 - accuracy: 0.5775 - val_loss: 0.3112 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3249 - accuracy: 0.5775 - val_loss: 0.4365 - val_accuracy: 0.8148
# Epoch 8/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.3241 - accuracy: 0.5798 - val_loss: 0.2981 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.3076 - accuracy: 0.5833 - val_loss: 0.3663 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.3019 - accuracy: 0.5857 - val_loss: 0.3108 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.3016 - accuracy: 0.5857 - val_loss: 0.2715 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2878 - accuracy: 0.5857 - val_loss: 0.2436 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2959 - accuracy: 0.5845 - val_loss: 0.2894 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.2840 - accuracy: 0.5857 - val_loss: 0.2450 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2846 - accuracy: 0.5869 - val_loss: 0.4116 - val_accuracy: 0.8148
# Epoch 16/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2847 - accuracy: 0.5857 - val_loss: 0.2946 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2907 - accuracy: 0.5845 - val_loss: 0.2953 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2792 - accuracy: 0.5869 - val_loss: 0.4377 - val_accuracy: 0.8148
# Epoch 19/100
# 27/27 [==============================] - 11s 390ms/step - loss: 0.2819 - accuracy: 0.5857 - val_loss: 0.4425 - val_accuracy: 0.7407
# Epoch 20/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2722 - accuracy: 0.5869 - val_loss: 0.2170 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2755 - accuracy: 0.5857 - val_loss: 0.2064 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2747 - accuracy: 0.5857 - val_loss: 0.2223 - val_accuracy: 0.8519
# Epoch 23/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2771 - accuracy: 0.5869 - val_loss: 0.2307 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2705 - accuracy: 0.5857 - val_loss: 0.1859 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.2723 - accuracy: 0.5869 - val_loss: 0.2348 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2693 - accuracy: 0.5869 - val_loss: 0.2459 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2775 - accuracy: 0.5869 - val_loss: 0.2333 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.2681 - accuracy: 0.5869 - val_loss: 0.2233 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2625 - accuracy: 0.5869 - val_loss: 0.2202 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 11s 392ms/step - loss: 0.2603 - accuracy: 0.5869 - val_loss: 0.2140 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2735 - accuracy: 0.5857 - val_loss: 0.1930 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2586 - accuracy: 0.5869 - val_loss: 0.2247 - val_accuracy: 0.8889
# Epoch 33/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2584 - accuracy: 0.5869 - val_loss: 0.2173 - val_accuracy: 0.8889
# Epoch 34/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2661 - accuracy: 0.5833 - val_loss: 0.2576 - val_accuracy: 0.8889
# Epoch 35/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2695 - accuracy: 0.5869 - val_loss: 0.2187 - val_accuracy: 0.9259
# Epoch 36/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2602 - accuracy: 0.5869 - val_loss: 0.2238 - val_accuracy: 0.8889
# Epoch 37/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2567 - accuracy: 0.5869 - val_loss: 0.2553 - val_accuracy: 0.8519
# Epoch 38/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2570 - accuracy: 0.5869 - val_loss: 0.2688 - val_accuracy: 0.8519
# Epoch 39/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2555 - accuracy: 0.5869 - val_loss: 0.2562 - val_accuracy: 0.8889
# 2/2 [==============================] - 1s 101ms/step - loss: 0.1510 - accuracy: 0.9118
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 16)         3904
#  l)
#
#  flatten (Flatten)           (None, 81920)             0
#
#  batch_normalization (BatchN  (None, 81920)            327680
#  ormalization)
#
#  dropout (Dropout)           (None, 81920)             0
#
#  dense (Dense)               (None, 256)               20971776
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 21,304,384
# Trainable params: 21,140,032
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               21304384
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 21,386,689
# Trainable params: 21,222,337
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 15s 435ms/step - loss: 0.5111 - accuracy: 0.5081 - val_loss: 0.7143 - val_accuracy: 0.7778
# Epoch 2/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.4009 - accuracy: 0.5532 - val_loss: 0.2162 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.3715 - accuracy: 0.5729 - val_loss: 0.1819 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.3468 - accuracy: 0.5718 - val_loss: 0.1726 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.3545 - accuracy: 0.5741 - val_loss: 0.1216 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.3300 - accuracy: 0.5822 - val_loss: 0.1815 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.3214 - accuracy: 0.5822 - val_loss: 0.1721 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3115 - accuracy: 0.5822 - val_loss: 0.1687 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 11s 392ms/step - loss: 0.3031 - accuracy: 0.5868 - val_loss: 0.1332 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3034 - accuracy: 0.5868 - val_loss: 0.1591 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.3046 - accuracy: 0.5856 - val_loss: 0.1204 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2965 - accuracy: 0.5856 - val_loss: 0.1297 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2903 - accuracy: 0.5880 - val_loss: 0.1180 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2879 - accuracy: 0.5856 - val_loss: 0.1134 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2910 - accuracy: 0.5856 - val_loss: 0.0938 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2853 - accuracy: 0.5845 - val_loss: 0.0982 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2776 - accuracy: 0.5880 - val_loss: 0.1500 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2786 - accuracy: 0.5845 - val_loss: 0.0759 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2854 - accuracy: 0.5856 - val_loss: 0.1267 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2797 - accuracy: 0.5868 - val_loss: 0.1317 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2722 - accuracy: 0.5880 - val_loss: 0.0934 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2699 - accuracy: 0.5880 - val_loss: 0.1174 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2701 - accuracy: 0.5880 - val_loss: 0.0802 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2701 - accuracy: 0.5880 - val_loss: 0.0832 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2681 - accuracy: 0.5880 - val_loss: 0.1230 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2685 - accuracy: 0.5880 - val_loss: 0.1040 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2758 - accuracy: 0.5880 - val_loss: 0.0920 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2727 - accuracy: 0.5880 - val_loss: 0.0794 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2737 - accuracy: 0.5880 - val_loss: 0.0735 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2676 - accuracy: 0.5880 - val_loss: 0.1164 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2657 - accuracy: 0.5868 - val_loss: 0.1042 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 11s 391ms/step - loss: 0.2677 - accuracy: 0.5880 - val_loss: 0.1042 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.2660 - accuracy: 0.5880 - val_loss: 0.1206 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.2780 - accuracy: 0.5880 - val_loss: 0.1062 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2602 - accuracy: 0.5880 - val_loss: 0.0880 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2578 - accuracy: 0.5880 - val_loss: 0.0791 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.2546 - accuracy: 0.5880 - val_loss: 0.1273 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2638 - accuracy: 0.5880 - val_loss: 0.1094 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.2589 - accuracy: 0.5880 - val_loss: 0.1220 - val_accuracy: 0.9630
# Epoch 40/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2603 - accuracy: 0.5880 - val_loss: 0.1282 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2569 - accuracy: 0.5880 - val_loss: 0.1143 - val_accuracy: 0.9630
# Epoch 42/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2580 - accuracy: 0.5868 - val_loss: 0.1490 - val_accuracy: 0.9630
# Epoch 43/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2550 - accuracy: 0.5880 - val_loss: 0.1598 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2578 - accuracy: 0.5880 - val_loss: 0.1415 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 95ms/step - loss: 0.0862 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 16)         3904
#  l)
#
#  flatten (Flatten)           (None, 81920)             0
#
#  batch_normalization (BatchN  (None, 81920)            327680
#  ormalization)
#
#  dropout (Dropout)           (None, 81920)             0
#
#  dense (Dense)               (None, 256)               20971776
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 21,304,384
# Trainable params: 21,140,032
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               21304384
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 21,386,689
# Trainable params: 21,222,337
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 15s 435ms/step - loss: 0.5183 - accuracy: 0.4873 - val_loss: 0.2525 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.4189 - accuracy: 0.5417 - val_loss: 0.2286 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 11s 391ms/step - loss: 0.3871 - accuracy: 0.5544 - val_loss: 0.1776 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3606 - accuracy: 0.5590 - val_loss: 0.1890 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.3398 - accuracy: 0.5706 - val_loss: 0.2260 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3232 - accuracy: 0.5706 - val_loss: 0.1621 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3390 - accuracy: 0.5718 - val_loss: 0.1381 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.3277 - accuracy: 0.5718 - val_loss: 0.1406 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.3206 - accuracy: 0.5729 - val_loss: 0.1601 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.3150 - accuracy: 0.5741 - val_loss: 0.1518 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.3168 - accuracy: 0.5752 - val_loss: 0.1097 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.3073 - accuracy: 0.5764 - val_loss: 0.1145 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2996 - accuracy: 0.5764 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2927 - accuracy: 0.5775 - val_loss: 0.1319 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.3038 - accuracy: 0.5775 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2919 - accuracy: 0.5787 - val_loss: 0.1090 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2973 - accuracy: 0.5775 - val_loss: 0.1246 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2846 - accuracy: 0.5787 - val_loss: 0.1102 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2801 - accuracy: 0.5787 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2740 - accuracy: 0.5787 - val_loss: 0.0689 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2821 - accuracy: 0.5775 - val_loss: 0.0768 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2905 - accuracy: 0.5752 - val_loss: 0.0981 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2897 - accuracy: 0.5775 - val_loss: 0.0702 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2847 - accuracy: 0.5787 - val_loss: 0.1038 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2831 - accuracy: 0.5764 - val_loss: 0.1158 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2780 - accuracy: 0.5787 - val_loss: 0.0799 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2829 - accuracy: 0.5775 - val_loss: 0.0720 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2700 - accuracy: 0.5787 - val_loss: 0.0756 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2756 - accuracy: 0.5787 - val_loss: 0.2101 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2699 - accuracy: 0.5787 - val_loss: 0.1082 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2703 - accuracy: 0.5787 - val_loss: 0.0933 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2723 - accuracy: 0.5787 - val_loss: 0.1145 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2709 - accuracy: 0.5787 - val_loss: 0.0947 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2720 - accuracy: 0.5787 - val_loss: 0.1265 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2739 - accuracy: 0.5787 - val_loss: 0.1758 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 100ms/step - loss: 0.1075 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 16)         3904
#  l)
#
#  flatten (Flatten)           (None, 81920)             0
#
#  batch_normalization (BatchN  (None, 81920)            327680
#  ormalization)
#
#  dropout (Dropout)           (None, 81920)             0
#
#  dense (Dense)               (None, 256)               20971776
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 21,304,384
# Trainable params: 21,140,032
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               21304384
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 21,386,689
# Trainable params: 21,222,337
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 436ms/step - loss: 0.6038 - accuracy: 0.4742 - val_loss: 0.6816 - val_accuracy: 0.5926
# Epoch 2/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.4260 - accuracy: 0.5317 - val_loss: 0.3042 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3881 - accuracy: 0.5446 - val_loss: 0.2402 - val_accuracy: 0.8889
# Epoch 4/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3679 - accuracy: 0.5540 - val_loss: 0.2868 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.3630 - accuracy: 0.5552 - val_loss: 0.2313 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3392 - accuracy: 0.5599 - val_loss: 0.1709 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.3229 - accuracy: 0.5610 - val_loss: 0.1719 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 11s 392ms/step - loss: 0.3292 - accuracy: 0.5599 - val_loss: 0.1837 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.3109 - accuracy: 0.5657 - val_loss: 0.1427 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.3163 - accuracy: 0.5610 - val_loss: 0.1405 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.3133 - accuracy: 0.5622 - val_loss: 0.1264 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.3218 - accuracy: 0.5575 - val_loss: 0.1496 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.3056 - accuracy: 0.5634 - val_loss: 0.1302 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.3049 - accuracy: 0.5599 - val_loss: 0.1326 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2922 - accuracy: 0.5657 - val_loss: 0.1061 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2895 - accuracy: 0.5622 - val_loss: 0.1344 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2939 - accuracy: 0.5634 - val_loss: 0.1053 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2885 - accuracy: 0.5646 - val_loss: 0.1075 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2905 - accuracy: 0.5657 - val_loss: 0.1103 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2963 - accuracy: 0.5657 - val_loss: 0.1025 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 11s 392ms/step - loss: 0.2779 - accuracy: 0.5657 - val_loss: 0.1165 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2905 - accuracy: 0.5657 - val_loss: 0.1468 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2824 - accuracy: 0.5657 - val_loss: 0.0900 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2784 - accuracy: 0.5657 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2756 - accuracy: 0.5657 - val_loss: 0.0980 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2727 - accuracy: 0.5657 - val_loss: 0.1165 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2805 - accuracy: 0.5646 - val_loss: 0.1168 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2848 - accuracy: 0.5657 - val_loss: 0.1140 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2850 - accuracy: 0.5646 - val_loss: 0.0973 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2749 - accuracy: 0.5657 - val_loss: 0.0895 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2726 - accuracy: 0.5657 - val_loss: 0.1196 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2838 - accuracy: 0.5646 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2815 - accuracy: 0.5657 - val_loss: 0.1106 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.2808 - accuracy: 0.5657 - val_loss: 0.1138 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2784 - accuracy: 0.5657 - val_loss: 0.0845 - val_accuracy: 0.9630
# Epoch 36/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2797 - accuracy: 0.5657 - val_loss: 0.0960 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2669 - accuracy: 0.5657 - val_loss: 0.1044 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 11s 403ms/step - loss: 0.2762 - accuracy: 0.5657 - val_loss: 0.0777 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.2722 - accuracy: 0.5657 - val_loss: 0.1047 - val_accuracy: 1.0000
# Epoch 40/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2650 - accuracy: 0.5657 - val_loss: 0.1205 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.2684 - accuracy: 0.5657 - val_loss: 0.1117 - val_accuracy: 1.0000
# Epoch 42/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2779 - accuracy: 0.5657 - val_loss: 0.1148 - val_accuracy: 0.9630
# Epoch 43/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2634 - accuracy: 0.5657 - val_loss: 0.1240 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2679 - accuracy: 0.5657 - val_loss: 0.1167 - val_accuracy: 0.9630
# Epoch 45/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2669 - accuracy: 0.5657 - val_loss: 0.0869 - val_accuracy: 0.9630
# Epoch 46/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2682 - accuracy: 0.5657 - val_loss: 0.1128 - val_accuracy: 1.0000
# Epoch 47/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2681 - accuracy: 0.5657 - val_loss: 0.1164 - val_accuracy: 0.9630
# Epoch 48/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2711 - accuracy: 0.5657 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 49/100
# 27/27 [==============================] - 11s 402ms/step - loss: 0.2674 - accuracy: 0.5657 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 50/100
# 27/27 [==============================] - 11s 402ms/step - loss: 0.2632 - accuracy: 0.5657 - val_loss: 0.0898 - val_accuracy: 1.0000
# Epoch 51/100
# 27/27 [==============================] - 11s 403ms/step - loss: 0.2637 - accuracy: 0.5657 - val_loss: 0.0651 - val_accuracy: 1.0000
# Epoch 52/100
# 27/27 [==============================] - 11s 402ms/step - loss: 0.2658 - accuracy: 0.5657 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 53/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.2636 - accuracy: 0.5657 - val_loss: 0.1216 - val_accuracy: 1.0000
# Epoch 54/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2599 - accuracy: 0.5657 - val_loss: 0.1120 - val_accuracy: 0.9630
# Epoch 55/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2613 - accuracy: 0.5657 - val_loss: 0.1215 - val_accuracy: 1.0000
# Epoch 56/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.2597 - accuracy: 0.5657 - val_loss: 0.1105 - val_accuracy: 1.0000
# Epoch 57/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2593 - accuracy: 0.5657 - val_loss: 0.1096 - val_accuracy: 1.0000
# Epoch 58/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2660 - accuracy: 0.5657 - val_loss: 0.1237 - val_accuracy: 0.9630
# Epoch 59/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2604 - accuracy: 0.5657 - val_loss: 0.1601 - val_accuracy: 0.8889
# Epoch 60/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2622 - accuracy: 0.5657 - val_loss: 0.1131 - val_accuracy: 0.9630
# Epoch 61/100
# 27/27 [==============================] - 11s 402ms/step - loss: 0.2634 - accuracy: 0.5657 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 62/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2655 - accuracy: 0.5657 - val_loss: 0.1604 - val_accuracy: 1.0000
# Epoch 63/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2618 - accuracy: 0.5657 - val_loss: 0.1583 - val_accuracy: 0.9630
# Epoch 64/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2615 - accuracy: 0.5657 - val_loss: 0.1292 - val_accuracy: 0.9630
# Epoch 65/100
# 27/27 [==============================] - 11s 402ms/step - loss: 0.2618 - accuracy: 0.5657 - val_loss: 0.1612 - val_accuracy: 0.9259
# Epoch 66/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2667 - accuracy: 0.5657 - val_loss: 0.1172 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 97ms/step - loss: 0.1710 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 16)         3904
#  l)
#
#  flatten (Flatten)           (None, 81920)             0
#
#  batch_normalization (BatchN  (None, 81920)            327680
#  ormalization)
#
#  dropout (Dropout)           (None, 81920)             0
#
#  dense (Dense)               (None, 256)               20971776
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 21,304,384
# Trainable params: 21,140,032
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               21304384
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 21,386,689
# Trainable params: 21,222,337
# Non-trainable params: 164,352
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 16s 438ms/step - loss: 0.5444 - accuracy: 0.5091 - val_loss: 0.2100 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.4033 - accuracy: 0.5590 - val_loss: 0.1919 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.3844 - accuracy: 0.5669 - val_loss: 0.2147 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.3503 - accuracy: 0.5828 - val_loss: 0.1362 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.3238 - accuracy: 0.5862 - val_loss: 0.1594 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.3120 - accuracy: 0.5941 - val_loss: 0.1608 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 11s 400ms/step - loss: 0.3034 - accuracy: 0.5975 - val_loss: 0.1648 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2980 - accuracy: 0.5930 - val_loss: 0.4208 - val_accuracy: 0.8148
# Epoch 9/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2953 - accuracy: 0.5998 - val_loss: 0.4260 - val_accuracy: 0.8148
# Epoch 10/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.2882 - accuracy: 0.5998 - val_loss: 0.2081 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.2877 - accuracy: 0.5975 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 11s 403ms/step - loss: 0.2868 - accuracy: 0.5941 - val_loss: 0.2097 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 11s 400ms/step - loss: 0.2782 - accuracy: 0.5975 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.2872 - accuracy: 0.5975 - val_loss: 0.0933 - val_accuracy: 0.9630
# Epoch 15/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.2712 - accuracy: 0.6009 - val_loss: 0.1626 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.2713 - accuracy: 0.6009 - val_loss: 0.1531 - val_accuracy: 0.9259
# Epoch 17/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.2655 - accuracy: 0.6009 - val_loss: 0.1314 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2648 - accuracy: 0.5986 - val_loss: 0.0650 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.2769 - accuracy: 0.6009 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 11s 400ms/step - loss: 0.2655 - accuracy: 0.6009 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.2671 - accuracy: 0.5998 - val_loss: 0.1024 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.2639 - accuracy: 0.5998 - val_loss: 0.0840 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.2682 - accuracy: 0.6009 - val_loss: 0.0951 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.2620 - accuracy: 0.6009 - val_loss: 0.1426 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.2670 - accuracy: 0.6009 - val_loss: 0.1050 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.2594 - accuracy: 0.5998 - val_loss: 0.0669 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.2679 - accuracy: 0.6009 - val_loss: 0.0932 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.2590 - accuracy: 0.6009 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2634 - accuracy: 0.6009 - val_loss: 0.0649 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2640 - accuracy: 0.5998 - val_loss: 0.0867 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2598 - accuracy: 0.6009 - val_loss: 0.1022 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2560 - accuracy: 0.6009 - val_loss: 0.2160 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.2638 - accuracy: 0.5986 - val_loss: 0.1369 - val_accuracy: 0.9259
# Epoch 34/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2507 - accuracy: 0.6009 - val_loss: 0.0736 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 112ms/step - loss: 0.2011 - accuracy: 0.9118
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f50df35be60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.9411764502525329]
# [0.9351481638044898]
# Epoch 1/100
# 28/28 [==============================] - 16s 432ms/step - loss: 0.5418 - accuracy: 0.5057 - val_loss: 0.3269 - val_accuracy: 0.9259
# Epoch 2/100
# 28/28 [==============================] - 11s 393ms/step - loss: 0.4125 - accuracy: 0.5471 - val_loss: 0.2155 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.3869 - accuracy: 0.5529 - val_loss: 0.2111 - val_accuracy: 0.9259
# Epoch 4/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.3705 - accuracy: 0.5690 - val_loss: 0.2683 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.3550 - accuracy: 0.5690 - val_loss: 0.1851 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 11s 400ms/step - loss: 0.3341 - accuracy: 0.5747 - val_loss: 0.1557 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.3234 - accuracy: 0.5793 - val_loss: 0.1640 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.3345 - accuracy: 0.5793 - val_loss: 0.1905 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.3199 - accuracy: 0.5793 - val_loss: 0.1707 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.3175 - accuracy: 0.5816 - val_loss: 0.1127 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.3210 - accuracy: 0.5782 - val_loss: 0.1015 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 11s 400ms/step - loss: 0.2986 - accuracy: 0.5828 - val_loss: 0.1631 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.3027 - accuracy: 0.5851 - val_loss: 0.2019 - val_accuracy: 0.9259
# Epoch 14/100
# ...
# Epoch 15/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3134 - accuracy: 0.5469 - val_loss: 0.1102 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 11s 390ms/step - loss: 0.3109 - accuracy: 0.5505 - val_loss: 0.1486 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 11s 390ms/step - loss: 0.3084 - accuracy: 0.5493 - val_loss: 0.1056 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 11s 392ms/step - loss: 0.3083 - accuracy: 0.5516 - val_loss: 0.0900 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 11s 393ms/step - loss: 0.3016 - accuracy: 0.5493 - val_loss: 0.0730 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 11s 390ms/step - loss: 0.3031 - accuracy: 0.5516 - val_loss: 0.1443 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 11s 391ms/step - loss: 0.3004 - accuracy: 0.5505 - val_loss: 0.1060 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2922 - accuracy: 0.5505 - val_loss: 0.1162 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2956 - accuracy: 0.5516 - val_loss: 0.2156 - val_accuracy: 0.8889
# Epoch 24/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2975 - accuracy: 0.5516 - val_loss: 0.1208 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2958 - accuracy: 0.5505 - val_loss: 0.1251 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2957 - accuracy: 0.5516 - val_loss: 0.0927 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2896 - accuracy: 0.5505 - val_loss: 0.1592 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2910 - accuracy: 0.5516 - val_loss: 0.1262 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2932 - accuracy: 0.5516 - val_loss: 0.1215 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2890 - accuracy: 0.5516 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2849 - accuracy: 0.5516 - val_loss: 0.0906 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2845 - accuracy: 0.5516 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2823 - accuracy: 0.5516 - val_loss: 0.0805 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2925 - accuracy: 0.5516 - val_loss: 0.0595 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2858 - accuracy: 0.5516 - val_loss: 0.0856 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2875 - accuracy: 0.5516 - val_loss: 0.0708 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2839 - accuracy: 0.5505 - val_loss: 0.1151 - val_accuracy: 1.0000
# Epoch 38/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2879 - accuracy: 0.5516 - val_loss: 0.1457 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2772 - accuracy: 0.5516 - val_loss: 0.1298 - val_accuracy: 0.9630
# Epoch 40/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2831 - accuracy: 0.5516 - val_loss: 0.0758 - val_accuracy: 1.0000
# Epoch 41/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2814 - accuracy: 0.5516 - val_loss: 0.1094 - val_accuracy: 1.0000
# Epoch 42/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2734 - accuracy: 0.5516 - val_loss: 0.1068 - val_accuracy: 1.0000
# Epoch 43/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2790 - accuracy: 0.5516 - val_loss: 0.0924 - val_accuracy: 1.0000
# Epoch 44/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2784 - accuracy: 0.5516 - val_loss: 0.0892 - val_accuracy: 0.9630
# Epoch 45/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2711 - accuracy: 0.5516 - val_loss: 0.1348 - val_accuracy: 0.9259
# Epoch 46/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2775 - accuracy: 0.5516 - val_loss: 0.1054 - val_accuracy: 0.9630
# Epoch 47/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2744 - accuracy: 0.5516 - val_loss: 0.0931 - val_accuracy: 1.0000
# Epoch 48/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.2773 - accuracy: 0.5516 - val_loss: 0.0989 - val_accuracy: 0.9630
# Epoch 49/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.2717 - accuracy: 0.5516 - val_loss: 0.0987 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 99ms/step - loss: 0.0781 - accuracy: 1.0000
# Epoch 1/100
# 28/28 [==============================] - 16s 431ms/step - loss: 0.5447 - accuracy: 0.5113 - val_loss: 0.4162 - val_accuracy: 0.8148
# Epoch 2/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.4101 - accuracy: 0.5680 - val_loss: 0.2453 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 11s 394ms/step - loss: 0.3769 - accuracy: 0.5714 - val_loss: 0.2468 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.3579 - accuracy: 0.5782 - val_loss: 0.2382 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 11s 400ms/step - loss: 0.3432 - accuracy: 0.5805 - val_loss: 0.2744 - val_accuracy: 0.9259
# Epoch 6/100
# 28/28 [==============================] - 11s 400ms/step - loss: 0.3236 - accuracy: 0.5907 - val_loss: 0.2044 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.3154 - accuracy: 0.5930 - val_loss: 0.1695 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.3041 - accuracy: 0.5964 - val_loss: 0.2072 - val_accuracy: 0.9259
# Epoch 9/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.2931 - accuracy: 0.5986 - val_loss: 0.1687 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.3070 - accuracy: 0.5941 - val_loss: 0.2564 - val_accuracy: 0.8889
# Epoch 11/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.2901 - accuracy: 0.5952 - val_loss: 0.1730 - val_accuracy: 0.8889
# Epoch 12/100
# 28/28 [==============================] - 11s 399ms/step - loss: 0.2884 - accuracy: 0.5975 - val_loss: 0.1323 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.2893 - accuracy: 0.5986 - val_loss: 0.1373 - val_accuracy: 1.0000
# Epoch 14/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.3012 - accuracy: 0.5952 - val_loss: 0.0960 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 11s 398ms/step - loss: 0.2901 - accuracy: 0.5986 - val_loss: 0.1251 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2849 - accuracy: 0.5975 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 11s 397ms/step - loss: 0.2923 - accuracy: 0.5964 - val_loss: 0.2051 - val_accuracy: 0.8889
# Epoch 18/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.2757 - accuracy: 0.5986 - val_loss: 0.1407 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 11s 401ms/step - loss: 0.2696 - accuracy: 0.5986 - val_loss: 0.1550 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 11s 394ms/step - loss: 0.2715 - accuracy: 0.5986 - val_loss: 0.1526 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 11s 388ms/step - loss: 0.2794 - accuracy: 0.5986 - val_loss: 0.1459 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 11s 392ms/step - loss: 0.2670 - accuracy: 0.5975 - val_loss: 0.1205 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.2641 - accuracy: 0.5986 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 11s 391ms/step - loss: 0.2638 - accuracy: 0.5975 - val_loss: 0.0959 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 11s 392ms/step - loss: 0.2677 - accuracy: 0.5975 - val_loss: 0.0971 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 11s 396ms/step - loss: 0.2727 - accuracy: 0.5975 - val_loss: 0.1352 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 11s 390ms/step - loss: 0.2640 - accuracy: 0.5986 - val_loss: 0.1215 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 11s 391ms/step - loss: 0.2674 - accuracy: 0.5986 - val_loss: 0.1824 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 11s 388ms/step - loss: 0.2622 - accuracy: 0.5986 - val_loss: 0.2032 - val_accuracy: 0.8889
# Epoch 30/100
# 28/28 [==============================] - 11s 395ms/step - loss: 0.2629 - accuracy: 0.5986 - val_loss: 0.1740 - val_accuracy: 0.8889
# Epoch 31/100
# 28/28 [==============================] - 11s 388ms/step - loss: 0.2661 - accuracy: 0.5986 - val_loss: 0.1424 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 101ms/step - loss: 0.0947 - accuracy: 1.0000
# Epoch 1/100
# 27/27 [==============================] - 16s 431ms/step - loss: 0.4658 - accuracy: 0.5163 - val_loss: 0.2086 - val_accuracy: 0.9259
# Epoch 2/100
# 27/27 [==============================] - 11s 394ms/step - loss: 0.3940 - accuracy: 0.5629 - val_loss: 0.2873 - val_accuracy: 0.8889
# Epoch 3/100
# 27/27 [==============================] - 11s 390ms/step - loss: 0.3615 - accuracy: 0.5699 - val_loss: 0.1843 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 11s 395ms/step - loss: 0.3538 - accuracy: 0.5804 - val_loss: 0.1898 - val_accuracy: 0.9259
# Epoch 5/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.3282 - accuracy: 0.5874 - val_loss: 0.1869 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.3265 - accuracy: 0.5886 - val_loss: 0.2203 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.3144 - accuracy: 0.5874 - val_loss: 0.2196 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.3020 - accuracy: 0.5932 - val_loss: 0.2017 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 11s 402ms/step - loss: 0.2975 - accuracy: 0.5921 - val_loss: 0.1558 - val_accuracy: 1.0000
# Epoch 10/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2992 - accuracy: 0.5921 - val_loss: 0.2128 - val_accuracy: 0.8889
# Epoch 11/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2991 - accuracy: 0.5897 - val_loss: 0.1772 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2827 - accuracy: 0.5944 - val_loss: 0.1633 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2827 - accuracy: 0.5944 - val_loss: 0.1899 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2800 - accuracy: 0.5944 - val_loss: 0.2000 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.2870 - accuracy: 0.5897 - val_loss: 0.1678 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2853 - accuracy: 0.5944 - val_loss: 0.1256 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2943 - accuracy: 0.5932 - val_loss: 0.1735 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2766 - accuracy: 0.5932 - val_loss: 0.1594 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2814 - accuracy: 0.5932 - val_loss: 0.2058 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2738 - accuracy: 0.5932 - val_loss: 0.2075 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2838 - accuracy: 0.5932 - val_loss: 0.1507 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.2665 - accuracy: 0.5944 - val_loss: 0.1299 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2680 - accuracy: 0.5944 - val_loss: 0.1294 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 11s 401ms/step - loss: 0.2719 - accuracy: 0.5932 - val_loss: 0.0996 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2682 - accuracy: 0.5932 - val_loss: 0.1479 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2626 - accuracy: 0.5932 - val_loss: 0.1356 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2617 - accuracy: 0.5944 - val_loss: 0.2193 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2556 - accuracy: 0.5944 - val_loss: 0.1113 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2625 - accuracy: 0.5944 - val_loss: 0.1550 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2536 - accuracy: 0.5944 - val_loss: 0.2320 - val_accuracy: 0.8519
# Epoch 32/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2641 - accuracy: 0.5932 - val_loss: 0.1314 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 11s 398ms/step - loss: 0.2602 - accuracy: 0.5944 - val_loss: 0.2180 - val_accuracy: 0.8889
# Epoch 34/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2659 - accuracy: 0.5944 - val_loss: 0.1057 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2603 - accuracy: 0.5944 - val_loss: 0.1210 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 11s 397ms/step - loss: 0.2530 - accuracy: 0.5944 - val_loss: 0.1845 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2531 - accuracy: 0.5944 - val_loss: 0.1392 - val_accuracy: 1.0000
# Epoch 38/100
# 27/27 [==============================] - 11s 396ms/step - loss: 0.2547 - accuracy: 0.5944 - val_loss: 0.1675 - val_accuracy: 0.9630
# Epoch 39/100
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2536 - accuracy: 0.5944 - val_loss: 0.1681 - val_accuracy: 0.9259
# Epoch 40/100
# 27/27 [==============================] - 11s 399ms/step - loss: 0.2553 - accuracy: 0.5944 - val_loss: 0.1529 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 103ms/step - loss: 0.1022 - accuracy: 1.0000
# [0.9411764502525329, 0.970588219165802, 0.9529411673545838, 0.9647058606147766, 0.9764705896377563]
# [0.9351481638044898, 0.9667720351392877, 0.9435444366508197, 0.9596211620633452, 0.9729545454545455]
# Mean test accuracy is 0.96, mean test f1 score is 0.96, max test accuracy is 0.98, max test f1 score is 0.97, min test accuracy is 0.94, min test f1 score is 0.94, std of test accuracy is 0.01, std of test f1 score is 0.01
# Time elapsed through all process: 11400.98, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.961, mean test f1 score is 0.956, max test accuracy is 0.976, max test f1 score is 0.973, min test accuracy is 0.941, min test f1 score is 0.935, std of test accuracy is 0.013, std of test f1 score is 0.014
