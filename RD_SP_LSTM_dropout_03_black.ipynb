# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/Range-Doppler-Spectrogram-LSTM/RD_SP_LSTM_dropout_03_black.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# dropout0.3

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number =   100 # 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.3 # 0.
repeat_of_mixup = 5
number_of_repeat = 5
unit_number_of_lstm = 16 #8 16 32
dense_unit_of_range_doppler_function = 256 #128 256 512
dense_unit_of_spectrogram_function = 8
decoder_dense_unit = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_range_doppler_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def lstm_encoder_network_2(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_spectrogram_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense_unit)(input)
      x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_lstm(range_doppler_input)

    input_shape = spectrogram_concat_shuffle_train.shape[1:3]
    base_network_lstm_2 = lstm_encoder_network_2(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_lstm_2(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(base_network_lstm_2.summary())
      print(base_decoder_network.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image, spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler, validation_spectrogram) , (spectrogram_validation_labels)))
    #plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'],color="black")
    #plt.title('model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('epoch')
    plt.legend(['Validation Accuracy'], loc='right')
    #plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='right')
    plt.show()
    # summarize history for loss
    # plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'],color="black")
    #plt.title('model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Validation Loss'], loc='upper right')
    plt.show()


    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    print(confusion_matrix(range_doppler_concat_label_shuffle_test, y_test_predicted_binary))
    print(classification_report(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, digits=3))


    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 19s 417ms/step - loss: 0.4268 - accuracy: 0.5455 - val_loss: 0.1854 - val_accuracy: 0.9259
# Epoch 2/100
# 27/27 [==============================] - 9s 348ms/step - loss: 0.3415 - accuracy: 0.5839 - val_loss: 0.1972 - val_accuracy: 0.9259
# Epoch 3/100
# 27/27 [==============================] - 9s 347ms/step - loss: 0.3121 - accuracy: 0.5967 - val_loss: 0.1956 - val_accuracy: 0.8519
# Epoch 4/100
# 27/27 [==============================] - 9s 350ms/step - loss: 0.3078 - accuracy: 0.5967 - val_loss: 0.1485 - val_accuracy: 1.0000
# Epoch 5/100
# 27/27 [==============================] - 9s 349ms/step - loss: 0.2960 - accuracy: 0.5979 - val_loss: 0.1130 - val_accuracy: 1.0000
# Epoch 6/100
# 27/27 [==============================] - 9s 347ms/step - loss: 0.2724 - accuracy: 0.6002 - val_loss: 0.1552 - val_accuracy: 0.9630
# Epoch 7/100
# 27/27 [==============================] - 10s 361ms/step - loss: 0.2799 - accuracy: 0.5967 - val_loss: 0.1072 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 9s 346ms/step - loss: 0.2664 - accuracy: 0.6014 - val_loss: 0.1446 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 9s 346ms/step - loss: 0.2661 - accuracy: 0.6002 - val_loss: 0.2107 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 9s 349ms/step - loss: 0.2572 - accuracy: 0.6014 - val_loss: 0.2108 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 9s 350ms/step - loss: 0.2550 - accuracy: 0.6014 - val_loss: 0.0700 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 9s 351ms/step - loss: 0.2638 - accuracy: 0.6014 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 9s 349ms/step - loss: 0.2533 - accuracy: 0.6014 - val_loss: 0.0776 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 9s 348ms/step - loss: 0.2534 - accuracy: 0.6014 - val_loss: 0.1252 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 347ms/step - loss: 0.2549 - accuracy: 0.6014 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 9s 347ms/step - loss: 0.2545 - accuracy: 0.6014 - val_loss: 0.1667 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 9s 348ms/step - loss: 0.2493 - accuracy: 0.6014 - val_loss: 0.1684 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 9s 352ms/step - loss: 0.2478 - accuracy: 0.6014 - val_loss: 0.0845 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 348ms/step - loss: 0.2456 - accuracy: 0.6014 - val_loss: 0.0804 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 9s 350ms/step - loss: 0.2400 - accuracy: 0.6014 - val_loss: 0.1316 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 348ms/step - loss: 0.2454 - accuracy: 0.6014 - val_loss: 0.1175 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 349ms/step - loss: 0.2397 - accuracy: 0.6014 - val_loss: 0.0978 - val_accuracy: 0.9630
# Epoch 23/100
# 27/27 [==============================] - 9s 349ms/step - loss: 0.2375 - accuracy: 0.6014 - val_loss: 0.0939 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 9s 345ms/step - loss: 0.2519 - accuracy: 0.6014 - val_loss: 0.2017 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 9s 346ms/step - loss: 0.2453 - accuracy: 0.6014 - val_loss: 0.0673 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 9s 350ms/step - loss: 0.2427 - accuracy: 0.6014 - val_loss: 0.0794 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 9s 349ms/step - loss: 0.2378 - accuracy: 0.6014 - val_loss: 0.0836 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 126ms/step - loss: 0.2219 - accuracy: 0.9118
# [[23  0]
#  [ 3  8]]
#               precision    recall  f1-score   support
#
#          0.0      0.885     1.000     0.939        23
#          1.0      1.000     0.727     0.842        11
#
#     accuracy                          0.912        34
#    macro avg      0.942     0.864     0.890        34
# weighted avg      0.922     0.912     0.907        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 20s 415ms/step - loss: 0.4359 - accuracy: 0.5317 - val_loss: 0.2825 - val_accuracy: 0.8889
# Epoch 2/100
# 28/28 [==============================] - 10s 351ms/step - loss: 0.3486 - accuracy: 0.5703 - val_loss: 0.2355 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 10s 347ms/step - loss: 0.3120 - accuracy: 0.5850 - val_loss: 0.2718 - val_accuracy: 0.8148
# Epoch 4/100
# 28/28 [==============================] - 10s 353ms/step - loss: 0.3163 - accuracy: 0.5805 - val_loss: 0.2075 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 10s 352ms/step - loss: 0.3010 - accuracy: 0.5862 - val_loss: 0.1787 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 10s 343ms/step - loss: 0.2873 - accuracy: 0.5839 - val_loss: 0.2612 - val_accuracy: 0.8889
# Epoch 7/100
# 28/28 [==============================] - 10s 345ms/step - loss: 0.2877 - accuracy: 0.5862 - val_loss: 0.2239 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 10s 345ms/step - loss: 0.2761 - accuracy: 0.5862 - val_loss: 0.3060 - val_accuracy: 0.8889
# Epoch 9/100
100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2423 - accuracy: 0.5873 - val_loss: 0.1179 - val_accuracy: 0.9630
# Epoch 50/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2367 - accuracy: 0.5873 - val_loss: 0.1722 - val_accuracy: 0.9630
# Epoch 51/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.2372 - accuracy: 0.5873 - val_loss: 0.1585 - val_accuracy: 0.9630
# Epoch 52/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2304 - accuracy: 0.5873 - val_loss: 0.1702 - val_accuracy: 0.9630
# Epoch 53/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2330 - accuracy: 0.5873 - val_loss: 0.1624 - val_accuracy: 0.9630
# Epoch 54/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2408 - accuracy: 0.5873 - val_loss: 0.1643 - val_accuracy: 0.9630
# Epoch 55/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2389 - accuracy: 0.5873 - val_loss: 0.1687 - val_accuracy: 0.9630
# Epoch 56/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2321 - accuracy: 0.5873 - val_loss: 0.2032 - val_accuracy: 0.9259
# Epoch 57/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2335 - accuracy: 0.5873 - val_loss: 0.1519 - val_accuracy: 0.9630
# Epoch 58/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2377 - accuracy: 0.5873 - val_loss: 0.1375 - val_accuracy: 0.9630
# Epoch 59/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2331 - accuracy: 0.5873 - val_loss: 0.1917 - val_accuracy: 0.9630
# Epoch 60/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2313 - accuracy: 0.5873 - val_loss: 0.1992 - val_accuracy: 0.9259
# Epoch 61/100
# 28/28 [==============================] - 9s 338ms/step - loss: 0.2312 - accuracy: 0.5873 - val_loss: 0.1500 - val_accuracy: 0.9259
# Epoch 62/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2299 - accuracy: 0.5873 - val_loss: 0.1803 - val_accuracy: 0.8889
# Epoch 63/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2295 - accuracy: 0.5873 - val_loss: 0.1527 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 105ms/step - loss: 0.0802 - accuracy: 0.9706
# [[23  0]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.958     1.000     0.979        23
#          1.0      1.000     0.909     0.952        11
#
#     accuracy                          0.971        34
#    macro avg      0.979     0.955     0.966        34
# weighted avg      0.972     0.971     0.970        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 19s 405ms/step - loss: 0.4256 - accuracy: 0.5420 - val_loss: 1.5089 - val_accuracy: 0.5926
# Epoch 2/100
# 27/27 [==============================] - 9s 336ms/step - loss: 0.3397 - accuracy: 0.5851 - val_loss: 0.8527 - val_accuracy: 0.6667
# Epoch 3/100
# 27/27 [==============================] - 9s 336ms/step - loss: 0.3325 - accuracy: 0.5815 - val_loss: 0.2445 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.3030 - accuracy: 0.5899 - val_loss: 0.4089 - val_accuracy: 0.8148
# Epoch 5/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.3005 - accuracy: 0.5911 - val_loss: 0.5196 - val_accuracy: 0.7407
# Epoch 6/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.3063 - accuracy: 0.5863 - val_loss: 0.5293 - val_accuracy: 0.7407
# Epoch 7/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3092 - accuracy: 0.5923 - val_loss: 0.3610 - val_accuracy: 0.8519
# Epoch 8/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2818 - accuracy: 0.5947 - val_loss: 0.3757 - val_accuracy: 0.8148
# Epoch 9/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2932 - accuracy: 0.5947 - val_loss: 0.2356 - val_accuracy: 0.8889
# Epoch 10/100
# 27/27 [==============================] - 9s 338ms/step - loss: 0.2871 - accuracy: 0.5935 - val_loss: 0.1807 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2748 - accuracy: 0.5959 - val_loss: 0.4219 - val_accuracy: 0.8148
# Epoch 12/100
# 27/27 [==============================] - 9s 338ms/step - loss: 0.2718 - accuracy: 0.5959 - val_loss: 0.1586 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2719 - accuracy: 0.5971 - val_loss: 0.2316 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2762 - accuracy: 0.5971 - val_loss: 0.2707 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2719 - accuracy: 0.5959 - val_loss: 0.2648 - val_accuracy: 0.8519
# Epoch 16/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2655 - accuracy: 0.5935 - val_loss: 0.4270 - val_accuracy: 0.8148
# Epoch 17/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2672 - accuracy: 0.5971 - val_loss: 0.3458 - val_accuracy: 0.8148
# Epoch 18/100
# 27/27 [==============================] - 9s 338ms/step - loss: 0.2702 - accuracy: 0.5959 - val_loss: 0.1438 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2692 - accuracy: 0.5959 - val_loss: 0.1973 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2688 - accuracy: 0.5971 - val_loss: 0.2652 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2578 - accuracy: 0.5971 - val_loss: 0.1638 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2562 - accuracy: 0.5971 - val_loss: 0.2422 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2580 - accuracy: 0.5971 - val_loss: 0.2135 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 9s 336ms/step - loss: 0.2620 - accuracy: 0.5947 - val_loss: 0.1404 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2661 - accuracy: 0.5971 - val_loss: 0.2788 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2602 - accuracy: 0.5959 - val_loss: 0.3371 - val_accuracy: 0.8889
# Epoch 27/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2633 - accuracy: 0.5959 - val_loss: 0.2890 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2620 - accuracy: 0.5971 - val_loss: 0.3558 - val_accuracy: 0.8519
# Epoch 29/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2531 - accuracy: 0.5971 - val_loss: 0.2875 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2617 - accuracy: 0.5947 - val_loss: 0.2237 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 9s 326ms/step - loss: 0.2617 - accuracy: 0.5959 - val_loss: 0.2782 - val_accuracy: 0.8889
# Epoch 32/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2536 - accuracy: 0.5971 - val_loss: 0.2620 - val_accuracy: 0.8889
# Epoch 33/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2516 - accuracy: 0.5971 - val_loss: 0.1442 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2496 - accuracy: 0.5959 - val_loss: 0.1559 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2480 - accuracy: 0.5971 - val_loss: 0.2024 - val_accuracy: 0.9259
# Epoch 36/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2485 - accuracy: 0.5971 - val_loss: 0.2034 - val_accuracy: 0.9259
# Epoch 37/100
# 27/27 [==============================] - 9s 328ms/step - loss: 0.2485 - accuracy: 0.5971 - val_loss: 0.1747 - val_accuracy: 0.9259
# Epoch 38/100
# 27/27 [==============================] - 9s 329ms/step - loss: 0.2547 - accuracy: 0.5971 - val_loss: 0.2043 - val_accuracy: 0.9259
# Epoch 39/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2499 - accuracy: 0.5971 - val_loss: 0.2324 - val_accuracy: 0.9259
# 2/2 [==============================] - 2s 113ms/step - loss: 0.0939 - accuracy: 0.9706
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2756092d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[22  1]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#          0.0      1.000     0.957     0.978        23
#          1.0      0.917     1.000     0.957        11
#
#     accuracy                          0.971        34
#    macro avg      0.958     0.978     0.967        34
# weighted avg      0.973     0.971     0.971        34
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 8)                 108296
#
#  batch_normalization_3 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_1 (Activation)   (None, 8)                 0
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
# =================================================================
# Total params: 171,304
# Trainable params: 144,216
# Non-trainable params: 27,088
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 264)]             0
#
#  dense_2 (Dense)             (None, 256)               67840
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 85,377
# Trainable params: 84,865
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 20s 407ms/step - loss: 0.4737 - accuracy: 0.5205 - val_loss: 0.3918 - val_accuracy: 0.8519
# Epoch 2/100
# 28/28 [==============================] - 9s 338ms/step - loss: 0.3683 - accuracy: 0.5674 - val_loss: 0.2340 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.3174 - accuracy: 0.5833 - val_loss: 0.3019 - val_accuracy: 0.8519
# Epoch 4/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.3148 - accuracy: 0.5890 - val_loss: 0.1357 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.3103 - accuracy: 0.5856 - val_loss: 0.1211 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2994 - accuracy: 0.5902 - val_loss: 0.1435 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2824 - accuracy: 0.5902 - val_loss: 0.1313 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2795 - accuracy: 0.5936 - val_loss: 0.1215 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.2852 - accuracy: 0.5925 - val_loss: 0.1857 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.2800 - accuracy: 0.5925 - val_loss: 0.1170 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.2670 - accuracy: 0.5936 - val_loss: 0.1417 - val_accuracy: 0.8889
# Epoch 12/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.2642 - accuracy: 0.5925 - val_loss: 0.1013 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2610 - accuracy: 0.5936 - val_loss: 0.1034 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2667 - accuracy: 0.5936 - val_loss: 0.1712 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2623 - accuracy: 0.5936 - val_loss: 0.1088 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2636 - accuracy: 0.5936 - val_loss: 0.1310 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2585 - accuracy: 0.5936 - val_loss: 0.0795 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2548 - accuracy: 0.5925 - val_loss: 0.0816 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.2530 - accuracy: 0.5936 - val_loss: 0.0941 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2579 - accuracy: 0.5925 - val_loss: 0.1432 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2575 - accuracy: 0.5936 - val_loss: 0.0942 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2524 - accuracy: 0.5936 - val_loss: 0.0900 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2556 - accuracy: 0.5936 - val_loss: 0.0890 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.2513 - accuracy: 0.5936 - val_loss: 0.0973 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2579 - accuracy: 0.5936 - val_loss: 0.1125 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2545 - accuracy: 0.5936 - val_loss: 0.0862 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2475 - accuracy: 0.5925 - val_loss: 0.0810 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2546 - accuracy: 0.5936 - val_loss: 0.1390 - val_accuracy: 0.8889
# Epoch 29/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2491 - accuracy: 0.5936 - val_loss: 0.0947 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2448 - accuracy: 0.5936 - val_loss: 0.0917 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2493 - accuracy: 0.5936 - val_loss: 0.1148 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 9s 338ms/step - loss: 0.2485 - accuracy: 0.5936 - val_loss: 0.0700 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2446 - accuracy: 0.5936 - val_loss: 0.0734 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2432 - accuracy: 0.5936 - val_loss: 0.0769 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2377 - accuracy: 0.5936 - val_loss: 0.1067 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2441 - accuracy: 0.5936 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2488 - accuracy: 0.5936 - val_loss: 0.1081 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2411 - accuracy: 0.5936 - val_loss: 0.1189 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2451 - accuracy: 0.5936 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 40/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2454 - accuracy: 0.5925 - val_loss: 0.1040 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2455 - accuracy: 0.5936 - val_loss: 0.0837 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2385 - accuracy: 0.5936 - val_loss: 0.0717 - val_accuracy: 0.9630
# Epoch 43/100
# ...
# Epoch 18/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2595 - accuracy: 0.5977 - val_loss: 0.1124 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2741 - accuracy: 0.5943 - val_loss: 0.1123 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2591 - accuracy: 0.5977 - val_loss: 0.1011 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2598 - accuracy: 0.5977 - val_loss: 0.1111 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2515 - accuracy: 0.5977 - val_loss: 0.1442 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2537 - accuracy: 0.5977 - val_loss: 0.2142 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2545 - accuracy: 0.5966 - val_loss: 0.1277 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2466 - accuracy: 0.5977 - val_loss: 0.1030 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2496 - accuracy: 0.5977 - val_loss: 0.1234 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2547 - accuracy: 0.5977 - val_loss: 0.0744 - val_accuracy: 1.0000
# Epoch 28/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2606 - accuracy: 0.5977 - val_loss: 0.0992 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2524 - accuracy: 0.5977 - val_loss: 0.0970 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2428 - accuracy: 0.5977 - val_loss: 0.1239 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2452 - accuracy: 0.5977 - val_loss: 0.0692 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2479 - accuracy: 0.5977 - val_loss: 0.0527 - val_accuracy: 1.0000
# Epoch 33/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2461 - accuracy: 0.5977 - val_loss: 0.1405 - val_accuracy: 1.0000
# Epoch 34/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2442 - accuracy: 0.5977 - val_loss: 0.1340 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2473 - accuracy: 0.5977 - val_loss: 0.2219 - val_accuracy: 0.8889
# Epoch 36/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2388 - accuracy: 0.5977 - val_loss: 0.1534 - val_accuracy: 1.0000
# Epoch 37/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2594 - accuracy: 0.5966 - val_loss: 0.1088 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2541 - accuracy: 0.5977 - val_loss: 0.1147 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2467 - accuracy: 0.5966 - val_loss: 0.1080 - val_accuracy: 1.0000
# Epoch 40/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2412 - accuracy: 0.5977 - val_loss: 0.1181 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2448 - accuracy: 0.5977 - val_loss: 0.1380 - val_accuracy: 1.0000
# Epoch 42/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2439 - accuracy: 0.5977 - val_loss: 0.1339 - val_accuracy: 0.9259
# Epoch 43/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2492 - accuracy: 0.5977 - val_loss: 0.1233 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2406 - accuracy: 0.5977 - val_loss: 0.1267 - val_accuracy: 0.9630
# Epoch 45/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2506 - accuracy: 0.5977 - val_loss: 0.1708 - val_accuracy: 0.9630
# Epoch 46/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2406 - accuracy: 0.5977 - val_loss: 0.1716 - val_accuracy: 0.9259
# Epoch 47/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2371 - accuracy: 0.5977 - val_loss: 0.1554 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 105ms/step - loss: 0.1220 - accuracy: 0.9412
# [[22  1]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.957     0.957     0.957        23
#          1.0      0.909     0.909     0.909        11
#
#     accuracy                          0.941        34
#    macro avg      0.933     0.933     0.933        34
# weighted avg      0.941     0.941     0.941        34
#
# Epoch 1/100
# 28/28 [==============================] - 20s 409ms/step - loss: 0.4477 - accuracy: 0.5402 - val_loss: 0.5768 - val_accuracy: 0.8148
# Epoch 2/100
# 28/28 [==============================] - 10s 341ms/step - loss: 0.3583 - accuracy: 0.5747 - val_loss: 0.3918 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 9s 339ms/step - loss: 0.3597 - accuracy: 0.5828 - val_loss: 0.1960 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 9s 339ms/step - loss: 0.3203 - accuracy: 0.5897 - val_loss: 0.1859 - val_accuracy: 0.9259
# Epoch 5/100
# 28/28 [==============================] - 10s 340ms/step - loss: 0.3067 - accuracy: 0.5966 - val_loss: 0.1209 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2964 - accuracy: 0.5977 - val_loss: 0.1554 - val_accuracy: 1.0000
# Epoch 7/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2968 - accuracy: 0.5989 - val_loss: 0.1368 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 10s 340ms/step - loss: 0.2819 - accuracy: 0.6000 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 10s 342ms/step - loss: 0.2689 - accuracy: 0.6011 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 339ms/step - loss: 0.2696 - accuracy: 0.6023 - val_loss: 0.0721 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2636 - accuracy: 0.6023 - val_loss: 0.0762 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2630 - accuracy: 0.6023 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2627 - accuracy: 0.6023 - val_loss: 0.0810 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 338ms/step - loss: 0.2622 - accuracy: 0.6011 - val_loss: 0.0899 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 10s 340ms/step - loss: 0.2561 - accuracy: 0.6023 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 16/100
- val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 9s 337ms/step - loss: 0.2527 - accuracy: 0.5874 - val_loss: 0.1336 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 9s 337ms/step - loss: 0.2490 - accuracy: 0.5874 - val_loss: 0.1411 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 9s 336ms/step - loss: 0.2571 - accuracy: 0.5874 - val_loss: 0.1406 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 339ms/step - loss: 0.2554 - accuracy: 0.5874 - val_loss: 0.1464 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 9s 339ms/step - loss: 0.2529 - accuracy: 0.5874 - val_loss: 0.2824 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2490 - accuracy: 0.5874 - val_loss: 0.0927 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 9s 337ms/step - loss: 0.2410 - accuracy: 0.5874 - val_loss: 0.1256 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 9s 336ms/step - loss: 0.2522 - accuracy: 0.5874 - val_loss: 0.1436 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2441 - accuracy: 0.5874 - val_loss: 0.1355 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 9s 338ms/step - loss: 0.2491 - accuracy: 0.5874 - val_loss: 0.1732 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 9s 336ms/step - loss: 0.2439 - accuracy: 0.5874 - val_loss: 0.1261 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 134ms/step - loss: 0.1645 - accuracy: 0.9412
# [[22  0]
#  [ 2 10]]
#               precision    recall  f1-score   support
#
#          0.0      0.917     1.000     0.957        22
#          1.0      1.000     0.833     0.909        12
#
#     accuracy                          0.941        34
#    macro avg      0.958     0.917     0.933        34
# weighted avg      0.946     0.941     0.940        34
#
# [0.970588219165802, 0.970588219165802, 0.9470588088035583, 0.9764705777168274, 0.9529411673545838]
# [0.964628464690646, 0.9651646403242147, 0.9375383610119966, 0.9723737206877818, 0.9451767343048564]
# Mean test accuracy is 0.964, mean test f1 score is 0.957, max test accuracy is 0.976, max test f1 score is 0.972, min test accuracy is 0.947, min test f1 score is 0.938, std of test accuracy is 0.011, std of test f1 score is 0.013
# Time elapsed through all process: 8735.194, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8fe932ef83cc> in <module>()
# ----> 1 print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
#       2 print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
#
# NameError: name 'test_accuracy_per_run' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
def createList(n):
    lst = []
    for i in range(n+1):
        lst.append(i)
    return(lst)


folds = createList(4)
values = [element * 100 for element in test_accuracy_per_fold]

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(folds, values, color ='black',
        width = 0.4)
plt.xlabel("Accuracy vs k-run")
plt.ylabel("Accuracy")
plt.show()

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(folds, f1_score_per_fold, color ='black',
        width = 0.4)
plt.xlabel("F1 Score vs k-run")
plt.ylabel("F1 Score")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1f2f720b1167> in <module>()
#      10
#      11 folds = createList(4)
# ---> 12 values = [element * 100 for element in test_accuracy_per_fold]
#      13
#      14 fig = plt.figure(figsize = (10, 5))
#
# NameError: name 'test_accuracy_per_fold' is not defined
