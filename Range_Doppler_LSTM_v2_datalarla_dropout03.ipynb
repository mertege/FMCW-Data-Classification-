# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_LSTM_v2_datalarla_dropout03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dropout selected as 0.3, 
#[0.9823529362678528, 0.970588219165802, 0.9823529243469238, 0.9764705777168274, 0.9647058606147766]
#[0.9789437689969607, 0.9654841563514089, 0.9796508230180756, 0.9736615994756604, 0.9603545628048348]
#Mean test accuracy is 0.98, mean test f1 score is 0.97, max test accuracy is 0.98, max test f1 score is 0.98, min test accuracy is 0.96, min test f1 score is 0.96, std of test accuracy is 0.01, std of test f1 score is 0.01
#Time elapsed through all process: 8976.75, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_resizedv2.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_resizedv2.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_slow_pocket_resizedv2.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/data/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
lstm_dropout_rate = 0.3
unit_number_of_lstm = 16
dense_unit_of_lstm_function = 256
decoder_dense = 256


for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_lstm_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)


    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense)(input)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    # input_shape = range_doppler_concat_shuffle.shape[1:]
    # base_network_range_doppler = encoder_for_range_doppler(input_shape)
    # range_doppler_input  = Input(shape=input_shape)
    # processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_lstm  = base_network_lstm(range_doppler_input)

    base_decoder_network = decoder_for_concat((processed_lstm.shape[1]))
    out = base_decoder_network(processed_lstm)

    model = Model(inputs=[range_doppler_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 15s 336ms/step - loss: 0.5654 - accuracy: 0.4886 - val_loss: 0.2786 - val_accuracy: 0.9259
# Epoch 2/100
# 28/28 [==============================] - 8s 300ms/step - loss: 0.4175 - accuracy: 0.5411 - val_loss: 0.2707 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.3806 - accuracy: 0.5605 - val_loss: 0.1753 - val_accuracy: 1.0000
# Epoch 4/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3609 - accuracy: 0.5662 - val_loss: 0.1948 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.3430 - accuracy: 0.5753 - val_loss: 0.2054 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.3296 - accuracy: 0.5765 - val_loss: 0.2389 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.3232 - accuracy: 0.5788 - val_loss: 0.2579 - val_accuracy: 0.8889
# Epoch 8/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.3062 - accuracy: 0.5833 - val_loss: 0.1530 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2990 - accuracy: 0.5845 - val_loss: 0.2485 - val_accuracy: 0.8889
# Epoch 10/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.3140 - accuracy: 0.5822 - val_loss: 0.1155 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2934 - accuracy: 0.5822 - val_loss: 0.1013 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2891 - accuracy: 0.5822 - val_loss: 0.1647 - val_accuracy: 0.9630
# Epoch 13/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2844 - accuracy: 0.5833 - val_loss: 0.1556 - val_accuracy: 0.9259
# Epoch 14/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.2820 - accuracy: 0.5833 - val_loss: 0.1700 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2879 - accuracy: 0.5833 - val_loss: 0.1369 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2849 - accuracy: 0.5833 - val_loss: 0.1239 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2807 - accuracy: 0.5833 - val_loss: 0.1235 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2786 - accuracy: 0.5833 - val_loss: 0.1833 - val_accuracy: 0.9259
# Epoch 19/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2758 - accuracy: 0.5822 - val_loss: 0.2651 - val_accuracy: 0.8519
# Epoch 20/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2756 - accuracy: 0.5833 - val_loss: 0.1588 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2772 - accuracy: 0.5845 - val_loss: 0.1074 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2760 - accuracy: 0.5845 - val_loss: 0.1291 - val_accuracy: 0.9259
# Epoch 23/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2700 - accuracy: 0.5845 - val_loss: 0.2237 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2714 - accuracy: 0.5845 - val_loss: 0.0696 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2676 - accuracy: 0.5822 - val_loss: 0.0760 - val_accuracy: 1.0000
# Epoch 26/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2679 - accuracy: 0.5845 - val_loss: 0.1955 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2646 - accuracy: 0.5845 - val_loss: 0.0968 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2642 - accuracy: 0.5845 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2726 - accuracy: 0.5845 - val_loss: 0.1578 - val_accuracy: 0.9259
# Epoch 30/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2678 - accuracy: 0.5845 - val_loss: 0.2054 - val_accuracy: 0.9259
# Epoch 31/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2686 - accuracy: 0.5845 - val_loss: 0.0778 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2552 - accuracy: 0.5845 - val_loss: 0.1018 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2634 - accuracy: 0.5845 - val_loss: 0.1038 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2591 - accuracy: 0.5845 - val_loss: 0.1074 - val_accuracy: 0.9259
# Epoch 35/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.2622 - accuracy: 0.5845 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 36/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2610 - accuracy: 0.5845 - val_loss: 0.1126 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2558 - accuracy: 0.5845 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2621 - accuracy: 0.5845 - val_loss: 0.0930 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2618 - accuracy: 0.5845 - val_loss: 0.1393 - val_accuracy: 0.9259
# Epoch 40/100
# 28/28 [==============================] - 8s 293ms/step - loss: 0.2619 - accuracy: 0.5845 - val_loss: 0.2069 - val_accuracy: 0.8889
# Epoch 41/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2584 - accuracy: 0.5845 - val_loss: 0.1055 - val_accuracy: 0.9259
# Epoch 42/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2593 - accuracy: 0.5845 - val_loss: 0.0941 - val_accuracy: 0.9630
# Epoch 43/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2606 - accuracy: 0.5845 - val_loss: 0.0926 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2603 - accuracy: 0.5845 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 45/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2582 - accuracy: 0.5845 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 46/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2664 - accuracy: 0.5845 - val_loss: 0.1273 - val_accuracy: 0.8889
# Epoch 47/100
# 28/28 [==============================] - 8s 294ms/step - loss: 0.2546 - accuracy: 0.5845 - val_loss: 0.0907 - val_accuracy: 0.9630
# Epoch 48/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2598 - accuracy: 0.5845 - val_loss: 0.0881 - val_accuracy: 1.0000
# Epoch 49/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2592 - accuracy: 0.5845 - val_loss: 0.0749 - val_accuracy: 1.0000
# Epoch 50/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2586 - accuracy: 0.5845 - val_loss: 0.0861 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 116ms/step - loss: 0.0426 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 328ms/step - loss: 0.5024 - accuracy: 0.4860 - val_loss: 0.2981 - val_accuracy: 0.8889
# Epoch 2/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3846 - accuracy: 0.5431 - val_loss: 0.3917 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3903 - accuracy: 0.5373 - val_loss: 0.2708 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3488 - accuracy: 0.5513 - val_loss: 0.2214 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3403 - accuracy: 0.5548 - val_loss: 0.2429 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3452 - accuracy: 0.5513 - val_loss: 0.3254 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3205 - accuracy: 0.5571 - val_loss: 0.2047 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3138 - accuracy: 0.5629 - val_loss: 0.1732 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3014 - accuracy: 0.5618 - val_loss: 0.1840 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3116 - accuracy: 0.5618 - val_loss: 0.1590 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2986 - accuracy: 0.5641 - val_loss: 0.1422 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2966 - accuracy: 0.5629 - val_loss: 0.1507 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2822 - accuracy: 0.5641 - val_loss: 0.2173 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2940 - accuracy: 0.5629 - val_loss: 0.1244 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2943 - accuracy: 0.5618 - val_loss: 0.1482 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2909 - accuracy: 0.5629 - val_loss: 0.1068 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2843 - accuracy: 0.5618 - val_loss: 0.1143 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2767 - accuracy: 0.5641 - val_loss: 0.1170 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2832 - accuracy: 0.5629 - val_loss: 0.1558 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2820 - accuracy: 0.5641 - val_loss: 0.1628 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2852 - accuracy: 0.5641 - val_loss: 0.2060 - val_accuracy: 0.9630
# Epoch 22/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2837 - accuracy: 0.5641 - val_loss: 0.1981 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2826 - accuracy: 0.5641 - val_loss: 0.1967 - val_accuracy: 0.9259
# Epoch 24/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2715 - accuracy: 0.5641 - val_loss: 0.1475 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2793 - accuracy: 0.5641 - val_loss: 0.1326 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2798 - accuracy: 0.5641 - val_loss: 0.1305 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2769 - accuracy: 0.5641 - val_loss: 0.1853 - val_accuracy: 0.9630
# Epoch 28/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2733 - accuracy: 0.5641 - val_loss: 0.1175 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2711 - accuracy: 0.5641 - val_loss: 0.1471 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2704 - accuracy: 0.5641 - val_loss: 0.1505 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2664 - accuracy: 0.5641 - val_loss: 0.1600 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 112ms/step - loss: 0.0934 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 331ms/step - loss: 0.5345 - accuracy: 0.4988 - val_loss: 0.3887 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.4062 - accuracy: 0.5475 - val_loss: 0.2450 - val_accuracy: 0.8519
# Epoch 3/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3818 - accuracy: 0.5544 - val_loss: 0.2143 - val_accuracy: 1.0000
# Epoch 4/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3425 - accuracy: 0.5764 - val_loss: 0.2149 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3286 - accuracy: 0.5787 - val_loss: 0.1947 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3239 - accuracy: 0.5752 - val_loss: 0.1977 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3140 - accuracy: 0.5822 - val_loss: 0.2000 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3211 - accuracy: 0.5810 - val_loss: 0.2471 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3063 - accuracy: 0.5845 - val_loss: 0.1577 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2903 - accuracy: 0.5833 - val_loss: 0.1933 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2999 - accuracy: 0.5856 - val_loss: 0.2074 - val_accuracy: 0.9259
# Epoch 12/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2909 - accuracy: 0.5856 - val_loss: 0.1633 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2896 - accuracy: 0.5822 - val_loss: 0.1445 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2904 - accuracy: 0.5833 - val_loss: 0.2004 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2870 - accuracy: 0.5856 - val_loss: 0.1501 - val_accuracy: 0.9630
# Epoch 16/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2804 - accuracy: 0.5845 - val_loss: 0.2128 - val_accuracy: 0.8889
# Epoch 17/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2781 - accuracy: 0.5845 - val_loss: 0.1170 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2655 - accuracy: 0.5845 - val_loss: 0.2123 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2782 - accuracy: 0.5856 - val_loss: 0.1773 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2671 - accuracy: 0.5856 - val_loss: 0.1721 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2713 - accuracy: 0.5845 - val_loss: 0.1688 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2717 - accuracy: 0.5856 - val_loss: 0.1118 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2697 - accuracy: 0.5856 - val_loss: 0.1349 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2662 - accuracy: 0.5856 - val_loss: 0.1468 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2773 - accuracy: 0.5833 - val_loss: 0.1934 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2644 - accuracy: 0.5856 - val_loss: 0.1211 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2691 - accuracy: 0.5845 - val_loss: 0.1162 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2667 - accuracy: 0.5856 - val_loss: 0.1305 - val_accuracy: 0.9630
# Epoch 29/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2650 - accuracy: 0.5856 - val_loss: 0.1947 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2629 - accuracy: 0.5845 - val_loss: 0.1813 - val_accuracy: 0.9259
# Epoch 31/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2637 - accuracy: 0.5856 - val_loss: 0.2392 - val_accuracy: 0.8519
# Epoch 32/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2690 - accuracy: 0.5845 - val_loss: 0.1529 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2650 - accuracy: 0.5845 - val_loss: 0.1589 - val_accuracy: 0.9630
# Epoch 34/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2592 - accuracy: 0.5856 - val_loss: 0.2135 - val_accuracy: 0.8889
# Epoch 35/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2622 - accuracy: 0.5856 - val_loss: 0.2071 - val_accuracy: 0.8519
# Epoch 36/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2537 - accuracy: 0.5845 - val_loss: 0.0917 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2544 - accuracy: 0.5845 - val_loss: 0.1889 - val_accuracy: 0.9630
# Epoch 38/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2562 - accuracy: 0.5856 - val_loss: 0.1541 - val_accuracy: 0.9259
# Epoch 39/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2505 - accuracy: 0.5856 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 40/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2525 - accuracy: 0.5856 - val_loss: 0.1133 - val_accuracy: 1.0000
# Epoch 41/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2478 - accuracy: 0.5856 - val_loss: 0.1383 - val_accuracy: 1.0000
# Epoch 42/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2523 - accuracy: 0.5856 - val_loss: 0.2079 - val_accuracy: 0.8889
# Epoch 43/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2540 - accuracy: 0.5856 - val_loss: 0.1447 - val_accuracy: 0.9630
# Epoch 44/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2619 - accuracy: 0.5856 - val_loss: 0.1307 - val_accuracy: 0.9630
# Epoch 45/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2519 - accuracy: 0.5856 - val_loss: 0.1612 - val_accuracy: 0.9630
# Epoch 46/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2508 - accuracy: 0.5856 - val_loss: 0.1989 - val_accuracy: 0.9259
# Epoch 47/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2549 - accuracy: 0.5856 - val_loss: 0.1283 - val_accuracy: 1.0000
# Epoch 48/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2533 - accuracy: 0.5856 - val_loss: 0.1266 - val_accuracy: 0.9630
# Epoch 49/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2484 - accuracy: 0.5856 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 50/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2514 - accuracy: 0.5856 - val_loss: 0.1116 - val_accuracy: 1.0000
# Epoch 51/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2489 - accuracy: 0.5856 - val_loss: 0.1184 - val_accuracy: 1.0000
# Epoch 52/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2506 - accuracy: 0.5856 - val_loss: 0.1194 - val_accuracy: 0.9630
# Epoch 53/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2490 - accuracy: 0.5856 - val_loss: 0.1055 - val_accuracy: 1.0000
# Epoch 54/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2509 - accuracy: 0.5856 - val_loss: 0.0818 - val_accuracy: 0.9630
# Epoch 55/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2503 - accuracy: 0.5856 - val_loss: 0.0789 - val_accuracy: 1.0000
# Epoch 56/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2491 - accuracy: 0.5856 - val_loss: 0.1101 - val_accuracy: 0.9630
# Epoch 57/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2448 - accuracy: 0.5856 - val_loss: 0.1096 - val_accuracy: 1.0000
# Epoch 58/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2479 - accuracy: 0.5856 - val_loss: 0.1044 - val_accuracy: 1.0000
# Epoch 59/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2483 - accuracy: 0.5856 - val_loss: 0.1573 - val_accuracy: 0.9259
# Epoch 60/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2487 - accuracy: 0.5856 - val_loss: 0.1322 - val_accuracy: 1.0000
# Epoch 61/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2484 - accuracy: 0.5856 - val_loss: 0.1111 - val_accuracy: 0.9630
# Epoch 62/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2470 - accuracy: 0.5856 - val_loss: 0.1065 - val_accuracy: 1.0000
# Epoch 63/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2472 - accuracy: 0.5856 - val_loss: 0.1056 - val_accuracy: 1.0000
# Epoch 64/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2460 - accuracy: 0.5856 - val_loss: 0.0885 - val_accuracy: 0.9630
# Epoch 65/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2451 - accuracy: 0.5856 - val_loss: 0.0879 - val_accuracy: 1.0000
# Epoch 66/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2492 - accuracy: 0.5856 - val_loss: 0.1123 - val_accuracy: 0.9630
# Epoch 67/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2428 - accuracy: 0.5856 - val_loss: 0.1135 - val_accuracy: 1.0000
# Epoch 68/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2426 - accuracy: 0.5856 - val_loss: 0.1140 - val_accuracy: 0.9630
# Epoch 69/100
# 27/27 [==============================] - 8s 303ms/step - loss: 0.2440 - accuracy: 0.5856 - val_loss: 0.1255 - val_accuracy: 1.0000
# Epoch 70/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2395 - accuracy: 0.5856 - val_loss: 0.1227 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 113ms/step - loss: 0.1797 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 330ms/step - loss: 0.5092 - accuracy: 0.5185 - val_loss: 0.1718 - val_accuracy: 0.9259
# Epoch 2/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.3994 - accuracy: 0.5579 - val_loss: 0.1413 - val_accuracy: 1.0000
# Epoch 3/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3711 - accuracy: 0.5694 - val_loss: 0.1374 - val_accuracy: 1.0000
# Epoch 4/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3493 - accuracy: 0.5706 - val_loss: 0.2588 - val_accuracy: 0.8519
# Epoch 5/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3341 - accuracy: 0.5787 - val_loss: 0.1524 - val_accuracy: 1.0000
# Epoch 6/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3155 - accuracy: 0.5833 - val_loss: 0.1190 - val_accuracy: 1.0000
# Epoch 7/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2979 - accuracy: 0.5856 - val_loss: 0.1210 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.3229 - accuracy: 0.5810 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 9/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2973 - accuracy: 0.5868 - val_loss: 0.1516 - val_accuracy: 1.0000
# Epoch 10/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2913 - accuracy: 0.5822 - val_loss: 0.1088 - val_accuracy: 1.0000
# Epoch 11/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2877 - accuracy: 0.5856 - val_loss: 0.1230 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2857 - accuracy: 0.5868 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2851 - accuracy: 0.5880 - val_loss: 0.0952 - val_accuracy: 1.0000
# Epoch 14/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2882 - accuracy: 0.5868 - val_loss: 0.0887 - val_accuracy: 1.0000
# Epoch 15/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2790 - accuracy: 0.5880 - val_loss: 0.0554 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2626 - accuracy: 0.5880 - val_loss: 0.0808 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2768 - accuracy: 0.5880 - val_loss: 0.0577 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2766 - accuracy: 0.5880 - val_loss: 0.1041 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2743 - accuracy: 0.5880 - val_loss: 0.1233 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2715 - accuracy: 0.5868 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2714 - accuracy: 0.5880 - val_loss: 0.0833 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2686 - accuracy: 0.5880 - val_loss: 0.1120 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2737 - accuracy: 0.5868 - val_loss: 0.0526 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2672 - accuracy: 0.5868 - val_loss: 0.0715 - val_accuracy: 0.9630
# Epoch 25/100
# 27/27 [==============================] - 8s 294ms/step - loss: 0.2635 - accuracy: 0.5880 - val_loss: 0.0803 - val_accuracy: 1.0000
# Epoch 26/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2661 - accuracy: 0.5880 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2583 - accuracy: 0.5880 - val_loss: 0.0541 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2632 - accuracy: 0.5880 - val_loss: 0.0572 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2664 - accuracy: 0.5880 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2602 - accuracy: 0.5880 - val_loss: 0.0872 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2562 - accuracy: 0.5880 - val_loss: 0.0606 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2602 - accuracy: 0.5880 - val_loss: 0.0809 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2554 - accuracy: 0.5880 - val_loss: 0.0890 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2535 - accuracy: 0.5880 - val_loss: 0.0791 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2502 - accuracy: 0.5880 - val_loss: 0.0710 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2497 - accuracy: 0.5880 - val_loss: 0.1084 - val_accuracy: 1.0000
# Epoch 37/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2572 - accuracy: 0.5880 - val_loss: 0.0658 - val_accuracy: 1.0000
# Epoch 38/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2565 - accuracy: 0.5880 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 39/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2546 - accuracy: 0.5880 - val_loss: 0.0810 - val_accuracy: 1.0000
# Epoch 40/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2477 - accuracy: 0.5880 - val_loss: 0.0649 - val_accuracy: 1.0000
# Epoch 41/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2549 - accuracy: 0.5868 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 42/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2487 - accuracy: 0.5880 - val_loss: 0.0628 - val_accuracy: 1.0000
# Epoch 43/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2464 - accuracy: 0.5880 - val_loss: 0.0656 - val_accuracy: 1.0000
# Epoch 44/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2546 - accuracy: 0.5880 - val_loss: 0.0502 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 115ms/step - loss: 0.1584 - accuracy: 0.9412
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5120, 52)]        0
#
#  model (Functional)          (None, 256)               42608512
#
#  model_1 (Functional)        (None, 1)                 82305
#
# =================================================================
# Total params: 42,690,817
# Trainable params: 42,362,625
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 12s 332ms/step - loss: 0.5770 - accuracy: 0.5231 - val_loss: 0.3071 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.4127 - accuracy: 0.5741 - val_loss: 0.2264 - val_accuracy: 0.8519
# Epoch 3/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3520 - accuracy: 0.5903 - val_loss: 0.2103 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3256 - accuracy: 0.6123 - val_loss: 0.2012 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3142 - accuracy: 0.6146 - val_loss: 0.1667 - val_accuracy: 0.9630
# Epoch 6/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.3049 - accuracy: 0.6123 - val_loss: 0.1485 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3100 - accuracy: 0.6169 - val_loss: 0.1915 - val_accuracy: 0.9259
# Epoch 8/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2903 - accuracy: 0.6169 - val_loss: 0.1256 - val_accuracy: 0.9630
# Epoch 9/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2995 - accuracy: 0.6169 - val_loss: 0.1479 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2823 - accuracy: 0.6181 - val_loss: 0.1330 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2760 - accuracy: 0.6181 - val_loss: 0.1455 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2725 - accuracy: 0.6204 - val_loss: 0.1138 - val_accuracy: 0.9630
# Epoch 13/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2750 - accuracy: 0.6192 - val_loss: 0.1458 - val_accuracy: 0.9259
# Epoch 14/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2677 - accuracy: 0.6204 - val_loss: 0.1483 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2747 - accuracy: 0.6204 - val_loss: 0.1158 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2672 - accuracy: 0.6204 - val_loss: 0.2057 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2732 - accuracy: 0.6192 - val_loss: 0.1123 - val_accuracy: 0.9259
# Epoch 18/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2627 - accuracy: 0.6204 - val_loss: 0.1254 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2733 - accuracy: 0.6192 - val_loss: 0.1299 - val_accuracy: 0.9630
# Epoch 20/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2635 - accuracy: 0.6192 - val_loss: 0.1320 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2544 - accuracy: 0.6204 - val_loss: 0.1303 - val_accuracy: 0.9259
# Epoch 22/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2600 - accuracy: 0.6204 - val_loss: 0.1328 - val_accuracy: 0.9259
# Epoch 23/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2629 - accuracy: 0.6204 - val_loss: 0.1489 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2502 - accuracy: 0.6204 - val_loss: 0.1436 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2563 - accuracy: 0.6204 - val_loss: 0.1602 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2537 - accuracy: 0.6204 - val_loss: 0.1402 - val_accuracy: 0.9259
# Epoch 27/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2537 - accuracy: 0.6204 - val_loss: 0.1101 - val_accuracy: 0.9259
# Epoch 28/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2493 - accuracy: 0.6192 - val_loss: 0.1287 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2463 - accuracy: 0.6204 - val_loss: 0.1349 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2475 - accuracy: 0.6204 - val_loss: 0.1430 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2464 - accuracy: 0.6204 - val_loss: 0.1776 - val_accuracy: 0.9630
# Epoch 32/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2454 - accuracy: 0.6204 - val_loss: 0.1637 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2485 - accuracy: 0.6204 - val_loss: 0.1194 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2452 - accuracy: 0.6204 - val_loss: 0.1440 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2392 - accuracy: 0.6204 - val_loss: 0.1883 - val_accuracy: 0.9259
# Epoch 36/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2508 - accuracy: 0.6204 - val_loss: 0.1503 - val_accuracy: 0.9259
# Epoch 37/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2446 - accuracy: 0.6204 - val_loss: 0.1158 - val_accuracy: 0.9259
# Epoch 38/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2365 - accuracy: 0.6204 - val_loss: 0.1599 - val_accuracy: 0.9259
# Epoch 39/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2375 - accuracy: 0.6204 - val_loss: 0.2531 - val_accuracy: 0.9259
# Epoch 40/100
# 27/27 [==============================] - 8s 295ms/step - loss: 0.2450 - accuracy: 0.6204 - val_loss: 0.1420 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2374 - accuracy: 0.6204 - val_loss: 0.1335 - val_accuracy: 0.9630
# Epoch 42/100
# 27/27 [==============================] - 8s 299ms/step - loss: 0.2368 - accuracy: 0.6204 - val_loss: 0.1513 - val_accuracy: 0.9630
# 2/2 [==============================] - 1s 113ms/step - loss: 0.0553 - accuracy: 1.0000
# ...
# Epoch 5/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.3352 - accuracy: 0.5629 - val_loss: 0.3148 - val_accuracy: 0.8889
# Epoch 6/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.3276 - accuracy: 0.5664 - val_loss: 0.2589 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.3135 - accuracy: 0.5688 - val_loss: 0.2724 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.3097 - accuracy: 0.5664 - val_loss: 0.2435 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 8s 302ms/step - loss: 0.3044 - accuracy: 0.5688 - val_loss: 0.2004 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3038 - accuracy: 0.5676 - val_loss: 0.2060 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2977 - accuracy: 0.5699 - val_loss: 0.2670 - val_accuracy: 0.8889
# Epoch 12/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2931 - accuracy: 0.5711 - val_loss: 0.2345 - val_accuracy: 0.8519
# Epoch 13/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3049 - accuracy: 0.5711 - val_loss: 0.2822 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2851 - accuracy: 0.5711 - val_loss: 0.2003 - val_accuracy: 0.8889
# Epoch 15/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2825 - accuracy: 0.5711 - val_loss: 0.1812 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2792 - accuracy: 0.5711 - val_loss: 0.2941 - val_accuracy: 0.8519
# Epoch 17/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2799 - accuracy: 0.5711 - val_loss: 0.3047 - val_accuracy: 0.8889
# Epoch 18/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2896 - accuracy: 0.5711 - val_loss: 0.1977 - val_accuracy: 0.8889
# Epoch 19/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2848 - accuracy: 0.5711 - val_loss: 0.2049 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 8s 303ms/step - loss: 0.2850 - accuracy: 0.5711 - val_loss: 0.1627 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2757 - accuracy: 0.5711 - val_loss: 0.2212 - val_accuracy: 0.8148
# Epoch 22/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2745 - accuracy: 0.5711 - val_loss: 0.3574 - val_accuracy: 0.8889
# Epoch 23/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2662 - accuracy: 0.5711 - val_loss: 0.2825 - val_accuracy: 0.8889
# Epoch 24/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2673 - accuracy: 0.5711 - val_loss: 0.1664 - val_accuracy: 0.9259
# Epoch 25/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2651 - accuracy: 0.5711 - val_loss: 0.3940 - val_accuracy: 0.8889
# Epoch 26/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2681 - accuracy: 0.5711 - val_loss: 0.2924 - val_accuracy: 0.8889
# Epoch 27/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2708 - accuracy: 0.5699 - val_loss: 0.2396 - val_accuracy: 0.8889
# Epoch 28/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2718 - accuracy: 0.5699 - val_loss: 0.2157 - val_accuracy: 0.9259
# Epoch 29/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2691 - accuracy: 0.5711 - val_loss: 0.2611 - val_accuracy: 0.8889
# Epoch 30/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2668 - accuracy: 0.5711 - val_loss: 0.2466 - val_accuracy: 0.8889
# Epoch 31/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2694 - accuracy: 0.5711 - val_loss: 0.2920 - val_accuracy: 0.8889
# Epoch 32/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2621 - accuracy: 0.5711 - val_loss: 0.3288 - val_accuracy: 0.8889
# Epoch 33/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2613 - accuracy: 0.5711 - val_loss: 0.3697 - val_accuracy: 0.8889
# Epoch 34/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2696 - accuracy: 0.5711 - val_loss: 0.2752 - val_accuracy: 0.8889
# Epoch 35/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2628 - accuracy: 0.5711 - val_loss: 0.2633 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 113ms/step - loss: 0.1262 - accuracy: 0.9706
# Epoch 1/100
# 27/27 [==============================] - 12s 331ms/step - loss: 0.5346 - accuracy: 0.4872 - val_loss: 0.2258 - val_accuracy: 0.9259
# Epoch 2/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.4084 - accuracy: 0.5501 - val_loss: 0.2694 - val_accuracy: 0.8519
# Epoch 3/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.3708 - accuracy: 0.5723 - val_loss: 0.1992 - val_accuracy: 0.9630
# Epoch 4/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.3520 - accuracy: 0.5746 - val_loss: 0.2060 - val_accuracy: 0.9630
# Epoch 5/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.3281 - accuracy: 0.5851 - val_loss: 0.3434 - val_accuracy: 0.7778
# Epoch 6/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3359 - accuracy: 0.5816 - val_loss: 0.2327 - val_accuracy: 0.8889
# Epoch 7/100
# 27/27 [==============================] - 8s 302ms/step - loss: 0.3211 - accuracy: 0.5816 - val_loss: 0.1691 - val_accuracy: 1.0000
# Epoch 8/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.3103 - accuracy: 0.5851 - val_loss: 0.2391 - val_accuracy: 0.8889
# Epoch 9/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2973 - accuracy: 0.5839 - val_loss: 0.1722 - val_accuracy: 1.0000
# Epoch 10/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2975 - accuracy: 0.5862 - val_loss: 0.1740 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2967 - accuracy: 0.5874 - val_loss: 0.1309 - val_accuracy: 1.0000
# Epoch 12/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2932 - accuracy: 0.5839 - val_loss: 0.1633 - val_accuracy: 1.0000
# Epoch 13/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2985 - accuracy: 0.5851 - val_loss: 0.1384 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2856 - accuracy: 0.5862 - val_loss: 0.1249 - val_accuracy: 0.9630
# Epoch 15/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2863 - accuracy: 0.5874 - val_loss: 0.1197 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2929 - accuracy: 0.5851 - val_loss: 0.1274 - val_accuracy: 1.0000
# Epoch 17/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2730 - accuracy: 0.5874 - val_loss: 0.0903 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2767 - accuracy: 0.5874 - val_loss: 0.0896 - val_accuracy: 1.0000
# Epoch 19/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2670 - accuracy: 0.5874 - val_loss: 0.0919 - val_accuracy: 1.0000
# Epoch 20/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2639 - accuracy: 0.5874 - val_loss: 0.0885 - val_accuracy: 1.0000
# Epoch 21/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2708 - accuracy: 0.5874 - val_loss: 0.0866 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2732 - accuracy: 0.5862 - val_loss: 0.0949 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2691 - accuracy: 0.5851 - val_loss: 0.1022 - val_accuracy: 0.9630
# Epoch 24/100
# 27/27 [==============================] - 8s 300ms/step - loss: 0.2647 - accuracy: 0.5874 - val_loss: 0.0731 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2659 - accuracy: 0.5874 - val_loss: 0.0897 - val_accuracy: 0.9630
# Epoch 26/100
# 27/27 [==============================] - 8s 301ms/step - loss: 0.2637 - accuracy: 0.5874 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 27/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2629 - accuracy: 0.5874 - val_loss: 0.1142 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2611 - accuracy: 0.5874 - val_loss: 0.1102 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2603 - accuracy: 0.5862 - val_loss: 0.1448 - val_accuracy: 0.9630
# Epoch 30/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2568 - accuracy: 0.5874 - val_loss: 0.0991 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2678 - accuracy: 0.5874 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2704 - accuracy: 0.5874 - val_loss: 0.1675 - val_accuracy: 0.9630
# Epoch 33/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2575 - accuracy: 0.5874 - val_loss: 0.1015 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2617 - accuracy: 0.5874 - val_loss: 0.1189 - val_accuracy: 1.0000
# Epoch 35/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2571 - accuracy: 0.5874 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 36/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2624 - accuracy: 0.5862 - val_loss: 0.1630 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2583 - accuracy: 0.5874 - val_loss: 0.1056 - val_accuracy: 1.0000
# Epoch 38/100
# 27/27 [==============================] - 8s 297ms/step - loss: 0.2524 - accuracy: 0.5874 - val_loss: 0.1546 - val_accuracy: 1.0000
# Epoch 39/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2554 - accuracy: 0.5874 - val_loss: 0.1209 - val_accuracy: 0.9630
# Epoch 40/100
# 27/27 [==============================] - 8s 296ms/step - loss: 0.2528 - accuracy: 0.5874 - val_loss: 0.0949 - val_accuracy: 1.0000
# Epoch 41/100
# 27/27 [==============================] - 8s 298ms/step - loss: 0.2558 - accuracy: 0.5874 - val_loss: 0.1444 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 108ms/step - loss: 0.0709 - accuracy: 0.9706
# Epoch 1/100
# 28/28 [==============================] - 12s 329ms/step - loss: 0.5474 - accuracy: 0.5068 - val_loss: 0.2094 - val_accuracy: 0.9259
# Epoch 2/100
# 28/28 [==============================] - 8s 300ms/step - loss: 0.3777 - accuracy: 0.5811 - val_loss: 0.2091 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 8s 300ms/step - loss: 0.3619 - accuracy: 0.5902 - val_loss: 0.2041 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.3206 - accuracy: 0.6073 - val_loss: 0.1464 - val_accuracy: 1.0000
# Epoch 5/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2963 - accuracy: 0.6096 - val_loss: 0.1712 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.3134 - accuracy: 0.6016 - val_loss: 0.2248 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2951 - accuracy: 0.6096 - val_loss: 0.1541 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 8s 300ms/step - loss: 0.3075 - accuracy: 0.6050 - val_loss: 0.1223 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2898 - accuracy: 0.6084 - val_loss: 0.1212 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2793 - accuracy: 0.6119 - val_loss: 0.1703 - val_accuracy: 0.9630
# Epoch 11/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2710 - accuracy: 0.6107 - val_loss: 0.1653 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2723 - accuracy: 0.6096 - val_loss: 0.2584 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2819 - accuracy: 0.6107 - val_loss: 0.1701 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2794 - accuracy: 0.6107 - val_loss: 0.2867 - val_accuracy: 0.9259
# Epoch 15/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2721 - accuracy: 0.6107 - val_loss: 0.1729 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2669 - accuracy: 0.6096 - val_loss: 0.2258 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2758 - accuracy: 0.6084 - val_loss: 0.2100 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2670 - accuracy: 0.6107 - val_loss: 0.1526 - val_accuracy: 0.9630
# Epoch 19/100
# 28/28 [==============================] - 8s 299ms/step - loss: 0.2735 - accuracy: 0.6119 - val_loss: 0.0751 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2658 - accuracy: 0.6107 - val_loss: 0.1199 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2620 - accuracy: 0.6119 - val_loss: 0.2568 - val_accuracy: 0.9259
# Epoch 22/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2620 - accuracy: 0.6107 - val_loss: 0.1646 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2556 - accuracy: 0.6119 - val_loss: 0.1187 - val_accuracy: 0.9630
# Epoch 24/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.2495 - accuracy: 0.6119 - val_loss: 0.1558 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2520 - accuracy: 0.6119 - val_loss: 0.1101 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2489 - accuracy: 0.6107 - val_loss: 0.1983 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2580 - accuracy: 0.6119 - val_loss: 0.3418 - val_accuracy: 0.8519
# Epoch 28/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2540 - accuracy: 0.6119 - val_loss: 0.2230 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2456 - accuracy: 0.6119 - val_loss: 0.1215 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2530 - accuracy: 0.6107 - val_loss: 0.1305 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 8s 296ms/step - loss: 0.2443 - accuracy: 0.6119 - val_loss: 0.1585 - val_accuracy: 0.9630
# Epoch 32/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2477 - accuracy: 0.6119 - val_loss: 0.1570 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 8s 295ms/step - loss: 0.2421 - accuracy: 0.6119 - val_loss: 0.0927 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 8s 298ms/step - loss: 0.2429 - accuracy: 0.6119 - val_loss: 0.1290 - val_accuracy: 0.9259
# 2/2 [==============================] - 1s 110ms/step - loss: 0.1391 - accuracy: 0.9118
# [0.9823529362678528, 0.970588219165802, 0.9823529243469238, 0.9764705777168274, 0.9647058606147766]
# [0.9789437689969607, 0.9654841563514089, 0.9796508230180756, 0.9736615994756604, 0.9603545628048348]
# Mean test accuracy is 0.98, mean test f1 score is 0.97, max test accuracy is 0.98, max test f1 score is 0.98, min test accuracy is 0.96, min test f1 score is 0.96, std of test accuracy is 0.01, std of test f1 score is 0.01
# Time elapsed through all process: 8976.75, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
# print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5a23d0e0df1c> in <module>()
# ----> 1 print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
#       2 # print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
#
# NameError: name 'test_accuracy_per_run' is not defined
