# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_and_Spectrogram_CNN_compare_slow_and_pocket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada range-doppler ve spectrogram dataları CNN için birlikte kullanıldı. Slow ve slow with pocket birlikte karşılaştırıldı.
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.54, mean test f1 score is 0.44, max test accuracy is 0.54, max test f1 score is 0.44, 
# Min test accuracy is 0.54, min test f1 score is 0.44, std of test accuracy is 0.00, std of test f1 score is 0.00
# Time elapsed through all process: 1043.46, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Spectrogram data from

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_slow_pocket_resized, range_doppler_slow_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_slow_pocket_resized.shape[0],:] = 1 # pocket = 1, slow = 0
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_slow_pocket_resized, spectrogram_slow_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_slow_pocket_resized.shape[0],:] = 1 # pocket = 1, slow = 0
# Shuffle concat range doppler
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])
def split_and_augmentation_of_training(range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train, randomlist_for_validation_indx, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation = 5
  size_of_validation = 16

  # Split validation
  if bool(randomlist_for_validation_indx) == False:
    randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
    randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  else:
    randomlist_for_validation_indx = randomlist_for_validation_indx # split validation data
    randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data

  validation_spectrograms = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  # get training data
  training_spectrograms = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  training_labels = range_doppler_concat_label_shuffle_train[randomlist_for_train_indx,:]
  # get slow and pocket indexes of training data
  slow_indexes = np.where(training_labels == 0)[0]
  pocket_indexes = np.delete(range(0, training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = training_spectrograms[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  pocket_spectrograms_train = training_spectrograms[pocket_indexes,:,:,:]  
  size_of_samples_pocket = pocket_spectrograms_train.shape[0]

  # -- Concat pocket and Slow Data at Validation Dataset -- 
  # validation_spectrograms = np.concatenate((pocket_spectrograms_val,slow_spectrograms_val),axis=0)
  # validation_labels = np.concatenate((pocket_label_val,slow_label_val),axis=0)
  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for pocket ----------------
    augmented_image_pocket = np.zeros((size_of_samples_pocket*repeat_of_augmentation,pocket_spectrograms_train.shape[1],pocket_spectrograms_train.shape[2],1))
    spectrograms_pocket_label = np.ones((size_of_samples_pocket*(repeat_of_augmentation+1),1))
    for jj in range(repeat_of_augmentation):
      for ii in range(size_of_samples_pocket):
        augmented_image_pocket[size_of_samples_pocket*jj+ii,:,:,:] = data_augmentation(pocket_spectrograms_train[ii,:,:,:])
    augmented_image_pocket = np.concatenate((augmented_image_pocket,pocket_spectrograms_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = np.zeros((size_of_samples_slow*repeat_of_augmentation,slow_spectrograms_train.shape[1],slow_spectrograms_train.shape[2],1))
    spectrograms_slow_label = np.zeros((size_of_samples_slow*(repeat_of_augmentation+1),1))
    if repeat_of_augmentation == 0:
      augmented_image_slow = slow_spectrograms_train
    else:
      for kk in range(repeat_of_augmentation):
        for ii in range(size_of_samples_slow):
          augmented_image_slow[size_of_samples_slow*kk+ii,:,:,:] = data_augmentation(slow_spectrograms_train[ii,:,:,:])
      augmented_image_slow = np.concatenate((augmented_image_slow,slow_spectrograms_train),axis=0)    
  else:
    augmented_image_pocket = pocket_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    spectrograms_pocket_label = np.ones((size_of_samples_pocket,1))
    spectrograms_slow_label = np.zeros((size_of_samples_slow,1))
  return (augmented_image_pocket,augmented_image_slow,spectrograms_pocket_label,spectrograms_slow_label,validation_spectrograms,validation_labels, randomlist_for_validation_indx)


def normalize_inputs(range_doppler_concat_shuffle_test, validation_spectrograms, augmented_image, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle_test)
    range_doppler_concat_shuffle_test = layer(range_doppler_concat_shuffle_test)
    layer = Normalization(axis=None)
    layer.adapt(validation_spectrograms)
    validation_spectrograms = layer(validation_spectrograms)
    layer = Normalization(axis=None)
    layer.adapt(augmented_image)
    augmented_image = layer(augmented_image)
  else:
    (range_doppler_concat_shuffle_test, validation_spectrograms, augmented_image) = (range_doppler_concat_shuffle_test, validation_spectrograms, augmented_image)
  return(range_doppler_concat_shuffle_test, validation_spectrograms, augmented_image)

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 32
dropout_prob_cnn = 0.1
dropout_prob_dense = 0.1
number_of_repeat = 1
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  for train, test in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   

    # ---------------- Range-Doppler Data ----------------
    randomlist_for_test_indx = test
    randomlist_for_train_indx = train
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    range_doppler_concat_label_shuffle_train = range_doppler_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- Split labels to equal them during augmentation for Validation ----------------
    randomlist_for_validation_indx = []
    (range_doppler_augmented_image_pocket,range_doppler_augmented_image_slow,range_doppler_pocket_label,range_doppler_slow_label,validation_range_doppler,\
     range_doppler_validation_labels, randomlist_for_validation_indx)  = split_and_augmentation_of_training(range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,randomlist_for_validation_indx, augmentation_enable)
    
    # ---------------- Concat Validation and Slow ----------------
    range_doppler_augmented_image = np.concatenate((range_doppler_augmented_image_pocket,range_doppler_augmented_image_slow),axis=0)
    range_doppler_concat_label_shuffle_concat = np.concatenate((range_doppler_pocket_label,range_doppler_slow_label),axis=0)

    range_doppler_augmented_image = np.concatenate((range_doppler_augmented_image_pocket,range_doppler_augmented_image_slow),axis=0)
    range_doppler_concat_label_shuffle_concat = np.concatenate((range_doppler_pocket_label,range_doppler_slow_label),axis=0)   

    # ---------------- Spectrogram Data ----------------
    # test data
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_label_shuffle_test = spectrogram_concat_label_shuffle[randomlist_for_validation_indx,:]
    #train data
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- Split labels to equal them during augmentation for Validation ----------------
    (spectrogram_augmented_image_pocket,spectrogram_augmented_image_slow,spectrogram_pocket_label,spectrogram_slow_label,validation_spectrogram,\
     spectrogram_validation_labels, randomlist_for_validation_indx)  = split_and_augmentation_of_training(spectrogram_concat_shuffle_train,spectrogram_concat_label_shuffle_train,randomlist_for_validation_indx, augmentation_enable)
    # ---------------- Concat Validation and Slow ----------------
    spectrogram_augmented_image = np.concatenate((spectrogram_augmented_image_pocket,spectrogram_augmented_image_slow),axis=0)
    spectrogram_concat_label_shuffle_concat = np.concatenate((spectrogram_pocket_label,spectrogram_slow_label),axis=0)


    # ---------------- Normalization ----------------
    (range_doppler_concat_shuffle_test, validation_range_doppler, range_doppler_augmented_image) = normalize_inputs(range_doppler_concat_shuffle_test,\
                                                                                                     validation_range_doppler, range_doppler_augmented_image, normalize_inputs_enable)   
    (spectrogram_concat_shuffle_test, validation_spectrogram, spectrogram_augmented_image) = normalize_inputs(spectrogram_concat_shuffle_test,\
                                                                                                     validation_spectrogram, spectrogram_augmented_image, normalize_inputs_enable)
    # ---------------- Neural Network Architecture ----------------


    def encoder_for_range_doppler(input_shape):
      input = Input(shape=input_shape)
      x = Conv2D(8, (3, 3),padding='same',kernel_initializer="glorot_normal")(input)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)
      x = Dropout(dropout_prob_cnn)(x)
      x = MaxPooling2D(pool_size=(2, 2))(x)
      x = Conv2D(16, (3, 3),padding='same',kernel_initializer="glorot_normal")(x)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)
      x = Dropout(dropout_prob_cnn)(x)
      x = MaxPooling2D(pool_size=(2, 2))(x)
      x = Conv2D(32, (3, 3),padding='same',kernel_initializer="glorot_normal")(x)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)
      x = Dropout(dropout_prob_cnn)(x)
      x = MaxPooling2D(pool_size=(2, 2))(x)
      x = Flatten()(x)
      return Model(input, x)

    def encoder_for_spectrogram(input_shape):
      input = Input(shape=input_shape)
      x = Conv2D(8, (3, 3),padding='same',kernel_initializer="glorot_normal")(input)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)
      x = Dropout(dropout_prob_cnn)(x)
      x = MaxPooling2D(pool_size=(2, 2))(x)
      x = Conv2D(16, (3, 3),padding='same',kernel_initializer="glorot_normal")(x)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)
      x = Dropout(dropout_prob_cnn)(x)
      x = MaxPooling2D(pool_size=(2, 2))(x)
      x = Conv2D(32, (3, 3),padding='same',kernel_initializer="glorot_normal")(x)
      x = BatchNormalization()(x)
      x = Activation('relu')(x)
      x = Dropout(dropout_prob_cnn)(x)
      x = MaxPooling2D(pool_size=(2, 2))(x)
      x = Flatten()(x)
      return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(128, activation="relu")(input)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(dense_size, activation="relu")(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:]
    base_network_range_doppler = encoder_for_range_doppler(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_range_doppler(range_doppler_input)

    input_shape = spectrogram_concat_shuffle.shape[1:]
    base_network_spectrogram = encoder_for_spectrogram(input_shape) 
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_spectrogram(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out])

   
    print(model.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=35, verbose=0,restore_best_weights=True, mode='min')
    # earlyStopping = EarlyStopping(monitor='val_accuracy', patience=15, verbose=0,restore_best_weights=True, mode='max')
    history = model.fit((range_doppler_augmented_image,spectrogram_augmented_image),(range_doppler_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler,validation_spectrogram) , (range_doppler_validation_labels)))
    tf.keras.models.load_model
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test,spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test,spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)

  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 52, 5120, 1  0           []
#                                 )]
#
#  input_19 (InputLayer)          [(None, 52, 423, 1)  0           []
#                                 ]
#
#  model_12 (Functional)          (None, 122880)       6112        ['input_17[0][0]']
#
#  model_13 (Functional)          (None, 9984)         6112        ['input_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 132864)       0           ['model_12[0][0]',
#                                                                   'model_13[0][0]']
#
#  model_14 (Functional)          (None, 1)            17010881    ['concatenate_3[0][0]']
#
# ==================================================================================================
# Total params: 17,023,105
# Trainable params: 17,022,881
# Non-trainable params: 224
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 15/15 [==============================] - 23s 318ms/step - loss: 28.1613 - accuracy: 0.5178 - val_loss: 0.8451 - val_accuracy: 0.5000
# Epoch 2/100
# 15/15 [==============================] - 4s 265ms/step - loss: 4.1361 - accuracy: 0.5000 - val_loss: 0.8024 - val_accuracy: 0.5000
# Epoch 3/100
# 15/15 [==============================] - 4s 262ms/step - loss: 2.6079 - accuracy: 0.5222 - val_loss: 1.5251 - val_accuracy: 0.5000
# Epoch 4/100
# 15/15 [==============================] - 4s 264ms/step - loss: 2.7800 - accuracy: 0.4822 - val_loss: 0.7882 - val_accuracy: 0.5000
# Epoch 5/100
# 15/15 [==============================] - 4s 264ms/step - loss: 1.1143 - accuracy: 0.5556 - val_loss: 0.7311 - val_accuracy: 0.5000
# Epoch 6/100
# 15/15 [==============================] - 4s 266ms/step - loss: 1.1701 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 7/100
# 15/15 [==============================] - 4s 263ms/step - loss: 1.0341 - accuracy: 0.5333 - val_loss: 0.7051 - val_accuracy: 0.5000
# Epoch 8/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.8579 - accuracy: 0.5133 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 9/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.8169 - accuracy: 0.5622 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 10/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.7513 - accuracy: 0.5133 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 11/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.7226 - accuracy: 0.5444 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 12/100
# 15/15 [==============================] - 4s 261ms/step - loss: 0.7111 - accuracy: 0.5400 - val_loss: 1.0495 - val_accuracy: 0.5000
# Epoch 13/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.8114 - accuracy: 0.5200 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 14/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7688 - accuracy: 0.5333 - val_loss: 0.6948 - val_accuracy: 0.4375
# Epoch 15/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7660 - accuracy: 0.5089 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 16/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7509 - accuracy: 0.5244 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 17/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.7037 - accuracy: 0.4933 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 18/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.6590 - accuracy: 0.5244 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 19/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.6884 - accuracy: 0.5133 - val_loss: 0.7840 - val_accuracy: 0.5000
# Epoch 20/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.6998 - accuracy: 0.5667 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 21/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.6903 - accuracy: 0.5867 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 22/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.6523 - accuracy: 0.6556 - val_loss: 0.7133 - val_accuracy: 0.5000
# Epoch 23/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.6382 - accuracy: 0.6511 - val_loss: 0.7183 - val_accuracy: 0.3750
# Epoch 24/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.5866 - accuracy: 0.6800 - val_loss: 0.7219 - val_accuracy: 0.4375
# Epoch 25/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.5957 - accuracy: 0.6556 - val_loss: 0.7029 - val_accuracy: 0.4375
# Epoch 26/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.4934 - accuracy: 0.7333 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 27/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.5066 - accuracy: 0.7089 - val_loss: 0.7033 - val_accuracy: 0.5000
# Epoch 28/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.4915 - accuracy: 0.7422 - val_loss: 0.8277 - val_accuracy: 0.3750
# Epoch 29/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.4083 - accuracy: 0.8067 - val_loss: 0.7061 - val_accuracy: 0.5000
# Epoch 30/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.3646 - accuracy: 0.8133 - val_loss: 0.7785 - val_accuracy: 0.4375
# Epoch 31/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.4081 - accuracy: 0.8244 - val_loss: 0.7552 - val_accuracy: 0.5000
# Epoch 32/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.3800 - accuracy: 0.8067 - val_loss: 0.7046 - val_accuracy: 0.5000
# Epoch 33/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.3350 - accuracy: 0.8156 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 34/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.2583 - accuracy: 0.8756 - val_loss: 1.4425 - val_accuracy: 0.5000
# Epoch 35/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.3097 - accuracy: 0.8622 - val_loss: 0.7878 - val_accuracy: 0.3750
# Epoch 36/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.2357 - accuracy: 0.8911 - val_loss: 0.7364 - val_accuracy: 0.4375
# Epoch 37/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.2746 - accuracy: 0.8778 - val_loss: 1.0542 - val_accuracy: 0.5000
# Epoch 38/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.2651 - accuracy: 0.8889 - val_loss: 0.7411 - val_accuracy: 0.1875
# Epoch 39/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.2609 - accuracy: 0.8667 - val_loss: 1.4109 - val_accuracy: 0.5000
# Epoch 40/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.2460 - accuracy: 0.8911 - val_loss: 0.7184 - val_accuracy: 0.3750
# Epoch 41/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.1641 - accuracy: 0.9178 - val_loss: 3.6008 - val_accuracy: 0.5000
# Epoch 42/100
# 15/15 [==============================] - 4s 266ms/step - loss: 0.2210 - accuracy: 0.9133 - val_loss: 1.2272 - val_accuracy: 0.4375
# Epoch 43/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.1339 - accuracy: 0.9311 - val_loss: 1.0900 - val_accuracy: 0.4375
# 1/1 [==============================] - 0s 318ms/step - loss: 0.6931 - accuracy: 0.5217
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "model_19"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_22 (InputLayer)          [(None, 52, 5120, 1  0           []
#                                 )]
#
#  input_24 (InputLayer)          [(None, 52, 423, 1)  0           []
#                                 ]
#
#  model_16 (Functional)          (None, 122880)       6112        ['input_22[0][0]']
#
#  model_17 (Functional)          (None, 9984)         6112        ['input_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 132864)       0           ['model_16[0][0]',
#                                                                   'model_17[0][0]']
#
#  model_18 (Functional)          (None, 1)            17010881    ['concatenate_4[0][0]']
#
# ==================================================================================================
# Total params: 17,023,105
# Trainable params: 17,022,881
# Non-trainable params: 224
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 15/15 [==============================] - 7s 292ms/step - loss: 22.0172 - accuracy: 0.5311 - val_loss: 0.9449 - val_accuracy: 0.3750
# Epoch 2/100
# 15/15 [==============================] - 4s 267ms/step - loss: 3.1844 - accuracy: 0.5422 - val_loss: 0.7133 - val_accuracy: 0.6250
# Epoch 3/100
# 15/15 [==============================] - 4s 269ms/step - loss: 2.2757 - accuracy: 0.5267 - val_loss: 0.6746 - val_accuracy: 0.6250
# Epoch 4/100
# 15/15 [==============================] - 4s 263ms/step - loss: 1.2669 - accuracy: 0.5667 - val_loss: 0.8231 - val_accuracy: 0.3750
# Epoch 5/100
# 15/15 [==============================] - 4s 263ms/step - loss: 1.0944 - accuracy: 0.5444 - val_loss: 0.7201 - val_accuracy: 0.3750
# Epoch 6/100
# 15/15 [==============================] - 4s 261ms/step - loss: 1.0892 - accuracy: 0.5467 - val_loss: 0.6972 - val_accuracy: 0.5000
# Epoch 7/100
# 15/15 [==============================] - 4s 260ms/step - loss: 0.8542 - accuracy: 0.5289 - val_loss: 0.7367 - val_accuracy: 0.3750
# Epoch 8/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.9958 - accuracy: 0.5489 - val_loss: 0.7720 - val_accuracy: 0.3750
# Epoch 9/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7827 - accuracy: 0.5511 - val_loss: 0.6793 - val_accuracy: 0.6250
# Epoch 10/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.8091 - accuracy: 0.5533 - val_loss: 0.7343 - val_accuracy: 0.3750
# Epoch 11/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.8301 - accuracy: 0.6089 - val_loss: 0.6750 - val_accuracy: 0.6250
# Epoch 12/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7891 - accuracy: 0.5600 - val_loss: 0.6955 - val_accuracy: 0.4375
# Epoch 13/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.7500 - accuracy: 0.5689 - val_loss: 0.7411 - val_accuracy: 0.3750
# Epoch 14/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.6724 - accuracy: 0.6311 - val_loss: 0.7403 - val_accuracy: 0.3750
# Epoch 15/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.6530 - accuracy: 0.6267 - val_loss: 0.7484 - val_accuracy: 0.3750
# Epoch 16/100
# 15/15 [==============================] - 4s 266ms/step - loss: 0.7435 - accuracy: 0.6444 - val_loss: 0.7383 - val_accuracy: 0.3750
# Epoch 17/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.6490 - accuracy: 0.7178 - val_loss: 0.7633 - val_accuracy: 0.3750
# Epoch 18/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.5617 - accuracy: 0.6933 - val_loss: 0.7218 - val_accuracy: 0.4375
# Epoch 19/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.4564 - accuracy: 0.7889 - val_loss: 0.7980 - val_accuracy: 0.3750
# Epoch 20/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.5788 - accuracy: 0.7378 - val_loss: 0.7011 - val_accuracy: 0.3750
# Epoch 21/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.4112 - accuracy: 0.7733 - val_loss: 0.8286 - val_accuracy: 0.3750
# Epoch 22/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.3460 - accuracy: 0.8378 - val_loss: 0.6910 - val_accuracy: 0.6250
# Epoch 23/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.4060 - accuracy: 0.8067 - val_loss: 0.7439 - val_accuracy: 0.4375
# Epoch 24/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.3371 - accuracy: 0.8489 - val_loss: 0.6486 - val_accuracy: 0.5625
# Epoch 25/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.2744 - accuracy: 0.8733 - val_loss: 0.8361 - val_accuracy: 0.4375
# Epoch 26/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.3558 - accuracy: 0.8622 - val_loss: 0.8091 - val_accuracy: 0.4375
# Epoch 27/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.2475 - accuracy: 0.8889 - val_loss: 1.0442 - val_accuracy: 0.3750
# Epoch 28/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1891 - accuracy: 0.9178 - val_loss: 0.9780 - val_accuracy: 0.3750
# Epoch 29/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.2110 - accuracy: 0.9156 - val_loss: 0.8082 - val_accuracy: 0.5000
# Epoch 30/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1648 - accuracy: 0.9356 - val_loss: 0.6545 - val_accuracy: 0.6250
# Epoch 31/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.2577 - accuracy: 0.9044 - val_loss: 0.8596 - val_accuracy: 0.3750
# Epoch 32/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1288 - accuracy: 0.9444 - val_loss: 0.6867 - val_accuracy: 0.5625
# Epoch 33/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.0979 - accuracy: 0.9600 - val_loss: 1.0048 - val_accuracy: 0.4375
# Epoch 34/100
# 15/15 [==============================] - 4s 261ms/step - loss: 0.2215 - accuracy: 0.9356 - val_loss: 0.6536 - val_accuracy: 0.6250
# Epoch 35/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.1280 - accuracy: 0.9467 - val_loss: 0.8561 - val_accuracy: 0.5000
# Epoch 36/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.0842 - accuracy: 0.9667 - val_loss: 0.9404 - val_accuracy: 0.4375
# Epoch 37/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.0977 - accuracy: 0.9533 - val_loss: 0.8964 - val_accuracy: 0.6250
# Epoch 38/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1186 - accuracy: 0.9622 - val_loss: 1.0129 - val_accuracy: 0.4375
# Epoch 39/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0887 - accuracy: 0.9733 - val_loss: 1.7348 - val_accuracy: 0.3750
# Epoch 40/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.0683 - accuracy: 0.9844 - val_loss: 1.1959 - val_accuracy: 0.4375
# Epoch 41/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1043 - accuracy: 0.9578 - val_loss: 0.8613 - val_accuracy: 0.5000
# Epoch 42/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.0354 - accuracy: 0.9800 - val_loss: 3.0673 - val_accuracy: 0.3750
# Epoch 43/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.0604 - accuracy: 0.9800 - val_loss: 1.2358 - val_accuracy: 0.5625
# Epoch 44/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0541 - accuracy: 0.9800 - val_loss: 1.6386 - val_accuracy: 0.4375
# Epoch 45/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0446 - accuracy: 0.9822 - val_loss: 1.0302 - val_accuracy: 0.5625
# Epoch 46/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.0495 - accuracy: 0.9889 - val_loss: 1.1272 - val_accuracy: 0.5625
# Epoch 47/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.1608 - accuracy: 0.9778 - val_loss: 1.3024 - val_accuracy: 0.5000
# Epoch 48/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.0179 - accuracy: 0.9911 - val_loss: 1.7512 - val_accuracy: 0.5000
# Epoch 49/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.0219 - accuracy: 0.9911 - val_loss: 2.1109 - val_accuracy: 0.5000
# Epoch 50/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 1.5765 - val_accuracy: 0.6250
# Epoch 51/100
# 15/15 [==============================] - 4s 266ms/step - loss: 0.2049 - accuracy: 0.9511 - val_loss: 1.5891 - val_accuracy: 0.5000
# Epoch 52/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.0273 - accuracy: 0.9933 - val_loss: 1.6898 - val_accuracy: 0.5625
# Epoch 53/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0091 - accuracy: 0.9978 - val_loss: 1.9387 - val_accuracy: 0.4375
# Epoch 54/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0260 - accuracy: 0.9844 - val_loss: 2.5481 - val_accuracy: 0.3750
# Epoch 55/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.0210 - accuracy: 0.9911 - val_loss: 1.8558 - val_accuracy: 0.5625
# Epoch 56/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0531 - accuracy: 0.9933 - val_loss: 1.5966 - val_accuracy: 0.5625
# Epoch 57/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0564 - accuracy: 0.9867 - val_loss: 1.5770 - val_accuracy: 0.3750
# Epoch 58/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.0226 - accuracy: 0.9889 - val_loss: 1.3654 - val_accuracy: 0.3750
# Epoch 59/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.8693 - val_accuracy: 0.5000
# 1/1 [==============================] - 0s 310ms/step - loss: 0.7564 - accuracy: 0.4783
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "model_23"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_27 (InputLayer)          [(None, 52, 5120, 1  0           []
#                                 )]
#
#  input_29 (InputLayer)          [(None, 52, 423, 1)  0           []
#                                 ]
#
#  model_20 (Functional)          (None, 122880)       6112        ['input_27[0][0]']
#
#  model_21 (Functional)          (None, 9984)         6112        ['input_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 132864)       0           ['model_20[0][0]',
#                                                                   'model_21[0][0]']
#
#  model_22 (Functional)          (None, 1)            17010881    ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 17,023,105
# Trainable params: 17,022,881
# Non-trainable params: 224
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 15/15 [==============================] - 7s 291ms/step - loss: 38.7656 - accuracy: 0.4978 - val_loss: 2.4820 - val_accuracy: 0.6875
# Epoch 2/100
# 15/15 [==============================] - 4s 266ms/step - loss: 12.4038 - accuracy: 0.5178 - val_loss: 0.6701 - val_accuracy: 0.5625
# Epoch 3/100
# 15/15 [==============================] - 4s 267ms/step - loss: 5.3675 - accuracy: 0.4533 - val_loss: 0.6513 - val_accuracy: 0.6875
# Epoch 4/100
# 15/15 [==============================] - 4s 264ms/step - loss: 2.0132 - accuracy: 0.5756 - val_loss: 2.4691 - val_accuracy: 0.6875
# Epoch 5/100
# 15/15 [==============================] - 4s 263ms/step - loss: 2.4070 - accuracy: 0.5867 - val_loss: 0.8114 - val_accuracy: 0.5000
# Epoch 6/100
# 15/15 [==============================] - 4s 263ms/step - loss: 1.5453 - accuracy: 0.4867 - val_loss: 0.6686 - val_accuracy: 0.6875
# Epoch 7/100
# 15/15 [==============================] - 4s 267ms/step - loss: 1.1807 - accuracy: 0.5467 - val_loss: 0.6428 - val_accuracy: 0.6875
# Epoch 8/100
# 15/15 [==============================] - 4s 265ms/step - loss: 1.0534 - accuracy: 0.5622 - val_loss: 0.6550 - val_accuracy: 0.6875
# Epoch 9/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.8444 - accuracy: 0.5778 - val_loss: 0.7150 - val_accuracy: 0.2500
# Epoch 10/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.9814 - accuracy: 0.5400 - val_loss: 0.6873 - val_accuracy: 0.6875
# Epoch 11/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.7915 - accuracy: 0.6356 - val_loss: 0.8296 - val_accuracy: 0.3125
# Epoch 12/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7276 - accuracy: 0.6267 - val_loss: 0.7294 - val_accuracy: 0.3125
# Epoch 13/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.6924 - accuracy: 0.6622 - val_loss: 0.7285 - val_accuracy: 0.3125
# Epoch 14/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.6616 - accuracy: 0.6867 - val_loss: 0.8098 - val_accuracy: 0.3125
# Epoch 15/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7647 - accuracy: 0.6489 - val_loss: 0.7358 - val_accuracy: 0.3125
# Epoch 16/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.5842 - accuracy: 0.7133 - val_loss: 0.7751 - val_accuracy: 0.3125
# Epoch 17/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.5301 - accuracy: 0.7400 - val_loss: 0.6921 - val_accuracy: 0.6250
# Epoch 18/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.5525 - accuracy: 0.7289 - val_loss: 0.7524 - val_accuracy: 0.3750
# Epoch 19/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.5545 - accuracy: 0.8044 - val_loss: 0.7522 - val_accuracy: 0.6875
# Epoch 20/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.4294 - accuracy: 0.8311 - val_loss: 0.7681 - val_accuracy: 0.4375
# Epoch 21/100
# 15/15 [==============================] - 4s 261ms/step - loss: 0.3697 - accuracy: 0.8133 - val_loss: 0.6780 - val_accuracy: 0.6875
# Epoch 22/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.3004 - accuracy: 0.8667 - val_loss: 1.3500 - val_accuracy: 0.3125
# Epoch 23/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.3576 - accuracy: 0.8400 - val_loss: 0.7207 - val_accuracy: 0.6875
# Epoch 24/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.3673 - accuracy: 0.8378 - val_loss: 0.8023 - val_accuracy: 0.3125
# Epoch 25/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.2313 - accuracy: 0.8978 - val_loss: 1.5968 - val_accuracy: 0.3125
# Epoch 26/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.3447 - accuracy: 0.8467 - val_loss: 0.8946 - val_accuracy: 0.3125
# Epoch 27/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1808 - accuracy: 0.9200 - val_loss: 0.6830 - val_accuracy: 0.6875
# Epoch 28/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.3938 - accuracy: 0.8733 - val_loss: 0.7898 - val_accuracy: 0.4375
# Epoch 29/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.2773 - accuracy: 0.9000 - val_loss: 0.7497 - val_accuracy: 0.6250
# Epoch 30/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.2148 - accuracy: 0.9067 - val_loss: 0.6643 - val_accuracy: 0.5625
# Epoch 31/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1745 - accuracy: 0.9378 - val_loss: 0.7570 - val_accuracy: 0.5000
# Epoch 32/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.1625 - accuracy: 0.9244 - val_loss: 0.7470 - val_accuracy: 0.6875
# Epoch 33/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.1607 - accuracy: 0.9333 - val_loss: 0.8524 - val_accuracy: 0.4375
# Epoch 34/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.1204 - accuracy: 0.9667 - val_loss: 1.6456 - val_accuracy: 0.3125
# Epoch 35/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1260 - accuracy: 0.9400 - val_loss: 1.1132 - val_accuracy: 0.3750
# Epoch 36/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.2668 - accuracy: 0.9267 - val_loss: 1.1039 - val_accuracy: 0.4375
# Epoch 37/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0917 - accuracy: 0.9667 - val_loss: 0.8980 - val_accuracy: 0.6875
# Epoch 38/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.1530 - accuracy: 0.9289 - val_loss: 0.8682 - val_accuracy: 0.5625
# Epoch 39/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.0620 - accuracy: 0.9733 - val_loss: 1.2709 - val_accuracy: 0.5625
# Epoch 40/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.1392 - accuracy: 0.9578 - val_loss: 0.8083 - val_accuracy: 0.6875
# Epoch 41/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.1154 - accuracy: 0.9578 - val_loss: 0.8364 - val_accuracy: 0.6250
# Epoch 42/100
# 15/15 [==============================] - 4s 266ms/step - loss: 0.0522 - accuracy: 0.9733 - val_loss: 1.3194 - val_accuracy: 0.3750
# 1/1 [==============================] - 0s 314ms/step - loss: 0.6992 - accuracy: 0.5217
# Model: "model_27"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_32 (InputLayer)          [(None, 52, 5120, 1  0           []
#                                 )]
#
#  input_34 (InputLayer)          [(None, 52, 423, 1)  0           []
#                                 ]
#
#  model_24 (Functional)          (None, 122880)       6112        ['input_32[0][0]']
#
#  model_25 (Functional)          (None, 9984)         6112        ['input_34[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 132864)       0           ['model_24[0][0]',
#                                                                   'model_25[0][0]']
#
#  model_26 (Functional)          (None, 1)            17010881    ['concatenate_6[0][0]']
#
# ==================================================================================================
# Total params: 17,023,105
# Trainable params: 17,022,881
# Non-trainable params: 224
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 15/15 [==============================] - 7s 291ms/step - loss: 48.3168 - accuracy: 0.4644 - val_loss: 0.6679 - val_accuracy: 0.6250
# Epoch 2/100
# 15/15 [==============================] - 4s 265ms/step - loss: 6.9591 - accuracy: 0.5356 - val_loss: 2.1097 - val_accuracy: 0.3750
# Epoch 3/100
# 15/15 [==============================] - 4s 263ms/step - loss: 3.5508 - accuracy: 0.5178 - val_loss: 1.2383 - val_accuracy: 0.6250
# Epoch 4/100
# 15/15 [==============================] - 4s 263ms/step - loss: 2.8741 - accuracy: 0.5378 - val_loss: 0.8705 - val_accuracy: 0.6250
# Epoch 5/100
# 15/15 [==============================] - 4s 264ms/step - loss: 1.4639 - accuracy: 0.5000 - val_loss: 0.6812 - val_accuracy: 0.5000
# Epoch 6/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.8752 - accuracy: 0.5467 - val_loss: 1.2004 - val_accuracy: 0.3750
# Epoch 7/100
# 15/15 [==============================] - 4s 265ms/step - loss: 1.1198 - accuracy: 0.5178 - val_loss: 1.6457 - val_accuracy: 0.3750
# Epoch 8/100
# 15/15 [==============================] - 4s 263ms/step - loss: 1.2153 - accuracy: 0.4844 - val_loss: 0.6971 - val_accuracy: 0.3750
# Epoch 9/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.6974 - accuracy: 0.5200 - val_loss: 0.6995 - val_accuracy: 0.3750
# Epoch 10/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.6860 - accuracy: 0.5422 - val_loss: 0.7013 - val_accuracy: 0.3750
# Epoch 11/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.6947 - accuracy: 0.5378 - val_loss: 0.7018 - val_accuracy: 0.3750
# Epoch 12/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7998 - accuracy: 0.5756 - val_loss: 0.7020 - val_accuracy: 0.3750
# Epoch 13/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.6831 - accuracy: 0.5778 - val_loss: 0.7031 - val_accuracy: 0.3750
# Epoch 14/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.7800 - accuracy: 0.5711 - val_loss: 0.7029 - val_accuracy: 0.3750
# Epoch 15/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.6406 - accuracy: 0.5867 - val_loss: 0.7029 - val_accuracy: 0.3750
# Epoch 16/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.6570 - accuracy: 0.5956 - val_loss: 0.7039 - val_accuracy: 0.3750
# Epoch 17/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.6922 - accuracy: 0.5956 - val_loss: 0.7047 - val_accuracy: 0.3750
# Epoch 18/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.7601 - accuracy: 0.5711 - val_loss: 0.7008 - val_accuracy: 0.3750
# Epoch 19/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.5785 - accuracy: 0.6044 - val_loss: 0.6984 - val_accuracy: 0.3750
# Epoch 20/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.6168 - accuracy: 0.6089 - val_loss: 0.6959 - val_accuracy: 0.3750
# Epoch 21/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.5649 - accuracy: 0.6556 - val_loss: 0.8738 - val_accuracy: 0.3750
# Epoch 22/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.5285 - accuracy: 0.6489 - val_loss: 0.6948 - val_accuracy: 0.3750
# Epoch 23/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.4819 - accuracy: 0.6800 - val_loss: 0.6945 - val_accuracy: 0.3750
# Epoch 24/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.4723 - accuracy: 0.6622 - val_loss: 0.6937 - val_accuracy: 0.3750
# Epoch 25/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.5426 - accuracy: 0.7089 - val_loss: 0.6950 - val_accuracy: 0.3750
# Epoch 26/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.4392 - accuracy: 0.7178 - val_loss: 0.6956 - val_accuracy: 0.3750
# Epoch 27/100
# 15/15 [==============================] - 4s 266ms/step - loss: 0.5090 - accuracy: 0.7000 - val_loss: 0.7053 - val_accuracy: 0.3750
# Epoch 28/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.4386 - accuracy: 0.7311 - val_loss: 0.8781 - val_accuracy: 0.3750
# Epoch 29/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.4125 - accuracy: 0.7222 - val_loss: 0.6938 - val_accuracy: 0.3750
# Epoch 30/100
# 15/15 [==============================] - 4s 265ms/step - loss: 0.3815 - accuracy: 0.7556 - val_loss: 2.8363 - val_accuracy: 0.6250
# Epoch 31/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.5263 - accuracy: 0.7200 - val_loss: 0.6950 - val_accuracy: 0.3750
# Epoch 32/100
# 15/15 [==============================] - 4s 266ms/step - loss: 0.3957 - accuracy: 0.7533 - val_loss: 0.6950 - val_accuracy: 0.3750
# Epoch 33/100
# 15/15 [==============================] - 4s 264ms/step - loss: 0.3690 - accuracy: 0.7489 - val_loss: 0.6943 - val_accuracy: 0.3750
# Epoch 34/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.3724 - accuracy: 0.7689 - val_loss: 0.9313 - val_accuracy: 0.6250
# Epoch 35/100
# 15/15 [==============================] - 4s 263ms/step - loss: 0.3684 - accuracy: 0.8044 - val_loss: 0.6918 - val_accuracy: 0.6250
# Epoch 36/100
# 15/15 [==============================] - 4s 266ms/step - loss: 0.3544 - accuracy: 0.7822 - val_loss: 0.6912 - val_accuracy: 0.6250
# 1/1 [==============================] - 0s 343ms/step - loss: 0.7534 - accuracy: 0.5652
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efe550aaf80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Model: "model_31"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_37 (InputLayer)          [(None, 52, 5120, 1  0           []
#                                 )]
#
#  input_39 (InputLayer)          [(None, 52, 423, 1)  0           []
#                                 ]
#
#  model_28 (Functional)          (None, 122880)       6112        ['input_37[0][0]']
#
#  model_29 (Functional)          (None, 9984)         6112        ['input_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 132864)       0           ['model_28[0][0]',
#                                                                   'model_29[0][0]']
#
#  model_30 (Functional)          (None, 1)            17010881    ['concatenate_7[0][0]']
#
# ==================================================================================================
# Total params: 17,023,105
# Trainable params: 17,022,881
# Non-trainable params: 224
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# 15/15 [==============================] - 7s 330ms/step - loss: 16.5079 - accuracy: 0.5285 - val_loss: 1.6568 - val_accuracy: 0.4375
# Epoch 2/100
# 15/15 [==============================] - 4s 271ms/step - loss: 2.7431 - accuracy: 0.4846 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 3/100
# 15/15 [==============================] - 4s 267ms/step - loss: 1.1016 - accuracy: 0.5307 - val_loss: 0.6932 - val_accuracy: 0.4375
# Epoch 4/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.8561 - accuracy: 0.5022 - val_loss: 0.6938 - val_accuracy: 0.4375
# Epoch 5/100
# 15/15 [==============================] - 4s 267ms/step - loss: 1.0464 - accuracy: 0.4693 - val_loss: 0.6932 - val_accuracy: 0.4375
# Epoch 6/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.9117 - accuracy: 0.5088 - val_loss: 0.6933 - val_accuracy: 0.4375
# Epoch 7/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.7742 - accuracy: 0.5110 - val_loss: 0.6999 - val_accuracy: 0.4375
# Epoch 8/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.9313 - accuracy: 0.5088 - val_loss: 0.6933 - val_accuracy: 0.4375
# Epoch 9/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.8690 - accuracy: 0.5022 - val_loss: 0.7018 - val_accuracy: 0.4375
# Epoch 10/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.7080 - accuracy: 0.4846 - val_loss: 0.6954 - val_accuracy: 0.4375
# Epoch 11/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.7437 - accuracy: 0.4890 - val_loss: 0.6934 - val_accuracy: 0.4375
# Epoch 12/100
# 15/15 [==============================] - 4s 266ms/step - loss: 0.7769 - accuracy: 0.5219 - val_loss: 0.6935 - val_accuracy: 0.4375
# Epoch 13/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.7591 - accuracy: 0.5154 - val_loss: 0.6936 - val_accuracy: 0.4375
# Epoch 14/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.7473 - accuracy: 0.5263 - val_loss: 0.6940 - val_accuracy: 0.4375
# Epoch 15/100
# 15/15 [==============================] - 4s 269ms/step - loss: 0.6886 - accuracy: 0.5066 - val_loss: 0.6940 - val_accuracy: 0.4375
# Epoch 16/100
# 15/15 [==============================] - 4s 271ms/step - loss: 0.7476 - accuracy: 0.5022 - val_loss: 0.6939 - val_accuracy: 0.4375
# Epoch 17/100
# 15/15 [==============================] - 4s 270ms/step - loss: 0.7302 - accuracy: 0.5066 - val_loss: 0.6939 - val_accuracy: 0.4375
# Epoch 18/100
# 15/15 [==============================] - 4s 269ms/step - loss: 0.6978 - accuracy: 0.5154 - val_loss: 0.6941 - val_accuracy: 0.4375
# Epoch 19/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.7118 - accuracy: 0.5132 - val_loss: 0.6942 - val_accuracy: 0.4375
# Epoch 20/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.7081 - accuracy: 0.5197 - val_loss: 0.6943 - val_accuracy: 0.4375
# Epoch 21/100
# 15/15 [==============================] - 4s 270ms/step - loss: 0.7020 - accuracy: 0.5110 - val_loss: 0.6944 - val_accuracy: 0.4375
# Epoch 22/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.7831 - accuracy: 0.5088 - val_loss: 0.6945 - val_accuracy: 0.4375
# Epoch 23/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.6950 - accuracy: 0.5307 - val_loss: 0.6947 - val_accuracy: 0.4375
# Epoch 24/100
# 15/15 [==============================] - 4s 269ms/step - loss: 0.7618 - accuracy: 0.5307 - val_loss: 0.6947 - val_accuracy: 0.4375
# Epoch 25/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.6952 - accuracy: 0.5417 - val_loss: 0.6950 - val_accuracy: 0.4375
# Epoch 26/100
# 15/15 [==============================] - 4s 269ms/step - loss: 0.6996 - accuracy: 0.5439 - val_loss: 0.6953 - val_accuracy: 0.4375
# Epoch 27/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.7276 - accuracy: 0.5768 - val_loss: 0.6962 - val_accuracy: 0.4375
# Epoch 28/100
# 15/15 [==============================] - 4s 269ms/step - loss: 0.7249 - accuracy: 0.5855 - val_loss: 0.6956 - val_accuracy: 0.5625
# Epoch 29/100
# 15/15 [==============================] - 4s 269ms/step - loss: 0.6767 - accuracy: 0.6382 - val_loss: 0.6976 - val_accuracy: 0.4375
# Epoch 30/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.6894 - accuracy: 0.6491 - val_loss: 0.7066 - val_accuracy: 0.5625
# Epoch 31/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.6410 - accuracy: 0.6535 - val_loss: 0.6984 - val_accuracy: 0.4375
# Epoch 32/100
# 15/15 [==============================] - 4s 269ms/step - loss: 0.6225 - accuracy: 0.6711 - val_loss: 0.7017 - val_accuracy: 0.3750
# Epoch 33/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.5933 - accuracy: 0.7083 - val_loss: 0.6973 - val_accuracy: 0.4375
# Epoch 34/100
# 15/15 [==============================] - 4s 267ms/step - loss: 0.5440 - accuracy: 0.7434 - val_loss: 0.6935 - val_accuracy: 0.5000
# Epoch 35/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.4888 - accuracy: 0.7719 - val_loss: 0.6972 - val_accuracy: 0.5000
# Epoch 36/100
# 15/15 [==============================] - 4s 268ms/step - loss: 0.4664 - accuracy: 0.7675 - val_loss: 0.7066 - val_accuracy: 0.4375
# Epoch 37/100
# 15/15 [==============================] - 4s 272ms/step - loss: 0.4032 - accuracy: 0.8158 - val_loss: 0.7045 - val_accuracy: 0.5000
# 1/1 [==============================] - 1s 645ms/step - loss: 0.6861 - accuracy: 0.5909
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efe57db3b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Mean test accuracy is 0.54, mean test f1 score is 0.44, max test accuracy is 0.54, max test f1 score is 0.44, min test accuracy is 0.54, min test f1 score is 0.44, std of test accuracy is 0.00, std of test f1 score is 0.00
# Time elapsed through all process: 1043.46, sec

# %%
print(f'Mean test accuracy is {"{:.2f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.2f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.2f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.2f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.2f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.2f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.2f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.2f}".format(np.std(f1_score_per_run, axis=0))}')
print(f'Time elapsed through all process: {"{:.2f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.54, mean test f1 score is 0.44, max test accuracy is 0.54, max test f1 score is 0.44, min test accuracy is 0.54, min test f1 score is 0.44, std of test accuracy is 0.00, std of test f1 score is 0.00
# Time elapsed through all process: 1043.46, sec

# %%
print(y_test_predicted)
# Out:
# [[0.44536555]
#  [0.4577653 ]
#  [0.46605754]
#  [0.47095448]
#  [0.4970678 ]
#  [0.48563138]
#  [0.49044713]
#  [0.4932826 ]
#  [0.4489855 ]
#  [0.4195289 ]
#  [0.45070305]
#  [0.4541195 ]
#  [0.4768964 ]
#  [0.4493063 ]
#  [0.4636053 ]
#  [0.45973113]
#  [0.40939012]
#  [0.43089116]
#  [0.4590946 ]
#  [0.4588199 ]
#  [0.49398267]
#  [0.46205243]
#  [0.44504672]]
