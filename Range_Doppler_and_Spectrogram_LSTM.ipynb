# %% [markdown]
# <a href="https://colab.research.google.com/github/mertege/FMCW-Data-Classification-/blob/main/Range_Doppler_and_Spectrogram_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Burada sadece range-doppler 2D image datası ve spectrogram datası LSTM ile train edildi.
# 2D image'ın column'ları lstm'e sokuldu ve çıktıları dense layer ile classification moduna getirildi.
# 5 defa run edildi ve değerler aşağıda paylaşıldı.
# Mean test accuracy is 0.961, mean test f1 score is 0.954, max test accuracy is 0.982, max test f1 score is 0.979, 
# Min test accuracy is 0.947, min test f1 score is 0.938, std of test accuracy is 0.012, std of test f1 score is 0.015
# Time elapsed through all process: 9018.423, sec

# %%
from keras.models import Sequential
from tensorflow.keras import layers
from keras.models import Model
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, Normalization, Input, Conv2D, MaxPooling2D, Concatenate, GRU, LSTM, GRU, TimeDistributed, Bidirectional
import tensorflow as tf
import scipy.io
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from numpy.random import seed
from sklearn.model_selection import KFold, StratifiedKFold
import time
from sklearn.metrics import precision_recall_fscore_support
from keras.callbacks import EarlyStopping
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras import backend as K 
import gc
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Get Range-Doppler data from
range_doppler_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_resized.mat')
range_doppler_fast_resized = range_doppler_fast_resized['range_doppler_fast_resized']
range_doppler_fast_resized = np.transpose(range_doppler_fast_resized, (2, 0, 1))
# range_doppler_fast_resized = np.delete(range_doppler_fast_resized,(49), axis=0) # 50th row is deleted since there is no 50th row in spectrogram fast data.
range_doppler_fast_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_fast_label.mat')
range_doppler_fast_label = range_doppler_fast_label['range_doppler_fast_label']  

range_doppler_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_resized.mat')
range_doppler_slow_resized = range_doppler_slow_resized['range_doppler_slow_resized']
range_doppler_slow_resized = np.transpose(range_doppler_slow_resized, (2, 0, 1))
range_doppler_slow_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_label.mat')
range_doppler_slow_label = range_doppler_slow_label['range_doppler_slow_label']  

range_doppler_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_slow_pocket_resized.mat')
range_doppler_slow_pocket_resized = range_doppler_slow_pocket_resized['range_doppler_slow_pocket_resized']
range_doppler_slow_pocket_resized = np.transpose(range_doppler_slow_pocket_resized, (2, 0, 1))
range_doppler_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/range_doppler_pocket_label.mat')
range_doppler_pocket_label = range_doppler_pocket_label['range_doppler_pocket_label']  
# Get Range-Doppler data from
spectrogram_fast_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_resized.mat')
spectrogram_fast_resized = spectrogram_fast_resized['spectrogram_fast_resized']
spectrogram_fast_resized = np.transpose(spectrogram_fast_resized, (2, 0, 1))
spectrogram_fast_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_fast_label.mat')
spectrogram_fast_label = spectrogram_fast_label['spectrogram_fast_label']  

spectrogram_slow_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_resized.mat')
spectrogram_slow_resized = spectrogram_slow_resized['spectrogram_slow_resized']
spectrogram_slow_resized = np.transpose(spectrogram_slow_resized, (2, 0, 1))
spectrogram_slow_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_label.mat')
spectrogram_slow_label = spectrogram_slow_label['spectrogram_slow_label']  

spectrogram_slow_pocket_resized = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_resized.mat')
spectrogram_slow_pocket_resized = spectrogram_slow_pocket_resized['spectrogram_slow_pocket_resized']
spectrogram_slow_pocket_resized = np.transpose(spectrogram_slow_pocket_resized, (2, 0, 1))
spectrogram_slow_pocket_label = scipy.io.loadmat('/content/drive/MyDrive/spectrogram_slow_pocket_label.mat')
spectrogram_slow_pocket_label = spectrogram_slow_pocket_label['spectrogram_slow_pocket_label']

# %%
# Concat range-doppler data
range_doppler_concat = np.concatenate((range_doppler_fast_resized,range_doppler_slow_resized),axis=0)
range_doppler_concat = np.concatenate((range_doppler_concat,range_doppler_slow_pocket_resized),axis=0)
range_doppler_concat = range_doppler_concat[:,:,:,np.newaxis] 
range_doppler_concat_label = np.zeros((range_doppler_concat.shape[0],1))
range_doppler_concat_label[:range_doppler_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
shuffle_indx = random.sample(range(0, range_doppler_concat.shape[0]), range_doppler_concat.shape[0]) # split validation data
range_doppler_concat_shuffle = range_doppler_concat[shuffle_indx,:,:,:]
range_doppler_concat_label_shuffle = range_doppler_concat_label[shuffle_indx,:]
# Concat range-doppler data
spectrogram_concat = np.concatenate((spectrogram_fast_resized,spectrogram_slow_resized),axis=0)
spectrogram_concat = np.concatenate((spectrogram_concat,spectrogram_slow_pocket_resized),axis=0)
spectrogram_concat = spectrogram_concat[:,:,:,np.newaxis] 
spectrogram_concat_label = np.zeros((spectrogram_concat.shape[0],1))
spectrogram_concat_label[:spectrogram_fast_resized.shape[0],:] = 1
# Shuffle concat range doppler
# shuffle_indx = random.sample(range(0, spectrogram_concat.shape[0]), spectrogram_concat.shape[0]) # split validation data
spectrogram_concat_shuffle = spectrogram_concat[shuffle_indx,:,:,:]
spectrogram_concat_label_shuffle = spectrogram_concat_label[shuffle_indx,:]

# %%
# ---------------- Augmente and shuffle (train and test) data data ----------------
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.1),
])


def mixup_augmentation(images,range_doppler_training_data, labels, repeat_of_mixup, alpha=0.2):
    batch_size = images.shape[0]
    concat_images = np.zeros((batch_size*(repeat_of_mixup+1),images.shape[1],images.shape[2],images.shape[3]))
    concat_images_range_doppler = np.zeros((batch_size*(repeat_of_mixup+1),range_doppler_training_data.shape[1],\
                                            range_doppler_training_data.shape[2],range_doppler_training_data.shape[3]))
    concat_label = np.zeros((batch_size*(repeat_of_mixup+1),labels.shape[1]))
    for ii in range(repeat_of_mixup):
      # shuffle train dataset
      shuffle_indx_1 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_1 = images[shuffle_indx_1,:,:,:]
      range_doppler_training_data_shuffled_1 = range_doppler_training_data[shuffle_indx_1,:,:,:]
      labels_shuffled_1 = labels[shuffle_indx_1,:]

      shuffle_indx_2 = random.sample(range(0, images.shape[0]), images.shape[0]) # split validation data
      images_shuffled_2 = images[shuffle_indx_2,:,:,:]
      range_doppler_training_data_shuffled_2 = range_doppler_training_data[shuffle_indx_2,:,:,:]
      labels_shuffled_2 = labels[shuffle_indx_2,:]

      # Sample lambda and reshape it to do the mixup
      gaussian_mean = 0.2
      gaussian_std = 0.02
      ll = np.random.normal(gaussian_mean, gaussian_std, (batch_size,1,1,1))
      x_l = np.reshape(ll, (batch_size,1,1,1))
      y_l = np.reshape(ll, (batch_size,1))
      
      # Perform mixup on both images and labels by combining a pair of images/labels
      images_mixup = images_shuffled_1 * x_l + images_shuffled_2 * (1 - x_l)
      images_mixup_range_doppler = range_doppler_training_data_shuffled_1 * x_l + range_doppler_training_data_shuffled_2 * (1 - x_l)
      labels_mixup = labels_shuffled_1 * y_l + labels_shuffled_2 * (1 - y_l)
      concat_images[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup
      concat_images_range_doppler[ii*batch_size:(ii+1)*batch_size,:,:,:] = images_mixup_range_doppler
      concat_label[ii*batch_size:(ii+1)*batch_size,:] = labels_mixup

    concat_images[repeat_of_mixup*batch_size:,:,:,:] = images
    concat_images_range_doppler[repeat_of_mixup*batch_size:,:,:,:] = range_doppler_training_data
    concat_label[repeat_of_mixup*batch_size:,:] = labels
    return (concat_images,concat_images_range_doppler, concat_label)
def split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,range_doppler_concat_label_shuffle_train,\
                                       repeat_of_mixup, augmentation_enable):
  # ---------------- Parameters ----------------
  repeat_of_augmentation_for_fast = 1
  repeat_of_augmentation_for_slow = np.floor(repeat_of_augmentation_for_fast/2)
  repeat_of_augmentation_for_slow = int(repeat_of_augmentation_for_slow)
  # size_of_validation = 30
  alpha = 0.2
  dummy_label = np.zeros((spectrogram_concat_shuffle_train.shape[0],1))
  for randomlist_for_train_indx, randomlist_for_validation_indx in kfold.split(spectrogram_concat_shuffle_train,dummy_label):   
    randomlist_for_validation_indx
  # Split validation
  # randomlist_for_validation_indx = random.sample(range(0, range_doppler_concat_shuffle_train.shape[0]), size_of_validation) # split validation data
  # randomlist_for_train_indx = np.delete(range(0, range_doppler_concat_shuffle_train.shape[0]), randomlist_for_validation_indx) # split training data
  # get validation data
  spectrogram_validation_data = spectrogram_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  spectrogram_validation_labels = range_doppler_concat_label_shuffle_train[randomlist_for_validation_indx,:]
  range_doppler_validation_data = range_doppler_concat_shuffle_train[randomlist_for_validation_indx,:,:,:]
  # get training data
  spectrogram_training_data = spectrogram_concat_shuffle_train[randomlist_for_train_indx,:,:,:]
  spectrogram_training_labels = spectrogram_concat_label_shuffle_train[randomlist_for_train_indx,:]
  range_doppler_training_data = range_doppler_concat_shuffle_train[randomlist_for_train_indx,:,:,:]

  # Rotate Augmentation
  # get slow and fast indexes of training data
  slow_indexes = np.where(spectrogram_training_labels == 0)[0]
  fast_indexes = np.delete(range(0, spectrogram_training_labels.shape[0]), slow_indexes)  

  slow_spectrograms_train = spectrogram_training_data[slow_indexes,:,:,:]
  size_of_samples_slow = slow_spectrograms_train.shape[0]

  fast_spectrograms_train = spectrogram_training_data[fast_indexes,:,:,:]  
  size_of_samples_fast = fast_spectrograms_train.shape[0]

  slow_range_train = range_doppler_training_data[slow_indexes,:,:,:]
  fast_range_train = range_doppler_training_data[fast_indexes,:,:,:]  

  if augmentation_enable == True: 
    # ---------------- Augmente Train Data for Fast ----------------
    augmented_image_fast = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_spectrograms_train.shape[1],fast_spectrograms_train.shape[2],1))
    spectrograms_fast_label = np.ones((size_of_samples_fast*(repeat_of_augmentation_for_fast+1),1))
    # augmented_image_fast = np.flip(fast_spectrograms_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast[size_of_samples_fast*jj+ii,:,:,:] = data_augmentation(fast_spectrograms_train[ii,:,:,:])
    augmented_image_fast = np.concatenate((augmented_image_fast,fast_spectrograms_train),axis=0)   

    augmented_image_fast_range = np.zeros((size_of_samples_fast*repeat_of_augmentation_for_fast,fast_range_train.shape[1],fast_range_train.shape[2],1))
    # augmented_image_fast_range  = np.flip(fast_range_train,axis=2)
    for jj in range(repeat_of_augmentation_for_fast):
      for ii in range(size_of_samples_fast):
        augmented_image_fast_range[size_of_samples_fast*jj+ii,:,:,:]  =data_augmentation(fast_range_train[ii,:,:,:])
    augmented_image_fast_range = np.concatenate((augmented_image_fast_range,fast_range_train),axis=0)   

    # ---------------- Augmente Train Data for Slow ----------------
    augmented_image_slow = slow_spectrograms_train
    augmented_image_slow_range = slow_range_train

  else:
    augmented_image_fast = fast_spectrograms_train
    augmented_image_slow = slow_spectrograms_train
    augmented_image_fast_range = fast_range_train
    augmented_image_slow_range = slow_range_train
    spectrograms_fast_label = np.ones((size_of_samples_fast,1))
    
  spectrograms_slow_label = np.zeros((size_of_samples_slow,1))

  spectrogram_training_data = np.concatenate((augmented_image_fast,augmented_image_slow),axis=0)
  range_doppler_training_data = np.concatenate((augmented_image_fast_range,augmented_image_slow_range),axis=0)
  spectrogram_training_labels = np.concatenate((spectrograms_fast_label,spectrograms_slow_label),axis=0)

  (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label)=\
   mixup_augmentation(spectrogram_training_data,range_doppler_training_data, spectrogram_training_labels, repeat_of_mixup, alpha=0.2)

  return (spectrogram_augmented_image,range_doppler_augmented_image,spectrograms_label,\
     spectrogram_validation_data,range_doppler_validation_data, spectrogram_validation_labels)
def normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable):
  # ---------------- Normalize Inputs ----------------
  if normalize_inputs_enable == True:
    layer = Normalization(axis=None)
    layer.adapt(range_doppler_concat_shuffle)
    range_doppler_concat_shuffle = layer(range_doppler_concat_shuffle)
  else:
    range_doppler_concat_shuffle = range_doppler_concat_shuffle
  return(range_doppler_concat_shuffle)

# %%
normalize_inputs_enable = 1
range_doppler_concat_shuffle = normalize_inputs(range_doppler_concat_shuffle, normalize_inputs_enable)
spectrogram_concat_shuffle = normalize_inputs(spectrogram_concat_shuffle, normalize_inputs_enable)
range_doppler_concat_shuffle = np.float32(range_doppler_concat_shuffle)
spectrogram_concat_shuffle = np.float32(spectrogram_concat_shuffle)

# %%
n_features = range_doppler_concat_shuffle.shape[1]
n_steps = range_doppler_concat_shuffle.shape[2]
range_doppler_concat_shuffle = np.transpose(range_doppler_concat_shuffle, axes = (0,2,1,3)) 
spectrogram_concat_shuffle = np.transpose(spectrogram_concat_shuffle, axes = (0,2,1,3))

# %%
t = time.time()
# ---------- Parameters ----------------
augmentation_enable = True
normalize_inputs_enable = True
num_folds = 5
kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state = None) # random_state = 1 ile split run'dan run'a sabit.
test_accuracy_per_run = []
f1_score_per_run = []
epoch_number = 100
batch_size = 32
dense_size = 64
dropout_prob_dense = 0.5
repeat_of_mixup = 5
number_of_repeat = 5
unit_number_of_lstm = 16
dense_unit_of_range_doppler_function = 256
dense_unit_of_spectrogram_function = 16
decoder_dense_unit = 256
for repeat_run_number in range(number_of_repeat):
  test_accuracy_per_fold = []
  f1_score_per_fold = []
  if repeat_run_number > 0:
    del range_doppler_concat_shuffle_test
    del spectrogram_concat_shuffle_test
    del range_doppler_augmented_image
    del range_doppler_concat_shuffle_train
    del spectrogram_concat_shuffle_train
    del spectrogram_augmented_image
   
  for randomlist_for_train_indx, randomlist_for_test_indx in kfold.split(range_doppler_concat_shuffle,range_doppler_concat_label_shuffle):   
    gc.collect()
    K.clear_session()
    
    # test data
    range_doppler_concat_shuffle_test = range_doppler_concat_shuffle[randomlist_for_test_indx,:,:,:]
    spectrogram_concat_shuffle_test = spectrogram_concat_shuffle[randomlist_for_test_indx,:,:,:]
    range_doppler_concat_label_shuffle_test = range_doppler_concat_label_shuffle[randomlist_for_test_indx,:]
    #train data
    range_doppler_concat_shuffle_train = range_doppler_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_shuffle_train = spectrogram_concat_shuffle[randomlist_for_train_indx,:,:,:]
    spectrogram_concat_label_shuffle_train = spectrogram_concat_label_shuffle[randomlist_for_train_indx,:]
      # ---------------- MixUp Augmentation ----------------
    (spectrogram_augmented_image,range_doppler_augmented_image,spectrogram_concat_label_shuffle_concat,\
     validation_spectrogram,validation_range_doppler, spectrogram_validation_labels)  =\
      split_and_augmentation_of_training(spectrogram_concat_shuffle_train,range_doppler_concat_shuffle_train,\
                                         spectrogram_concat_label_shuffle_train,\
                                         repeat_of_mixup, augmentation_enable)
    
    # ---------------- Neural Network Architecture ----------------



    def lstm_encoder_network_1(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_range_doppler_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def lstm_encoder_network_2(input_shape):
        input = Input(shape=input_shape)
        x = Bidirectional(LSTM(unit_number_of_lstm, return_sequences=True, dropout = 0.5))(input)
        x = Flatten()(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(dense_unit_of_spectrogram_function)(x)
        x = BatchNormalization()(x)
        x = Activation('LeakyReLU')(x)
        x = Dropout(dropout_prob_dense)(x)
        return Model(input, x)

    def decoder_for_concat(input_shape):
      input = Input(shape=input_shape)
      x = Dense(decoder_dense_unit)(input)
      x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(0.3)(x)
      x = Dense(dense_size)(x)
      # x = BatchNormalization()(x)
      x = Activation('LeakyReLU')(x)
      x = Dropout(dropout_prob_dense)(x)
      x = Dense(1, activation="sigmoid")(x)
      return Model(input, x)

    input_shape = range_doppler_concat_shuffle.shape[1:3]
    base_network_lstm = lstm_encoder_network_1(input_shape)
    range_doppler_input  = Input(shape=input_shape)
    processed_range_doppler  = base_network_lstm(range_doppler_input)

    input_shape = spectrogram_concat_shuffle_train.shape[1:3]
    base_network_lstm_2 = lstm_encoder_network_2(input_shape)
    spectrogram_input  = Input(shape=input_shape)
    processed_spectrogram  = base_network_lstm_2(spectrogram_input)

    concat_layer = Concatenate()([processed_range_doppler, processed_spectrogram])

    base_decoder_network = decoder_for_concat((concat_layer.shape[1]))
    out = base_decoder_network(concat_layer)

    model = Model(inputs=[range_doppler_input, spectrogram_input], outputs=[out]) 
    if repeat_run_number == 0:
      print(base_network_lstm.summary())
      print(base_network_lstm_2.summary())
      print(base_decoder_network.summary())
    # ---------------- Compile and Fit ----------------
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    earlyStopping = EarlyStopping(monitor='val_loss', patience=15, verbose=0,restore_best_weights=True, mode='min')
    history = model.fit((range_doppler_augmented_image, spectrogram_augmented_image),(spectrogram_concat_label_shuffle_concat),
                    epochs=epoch_number,
                    batch_size=batch_size,
                    shuffle = True,
                    callbacks=[earlyStopping],
                    validation_data = ((validation_range_doppler, validation_spectrogram) , (spectrogram_validation_labels)))
    test_loss, test_accuracy  = model.evaluate([range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test],\
                                               [range_doppler_concat_label_shuffle_test],
                  batch_size=batch_size)
    gc.collect()
    # ---------------- Get Test Results ----------------
    y_test_predicted = model.predict((range_doppler_concat_shuffle_test, spectrogram_concat_shuffle_test), batch_size=batch_size)
    # ----- Binarize y_test_predicted values -----
    y_test_predicted_binary = np.zeros(y_test_predicted.size)
    for ii in range(y_test_predicted.size):
      if y_test_predicted[ii] < 0.5:
        y_test_predicted_binary[ii] = 0
      else:
        y_test_predicted_binary[ii] = 1
    
    test_precision, test_recall, test_f1_score, support = precision_recall_fscore_support(range_doppler_concat_label_shuffle_test, y_test_predicted_binary, average='macro')

    test_accuracy_per_fold.append(test_accuracy)
    f1_score_per_fold.append(test_f1_score)
    del model
  test_accuracy_per_run.append(sum(test_accuracy_per_fold)/num_folds)
  f1_score_per_run.append(sum(f1_score_per_fold)/num_folds)
  print(test_accuracy_per_run)
  print(f1_score_per_run)
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
elapsed = time.time() - t
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 16)                216592
#
#  batch_normalization_3 (Batc  (None, 16)               64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 16)                0
#
#  dropout_3 (Dropout)         (None, 16)                0
#
# =================================================================
# Total params: 279,632
# Trainable params: 252,528
# Non-trainable params: 27,104
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 272)]             0
#
#  dense_2 (Dense)             (None, 256)               69888
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 87,425
# Trainable params: 86,913
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 20s 388ms/step - loss: 0.5325 - accuracy: 0.5103 - val_loss: 0.6396 - val_accuracy: 0.7407
# Epoch 2/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.4424 - accuracy: 0.5517 - val_loss: 0.1738 - val_accuracy: 0.9259
# Epoch 3/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3719 - accuracy: 0.5713 - val_loss: 0.1547 - val_accuracy: 0.9630
# Epoch 4/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3562 - accuracy: 0.5759 - val_loss: 0.1166 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.3533 - accuracy: 0.5816 - val_loss: 0.1119 - val_accuracy: 0.9630
# Epoch 6/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.3259 - accuracy: 0.5839 - val_loss: 0.1006 - val_accuracy: 0.9630
# Epoch 7/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.3115 - accuracy: 0.5908 - val_loss: 0.0974 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2933 - accuracy: 0.5908 - val_loss: 0.0995 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2966 - accuracy: 0.5885 - val_loss: 0.1062 - val_accuracy: 0.9630
# Epoch 10/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2929 - accuracy: 0.5920 - val_loss: 0.1086 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2938 - accuracy: 0.5897 - val_loss: 0.1351 - val_accuracy: 1.0000
# Epoch 12/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2829 - accuracy: 0.5897 - val_loss: 0.0879 - val_accuracy: 1.0000
# Epoch 13/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2771 - accuracy: 0.5931 - val_loss: 0.1120 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2813 - accuracy: 0.5920 - val_loss: 0.1300 - val_accuracy: 0.8889
# Epoch 15/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2825 - accuracy: 0.5920 - val_loss: 0.0791 - val_accuracy: 0.9630
# Epoch 16/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2721 - accuracy: 0.5931 - val_loss: 0.0821 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2857 - accuracy: 0.5874 - val_loss: 0.1406 - val_accuracy: 0.8889
# Epoch 18/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2701 - accuracy: 0.5931 - val_loss: 0.1700 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2723 - accuracy: 0.5931 - val_loss: 0.0918 - val_accuracy: 0.9630
# Epoch 20/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2798 - accuracy: 0.5908 - val_loss: 0.0715 - val_accuracy: 0.9630
# Epoch 21/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2788 - accuracy: 0.5920 - val_loss: 0.0666 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2655 - accuracy: 0.5931 - val_loss: 0.0783 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2668 - accuracy: 0.5931 - val_loss: 0.1147 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2607 - accuracy: 0.5931 - val_loss: 0.0763 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2596 - accuracy: 0.5931 - val_loss: 0.1579 - val_accuracy: 0.9259
# Epoch 26/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2602 - accuracy: 0.5920 - val_loss: 0.1185 - val_accuracy: 0.9630
# Epoch 27/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2569 - accuracy: 0.5931 - val_loss: 0.1464 - val_accuracy: 0.9259
# Epoch 28/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2632 - accuracy: 0.5931 - val_loss: 0.0956 - val_accuracy: 0.9630
# Epoch 29/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2621 - accuracy: 0.5920 - val_loss: 0.1250 - val_accuracy: 0.8889
# Epoch 30/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2633 - accuracy: 0.5931 - val_loss: 0.1179 - val_accuracy: 0.9259
# Epoch 31/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2608 - accuracy: 0.5920 - val_loss: 0.1018 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2536 - accuracy: 0.5931 - val_loss: 0.1175 - val_accuracy: 0.9259
# Epoch 33/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2509 - accuracy: 0.5931 - val_loss: 0.1736 - val_accuracy: 0.8889
# Epoch 34/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2513 - accuracy: 0.5931 - val_loss: 0.1287 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2541 - accuracy: 0.5931 - val_loss: 0.1296 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2476 - accuracy: 0.5931 - val_loss: 0.1148 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 123ms/step - loss: 0.1398 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 16)                216592
#
#  batch_normalization_3 (Batc  (None, 16)               64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 16)                0
#
#  dropout_3 (Dropout)         (None, 16)                0
#
# =================================================================
# Total params: 279,632
# Trainable params: 252,528
# Non-trainable params: 27,104
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 272)]             0
#
#  dense_2 (Dense)             (None, 256)               69888
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 87,425
# Trainable params: 86,913
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 28/28 [==============================] - 17s 385ms/step - loss: 0.5465 - accuracy: 0.4853 - val_loss: 0.7242 - val_accuracy: 0.7778
# Epoch 2/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.4223 - accuracy: 0.5385 - val_loss: 0.4225 - val_accuracy: 0.8519
# Epoch 3/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.3922 - accuracy: 0.5442 - val_loss: 0.2626 - val_accuracy: 0.8889
# Epoch 4/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3700 - accuracy: 0.5556 - val_loss: 0.3327 - val_accuracy: 0.8519
# Epoch 5/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3507 - accuracy: 0.5635 - val_loss: 0.3067 - val_accuracy: 0.8519
# Epoch 6/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.3253 - accuracy: 0.5646 - val_loss: 0.2407 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3211 - accuracy: 0.5669 - val_loss: 0.2559 - val_accuracy: 0.9630
# Epoch 8/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.3106 - accuracy: 0.5680 - val_loss: 0.2509 - val_accuracy: 0.8889
# Epoch 9/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3076 - accuracy: 0.5658 - val_loss: 0.2526 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2983 - accuracy: 0.5646 - val_loss: 0.2337 - val_accuracy: 0.9259
# Epoch 11/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3020 - accuracy: 0.5680 - val_loss: 0.2591 - val_accuracy: 0.9259
# Epoch 12/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2985 - accuracy: 0.5680 - val_loss: 0.2856 - val_accuracy: 0.8889
# Epoch 13/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2964 - accuracy: 0.5692 - val_loss: 0.2880 - val_accuracy: 0.8889
# Epoch 14/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2876 - accuracy: 0.5692 - val_loss: 0.4026 - val_accuracy: 0.8148
# Epoch 15/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2997 - accuracy: 0.5669 - val_loss: 0.3860 - val_accuracy: 0.8519
# Epoch 16/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2872 - accuracy: 0.5680 - val_loss: 0.2724 - val_accuracy: 0.8889
# Epoch 17/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.3000 - accuracy: 0.5680 - val_loss: 0.2617 - val_accuracy: 0.9259
# Epoch 18/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2789 - accuracy: 0.5692 - val_loss: 0.2872 - val_accuracy: 0.8519
# Epoch 19/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2779 - accuracy: 0.5692 - val_loss: 0.2773 - val_accuracy: 0.9259
# Epoch 20/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2919 - accuracy: 0.5692 - val_loss: 0.2605 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2767 - accuracy: 0.5692 - val_loss: 0.2852 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2752 - accuracy: 0.5692 - val_loss: 0.2762 - val_accuracy: 0.8519
# Epoch 23/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2743 - accuracy: 0.5692 - val_loss: 0.2491 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2703 - accuracy: 0.5692 - val_loss: 0.2433 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2732 - accuracy: 0.5692 - val_loss: 0.2899 - val_accuracy: 0.8889
# 2/2 [==============================] - 2s 123ms/step - loss: 0.2020 - accuracy: 0.9118
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 16)                216592
#
#  batch_normalization_3 (Batc  (None, 16)               64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 16)                0
#
#  dropout_3 (Dropout)         (None, 16)                0
#
# =================================================================
# Total params: 279,632
# Trainable params: 252,528
# Non-trainable params: 27,104
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 272)]             0
#
#  dense_2 (Dense)             (None, 256)               69888
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 87,425
# Trainable params: 86,913
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 17s 388ms/step - loss: 0.5048 - accuracy: 0.5106 - val_loss: 0.7281 - val_accuracy: 0.7037
# Epoch 2/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.3891 - accuracy: 0.5552 - val_loss: 0.4363 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.3577 - accuracy: 0.5692 - val_loss: 0.2581 - val_accuracy: 0.9259
# Epoch 4/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.3335 - accuracy: 0.5669 - val_loss: 0.2816 - val_accuracy: 0.8889
# Epoch 5/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.3182 - accuracy: 0.5763 - val_loss: 0.3540 - val_accuracy: 0.8519
# Epoch 6/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.3158 - accuracy: 0.5763 - val_loss: 0.3194 - val_accuracy: 0.8519
# Epoch 7/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.3023 - accuracy: 0.5798 - val_loss: 0.2084 - val_accuracy: 0.9630
# Epoch 8/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2804 - accuracy: 0.5822 - val_loss: 0.2177 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 336ms/step - loss: 0.2894 - accuracy: 0.5810 - val_loss: 0.1925 - val_accuracy: 0.9630
# Epoch 10/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2844 - accuracy: 0.5810 - val_loss: 0.1868 - val_accuracy: 0.9630
# Epoch 11/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2826 - accuracy: 0.5822 - val_loss: 0.1855 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2756 - accuracy: 0.5822 - val_loss: 0.2368 - val_accuracy: 0.8889
# Epoch 13/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2790 - accuracy: 0.5810 - val_loss: 0.2414 - val_accuracy: 0.8889
# Epoch 14/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2754 - accuracy: 0.5822 - val_loss: 0.2347 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2885 - accuracy: 0.5822 - val_loss: 0.1939 - val_accuracy: 0.9259
# Epoch 16/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2801 - accuracy: 0.5810 - val_loss: 0.2281 - val_accuracy: 0.9259
# Epoch 17/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2713 - accuracy: 0.5822 - val_loss: 0.1959 - val_accuracy: 0.9630
# Epoch 18/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2779 - accuracy: 0.5822 - val_loss: 0.1747 - val_accuracy: 0.9630
# Epoch 19/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2640 - accuracy: 0.5822 - val_loss: 0.2413 - val_accuracy: 0.8889
# Epoch 20/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2651 - accuracy: 0.5822 - val_loss: 0.1899 - val_accuracy: 0.9630
# Epoch 21/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2640 - accuracy: 0.5822 - val_loss: 0.2595 - val_accuracy: 0.8889
# Epoch 22/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2594 - accuracy: 0.5822 - val_loss: 0.2186 - val_accuracy: 0.8889
# Epoch 23/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2571 - accuracy: 0.5822 - val_loss: 0.2423 - val_accuracy: 0.8889
# Epoch 24/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2698 - accuracy: 0.5822 - val_loss: 0.2506 - val_accuracy: 0.8889
# Epoch 25/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2536 - accuracy: 0.5822 - val_loss: 0.2427 - val_accuracy: 0.8519
# Epoch 26/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2599 - accuracy: 0.5822 - val_loss: 0.1564 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2613 - accuracy: 0.5822 - val_loss: 0.2701 - val_accuracy: 0.8519
# Epoch 28/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2544 - accuracy: 0.5822 - val_loss: 0.2855 - val_accuracy: 0.8889
# Epoch 29/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2561 - accuracy: 0.5822 - val_loss: 0.1987 - val_accuracy: 0.9259
# Epoch 30/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2548 - accuracy: 0.5822 - val_loss: 0.1655 - val_accuracy: 0.9630
# Epoch 31/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2516 - accuracy: 0.5822 - val_loss: 0.2446 - val_accuracy: 0.8519
# Epoch 32/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2570 - accuracy: 0.5810 - val_loss: 0.2120 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2505 - accuracy: 0.5822 - val_loss: 0.2203 - val_accuracy: 0.9259
# Epoch 34/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2564 - accuracy: 0.5822 - val_loss: 0.1865 - val_accuracy: 0.9630
# Epoch 35/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2547 - accuracy: 0.5822 - val_loss: 0.1653 - val_accuracy: 0.9259
# Epoch 36/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2476 - accuracy: 0.5822 - val_loss: 0.2170 - val_accuracy: 0.8889
# Epoch 37/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2483 - accuracy: 0.5822 - val_loss: 0.1710 - val_accuracy: 0.9259
# Epoch 38/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2537 - accuracy: 0.5822 - val_loss: 0.2231 - val_accuracy: 0.8889
# Epoch 39/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2487 - accuracy: 0.5822 - val_loss: 0.1894 - val_accuracy: 0.9259
# Epoch 40/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2488 - accuracy: 0.5822 - val_loss: 0.1928 - val_accuracy: 0.9259
# Epoch 41/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2496 - accuracy: 0.5822 - val_loss: 0.1945 - val_accuracy: 0.9259
# 2/2 [==============================] - 2s 122ms/step - loss: 0.1060 - accuracy: 1.0000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 16)                216592
#
#  batch_normalization_3 (Batc  (None, 16)               64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 16)                0
#
#  dropout_3 (Dropout)         (None, 16)                0
#
# =================================================================
# Total params: 279,632
# Trainable params: 252,528
# Non-trainable params: 27,104
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 272)]             0
#
#  dense_2 (Dense)             (None, 256)               69888
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 87,425
# Trainable params: 86,913
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 17s 391ms/step - loss: 0.5093 - accuracy: 0.5035 - val_loss: 0.9540 - val_accuracy: 0.5556
# Epoch 2/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.3985 - accuracy: 0.5556 - val_loss: 0.4128 - val_accuracy: 0.8148
# Epoch 3/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.3568 - accuracy: 0.5662 - val_loss: 0.4115 - val_accuracy: 0.8148
# Epoch 4/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.3331 - accuracy: 0.5757 - val_loss: 0.2891 - val_accuracy: 0.8148
# Epoch 5/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.3120 - accuracy: 0.5768 - val_loss: 0.2103 - val_accuracy: 0.9259
# Epoch 6/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.3096 - accuracy: 0.5768 - val_loss: 0.1612 - val_accuracy: 0.9259
# Epoch 7/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3092 - accuracy: 0.5804 - val_loss: 0.2283 - val_accuracy: 0.8889
# Epoch 8/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2886 - accuracy: 0.5804 - val_loss: 0.1750 - val_accuracy: 0.9259
# Epoch 9/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2844 - accuracy: 0.5804 - val_loss: 0.1528 - val_accuracy: 0.9259
# Epoch 10/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.3054 - accuracy: 0.5792 - val_loss: 0.1633 - val_accuracy: 0.9259
# Epoch 11/100
# 27/27 [==============================] - 9s 336ms/step - loss: 0.3052 - accuracy: 0.5792 - val_loss: 0.1125 - val_accuracy: 0.9630
# Epoch 12/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2813 - accuracy: 0.5816 - val_loss: 0.1459 - val_accuracy: 0.9259
# Epoch 13/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2771 - accuracy: 0.5816 - val_loss: 0.1074 - val_accuracy: 0.9630
# Epoch 14/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2715 - accuracy: 0.5816 - val_loss: 0.1452 - val_accuracy: 0.9259
# Epoch 15/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2721 - accuracy: 0.5816 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 16/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2730 - accuracy: 0.5816 - val_loss: 0.1038 - val_accuracy: 0.9630
# Epoch 17/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2742 - accuracy: 0.5816 - val_loss: 0.0970 - val_accuracy: 1.0000
# Epoch 18/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2741 - accuracy: 0.5804 - val_loss: 0.1102 - val_accuracy: 0.9259
# Epoch 19/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2665 - accuracy: 0.5816 - val_loss: 0.1488 - val_accuracy: 0.9259
# Epoch 20/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2659 - accuracy: 0.5804 - val_loss: 0.1098 - val_accuracy: 0.9259
# Epoch 21/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2579 - accuracy: 0.5816 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 22/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2633 - accuracy: 0.5816 - val_loss: 0.0922 - val_accuracy: 1.0000
# Epoch 23/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2660 - accuracy: 0.5804 - val_loss: 0.0923 - val_accuracy: 1.0000
# Epoch 24/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2666 - accuracy: 0.5816 - val_loss: 0.0910 - val_accuracy: 1.0000
# Epoch 25/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2618 - accuracy: 0.5816 - val_loss: 0.1057 - val_accuracy: 0.9259
# Epoch 26/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2643 - accuracy: 0.5804 - val_loss: 0.1052 - val_accuracy: 0.9630
# Epoch 27/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2554 - accuracy: 0.5816 - val_loss: 0.0715 - val_accuracy: 1.0000
# Epoch 28/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2638 - accuracy: 0.5816 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 29/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2628 - accuracy: 0.5816 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 30/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2593 - accuracy: 0.5816 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 31/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2592 - accuracy: 0.5816 - val_loss: 0.1221 - val_accuracy: 0.9259
# Epoch 32/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2570 - accuracy: 0.5816 - val_loss: 0.1217 - val_accuracy: 0.9259
# Epoch 33/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2516 - accuracy: 0.5816 - val_loss: 0.1072 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2510 - accuracy: 0.5816 - val_loss: 0.1117 - val_accuracy: 0.9259
# Epoch 35/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2635 - accuracy: 0.5816 - val_loss: 0.1264 - val_accuracy: 0.9259
# Epoch 36/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2585 - accuracy: 0.5816 - val_loss: 0.0890 - val_accuracy: 0.9630
# Epoch 37/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2488 - accuracy: 0.5816 - val_loss: 0.1045 - val_accuracy: 0.9259
# Epoch 38/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2556 - accuracy: 0.5816 - val_loss: 0.1258 - val_accuracy: 0.9259
# Epoch 39/100
# 27/27 [==============================] - 9s 331ms/step - loss: 0.2519 - accuracy: 0.5816 - val_loss: 0.1348 - val_accuracy: 0.9259
# Epoch 40/100
# 27/27 [==============================] - 9s 332ms/step - loss: 0.2563 - accuracy: 0.5816 - val_loss: 0.1332 - val_accuracy: 0.9630
# Epoch 41/100
# 27/27 [==============================] - 9s 330ms/step - loss: 0.2549 - accuracy: 0.5816 - val_loss: 0.1362 - val_accuracy: 0.9259
# Epoch 42/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2555 - accuracy: 0.5816 - val_loss: 0.1077 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 127ms/step - loss: 0.1282 - accuracy: 0.9706
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5120, 52)]        0
#
#  bidirectional (Bidirectiona  (None, 5120, 32)         8832
#  l)
#
#  flatten (Flatten)           (None, 163840)            0
#
#  batch_normalization (BatchN  (None, 163840)           655360
#  ormalization)
#
#  dropout (Dropout)           (None, 163840)            0
#
#  dense (Dense)               (None, 256)               41943296
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
# =================================================================
# Total params: 42,608,512
# Trainable params: 42,280,320
# Non-trainable params: 328,192
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 423, 52)]         0
#
#  bidirectional_1 (Bidirectio  (None, 423, 32)          8832
#  nal)
#
#  flatten_1 (Flatten)         (None, 13536)             0
#
#  batch_normalization_2 (Batc  (None, 13536)            54144
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 13536)             0
#
#  dense_1 (Dense)             (None, 16)                216592
#
#  batch_normalization_3 (Batc  (None, 16)               64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 16)                0
#
#  dropout_3 (Dropout)         (None, 16)                0
#
# =================================================================
# Total params: 279,632
# Trainable params: 252,528
# Non-trainable params: 27,104
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 272)]             0
#
#  dense_2 (Dense)             (None, 256)               69888
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 64)                16448
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 87,425
# Trainable params: 86,913
# Non-trainable params: 512
# _________________________________________________________________
# None
# Epoch 1/100
# 27/27 [==============================] - 16s 406ms/step - loss: 0.5407 - accuracy: 0.4722 - val_loss: 0.4573 - val_accuracy: 0.8519
# Epoch 2/100
# 27/27 [==============================] - 9s 338ms/step - loss: 0.4323 - accuracy: 0.5278 - val_loss: 0.2467 - val_accuracy: 0.8519
# Epoch 3/100
# ...
# Epoch 31/100
# 27/27 [==============================] - 9s 334ms/step - loss: 0.2567 - accuracy: 0.5845 - val_loss: 0.0541 - val_accuracy: 1.0000
# Epoch 32/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2567 - accuracy: 0.5845 - val_loss: 0.0701 - val_accuracy: 1.0000
# Epoch 33/100
# 27/27 [==============================] - 9s 333ms/step - loss: 0.2513 - accuracy: 0.5845 - val_loss: 0.0742 - val_accuracy: 1.0000
# Epoch 34/100
# 27/27 [==============================] - 9s 335ms/step - loss: 0.2518 - accuracy: 0.5845 - val_loss: 0.0247 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 123ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 1/100
# 28/28 [==============================] - 17s 389ms/step - loss: 0.5558 - accuracy: 0.4671 - val_loss: 0.5677 - val_accuracy: 0.7407
# Epoch 2/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.4138 - accuracy: 0.5227 - val_loss: 0.1722 - val_accuracy: 0.9630
# Epoch 3/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.3876 - accuracy: 0.5408 - val_loss: 0.1639 - val_accuracy: 0.9259
# Epoch 4/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.3642 - accuracy: 0.5499 - val_loss: 0.1215 - val_accuracy: 0.9630
# Epoch 5/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.3411 - accuracy: 0.5510 - val_loss: 0.1444 - val_accuracy: 1.0000
# Epoch 6/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3329 - accuracy: 0.5590 - val_loss: 0.2055 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.3206 - accuracy: 0.5578 - val_loss: 0.1019 - val_accuracy: 1.0000
# Epoch 8/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.3162 - accuracy: 0.5567 - val_loss: 0.1101 - val_accuracy: 1.0000
# Epoch 9/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2984 - accuracy: 0.5612 - val_loss: 0.1199 - val_accuracy: 1.0000
# Epoch 10/100
# 28/28 [==============================] - 9s 340ms/step - loss: 0.3026 - accuracy: 0.5590 - val_loss: 0.0963 - val_accuracy: 1.0000
# Epoch 11/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2996 - accuracy: 0.5624 - val_loss: 0.1638 - val_accuracy: 0.9630
# Epoch 12/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2995 - accuracy: 0.5590 - val_loss: 0.2096 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3004 - accuracy: 0.5612 - val_loss: 0.1353 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2929 - accuracy: 0.5612 - val_loss: 0.1041 - val_accuracy: 1.0000
# Epoch 15/100
# 28/28 [==============================] - 9s 337ms/step - loss: 0.2861 - accuracy: 0.5624 - val_loss: 0.1075 - val_accuracy: 1.0000
# Epoch 16/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2928 - accuracy: 0.5612 - val_loss: 0.1024 - val_accuracy: 1.0000
# Epoch 17/100
# 28/28 [==============================] - 9s 336ms/step - loss: 0.2794 - accuracy: 0.5624 - val_loss: 0.0814 - val_accuracy: 1.0000
# Epoch 18/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2802 - accuracy: 0.5624 - val_loss: 0.0709 - val_accuracy: 1.0000
# Epoch 19/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2838 - accuracy: 0.5624 - val_loss: 0.1265 - val_accuracy: 1.0000
# Epoch 20/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2739 - accuracy: 0.5624 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 21/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2791 - accuracy: 0.5624 - val_loss: 0.0836 - val_accuracy: 1.0000
# Epoch 22/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2762 - accuracy: 0.5612 - val_loss: 0.1013 - val_accuracy: 1.0000
# Epoch 23/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2818 - accuracy: 0.5612 - val_loss: 0.0677 - val_accuracy: 1.0000
# Epoch 24/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2758 - accuracy: 0.5624 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 25/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2735 - accuracy: 0.5624 - val_loss: 0.0835 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2714 - accuracy: 0.5624 - val_loss: 0.1015 - val_accuracy: 1.0000
# Epoch 27/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2763 - accuracy: 0.5624 - val_loss: 0.0757 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2807 - accuracy: 0.5624 - val_loss: 0.1075 - val_accuracy: 1.0000
# Epoch 29/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2732 - accuracy: 0.5624 - val_loss: 0.0792 - val_accuracy: 1.0000
# Epoch 30/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2712 - accuracy: 0.5624 - val_loss: 0.0709 - val_accuracy: 1.0000
# Epoch 31/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2756 - accuracy: 0.5624 - val_loss: 0.0856 - val_accuracy: 1.0000
# Epoch 32/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2706 - accuracy: 0.5624 - val_loss: 0.1337 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2663 - accuracy: 0.5624 - val_loss: 0.0633 - val_accuracy: 0.9630
# Epoch 34/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2717 - accuracy: 0.5624 - val_loss: 0.1551 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2690 - accuracy: 0.5624 - val_loss: 0.0763 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2629 - accuracy: 0.5624 - val_loss: 0.1366 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2588 - accuracy: 0.5624 - val_loss: 0.0575 - val_accuracy: 1.0000
# Epoch 38/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2692 - accuracy: 0.5624 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 39/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2637 - accuracy: 0.5624 - val_loss: 0.1161 - val_accuracy: 0.9630
# Epoch 40/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2657 - accuracy: 0.5612 - val_loss: 0.0676 - val_accuracy: 1.0000
# Epoch 41/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2651 - accuracy: 0.5624 - val_loss: 0.1847 - val_accuracy: 0.9630
# Epoch 42/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2648 - accuracy: 0.5624 - val_loss: 0.1376 - val_accuracy: 1.0000
# Epoch 43/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2684 - accuracy: 0.5624 - val_loss: 0.1039 - val_accuracy: 1.0000
# Epoch 44/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2676 - accuracy: 0.5624 - val_loss: 0.0758 - val_accuracy: 0.9630
# Epoch 45/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2592 - accuracy: 0.5624 - val_loss: 0.1378 - val_accuracy: 0.9630
# Epoch 46/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2614 - accuracy: 0.5612 - val_loss: 0.1714 - val_accuracy: 0.9630
# Epoch 47/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2587 - accuracy: 0.5624 - val_loss: 0.1773 - val_accuracy: 0.9630
# Epoch 48/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2624 - accuracy: 0.5612 - val_loss: 0.1552 - val_accuracy: 0.9630
# Epoch 49/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2627 - accuracy: 0.5624 - val_loss: 0.1968 - val_accuracy: 0.9630
# Epoch 50/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2601 - accuracy: 0.5624 - val_loss: 0.0717 - val_accuracy: 1.0000
# Epoch 51/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2578 - accuracy: 0.5624 - val_loss: 0.1378 - val_accuracy: 0.9630
# Epoch 52/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2656 - accuracy: 0.5624 - val_loss: 0.0906 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 123ms/step - loss: 0.0903 - accuracy: 0.9706
# Epoch 1/100
# 28/28 [==============================] - 17s 387ms/step - loss: 0.5312 - accuracy: 0.4852 - val_loss: 0.7372 - val_accuracy: 0.7407
# Epoch 2/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.4163 - accuracy: 0.5320 - val_loss: 0.3336 - val_accuracy: 0.8889
# Epoch 3/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.3716 - accuracy: 0.5491 - val_loss: 0.3170 - val_accuracy: 0.8148
# Epoch 4/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.3578 - accuracy: 0.5514 - val_loss: 0.2445 - val_accuracy: 0.8889
# Epoch 5/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3567 - accuracy: 0.5548 - val_loss: 0.2997 - val_accuracy: 0.8889
# Epoch 6/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.3290 - accuracy: 0.5582 - val_loss: 0.1809 - val_accuracy: 0.9259
# Epoch 7/100
# 28/28 [==============================] - 9s 329ms/step - loss: 0.3318 - accuracy: 0.5594 - val_loss: 0.1927 - val_accuracy: 0.9259
# Epoch 8/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.3140 - accuracy: 0.5616 - val_loss: 0.1595 - val_accuracy: 0.9630
# Epoch 9/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3125 - accuracy: 0.5651 - val_loss: 0.1936 - val_accuracy: 0.9259
# Epoch 10/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3134 - accuracy: 0.5616 - val_loss: 0.2317 - val_accuracy: 0.8889
# Epoch 11/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.3075 - accuracy: 0.5651 - val_loss: 0.1991 - val_accuracy: 0.8889
# Epoch 12/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.3046 - accuracy: 0.5628 - val_loss: 0.2058 - val_accuracy: 0.9259
# Epoch 13/100
# 28/28 [==============================] - 9s 335ms/step - loss: 0.2955 - accuracy: 0.5616 - val_loss: 0.1454 - val_accuracy: 0.9630
# Epoch 14/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2897 - accuracy: 0.5651 - val_loss: 0.2509 - val_accuracy: 0.8519
# Epoch 15/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2929 - accuracy: 0.5651 - val_loss: 0.1783 - val_accuracy: 0.9259
# Epoch 16/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2921 - accuracy: 0.5639 - val_loss: 0.1395 - val_accuracy: 0.9630
# Epoch 17/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2928 - accuracy: 0.5628 - val_loss: 0.1492 - val_accuracy: 0.9630
# Epoch 18/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2880 - accuracy: 0.5662 - val_loss: 0.2546 - val_accuracy: 0.8889
# Epoch 19/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2788 - accuracy: 0.5662 - val_loss: 0.2958 - val_accuracy: 0.8889
# Epoch 20/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2669 - accuracy: 0.5662 - val_loss: 0.2147 - val_accuracy: 0.9259
# Epoch 21/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2786 - accuracy: 0.5651 - val_loss: 0.1544 - val_accuracy: 0.9630
# Epoch 22/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2866 - accuracy: 0.5662 - val_loss: 0.1526 - val_accuracy: 0.9630
# Epoch 23/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2750 - accuracy: 0.5662 - val_loss: 0.2480 - val_accuracy: 0.9259
# Epoch 24/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2727 - accuracy: 0.5662 - val_loss: 0.1543 - val_accuracy: 0.9630
# Epoch 25/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2782 - accuracy: 0.5662 - val_loss: 0.1736 - val_accuracy: 0.9630
# Epoch 26/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2768 - accuracy: 0.5662 - val_loss: 0.1378 - val_accuracy: 0.9259
# Epoch 27/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2708 - accuracy: 0.5662 - val_loss: 0.1430 - val_accuracy: 0.9630
# Epoch 28/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2677 - accuracy: 0.5662 - val_loss: 0.1607 - val_accuracy: 0.9259
# Epoch 29/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2708 - accuracy: 0.5662 - val_loss: 0.1687 - val_accuracy: 0.9630
# Epoch 30/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2718 - accuracy: 0.5662 - val_loss: 0.1680 - val_accuracy: 0.9630
# Epoch 31/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2613 - accuracy: 0.5662 - val_loss: 0.1600 - val_accuracy: 0.9259
# Epoch 32/100
# 28/28 [==============================] - 9s 330ms/step - loss: 0.2729 - accuracy: 0.5662 - val_loss: 0.1542 - val_accuracy: 0.9630
# Epoch 33/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2727 - accuracy: 0.5662 - val_loss: 0.1718 - val_accuracy: 0.9259
# Epoch 34/100
# 28/28 [==============================] - 9s 334ms/step - loss: 0.2697 - accuracy: 0.5662 - val_loss: 0.1251 - val_accuracy: 0.9630
# Epoch 35/100
# 28/28 [==============================] - 9s 333ms/step - loss: 0.2611 - accuracy: 0.5662 - val_loss: 0.1191 - val_accuracy: 0.9630
# Epoch 36/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2641 - accuracy: 0.5662 - val_loss: 0.1332 - val_accuracy: 0.9630
# Epoch 37/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2655 - accuracy: 0.5662 - val_loss: 0.1368 - val_accuracy: 0.9630
# Epoch 38/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2628 - accuracy: 0.5662 - val_loss: 0.1494 - val_accuracy: 0.9630
# Epoch 39/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2590 - accuracy: 0.5662 - val_loss: 0.1543 - val_accuracy: 0.9259
# Epoch 40/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2635 - accuracy: 0.5662 - val_loss: 0.2114 - val_accuracy: 0.9630
# Epoch 41/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2644 - accuracy: 0.5662 - val_loss: 0.1847 - val_accuracy: 0.9630
# Epoch 42/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2583 - accuracy: 0.5662 - val_loss: 0.1464 - val_accuracy: 0.9630
# Epoch 43/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2654 - accuracy: 0.5651 - val_loss: 0.1544 - val_accuracy: 0.9630
# Epoch 44/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2576 - accuracy: 0.5662 - val_loss: 0.1414 - val_accuracy: 0.9259
# Epoch 45/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2590 - accuracy: 0.5662 - val_loss: 0.1374 - val_accuracy: 0.9259
# Epoch 46/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2585 - accuracy: 0.5662 - val_loss: 0.1814 - val_accuracy: 0.9630
# Epoch 47/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2613 - accuracy: 0.5662 - val_loss: 0.1691 - val_accuracy: 0.9630
# Epoch 48/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2592 - accuracy: 0.5662 - val_loss: 0.1791 - val_accuracy: 0.9630
# Epoch 49/100
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2540 - accuracy: 0.5662 - val_loss: 0.2129 - val_accuracy: 0.9630
# Epoch 50/100
# 28/28 [==============================] - 9s 332ms/step - loss: 0.2606 - accuracy: 0.5662 - val_loss: 0.1480 - val_accuracy: 0.9630
# 2/2 [==============================] - 2s 119ms/step - loss: 0.0959 - accuracy: 0.9706
# [0.9588235139846801, 0.9647058606147766, 0.9529411554336548, 0.9470588207244873, 0.9823529243469238]
# [0.9504617980239793, 0.9598824708029149, 0.9431030194005044, 0.9376038876128774, 0.9793313069908816]
# Mean test accuracy is 0.961, mean test f1 score is 0.954, max test accuracy is 0.982, max test f1 score is 0.979, min test accuracy is 0.947, min test f1 score is 0.938, std of test accuracy is 0.012, std of test f1 score is 0.015
# Time elapsed through all process: 9018.423, sec

# %%
print(f'Mean test accuracy is {"{:.3f}".format(sum(test_accuracy_per_run)/number_of_repeat)}, mean test f1 score is {"{:.3f}".format(sum(f1_score_per_run)/number_of_repeat)}, \
max test accuracy is {"{:.3f}".format(max(test_accuracy_per_run))}, max test f1 score is {"{:.3f}".format(max(f1_score_per_run))}, \
min test accuracy is {"{:.3f}".format(min(test_accuracy_per_run))}, min test f1 score is {"{:.3f}".format(min(f1_score_per_run))}, \
std of test accuracy is {"{:.3f}".format(np.std(test_accuracy_per_run, axis=0))}, std of test f1 score is {"{:.3f}".format(np.std(f1_score_per_run, axis=0))}')
print(f'Time elapsed through all process: {"{:.3f}".format(elapsed)}, sec')
# Out:
# Mean test accuracy is 0.961, mean test f1 score is 0.954, max test accuracy is 0.982, max test f1 score is 0.979, min test accuracy is 0.947, min test f1 score is 0.938, std of test accuracy is 0.012, std of test f1 score is 0.015
# Time elapsed through all process: 9018.423, sec
